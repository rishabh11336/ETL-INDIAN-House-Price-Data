# %%
import pandas as pd

# %% [markdown]
# ## Connecting PostgreSQL with notebook
# postgresql://postgres:{password}@localhost:{port}/{database}

# %%
import psycopg2

# %%
from sqlalchemy import create_engine
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# %% [markdown]
# Connecting to table Ahmedabad

# %%
Ahmedabad = pd.read_sql_table("Ahmedabad", con=engine)
Ahmedabad
# Out:
#               possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0      Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 1      Under Construction  13240000   1.32 Cr  No/Rare Powercut      1457.0
# 2           Ready to Move  11199600   1.11 Cr  No/Rare Powercut      1017.0
# 3           Ready to Move   6500000    65 Lac  No/Rare Powercut       775.0
# 4      Under Construction   9675000  96.8 Lac  No/Rare Powercut      1113.0
# ...                   ...       ...       ...               ...         ...
# 15024  Under Construction  14290000   1.42 Cr  No/Rare Powercut      1507.0
# 15025  Under Construction  15590000   1.55 Cr  No/Rare Powercut      2078.4
# 15026  Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 15027  Under Construction  11250000   1.12 Cr  No/Rare Powercut       143.0
# 15028             Apr '24   9740000  97.4 Lac  No/Rare Powercut      1558.4
#
# ...

# %% [markdown]
# Connecting to table Ghaziabad

# %%
Ghaziabad = pd.read_sql_table('Ghaziabd', con=engine)
Ghaziabad
# Out:
#              possStatusD     price    priceD               powerStatusD  \
# 0     Under Construction  11500000   1.15 Cr           No/Rare Powercut
# 1     Under Construction  11050000   1.10 Cr           No/Rare Powercut
# 2     Under Construction  13860000   1.38 Cr           No/Rare Powercut
# 3          Ready to Move   7450000  74.5 Lac           No/Rare Powercut
# 4          Ready to Move   5000000    50 Lac  Less Than 2 Hour Powercut
# ...                  ...       ...       ...                        ...
# 8199       Ready to Move   4500000    45 Lac           No/Rare Powercut
# 8200       Ready to Move  11500000   1.15 Cr  Less Than 2 Hour Powercut
# 8201  Under Construction  11007000   1.10 Cr           No/Rare Powercut
# 8202       Ready to Move   4600000    46 Lac  Less Than 2 Hour Powercut
# 8203  Under Construction   4000000    40 Lac           No/Rare Powercut
#
#       carpetArea  sqFtPrice      furnishedD  balconiesD  bathD  \
# ...

# %% [markdown]
# Connecting to table Noida

# %%
Noida = pd.read_sql_table('Noida', con=engine)
Noida
# Out:
#              possStatusD     price   priceD      powerStatusD  sqFtPrice  \
# 0     Under Construction  59000000  5.90 Cr  No/Rare Powercut    18043.0
# 1     Under Construction  32256000  3.22 Cr  No/Rare Powercut    14000.0
# 2     Under Construction  12000000  1.20 Cr  No/Rare Powercut     8547.0
# 3     Under Construction  30000000     3 Cr  No/Rare Powercut    11742.0
# 4          Ready to Move  14000000  1.40 Cr  No/Rare Powercut    10108.0
# ...                  ...       ...      ...               ...        ...
# 9071       Ready to Move  11550000  1.15 Cr  No/Rare Powercut    11000.0
# 9072             Apr '28  13989600  1.39 Cr  No/Rare Powercut     8700.0
# 9073  Under Construction  12750000  1.27 Cr  No/Rare Powercut    11591.0
# 9074  Under Construction  25000000  2.50 Cr  No/Rare Powercut    13889.0
# 9075  Under Construction  28476000  2.84 Cr  No/Rare Powercut    14000.0
#
#           furnishedD balconiesD  bathD           parkingD       facingD  \
# ...

# %% [markdown]
# Connecting to table Gurugram

# %%
Gurugram = pd.read_sql_table("Gurugram", con=engine)
Gurugram
# Out:
#               possStatusD     price    priceD  carpetArea  sqFtPrice  \
# 0      Under Construction  33500000   3.35 Cr      1769.0    17031.0
# 1      Under Construction  31450000   3.14 Cr      1458.0    17000.0
# 2           Ready to Move  23000000   2.30 Cr       160.0     8434.0
# 3           Ready to Move  23000000   2.30 Cr      1099.0    16655.0
# 4           Ready to Move  18000000   1.80 Cr      1320.0    10909.0
# ...                   ...       ...       ...         ...        ...
# 16524       Ready to Move  26300000   2.63 Cr      1719.2    12238.0
# 16525             Dec '26   9424800  94.2 Lac       952.0     7920.0
# 16526             Feb '31  56200000   5.62 Cr      2428.0    18517.0
# 16527             Aug '29  13900000   1.39 Cr      1160.0     9586.0
# 16528       Ready to Move  51420000   5.14 Cr      2500.0    18490.0
#
#            furnishedD  balconiesD  bathD       facingD   ctName  bedroomD  \
# ...

# %% [markdown]
# Connecting to table Faridabad

# %%
Faridabad = pd.read_sql_table("Faridabad", con=engine)
Faridabad
# Out:
#         possStatusD     price   priceD      powerStatusD  carpetArea  \
# 0     Ready to Move   4000000   40 Lac  No/Rare Powercut       625.0
# 1     Ready to Move  10700000  1.07 Cr  No/Rare Powercut      1660.0
# 2     Ready to Move  10500000  1.05 Cr  No/Rare Powercut      1160.0
# 3     Ready to Move  16000000  1.60 Cr  No/Rare Powercut      1750.0
# 4     Ready to Move   2700000   27 Lac  No/Rare Powercut       675.0
# ...             ...       ...      ...               ...         ...
# 2958  Ready to Move  19500000  1.95 Cr  No/Rare Powercut      1050.0
# 2959  Ready to Move  10700000  1.07 Cr  No/Rare Powercut       225.0
# 2960  Ready to Move   7800000   78 Lac  No/Rare Powercut       882.4
# 2961  Ready to Move   9000000   90 Lac  No/Rare Powercut      1500.0
# 2962  Ready to Move  10800000  1.08 Cr  No/Rare Powercut      1700.0
#
#       sqFtPrice      furnishedD  balconiesD bathD       facingD     ctName  \
# ...

# %% [markdown]
# Connecting to table New Delhi

# %%
New_Delhi = pd.read_sql_table("New Delhi", con=engine)
New_Delhi
# Out:
#          possStatusD      price   priceD      powerStatusD  sqFtPrice  \
# 0      Ready to Move   35000000  3.50 Cr  No/Rare Powercut    19444.0
# 1      Ready to Move   42500000  4.25 Cr  No/Rare Powercut    22703.0
# 2      Ready to Move   62500000  6.25 Cr  No/Rare Powercut    31250.0
# 3      Ready to Move   18000000  1.80 Cr  No/Rare Powercut    13846.0
# 4      Ready to Move    4500000   45 Lac  No/Rare Powercut     5556.0
# ...              ...        ...      ...               ...        ...
# 19072  Ready to Move   22200000  2.22 Cr  No/Rare Powercut    11684.0
# 19073        May '25  220000000    22 Cr  No/Rare Powercut    91173.0
# 19074  Ready to Move   50000000     5 Cr  No/Rare Powercut    29412.0
# 19075  Ready to Move   13200000  1.32 Cr  No/Rare Powercut    13895.0
# 19076  Ready to Move   55000000  5.50 Cr  No/Rare Powercut    25463.0
#
#            furnishedD  balconiesD  bathD           parkingD       facingD  \
# ...

# %% [markdown]
# Connecting to table Mumbai

# %%
Mumbai = pd.read_sql_table("Mumbai", con=engine)
Mumbai
# Out:
#               possStatusD     price   priceD      powerStatusD  carpetArea  \
# 0                 Dec '28  54500000  5.45 Cr  No/Rare Powercut      1340.0
# 1                 Nov '28  23380000  2.33 Cr  No/Rare Powercut       835.0
# 2                 Dec '26  18400000  1.84 Cr  No/Rare Powercut       763.0
# 3      Under Construction  30000000     3 Cr  No/Rare Powercut       772.0
# 4                 Jun '26  14300000  1.43 Cr  No/Rare Powercut       623.0
# ...                   ...       ...      ...               ...         ...
# 14890             Jun '29  53400000  5.34 Cr  No/Rare Powercut       866.0
# 14891       Ready to Move  30900000  3.09 Cr  No/Rare Powercut      1037.0
# 14892             Dec '26  15200000  1.52 Cr  No/Rare Powercut       605.0
# 14893       Ready to Move  29000000  2.90 Cr  No/Rare Powercut       850.0
# 14894             Dec '28  47500000  4.75 Cr  No/Rare Powercut      1100.0
#
# ...

# %% [markdown]
# Connecting to table Bangalore

# %%
Bangalore = pd.read_sql_table("Bangalore", con=engine)
Bangalore
# Out:
#               possStatusD     price    priceD      powerStatusD  sqFtPrice  \
# 0                 Mar '27  10900000   1.09 Cr  No/Rare Powercut     8456.0
# 1      Under Construction   8664229  86.6 Lac  No/Rare Powercut     7399.0
# 2           Ready to Move  18436223   1.84 Cr  No/Rare Powercut     9891.0
# 3                 Dec '28   7000000    70 Lac  No/Rare Powercut     6567.0
# 4                 Sep '25  17289000   1.72 Cr  No/Rare Powercut     8500.0
# ...                   ...       ...       ...               ...        ...
# 28912             Dec '25  39900000   3.99 Cr  No/Rare Powercut    12871.0
# 28913       Ready to Move  12808571   1.28 Cr  No/Rare Powercut     7196.0
# 28914             Jan '29  11238554   1.12 Cr  No/Rare Powercut     9858.0
# 28915             Jun '26  13218724   1.32 Cr  No/Rare Powercut     7767.0
# 28916             Aug '28  21055454   2.10 Cr  No/Rare Powercut    12045.0
#
# ...

# %% [markdown]
# Connecting to table Kolkata

# %%
Kolkata = pd.read_sql_table("Kolkata", con=engine)
Kolkata
# Out:
#          possStatusD     price    priceD      powerStatusD  sqFtPrice  \
# 0            Dec '24   4170000  41.7 Lac  No/Rare Powercut     4317.0
# 1            Dec '27   8720103  87.2 Lac  No/Rare Powercut     6527.0
# 2            Dec '27   5300000    53 Lac  No/Rare Powercut     5146.0
# 3      Ready to Move  19200000   1.92 Cr  No/Rare Powercut    11608.0
# 4      Ready to Move   5062200  50.6 Lac  No/Rare Powercut     3900.0
# ...              ...       ...       ...               ...        ...
# 22935        Oct '28   6043800  60.4 Lac  No/Rare Powercut     4200.0
# 22936        Feb '26   4115000  41.2 Lac  No/Rare Powercut     5465.0
# 22937        Dec '27   8600000    86 Lac  No/Rare Powercut     7985.0
# 22938        Dec '28   5230350  52.3 Lac  No/Rare Powercut     7865.0
# 22939        Dec '24   3280000  32.8 Lac  No/Rare Powercut     4537.0
#
#            furnishedD bathD  bedroomD  coveredArea           parkingD  \
# ...

# %% [markdown]
# Connecting to table Hyderabad

# %%
Hyderabad = pd.read_sql_table("Hyderabad", con=engine)
Hyderabad
# Out:
#               possStatusD     price    priceD      powerStatusD  sqFtPrice  \
# 0                 Jun '26  25306638   2.53 Cr  No/Rare Powercut    11153.0
# 1                 Jun '28   9880000  98.8 Lac  No/Rare Powercut     6500.0
# 2           Ready to Move   7001500    70 Lac  No/Rare Powercut     5500.0
# 3                 May '26   9506000  95.1 Lac  No/Rare Powercut     6300.0
# 4           Ready to Move   8326612  83.3 Lac  No/Rare Powercut     5999.0
# ...                   ...       ...       ...               ...        ...
# 19972             Oct '25  31123600   3.11 Cr  No/Rare Powercut     9950.0
# 19973  Under Construction   4723950  47.2 Lac  No/Rare Powercut     4499.0
# 19974             Mar '26   9316800  93.2 Lac  No/Rare Powercut     7200.0
# 19975             Jun '28   9398120    94 Lac  No/Rare Powercut     4999.0
# 19976             Nov '27  12970120   1.29 Cr  No/Rare Powercut     6899.0
#
# ...

# %% [markdown]
# Connecting to table Pune

# %%
Pune = pd.read_sql_table("Pune", con=engine)
Pune
# Out:
#          possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0            Dec '26   9681975  96.8 Lac  No/Rare Powercut       862.0
# 1            Jun '25  14400000   1.44 Cr  No/Rare Powercut      1113.0
# 2            Oct '26  17675000   1.76 Cr  No/Rare Powercut      1087.0
# 3      Ready to Move   9918888  99.2 Lac  No/Rare Powercut       636.0
# 4      Ready to Move   9500000    95 Lac  No/Rare Powercut       860.0
# ...              ...       ...       ...               ...         ...
# 22653        Sep '25  22422000   2.24 Cr  No/Rare Powercut       951.0
# 22654        Sep '25  21857000   2.18 Cr  No/Rare Powercut      1472.0
# 22655        Dec '24  20502989   2.05 Cr  No/Rare Powercut      1079.0
# 22656        Dec '26  10097000      1 Cr  No/Rare Powercut       903.0
# 22657        Jun '25  15000000   1.50 Cr  No/Rare Powercut      1157.0
#
#        sqFtPrice   furnishedD bathD   parkingD ctName  bedroomD  coveredArea  \
# ...
