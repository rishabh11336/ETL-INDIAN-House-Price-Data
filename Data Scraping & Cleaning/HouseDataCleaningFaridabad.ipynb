# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsFaridabad.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': '2ccp9bYXqINzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': 'PNn17xcTwM1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# ...

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': '2ccp9bYXqINzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': 'PNn17xcTwM1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'b9GyQhbfkedzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': 'LjsQQw1rIuhzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# ...

# %%
df = data.iloc[0,:]

# %%
df
# Out:
# 2      [{'encId': '2ccp9bYXqINzpSvf+uAgZw==', 'possSt...
# 3      [{'encId': 'PNn17xcTwM1zpSvf+uAgZw==', 'possSt...
# 4      [{'encId': 'b9GyQhbfkedzpSvf+uAgZw==', 'possSt...
# 5      [{'encId': 'LjsQQw1rIuhzpSvf+uAgZw==', 'possSt...
# 6      [{'encId': '7DN8C/emtMpzpSvf+uAgZw==', 'possSt...
#                              ...
# 103    [{'encId': 'siS0dLHXKhhzpSvf+uAgZw==', 'possSt...
# 104    [{'encId': 'siS0dLHXKhhzpSvf+uAgZw==', 'possSt...
# 105    [{'encId': 'siS0dLHXKhhzpSvf+uAgZw==', 'possSt...
# 106    [{'encId': 'siS0dLHXKhhzpSvf+uAgZw==', 'possSt...
# 107    [{'encId': 'siS0dLHXKhhzpSvf+uAgZw==', 'possSt...
# Name: resultList, Length: 106, dtype: object

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "Faridabad"

# %%
house_data
# Out:
#                          encId    possStatusD    pmtSource cntvl  \
# 0     2ccp9bYXqINzpSvf+uAgZw==  Ready to Move  Telecalling   100
# 1     uJUsI1SDuN5zpSvf+uAgZw==  Ready to Move          Web   100
# 2     fs+FV7fbz9tzpSvf+uAgZw==  Ready to Move          Web   100
# 3     YMglNHqc5pFzpSvf+uAgZw==  Ready to Move      android   120
# 4     tHFRgzwQqEBzpSvf+uAgZw==  Ready to Move          Web   100
# ...                        ...            ...          ...   ...
# 3175  lx1Qy33asD9zpSvf+uAgZw==  Ready to Move      android   100
# 3176  7QuK2HZEi1RzpSvf+uAgZw==  Ready to Move      android    70
# 3177  xaCwFmdiqVpzpSvf+uAgZw==  Ready to Move          Web    70
# 3178  62/GkNu0CxpzpSvf+uAgZw==  Ready to Move          Web   100
# 3179  XzEfzKfIJw5zpSvf+uAgZw==  Ready to Move      android   120
#
#                                                     url floorNo  noBfCt   st  \
# 0     3-BHK-730-Sq-ft-Multistorey-Apartment-FOR-Sale...      10       0  509
# ...

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# cntvl
# url
# floorNo
# noBfCt
# st
# modstat
# lCtDate
# appSub
# sendbirdId
# lastAccessDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# cScore
# devName
# postDateT
# endDateT
# pl
# nriPref
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# propertyImageNew
# dsla
# seoDesc
# ctaRuleId
# personType
# minPrice
# maxPrice
# propCat
# id
# pmtmtrendPercentage
# flooringTyD
# powerStatusD
# maintenanceD
# sv
# cg
# pp
# maintenanceCharges
# bookingAmtExact
# dImgSrc
# landmark
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# ac
# acD
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# oid
# oname
# sdp
# auto_desc
# prjname
# sqFtPrD
# carpetArea
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# imageDate
# supV
# lmtDName
# pkgid
# achTdS
# tag
# tagWap
# sid
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# showupfront
# agtCerStatus
# caCompNameD
# ...

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId fs+FV7fbz9tzpSvf+uAgZw== YMglNHqc5pFzpSvf+uAgZw==
# possStatusD Ready to Move Ready to Move
# pmtSource Web android
# cntvl 100 120
# url 3-BHK-1450-Sq-ft-Multistorey-Apartment-FOR-Sale-Charmwood-Village-in-Faridabad&id=4d423638373738333935 3-BHK-2000-Sq-ft-Builder-Floor-Apartment-FOR-Sale-Sector-28-in-Faridabad&id=4d423730353630363733
# floorNo 5 4
# noBfCt 0 0
# st 509 509
# modstat 20205 20205
# lCtDate 1710052977000.0 1708062756000.0
# appSub Y Y
# sendbirdId 326adaa0-d714-4c06-9add-f1c1bd98c425amin7143 nan
# lastAccessDate 1708108200000.0 1709663400000.0
# projectSocietyLink mayfair-towers-charmwood-village-faridabad-pdpid-4d4235303130303734 nan
# sipro 69799859 70279201 70725695 69047281 62047545 56875383 71024397 71133695
# comFlag N N
# appExc N N
# cScore 86 69
# devName Eros Group nan
# postDateT 2024-03-12T23:45:28.000Z 2024-03-10T23:45:35.000Z
# endDateT 2024-05-11T23:45:28.000Z 2024-05-09T23:45:35.000Z
# pl Y Y
# nriPref nan nan
# ...

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"lc",
"pSc",
"lcLst",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"appExcRe",
"pbrk",
"pbrkp",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#         possStatusD       price   priceD  \
# 0     Ready to Move   4000000.0   40 Lac
# 1     Ready to Move  10700000.0  1.07 Cr
# 2     Ready to Move  10500000.0  1.05 Cr
# 3     Ready to Move  16000000.0  1.60 Cr
# 4     Ready to Move   2700000.0   27 Lac
# ...             ...         ...      ...
# 3175  Ready to Move  10700000.0  1.07 Cr
# 3176  Ready to Move   7800000.0   78 Lac
# 3177  Ready to Move   9000000.0   90 Lac
# 3178  Ready to Move  10800000.0  1.08 Cr
# 3179  Ready to Move  16000000.0  1.60 Cr
#
#                                        propertyImageNew      powerStatusD  \
# 0     https://img.staticmb.com/mbphoto/property/crop...  No/Rare Powercut
# 1     https://img.staticmb.com/mbphoto/property/crop...               NaN
# 2     https://img.staticmb.com/mbphoto/property/crop...  No/Rare Powercut
# 3     https://img.staticmb.com/mbphoto/property/crop...               NaN
# 4     https://img.staticmb.com/mbphoto/property/crop...  No/Rare Powercut
# ...

# %%
house_data.isna().sum()
# Out:
# possStatusD           24
# price                 16
# priceD                 0
# propertyImageNew    1209
# powerStatusD        1096
# maintenanceD        1087
# sqFtPrD              214
# carpetArea           757
# sqFtPrice            216
# OwnershipTypeD       809
# furnishedD            21
# balconiesD           522
# bathD                 13
# facingD              853
# floorD               237
# ctName                 0
# bedroomD               0
# floors               241
# coveredArea          207
# covAreaUnit          207
# carpAreaUnit         757
# image                565
# luxAmenities        1075
# luxAmenitiesD       1075
# amenities            930
# ctLast              1838
# parkingD            1309
# city                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# price                 16
# priceD                 0
# propertyImageNew    1209
# powerStatusD        1096
# maintenanceD        1087
# sqFtPrD              214
# carpetArea           757
# sqFtPrice            216
# OwnershipTypeD       809
# furnishedD            21
# balconiesD           522
# bathD                 13
# facingD              853
# floorD               237
# ctName                 0
# bedroomD               0
# floors               241
# coveredArea          207
# covAreaUnit          207
# carpAreaUnit         757
# image                565
# luxAmenities        1075
# luxAmenitiesD       1075
# amenities            930
# ctLast              1838
# parkingD            1309
# city                   0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#         possStatusD       price   priceD      powerStatusD carpetArea  \
# 0     Ready to Move   4000000.0   40 Lac  No/Rare Powercut        625
# 1     Ready to Move  10700000.0  1.07 Cr               NaN       1660
# 2     Ready to Move  10500000.0  1.05 Cr  No/Rare Powercut        NaN
# 3     Ready to Move  16000000.0  1.60 Cr               NaN       1750
# 4     Ready to Move   2700000.0   27 Lac  No/Rare Powercut        675
# ...             ...         ...      ...               ...        ...
# 3175  Ready to Move  10700000.0  1.07 Cr  No/Rare Powercut        225
# 3176  Ready to Move   7800000.0   78 Lac               NaN        NaN
# 3177  Ready to Move   9000000.0   90 Lac  No/Rare Powercut       1500
# 3178  Ready to Move  10800000.0  1.08 Cr               NaN       1700
# 3179  Ready to Move  16000000.0  1.60 Cr               NaN       1800
#
#       sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3180 entries, 0 to 3179
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   3180 non-null   object
#  1   price         3164 non-null   float64
#  2   priceD        3180 non-null   object
#  3   powerStatusD  2084 non-null   object
#  4   carpetArea    2423 non-null   object
#  5   sqFtPrice     2964 non-null   float64
#  6   furnishedD    3159 non-null   object
#  7   balconiesD    2658 non-null   object
#  8   bathD         3167 non-null   object
#  9   facingD       2327 non-null   object
#  10  ctName        3180 non-null   object
#  11  bedroomD      3180 non-null   object
#  12  floors        2939 non-null   object
#  13  coveredArea   2973 non-null   object
#  14  carpAreaUnit  2423 non-null   object
#  15  parkingD      1871 non-null   object
# dtypes: float64(2), object(14)
# memory usage: 397.6+ KB

# %%
house_data.drop(["vl"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 house_data.drop(["vl"], axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
house_data
# Out:
#         possStatusD       price   priceD      powerStatusD carpetArea  \
# 0     Ready to Move   4000000.0   40 Lac  No/Rare Powercut        625
# 1     Ready to Move  10700000.0  1.07 Cr               NaN       1660
# 2     Ready to Move  10500000.0  1.05 Cr  No/Rare Powercut        NaN
# 3     Ready to Move  16000000.0  1.60 Cr               NaN       1750
# 4     Ready to Move   2700000.0   27 Lac  No/Rare Powercut        675
# ...             ...         ...      ...               ...        ...
# 3175  Ready to Move  10700000.0  1.07 Cr  No/Rare Powercut        225
# 3176  Ready to Move   7800000.0   78 Lac               NaN        NaN
# 3177  Ready to Move   9000000.0   90 Lac  No/Rare Powercut       1500
# 3178  Ready to Move  10800000.0  1.08 Cr               NaN       1700
# 3179  Ready to Move  16000000.0  1.60 Cr               NaN       1800
#
#       sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# ...

# %%
Index(['possStatusD', 'iTarget', 'price', 'priceD', 'powerStatusD', 'sqFtPrD',
       'sqFtPrice', 'furnishedD', 'bathD', 'ctName', 'bedroomD', 'coveredArea',
       'covAreaUnit', 'image', 'luxAmenities', 'luxAmenitiesD', 'amenities',
       'parkingD', 'ctLast', 'grpBky', 'maintenanceD', 'vl', 'floorD',
       'floors', 'carpetArea', 'OwnershipTypeD', 'balconiesD', 'facingD',
       'carpAreaUnit', 'propertyImageNew', 'attrImg', 'primeBrokerageText',
       'bachelor', 'crisilRv1', 'crisilRv2', 'crisilRv2CtBy', 'crircname1',
       'crircname2', 'ownerResides', 'city'],
      dtype='object')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 Index(['possStatusD', 'iTarget', 'price', 'priceD', 'powerStatusD', 'sqFtPrD',
#       2        'sqFtPrice', 'furnishedD', 'bathD', 'ctName', 'bedroomD', 'coveredArea',
#       3        'covAreaUnit', 'image', 'luxAmenities', 'luxAmenitiesD', 'amenities',
#       4        'parkingD', 'ctLast', 'grpBky', 'maintenanceD', 'vl', 'floorD',
#       5        'floors', 'carpetArea', 'OwnershipTypeD', 'balconiesD', 'facingD',
#       6        'carpAreaUnit', 'propertyImageNew', 'attrImg', 'primeBrokerageText',
#       7        'bachelor', 'crisilRv1', 'crisilRv2', 'crisilRv2CtBy', 'crircname1',
#       8        'crircname2', 'ownerResides', 'city'],
#       9       dtype='object')
#
# NameError: name 'Index' is not defined

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             2076
# Less Than 2 Hour Powercut       7
# 2 To 4 Hours Powercut           1
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#        possStatusD      price  priceD               powerStatusD carpetArea  \
# 224  Ready to Move  7000000.0  70 Lac  Less Than 2 Hour Powercut        747
# 400  Ready to Move  1999999.0  20 Lac  Less Than 2 Hour Powercut        450
# 430  Ready to Move  3500000.0  35 Lac  Less Than 2 Hour Powercut        NaN
# 438  Ready to Move  4800000.0  48 Lac  Less Than 2 Hour Powercut        NaN
# 615  Ready to Move  4000000.0  40 Lac  Less Than 2 Hour Powercut        NaN
# 728  Ready to Move  3800000.0  38 Lac  Less Than 2 Hour Powercut       1050
# 743  Ready to Move  4200000.0  42 Lac  Less Than 2 Hour Powercut        720
#
#      sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# 224     8065.0  Semi-Furnished          1     2         North  Faridabad
# 400     3704.0     Unfurnished        NaN     1          East  Faridabad
# 430     3889.0  Semi-Furnished        NaN     2         North  Faridabad
# ...

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price             16
# priceD             0
# powerStatusD    1096
# carpetArea       757
# sqFtPrice        216
# furnishedD        21
# balconiesD       522
# bathD             13
# facingD          853
# ctName             0
# bedroomD           0
# floors           241
# coveredArea      207
# carpAreaUnit     757
# parkingD        1309
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 3180

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.14383561643835616' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.13929640924655606

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#         possStatusD       price   priceD      powerStatusD carpetArea  \
# 0     Ready to Move   4000000.0   40 Lac  No/Rare Powercut        625
# 1     Ready to Move  10700000.0  1.07 Cr  No/Rare Powercut       1660
# 2     Ready to Move  10500000.0  1.05 Cr  No/Rare Powercut     1160.0
# 3     Ready to Move  16000000.0  1.60 Cr  No/Rare Powercut       1750
# 4     Ready to Move   2700000.0   27 Lac  No/Rare Powercut        675
# ...             ...         ...      ...               ...        ...
# 3174  Ready to Move  19500000.0  1.95 Cr  No/Rare Powercut       1050
# 3175  Ready to Move  10700000.0  1.07 Cr  No/Rare Powercut        225
# 3176  Ready to Move   7800000.0   78 Lac  No/Rare Powercut      882.4
# 3177  Ready to Move   9000000.0   90 Lac  No/Rare Powercut       1500
# 3178  Ready to Move  10800000.0  1.08 Cr  No/Rare Powercut       1700
#
#       sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# ...

# %%
house_data.isna().sum()
# Out:
# possStatusD       0
# price            10
# priceD            0
# powerStatusD      0
# carpetArea        0
# sqFtPrice         0
# furnishedD        0
# balconiesD      428
# bathD            13
# facingD         741
# ctName            0
# bedroomD          0
# floors            0
# coveredArea       0
# carpAreaUnit      0
# parkingD          0
# areaPercent       0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#        possStatusD  price          priceD      powerStatusD carpetArea  \
# 851  Ready to Move    NaN  Call for Price  No/Rare Powercut     1944.0
# 852  Ready to Move    NaN  Call for Price  No/Rare Powercut      606.4
# 853  Ready to Move    NaN  Call for Price  No/Rare Powercut      200.0
# 855  Ready to Move    NaN  Call for Price  No/Rare Powercut      800.0
# 859  Ready to Move    NaN  Call for Price  No/Rare Powercut      216.0
# 861  Ready to Move    NaN  Call for Price  No/Rare Powercut      960.0
# 863  Ready to Move    NaN  Call for Price  No/Rare Powercut       1440
# 864  Ready to Move    NaN  Call for Price  No/Rare Powercut       72.0
# 865  Ready to Move    NaN  Call for Price  No/Rare Powercut      128.8
# 866    Select Date    NaN  Call for Price  No/Rare Powercut      280.0
#
#      sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# 851        0.0     Unfurnished        NaN   NaN           NaN  Faridabad
# ...

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD       0
# price             0
# priceD            0
# powerStatusD      0
# carpetArea        0
# sqFtPrice         0
# furnishedD        0
# balconiesD      428
# bathD            13
# facingD         741
# ctName            0
# bedroomD          0
# floors            0
# coveredArea       0
# carpAreaUnit      0
# parkingD          0
# areaPercent       0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['92', 'Lac']

# %%
house_data[house_data['price']==0]
# Out:
#        possStatusD  price          priceD      powerStatusD carpetArea  \
# 851  Ready to Move      0  Call for Price  No/Rare Powercut     1944.0
# 852  Ready to Move      0  Call for Price  No/Rare Powercut      606.4
# 853  Ready to Move      0  Call for Price  No/Rare Powercut      200.0
# 855  Ready to Move      0  Call for Price  No/Rare Powercut      800.0
# 859  Ready to Move      0  Call for Price  No/Rare Powercut      216.0
# 861  Ready to Move      0  Call for Price  No/Rare Powercut      960.0
# 863  Ready to Move      0  Call for Price  No/Rare Powercut       1440
# 864  Ready to Move      0  Call for Price  No/Rare Powercut       72.0
# 865  Ready to Move      0  Call for Price  No/Rare Powercut      128.8
# 866    Select Date      0  Call for Price  No/Rare Powercut      280.0
#
#      sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# 851        0.0     Unfurnished        NaN   NaN           NaN  Faridabad
# ...

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD       0
# price             0
# priceD            0
# powerStatusD      0
# carpetArea        0
# sqFtPrice         0
# furnishedD        0
# balconiesD      420
# bathD             8
# facingD         732
# ctName            0
# bedroomD          0
# floors            0
# coveredArea       0
# carpAreaUnit      0
# parkingD          0
# areaPercent       0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array(['North - East', 'North', 'East', 'South -West', 'West', nan,
#        'South - East', 'South', 'North - West'], dtype=object)

# %%
house_data
# Out:
#         possStatusD     price   priceD      powerStatusD carpetArea  \
# 0     Ready to Move   4000000   40 Lac  No/Rare Powercut        625
# 1     Ready to Move  10700000  1.07 Cr  No/Rare Powercut       1660
# 2     Ready to Move  10500000  1.05 Cr  No/Rare Powercut     1160.0
# 3     Ready to Move  16000000  1.60 Cr  No/Rare Powercut       1750
# 4     Ready to Move   2700000   27 Lac  No/Rare Powercut        675
# ...             ...       ...      ...               ...        ...
# 3174  Ready to Move  19500000  1.95 Cr  No/Rare Powercut       1050
# 3175  Ready to Move  10700000  1.07 Cr  No/Rare Powercut        225
# 3176  Ready to Move   7800000   78 Lac  No/Rare Powercut      882.4
# 3177  Ready to Move   9000000   90 Lac  No/Rare Powercut       1500
# 3178  Ready to Move  10800000  1.08 Cr  No/Rare Powercut       1700
#
#       sqFtPrice      furnishedD balconiesD bathD       facingD     ctName  \
# 0        5479.0     Unfurnished          2     2  North - East  Faridabad
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2963 entries, 0 to 3178
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   2963 non-null   object
#  1   price         2963 non-null   int32
#  2   priceD        2963 non-null   object
#  3   powerStatusD  2963 non-null   object
#  4   carpetArea    2963 non-null   object
#  5   sqFtPrice     2963 non-null   float64
#  6   furnishedD    2963 non-null   object
#  7   balconiesD    2543 non-null   object
#  8   bathD         2955 non-null   object
#  9   facingD       2231 non-null   object
#  10  ctName        2963 non-null   object
#  11  bedroomD      2963 non-null   object
#  12  floors        2963 non-null   object
#  13  coveredArea   2963 non-null   float64
#  14  carpAreaUnit  2963 non-null   object
#  15  parkingD      2963 non-null   object
#  16  areaPercent   2963 non-null   float64
# dtypes: float64(3), int32(1), object(13)
# ...

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
house_data['balconiesD'] = house_data['balconiesD'].astype(float)
# house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Ready to Move', 'Under Construction'], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Ready to Move', 'Under Construction'], dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 1845.1457147784101

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#              possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0          Ready to Move   4000000    40 Lac  No/Rare Powercut       625.0
# 1          Ready to Move  10700000   1.07 Cr  No/Rare Powercut      1660.0
# 9          Ready to Move   3800000    38 Lac  No/Rare Powercut       645.0
# 10         Ready to Move   3000000    30 Lac  No/Rare Powercut       480.0
# 12         Ready to Move   4500000    45 Lac  No/Rare Powercut      1187.0
# ...                  ...       ...       ...               ...         ...
# 3172  Under Construction   3387000  33.9 Lac  No/Rare Powercut       645.0
# 3173  Under Construction   5200000    52 Lac  No/Rare Powercut      1050.0
# 3176       Ready to Move   7800000    78 Lac  No/Rare Powercut       882.4
# 3177       Ready to Move   9000000    90 Lac  No/Rare Powercut      1500.0
# 3178       Ready to Move  10800000   1.08 Cr  No/Rare Powercut      1700.0
#
# ...

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18412\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, parkingD, areaPercent]
# Index: []

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, parkingD, areaPercent]
# Index: []

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  carpetArea  sqFtPrice  balconiesD  bedroomD    floors  \
# price        1.000000    0.137471   0.401175    0.031286  0.144169 -0.351924
# carpetArea   0.137471    1.000000  -0.034218    0.211385  0.117451  0.123652
# sqFtPrice    0.401175   -0.034218   1.000000   -0.058033 -0.087647 -0.245574
# balconiesD   0.031286    0.211385  -0.058033    1.000000  0.146542  0.244121
# bedroomD     0.144169    0.117451  -0.087647    0.146542  1.000000 -0.057153
# floors      -0.351924    0.123652  -0.245574    0.244121 -0.057153  1.000000
# coveredArea  0.094234    0.918898  -0.055525    0.203133  0.074734  0.209442
# areaPercent -0.026972   -0.026189  -0.055989    0.008817  0.000115  0.168533
#
#              coveredArea  areaPercent
# price           0.094234    -0.026972
# carpetArea      0.918898    -0.026189
# sqFtPrice      -0.055525    -0.055989
# balconiesD      0.203133     0.008817
# bedroomD        0.074734     0.000115
# floors          0.209442     0.168533
# ...

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# ...

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2963 entries, 0 to 3178
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   2963 non-null   object
#  1   price         2963 non-null   int32
#  2   priceD        2963 non-null   object
#  3   powerStatusD  2963 non-null   object
#  4   carpetArea    2963 non-null   float64
#  5   sqFtPrice     2963 non-null   float64
#  6   furnishedD    2963 non-null   object
#  7   balconiesD    2543 non-null   float64
#  8   bathD         2955 non-null   object
#  9   facingD       2231 non-null   object
#  10  ctName        2963 non-null   object
#  11  bedroomD      2963 non-null   float64
#  12  floors        2963 non-null   float64
#  13  coveredArea   2963 non-null   float64
#  14  carpAreaUnit  2963 non-null   object
#  15  parkingD      2963 non-null   object
#  16  areaPercent   2963 non-null   float64
# dtypes: float64(7), int32(1), object(9)
# ...

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ('Ready to Move',
#  10500000,
#  '1.05 Cr',
#  'No/Rare Powercut',
#  1160.0,
#  7241.0,
#  'Semi-Furnished',
#  2.0,
#  '2',
#  'East',
#  'Faridabad',
#  3.0,
#  8.0,
#  1450.0,
#  'Sq-ft',
#  0,
#  0.0)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'carpetArea',
#  'sqFtPrice',
#  'furnishedD',
#  'balconiesD',
#  'bathD',
#  'facingD',
#  'ctName',
#  'bedroomD',
#  'floors',
#  'coveredArea',
#  'carpAreaUnit',
#  'parkingD',
#  'areaPercent']

# %%
# !pip install psycopg2

# %%
city = 'Faridabad'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 963
