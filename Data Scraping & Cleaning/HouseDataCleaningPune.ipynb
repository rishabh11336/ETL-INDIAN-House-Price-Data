# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsPune.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'vU+RAJoOUfVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': '8PatJJDG6D1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': '15j7wNsugBBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': 'TT7Bb5WqF/tzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': '0llS6UZT7GJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': '/9Rklh36Sk5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': 'tTtx51eCiMNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': 'a0HQPJDaIFtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': 'vV+UUkYZ8lFzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'SUw+/hPxI25zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        990  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        991  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        992  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        993  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        994  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        995  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        996  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        997  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        998  \
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        999
# nsrResultList                                                         None
# resultList               [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 998 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'vU+RAJoOUfVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': '8PatJJDG6D1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': '15j7wNsugBBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': 'TT7Bb5WqF/tzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': '0llS6UZT7GJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': '/9Rklh36Sk5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': 'tTtx51eCiMNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': 'a0HQPJDaIFtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': 'vV+UUkYZ8lFzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'SUw+/hPxI25zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       990  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       991  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       992  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       993  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       994  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       995  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       996  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       997  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       998  \
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       999
# resultList              [{'encId': 'r6a67HwN5eRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 998 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "Pune"

# %%
house_data
# Out:
#                           encId    possStatusD pmtSource   possBy  \
# 0      vU+RAJoOUfVzpSvf+uAgZw==        Dec '26   Project  Dec '26
# 1      1SeJ7TE71lBzpSvf+uAgZw==        Jun '25   Project  Jun '25
# 2      HSwIcQgAgTJzpSvf+uAgZw==        Oct '26   Project  Oct '26
# 3      S9maf0guU2FzpSvf+uAgZw==        Mar '28   Project  Mar '28
# 4      tL18eN4qBENzpSvf+uAgZw==  Ready to Move   Project      NaN
# ...                         ...            ...       ...      ...
# 29935  JXNREigSXvVzpSvf+uAgZw==        Sep '25   Project  Sep '25
# 29936  YIgdSMMexdBzpSvf+uAgZw==        Dec '24   Project  Dec '24
# 29937  Kp1BtAAoNhNzpSvf+uAgZw==        Dec '26   Project  Dec '26
# 29938  lx72KbtLBqFzpSvf+uAgZw==        Dec '26   Project  Dec '26
# 29939  sJD+7ag/63hzpSvf+uAgZw==        Jun '25   Project  Jun '25
#
#       availableFrom cntvl                                                url  \
# 0           Dec '26   543  2-BHK-1121-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 1           Jun '25   NaN  2-BHK-1400-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 2           Oct '26   604  3-BHK-1523-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 3           Mar '28   525  3-BHK-1062-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 4               NaN   323  2-BHK-807-Sq-ft-Multistorey-Apartment-FOR-Sale...
# ...             ...   ...                                                ...
# 29935       Sep '25   723  3-BHK-1987-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 29936       Dec '24   385  3-BHK-1490-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 29937       Dec '26   880  3-BHK-1199-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 29938       Dec '26   543  2-BHK-1174-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 29939       Jun '25   NaN  2-BHK-1410-Sq-ft-Multistorey-Apartment-FOR-Sal...
#
#        noBfCt   st modstat  ... sVisMinDt sVisMaxDt  noOfSVis adCn comPantry  \
# 0           0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 1           0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 2           0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 3           0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 4           0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# ...       ...  ...     ...  ...       ...       ...       ...  ...       ...
# 29935       0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 29936       0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 29937       0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 29938       0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
# 29939       0  520   20205  ...       NaN       NaN       NaN  NaN       NaN
#
#       brfdesc appExcRe gateComm propVid  city
# 0         NaN      NaN      NaN     NaN  Pune
# 1         NaN      NaN      NaN     NaN  Pune
# 2         NaN      NaN      NaN     NaN  Pune
# 3         NaN      NaN      NaN     NaN  Pune
# 4         NaN      NaN      NaN     NaN  Pune
# ...       ...      ...      ...     ...   ...
# 29935     NaN      NaN      NaN     NaN  Pune
# 29936     NaN      NaN      NaN     NaN  Pune
# 29937     NaN      NaN      NaN     NaN  Pune
# 29938     NaN      NaN      NaN     NaN  Pune
# 29939     NaN      NaN      NaN     NaN  Pune
#
# [29940 rows x 260 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# possBy
# availableFrom
# cntvl
# url
# noBfCt
# st
# modstat
# appSub
# sendbirdId
# lastAccessDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# cScore
# devName
# prjHl1
# prjLtHl1
# postDateT
# endDateT
# pl
# prjSrc
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# seoDesc
# psmImage
# propCat
# siteVisitProp
# vl
# id
# pmtmtrendPercentage
# powerStatusD
# sv
# cg
# pp
# prjid
# bookingAmtExact
# dImgSrc
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# ac
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# auto_desc
# prjname
# sqFtPrD
# carpetArea
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# supV
# lmtDName
# achTdS
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# isVis
# showupfront
# agtCerStatus
# isRera
# reraId
# caCompNameD
# postedLabelD
# furnishedD
# bathD
# parkingD
# transactionTypeD
# propTypeD
# ctName
# bedroomD
# userType
# transType
# isPreferred
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# psmImgCt
# waterStatus
# isLuxury
# coveredArea
# covAreaUnit
# carpAreaUnit
# modifiedDate
# image
# actualOwner
# isProjProp
# devId
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# rEcd
# endDt
# newUrl
# seoPsmDt
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# isVTReqEligible
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# isLuxuryServiceAvailable
# ctaDetailBean
# lCtDate
# flooringTyD
# adroomD
# dealDesc
# floorCsntrAllowed
# appVer
# deviceType
# companyname
# contName
# opSn
# opSnD
# pckCon
# ctCurr
# ctLast
# operatingSinceYear
# agentContinuityStr
# psmapproved
# psmUspImgWeb
# psmUspImgMob
# floorNo
# lastReplyDate
# taImg
# luxAmenities
# luxAmenitiesD
# nriPref
# availUnit
# propertyImageNew
# pfAgCg
# maintenanceD
# agtCrSt
# maintenanceCharges
# landmark
# acD
# imageDate
# pkgid
# pmtUspWap
# tag
# tagWap
# sid
# pmtUsp
# OwnershipTypeD
# balconiesD
# facingD
# amenFacingD
# floorD
# floors
# brokerConnect
# crisilRv1CtBy
# crisilNoOfEmployees
# crisilStarRating
# crisilOpSinceYear
# smartDiaryApiTag
# imgUrl
# amenities
# ranPropImg
# catAdd1
# investorlisting
# investorguide
# luxAmenMap
# nonluxAmenMap
# appovedAuthC
# isReraAgent
# agentReraState
# agComCt
# lc
# lcLst
# criLogo
# ltOther
# pmtUsp1
# pmtUsp2
# pmtUsp2Wap
# iTarget
# agentDetailUrl
# isprimeListingType
# la
# landAreaUnit
# rdWidth
# nOs
# landAreaUnitD
# pmtTCabin
# dues
# pbrk
# pbrkp
# isCornerPlot
# dimD
# isExcl
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# sVisMinDt
# sVisMaxDt
# noOfSVis
# adCn
# comPantry
# brfdesc
# appExcRe
# gateComm
# propVid
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId HSwIcQgAgTJzpSvf+uAgZw== S9maf0guU2FzpSvf+uAgZw==
# possStatusD Oct '26 Mar '28
# pmtSource Project Project
# possBy Oct '26 Mar '28
# availableFrom Oct '26 Mar '28
# cntvl 604 525
# url 3-BHK-1523-Sq-ft-Multistorey-Apartment-FOR-Sale-Kharadi-in-Pune&id=4d423731333731393639 3-BHK-1062-Sq-ft-Multistorey-Apartment-FOR-Sale-Kharadi-in-Pune&id=4d423731363132373939
# noBfCt 0 0
# st 520 520
# modstat 20205 20205
# appSub Y Y
# sendbirdId nan db0ed88b-eeb9-4740-aedb-50f81edfd333lead9538
# lastAccessDate 1710009000000.0 1693420200000.0
# projectSocietyLink lodha-giardino-kharadi-pune-pdpid-4d4235343139303233 flamante-by-vtp-luxe-phase-1-kharadi-pune-pdpid-4d4235343135383331
# sipro 71312633 71627917 71382823 71612799 71312633 69944845 66579501 71450649
# comFlag Y Y
# appExc N N
# cScore 41 37
# devName Lodha Group VTP Realty
# prjHl1 5-minute drive away from Nagar road Airport & railway station is within 11km
# prjLtHl1 400 mts. from world trade center Holy Angels Convent School: 2.9 km
# postDateT 2024-03-11T17:35:38.000Z 2024-03-10T17:35:30.000Z
# endDateT 2024-05-10T17:35:38.000Z 2024-05-09T17:35:30.000Z
# pl Y Y
# prjSrc 20527 20527
# enc_Id HSwIcQgAgTLmbrdH56NYtg== S9maf0guU2H784ijC3tmtQ==
# cowDays 0 0
# price 17675000.0 12800000.0
# priceD 1.76 Cr 1.28 Cr
# imgCt 11 29
# landmarkDetails ['19201|1.1 Km from International Tech Park Pune Kharadi', '19210|5.8 Km from Ramwadi Metro Station', '19202|1.0 Km from Dhole Patil College of Engineering'] ['19201|1.8 Km from Gera Commerzone', '19210|6.5 Km from Ramwadi Metro Station', '19202|1.4 Km from Dhole Patil College of Engineering']
# seoDesc 3 BHK flat available for sale in Pune in the prime location of Kharadi. The property is in a strategic location within Lodha Giardino. This spacious flat is available for sale at a very reasonable price. Available at a reasonable price of INR 1.76 Cr, this oct '26 flat in Kharadi is an excellent choice. Its date of possession is Oct '26. This property is unfurnished. 3 BHK flat is offered for sale in Kharadi, Pune. This flat is placed in a premium location within Flamante By Vtp Luxe Phase 1. This flat for sale can be purchased by you at an attractive price. Costing just INR 1.28 Cr, this mar '28 apartment in Kharadi is a great buy. This leading project is ready for possession on Mar '28. This semi-furnished apartment for sale is strategically designed.
# psmImage https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/02/13/Project-Photo-1-Lodha-Giardino-Pune-5419023_345_1366_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/07/17/Project-Photo-1-Flamante-By-VTP-Luxe-Phase-1-Pune-5415831_345_1366_310_462.jpg
# propCat 20292 20292
# siteVisitProp 0.0 0.0
# vl Y Y
# id 71371969 71612799
# pmtmtrendPercentage 0 0
# powerStatusD No/Rare Powercut No/Rare Powercut
# sv Y Y
# cg b b
# pp Z Z
# prjid 173525 644475
# bookingAmtExact nan nan
# dImgSrc 11120 11120
# seoLtSc 1 1
# pSc 0 0
# pCct 0 0
# lCct 0 0
# pcTcCt 0 0
# ac 10080.0 10080.0
# caSqFt 1523.0 nan
# ltcoordGeo 18.5527185,73.9454065 18.5527185,73.9454065
# iba X X
# ct 4378 4378
# lt 82346.0 82346.0
# loc 82346.0 82346.0
# bd 11702 11702
# ca 1523 nan
# ty 10002 10002
# dtldesc Presenting Lodha Giardino - an urban oasis set in one of Pune's most sought after residential neighbourhoods - Kharadi. With over 1000 trees of different species, swimming pools, engaging kid's play village, a serene temple & outdoor work from home spaces, Lodha Giardino is a complete ecosystem unto itself. Fitting harmoniously into this natural haven are a variety of themed gardens, shaded walkways and avenues, pavillions for the elderly and world class open air sports & fitness facilities. Creating a world complete in itself, and in perfect harmony with the nature. Flamante by VTP Luxe, in Kharadi is our labour of love for those, whose passion for what they do has taken them to heights of recognition and respect. Those who saw things from their minds, heard from their hearts and danced to their own rhythm.Located in the poshest part of Kharadi, Flamante by VTP Luxe has 6 towers, rising-up to 33 storeys and will once again light up the elite neighbourhood with its luminance.
# plgdtldesc Presenting Lodha Giardino - an urban oasis set in one of Pune's most sought after residential neighbourhoods - Kharadi. With over 1000 trees of different species, swimming pools, engaging kid's play village, a serene temple & outdoor work from home spaces, Lodha Giardino is a complete ecosystem unto itself. Fitting harmoniously into this natural haven are a variety of themed gardens, shaded walkways and avenues, pavillions for the elderly and world class open air sports & fitness facilities. Creating a world complete in itself, and in perfect harmony with the nature. Flamante by VTP Luxe, in Kharadi is our labour of love for those, whose passion for what they do has taken them to heights of recognition and respect. Those who saw things from their minds, heard from their hearts and danced to their own rhythm.Located in the poshest part of Kharadi, Flamante by VTP Luxe has 6 towers, rising-up to 33 storeys and will once again light up the elite neighbourhood with its luminance.
# oid 47544769 29979459
# oname Suraj Singh Bharat  Gholap
# sdp Y Y
# auto_desc 3 BHK, Multistorey Apartment is available for Sale in Kharadi, Pune for 1.7 Crore(s) 3 BHK, Multistorey Apartment is available for Sale in Kharadi, Pune for 1.2 Crore(s)
# prjname Lodha Giardino Flamante By VTP Luxe Phase 1
# sqFtPrD 11605.0 nan
# carpetArea 1087 1062
# pkg 10070 10070
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 18.56261572 18.54765945
# pmtLong 73.96683975 73.97238111
# moisd 50 50
# supV Y Y
# lmtDName Kharadi Kharadi
# achTdS 0 0
# locSeoName Kharadi Kharadi
# propImg 2024/02/13/Project-Photo-4-Lodha-Giardino-Pune-5419023_384_800.jpg 2023/07/17/Project-Photo-14-Flamante-By-VTP-Luxe-Phase-1-Pune-5415831_600_800.jpg
# coverAreaUnitD Sq-ft nan
# ppd 20240311 20240310
# ppdL 1710178538000 1710092130000
# achTm 0 0
# achTmS 0 0
# soc N N
# tmsrt 143104 105413
# ecd 20240221 20240306
# prm y y
# sqFtPrice 11605.0 nan
# psmid 5419023 5415831
# isVis Z Z
# showupfront N N
# agtCerStatus nan nan
# isRera Y Y
# reraId P52100047587 P52100051826
# caCompNameD Squarea Consulting Pvt Ltd Property Junctions and Infrastructure Private Limited
# postedLabelD Posted: Mar 11, '24 Posted: Mar 10, '24
# furnishedD Unfurnished Semi-Furnished
# bathD 3 3
# parkingD 1 Covered 1 Covered
# transactionTypeD New Property New Property
# propTypeD Apartment Apartment
# ctName Pune Pune
# bedroomD 3 3
# userType Agent Agent
# transType Sale Sale
# isPreferred false false
# dImgRf PROJ2318237 PROJ2197863
# localityPhoto 0 0
# defaultAdddressGoogle Pune, Maharashtra Pune, Maharashtra
# propertyTitle 3BHK Multistorey Apartment for New Property in Lodha Giardino at Kharadi 3BHK Multistorey Apartment for New Property in Flamante By VTP Luxe Phase 1 at Kharadi
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbimages/project/Photo_h80_w120/2024/02/13/Project-Photo-4-Lodha-Giardino-Pune-5419023_384_800_80_120.jpg https://img.staticmb.com/mbimages/project/Photo_h80_w120/2023/07/17/Project-Photo-14-Flamante-By-VTP-Luxe-Phase-1-Pune-5415831_600_800_80_120.jpg
# wapImgUrl1 https://img.staticmb.com/mbimages/project/Photo_h100_w150/2024/02/13/Project-Photo-4-Lodha-Giardino-Pune-5419023_384_800_100_150.jpg https://img.staticmb.com/mbimages/project/Photo_h100_w150/2023/07/17/Project-Photo-14-Flamante-By-VTP-Luxe-Phase-1-Pune-5415831_600_800_100_150.jpg
# seoURL propertyDetails-3-BHK-1523-Sqft-Flat-FOR-Sale-Kharadi-in-Pune&id=HSwIcQgAgTJzpSvf+uAgZw==&category=Sale propertyDetails-3-BHK-1062-Sqft-Flat-FOR-Sale-Kharadi-in-Pune&id=S9maf0guU2FzpSvf+uAgZw==&category=Sale
# psmImgCt 11 29
# waterStatus Water Availability 24 Hours Available Water Availability 24 Hours Available
# isLuxury F F
# coveredArea 1523 nan
# covAreaUnit 12800 nan
# carpAreaUnit Sq-ft Sq-ft
# modifiedDate Mar 11, '24 Mar 10, '24
# image https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/02/13/Project-Photo-4-Lodha-Giardino-Pune-5419023_384_800_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/07/17/Project-Photo-14-Flamante-By-VTP-Luxe-Phase-1-Pune-5415831_600_800_310_462.jpg
# actualOwner 47544769 29979459
# isProjProp Y Y
# devId 53594 78743
# pglmtkey 47544769_1 29979459_2
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 63814468.0 63814468.0
# sortCode1b 63814468.0 63814468.0
# sortCode22 0.0 0.0
# sortCode26 45045684.0 45045684.0
# ubicnt 50 50
# rEcd 20240311 20240310
# endDt May 10, '24 May 09, '24
# newUrl project-lodha-giardino-for-sale-in-pune-pppfs project-flamante-by-vtp-luxe-phase-1-for-sale-in-pune-pppfs
# seoPsmDt {"bhkPriceRange":{"3 BHK":{"minPrice":"1.75 Cr","maxPrice":"1.83 Cr"}}} {"bhkPriceRange":{"4 BHK":{"minPrice":"2.12 Cr","maxPrice":"2.20 Cr"},"3 BHK":{"minPrice":"1.28 Cr","maxPrice":"1.78 Cr"},"2 BHK":{"minPrice":"83.0 Lac","maxPrice":"1.55 Cr"}}}
# pmtdesc_hi पुणे के प्रीमियम खराड़ी में स्थित यह रेडी टू मूव-इन 3 BHK फ्लैट बिक्री के लिए उपलब्ध है। यह फ्लैट Lodha Giardino की प्रसिद्ध टाउनशिप में स्थित है। कुल 3 बाथरूम हैं, जिनमें अच्छी क्वालिटी के फिक्स्चर लगाये गए हैं। इस 3 BHK अपार्टमेंट के साथ अपनी गाड़ी को आसानी से पार्क करने के लिए 1कवर्ड पार्किंग की सुविधा उपलब्ध है। यह अपार्टमेंट सेल के लिए काफी पसंदीदा प्रॉपर्टी है। खराड़ी में स्थित यह oct '26 फ्लैट रु. 1.76 Cr की आकर्षक कीमत पर उपलब्ध है। इसके पज़ेशन की तारीख Oct '26 है। फ्लैट अनफर्निश्ड कंडीशन में बेचा जाता है।  खराड़ी, पुणे में स्थित यह शानदार 3 BHK फ्लैट बिक्री के लिए उपलब्ध है। यह फ्लैट Flamante By Vtp Luxe Phase 1 टाउनशिप में स्थित है और इसमें कई प्रीमियम सुविधाएं हैं। यहां रहने वाले लोगों की सुविधा के लिए 3 बाथरूम हैं। बिक्री के लिए उपलब्ध इस 3 BHK फ्लैट की 1कवर्ड कार पार्किंग एक मुख्य विशेषता है। यह अपार्टमेंट सेल के लिए काफी पसंदीदा प्रॉपर्टी है। खराड़ी में स्थित रु. 1.28 Cr के उचित बिक्री मूल्य के लिए उपलब्ध, यह mar '28 अपार्टमेंट एक शानदार मौका है। यह प्रोजेक्ट Mar '28 तक पज़ेशन के लिए तैयार है। यह अपार्टमेंट सेमि-फर्निश्ड है।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# isVTReqEligible True True
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc Sq-ft nan
# ampDesc Presenting Lodha Giardino - an urban oasis set in one of Pune's most sought after residential neighb Flamante by VTP Luxe, in Kharadi is our labour of love for those, whose passion for what they do has
# b2cCardEligibility false false
# maskedMobileNumber +91-91XXXXXXX07 +91-90XXXXXXX34
# isLuxuryServiceAvailable False False
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# lCtDate nan nan
# flooringTyD nan nan
# adroomD nan nan
# dealDesc nan nan
# floorCsntrAllowed nan nan
# appVer 328.0 324.0
# deviceType ios ios
# companyname Squarea Consulting Pvt Ltd Property Junctions and Infrastructure Private Limited
# contName Suraj Singh Bharat Gholap
# opSn 11075 11080
# opSnD 1980 1985
# pckCon 7.1 0.47
# ctCurr 448 2
# ctLast 237 0
# operatingSinceYear 1980 1985
# agentContinuityStr 500+ Buyers Served nan
# psmapproved nan nan
# psmUspImgWeb nan nan
# psmUspImgMob nan nan
# floorNo nan nan
# lastReplyDate nan nan
# taImg nan nan
# luxAmenities nan nan
# luxAmenitiesD nan nan
# nriPref nan nan
# availUnit nan nan
# propertyImageNew nan nan
# pfAgCg nan nan
# maintenanceD nan nan
# agtCrSt nan nan
# maintenanceCharges nan nan
# landmark nan nan
# acD nan nan
# imageDate nan nan
# pkgid nan nan
# pmtUspWap nan nan
# tag nan nan
# tagWap nan nan
# sid nan nan
# pmtUsp nan nan
# OwnershipTypeD nan nan
# balconiesD nan nan
# facingD nan nan
# amenFacingD nan nan
# floorD nan nan
# floors nan nan
# brokerConnect nan nan
# crisilRv1CtBy nan nan
# crisilNoOfEmployees nan nan
# crisilStarRating nan nan
# crisilOpSinceYear nan nan
# smartDiaryApiTag nan nan
# imgUrl nan nan
# amenities nan nan
# ranPropImg nan nan
# catAdd1 nan nan
# investorlisting nan nan
# investorguide nan nan
# luxAmenMap nan nan
# nonluxAmenMap nan nan
# appovedAuthC nan nan
# isReraAgent nan nan
# agentReraState nan nan
# agComCt nan nan
# lc nan nan
# lcLst nan nan
# criLogo nan nan
# ltOther nan nan
# pmtUsp1 nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# iTarget nan nan
# agentDetailUrl nan nan
# isprimeListingType nan nan
# la nan nan
# landAreaUnit nan nan
# rdWidth nan nan
# nOs nan nan
# landAreaUnitD nan nan
# pmtTCabin nan nan
# dues nan nan
# pbrk nan nan
# pbrkp nan nan
# isCornerPlot nan nan
# dimD nan nan
# isExcl nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# noOfSVis nan nan
# adCn nan nan
# comPantry nan nan
# brfdesc nan nan
# appExcRe nan nan
# gateComm nan nan
# propVid nan nan
# city Pune Pune

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"pSc",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"appExcRe",
"pbrk",
"pbrkp",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD       price    priceD   vl      powerStatusD  sqFtPrD  \
# 0            Dec '26   9681975.0  96.8 Lac    Y  No/Rare Powercut   8637.0
# 1            Jun '25  14400000.0   1.44 Cr  NaN  No/Rare Powercut  10286.0
# 2            Oct '26  17675000.0   1.76 Cr    Y  No/Rare Powercut  11605.0
# 3            Mar '28  12800000.0   1.28 Cr    Y  No/Rare Powercut      NaN
# 4      Ready to Move   9918888.0  99.2 Lac    Y  No/Rare Powercut  12291.0
# ...              ...         ...       ...  ...               ...      ...
# 29935        Sep '25  21857000.0   2.18 Cr    Y  No/Rare Powercut  11000.0
# 29936        Dec '24  20502989.0   2.05 Cr    Y  No/Rare Powercut  13760.0
# 29937        Dec '26  13400000.0   1.34 Cr  NaN  No/Rare Powercut      NaN
# 29938        Dec '26  10097000.0      1 Cr    Y  No/Rare Powercut   8601.0
# 29939        Jun '25  15000000.0   1.50 Cr  NaN  No/Rare Powercut  10638.0
#
#       carpetArea  sqFtPrice      furnishedD bathD  ... facingD floorD floors  \
# 0            862     8637.0     Unfurnished     2  ...     NaN    NaN    NaN
# 1           1113    10286.0     Unfurnished     3  ...     NaN    NaN    NaN
# 2           1087    11605.0     Unfurnished     3  ...     NaN    NaN    NaN
# 3           1062        NaN  Semi-Furnished     3  ...     NaN    NaN    NaN
# 4            636    12291.0     Unfurnished     2  ...     NaN    NaN    NaN
# ...          ...        ...             ...   ...  ...     ...    ...    ...
# 29935       1472    11000.0     Unfurnished     3  ...     NaN    NaN    NaN
# 29936       1079    13760.0     Unfurnished     3  ...     NaN    NaN    NaN
# 29937       1199        NaN     Unfurnished     3  ...     NaN    NaN    NaN
# 29938        903     8601.0     Unfurnished     2  ...     NaN    NaN    NaN
# 29939       1157    10638.0     Unfurnished     3  ...     NaN    NaN    NaN
#
#       amenities   lc lcLst iTarget brfdesc propVid  city
# 0           NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 1           NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 2           NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 3           NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 4           NaN  NaN   NaN     NaN     NaN     NaN  Pune
# ...         ...  ...   ...     ...     ...     ...   ...
# 29935       NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 29936       NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 29937       NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 29938       NaN  NaN   NaN     NaN     NaN     NaN  Pune
# 29939       NaN  NaN   NaN     NaN     NaN     NaN  Pune
#
# [29940 rows x 35 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD           165
# price                 160
# priceD                  0
# vl                  14705
# powerStatusD         6170
# sqFtPrD              7215
# carpetArea           5571
# sqFtPrice            7281
# furnishedD            414
# bathD                 140
# parkingD            15618
# ctName                  0
# bedroomD                0
# coveredArea          7155
# covAreaUnit          7153
# carpAreaUnit         5585
# image                2352
# isVTReqEligible      7252
# ctLast              21108
# luxAmenities        25888
# luxAmenitiesD       25889
# propertyImageNew    25096
# maintenanceD        24302
# OwnershipTypeD      26241
# balconiesD          24900
# facingD             26368
# floorD              21457
# floors              22190
# amenities           25333
# lc                  29162
# lcLst               29162
# iTarget             29938
# brfdesc             29939
# propVid             29939
# city                    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD             0
# price                 160
# priceD                  0
# vl                  14705
# powerStatusD         6170
# sqFtPrD              7215
# carpetArea           5571
# sqFtPrice            7281
# furnishedD            414
# bathD                 140
# parkingD            15618
# ctName                  0
# bedroomD                0
# coveredArea          7155
# covAreaUnit          7153
# carpAreaUnit         5585
# image                2352
# isVTReqEligible      7252
# ctLast              21108
# luxAmenities        25888
# luxAmenitiesD       25889
# propertyImageNew    25096
# maintenanceD        24302
# OwnershipTypeD      26241
# balconiesD          24900
# facingD             26368
# floorD              21457
# floors              22190
# amenities           25333
# lc                  29162
# lcLst               29162
# iTarget             29938
# brfdesc             29939
# propVid             29939
# city                    0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD       price    priceD   vl      powerStatusD carpetArea  \
# 0            Dec '26   9681975.0  96.8 Lac    Y  No/Rare Powercut        862
# 1            Jun '25  14400000.0   1.44 Cr  NaN  No/Rare Powercut       1113
# 2            Oct '26  17675000.0   1.76 Cr    Y  No/Rare Powercut       1087
# 3            Mar '28  12800000.0   1.28 Cr    Y  No/Rare Powercut       1062
# 4      Ready to Move   9918888.0  99.2 Lac    Y  No/Rare Powercut        636
# ...              ...         ...       ...  ...               ...        ...
# 29935        Sep '25  21857000.0   2.18 Cr    Y  No/Rare Powercut       1472
# 29936        Dec '24  20502989.0   2.05 Cr    Y  No/Rare Powercut       1079
# 29937        Dec '26  13400000.0   1.34 Cr  NaN  No/Rare Powercut       1199
# 29938        Dec '26  10097000.0      1 Cr    Y  No/Rare Powercut        903
# 29939        Jun '25  15000000.0   1.50 Cr  NaN  No/Rare Powercut       1157
#
#        sqFtPrice      furnishedD bathD   parkingD  ... carpAreaUnit  \
# 0         8637.0     Unfurnished     2  1 Covered  ...        Sq-ft
# 1        10286.0     Unfurnished     3        NaN  ...        Sq-ft
# 2        11605.0     Unfurnished     3  1 Covered  ...        Sq-ft
# 3            NaN  Semi-Furnished     3  1 Covered  ...        Sq-ft
# 4        12291.0     Unfurnished     2  1 Covered  ...        Sq-ft
# ...          ...             ...   ...        ...  ...          ...
# 29935    11000.0     Unfurnished     3        NaN  ...        Sq-ft
# 29936    13760.0     Unfurnished     3        NaN  ...        Sq-ft
# 29937        NaN     Unfurnished     3        NaN  ...        Sq-ft
# 29938     8601.0     Unfurnished     2  1 Covered  ...        Sq-ft
# 29939    10638.0     Unfurnished     3        NaN  ...        Sq-ft
#
#       isVTReqEligible balconiesD facingD floors   lc lcLst iTarget brfdesc  \
# 0                True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 1                True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 2                True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 3                True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 4                True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# ...               ...        ...     ...    ...  ...   ...     ...     ...
# 29935            True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 29936            True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 29937            True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 29938            True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
# 29939            True        NaN     NaN    NaN  NaN   NaN     NaN     NaN
#
#       propVid
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 29935     NaN
# 29936     NaN
# 29937     NaN
# 29938     NaN
# 29939     NaN
#
# [29940 rows x 23 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             23006
# Less Than 2 Hour Powercut      760
# 2 To 4 Hours Powercut            2
# Over 6 Hours Powercut            2
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#               possStatusD      price    priceD   vl  \
# 432         Ready to Move  3300000.0    33 Lac  NaN
# 751         Ready to Move  6200000.0    62 Lac  NaN
# 774    Under Construction  8000000.0    80 Lac  NaN
# 1531        Ready to Move  7250000.0  72.5 Lac  NaN
# 1748        Ready to Move  3500000.0    35 Lac  NaN
# ...                   ...        ...       ...  ...
# 29790             Dec '28  9797000.0    98 Lac    Y
# 29820             Dec '28  9797000.0    98 Lac    Y
# 29850             Dec '28  9797000.0    98 Lac    Y
# 29880             Dec '28  9797000.0    98 Lac    Y
# 29910             Dec '28  9797000.0    98 Lac    Y
#
#                     powerStatusD carpetArea  sqFtPrice      furnishedD bathD  \
# 432    Less Than 2 Hour Powercut        728     3492.0     Unfurnished     2
# 751    Less Than 2 Hour Powercut        745     5905.0  Semi-Furnished     2
# 774    Less Than 2 Hour Powercut        712        NaN     Unfurnished     2
# 1531   Less Than 2 Hour Powercut       1055     6591.0  Semi-Furnished     2
# 1748   Less Than 2 Hour Powercut        700     3846.0     Unfurnished     2
# ...                          ...        ...        ...             ...   ...
# 29790  Less Than 2 Hour Powercut        927        NaN     Unfurnished     2
# 29820  Less Than 2 Hour Powercut        927        NaN     Unfurnished     2
# 29850  Less Than 2 Hour Powercut        927        NaN     Unfurnished     2
# 29880  Less Than 2 Hour Powercut        927        NaN     Unfurnished     2
# 29910  Less Than 2 Hour Powercut        927        NaN     Unfurnished     2
#
#         parkingD  ... carpAreaUnit isVTReqEligible balconiesD      facingD  \
# 432          NaN  ...        Sq-ft             NaN          2         West
# 751          NaN  ...        Sq-ft             NaN          2         West
# 774          NaN  ...        Sq-ft             NaN          1          NaN
# 1531      1 Open  ...        Sq-ft             NaN          1  South -West
# 1748   1 Covered  ...        Sq-ft             NaN          1         West
# ...          ...  ...          ...             ...        ...          ...
# 29790        NaN  ...        Sq-ft            True        NaN          NaN
# 29820        NaN  ...        Sq-ft            True        NaN          NaN
# 29850        NaN  ...        Sq-ft            True        NaN          NaN
# 29880        NaN  ...        Sq-ft            True        NaN          NaN
# 29910        NaN  ...        Sq-ft            True        NaN          NaN
#
#       floors   lc lcLst iTarget brfdesc propVid
# 432       11  NaN   NaN     NaN     NaN     NaN
# 751       11  NaN   NaN     NaN     NaN     NaN
# 774       13  NaN   NaN     NaN     NaN     NaN
# 1531       7  NaN   NaN     NaN     NaN     NaN
# 1748      12  NaN   NaN     NaN     NaN     NaN
# ...      ...  ...   ...     ...     ...     ...
# 29790    NaN  NaN   NaN     NaN     NaN     NaN
# 29820    NaN  NaN   NaN     NaN     NaN     NaN
# 29850    NaN  NaN   NaN     NaN     NaN     NaN
# 29880    NaN  NaN   NaN     NaN     NaN     NaN
# 29910    NaN  NaN   NaN     NaN     NaN     NaN
#
# [760 rows x 23 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# price                160
# priceD                 0
# vl                 14705
# powerStatusD        6170
# carpetArea          5571
# sqFtPrice           7281
# furnishedD           414
# bathD                140
# parkingD           15618
# ctName                 0
# bedroomD               0
# coveredArea         7155
# carpAreaUnit        5585
# isVTReqEligible     7252
# balconiesD         24900
# facingD            26368
# floors             22190
# lc                 29162
# lcLst              29162
# iTarget            29938
# brfdesc            29939
# propVid            29939
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 29940

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.2310437109723461' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.19645619453856175

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#          possStatusD       price    priceD   vl      powerStatusD carpetArea  \
# 0            Dec '26   9681975.0  96.8 Lac    Y  No/Rare Powercut        862
# 1            Jun '25  14400000.0   1.44 Cr  NaN  No/Rare Powercut       1113
# 2            Oct '26  17675000.0   1.76 Cr    Y  No/Rare Powercut       1087
# 4      Ready to Move   9918888.0  99.2 Lac    Y  No/Rare Powercut        636
# 7      Ready to Move   9500000.0    95 Lac  NaN  No/Rare Powercut        860
# ...              ...         ...       ...  ...               ...        ...
# 29934        Sep '25  22422000.0   2.24 Cr    Y  No/Rare Powercut        951
# 29935        Sep '25  21857000.0   2.18 Cr    Y  No/Rare Powercut       1472
# 29936        Dec '24  20502989.0   2.05 Cr    Y  No/Rare Powercut       1079
# 29938        Dec '26  10097000.0      1 Cr    Y  No/Rare Powercut        903
# 29939        Jun '25  15000000.0   1.50 Cr  NaN  No/Rare Powercut       1157
#
#        sqFtPrice   furnishedD bathD   parkingD  ... isVTReqEligible  \
# 0         8637.0  Unfurnished     2  1 Covered  ...            True
# 1        10286.0  Unfurnished     3          0  ...            True
# 2        11605.0  Unfurnished     3  1 Covered  ...            True
# 4        12291.0  Unfurnished     2  1 Covered  ...            True
# 7         9039.0  Unfurnished     2  1 Covered  ...            True
# ...          ...          ...   ...        ...  ...             ...
# 29934    16961.0  Unfurnished     2          0  ...            True
# 29935    11000.0  Unfurnished     3          0  ...            True
# 29936    13760.0  Unfurnished     3          0  ...            True
# 29938     8601.0  Unfurnished     2  1 Covered  ...            True
# 29939    10638.0  Unfurnished     3          0  ...            True
#
#       balconiesD  facingD floors   lc lcLst iTarget brfdesc propVid  \
# 0            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 1            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 2            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 4            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 7              1     East      7  NaN   NaN     NaN     NaN     NaN
# ...          ...      ...    ...  ...   ...     ...     ...     ...
# 29934        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29935        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29936        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29938        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29939        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
#
#       areaPercent
# 0        0.231044
# 1        0.205000
# 2        0.286277
# 4        0.211896
# 7        0.181732
# ...           ...
# 29934    0.280635
# 29935    0.259185
# 29936    0.275839
# 29938    0.230835
# 29939    0.179433
#
# [22785 rows x 24 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# price                127
# priceD                 0
# vl                 10452
# powerStatusD           0
# carpetArea             0
# sqFtPrice              0
# furnishedD             0
# bathD                123
# parkingD               0
# ctName                 0
# bedroomD               0
# coveredArea            0
# carpAreaUnit           0
# isVTReqEligible     6670
# balconiesD         18254
# facingD            19440
# floors                 0
# lc                 22007
# lcLst              22007
# iTarget            22783
# brfdesc            22784
# propVid            22784
# areaPercent            0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#         possStatusD  price          priceD   vl      powerStatusD carpetArea  \
# 8023  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      720.0
# 8024  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      720.0
# 8025  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      607.2
# 8026  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      672.0
# 8027  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      564.0
# ...             ...    ...             ...  ...               ...        ...
# 8177  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut        780
# 8178  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut        780
# 8179  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut     1440.0
# 8180  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      760.0
# 8182  Ready to Move    NaN  Call for Price  NaN  No/Rare Powercut      780.0
#
#       sqFtPrice      furnishedD bathD parkingD  ... isVTReqEligible  \
# 8023        0.0     Unfurnished   NaN        0  ...             NaN
# 8024        0.0     Unfurnished   NaN        0  ...             NaN
# 8025        0.0     Unfurnished   NaN        0  ...             NaN
# 8026        0.0     Unfurnished   NaN        0  ...             NaN
# 8027        0.0     Unfurnished   NaN        0  ...             NaN
# ...         ...             ...   ...      ...  ...             ...
# 8177        0.0  Semi-Furnished     2        0  ...             NaN
# 8178        0.0  Semi-Furnished     2        0  ...             NaN
# 8179        0.0     Unfurnished   NaN        0  ...             NaN
# 8180        0.0       Furnished     2        0  ...             NaN
# 8182        0.0     Unfurnished   NaN        0  ...             NaN
#
#      balconiesD  facingD floors   lc lcLst iTarget brfdesc propVid areaPercent
# 8023        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8024        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8025        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8026        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8027        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# ...         ...      ...    ...  ...   ...     ...     ...     ...         ...
# 8177          1      NaN      9  NaN   NaN     NaN     NaN     NaN    0.204082
# 8178          2      NaN     22  NaN   NaN     NaN     NaN     NaN    0.230769
# 8179        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8180        NaN      NaN      6  NaN   NaN     NaN     NaN     NaN    0.000000
# 8182        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
#
# [127 rows x 24 columns]

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\1780203852.py:2: RuntimeWarning: invalid value encountered in cast
#   house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# price                  0
# priceD                 0
# vl                 10452
# powerStatusD           0
# carpetArea             0
# sqFtPrice              0
# furnishedD             0
# bathD                123
# parkingD               0
# ctName                 0
# bedroomD               0
# coveredArea            0
# carpAreaUnit           0
# isVTReqEligible     6670
# balconiesD         18254
# facingD            19440
# floors                 0
# lc                 22007
# lcLst              22007
# iTarget            22783
# brfdesc            22784
# propVid            22784
# areaPercent            0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['1.56', 'Cr']

# %%
house_data[house_data['price']==0]
# Out:
#         possStatusD  price          priceD   vl      powerStatusD carpetArea  \
# 8023  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      720.0
# 8024  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      720.0
# 8025  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      607.2
# 8026  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      672.0
# 8027  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      564.0
# ...             ...    ...             ...  ...               ...        ...
# 8177  Ready to Move      0  Call for Price  NaN  No/Rare Powercut        780
# 8178  Ready to Move      0  Call for Price  NaN  No/Rare Powercut        780
# 8179  Ready to Move      0  Call for Price  NaN  No/Rare Powercut     1440.0
# 8180  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      760.0
# 8182  Ready to Move      0  Call for Price  NaN  No/Rare Powercut      780.0
#
#       sqFtPrice      furnishedD bathD parkingD  ... isVTReqEligible  \
# 8023        0.0     Unfurnished   NaN        0  ...             NaN
# 8024        0.0     Unfurnished   NaN        0  ...             NaN
# 8025        0.0     Unfurnished   NaN        0  ...             NaN
# 8026        0.0     Unfurnished   NaN        0  ...             NaN
# 8027        0.0     Unfurnished   NaN        0  ...             NaN
# ...         ...             ...   ...      ...  ...             ...
# 8177        0.0  Semi-Furnished     2        0  ...             NaN
# 8178        0.0  Semi-Furnished     2        0  ...             NaN
# 8179        0.0     Unfurnished   NaN        0  ...             NaN
# 8180        0.0       Furnished     2        0  ...             NaN
# 8182        0.0     Unfurnished   NaN        0  ...             NaN
#
#      balconiesD  facingD floors   lc lcLst iTarget brfdesc propVid areaPercent
# 8023        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8024        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8025        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8026        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8027        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# ...         ...      ...    ...  ...   ...     ...     ...     ...         ...
# 8177          1      NaN      9  NaN   NaN     NaN     NaN     NaN    0.204082
# 8178          2      NaN     22  NaN   NaN     NaN     NaN     NaN    0.230769
# 8179        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
# 8180        NaN      NaN      6  NaN   NaN     NaN     NaN     NaN    0.000000
# 8182        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN    0.000000
#
# [127 rows x 24 columns]

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# price                  0
# priceD                 0
# vl                 10325
# powerStatusD           0
# carpetArea             0
# sqFtPrice              0
# furnishedD             0
# bathD                 53
# parkingD               0
# ctName                 0
# bedroomD               0
# coveredArea            0
# carpAreaUnit           0
# isVTReqEligible     6543
# balconiesD         18158
# facingD            19320
# floors                 0
# lc                 21880
# lcLst              21880
# iTarget            22656
# brfdesc            22657
# propVid            22657
# areaPercent            0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array([nan, 'East', 'West', 'North - East', 'North', 'South - East',
#        'South -West', 'North - West', 'South'], dtype=object)

# %%
house_data
# Out:
#          possStatusD     price    priceD   vl      powerStatusD carpetArea  \
# 0            Dec '26   9681975  96.8 Lac    Y  No/Rare Powercut        862
# 1            Jun '25  14400000   1.44 Cr  NaN  No/Rare Powercut       1113
# 2            Oct '26  17675000   1.76 Cr    Y  No/Rare Powercut       1087
# 4      Ready to Move   9918888  99.2 Lac    Y  No/Rare Powercut        636
# 7      Ready to Move   9500000    95 Lac  NaN  No/Rare Powercut        860
# ...              ...       ...       ...  ...               ...        ...
# 29934        Sep '25  22422000   2.24 Cr    Y  No/Rare Powercut        951
# 29935        Sep '25  21857000   2.18 Cr    Y  No/Rare Powercut       1472
# 29936        Dec '24  20502989   2.05 Cr    Y  No/Rare Powercut       1079
# 29938        Dec '26  10097000      1 Cr    Y  No/Rare Powercut        903
# 29939        Jun '25  15000000   1.50 Cr  NaN  No/Rare Powercut       1157
#
#        sqFtPrice   furnishedD bathD   parkingD  ... isVTReqEligible  \
# 0         8637.0  Unfurnished     2  1 Covered  ...            True
# 1        10286.0  Unfurnished     3          0  ...            True
# 2        11605.0  Unfurnished     3  1 Covered  ...            True
# 4        12291.0  Unfurnished     2  1 Covered  ...            True
# 7         9039.0  Unfurnished     2  1 Covered  ...            True
# ...          ...          ...   ...        ...  ...             ...
# 29934    16961.0  Unfurnished     2          0  ...            True
# 29935    11000.0  Unfurnished     3          0  ...            True
# 29936    13760.0  Unfurnished     3          0  ...            True
# 29938     8601.0  Unfurnished     2  1 Covered  ...            True
# 29939    10638.0  Unfurnished     3          0  ...            True
#
#       balconiesD  facingD floors   lc lcLst iTarget brfdesc propVid  \
# 0            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 1            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 2            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 4            NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 7              1     East      7  NaN   NaN     NaN     NaN     NaN
# ...          ...      ...    ...  ...   ...     ...     ...     ...
# 29934        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29935        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29936        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29938        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
# 29939        NaN      NaN      0  NaN   NaN     NaN     NaN     NaN
#
#       areaPercent
# 0        0.231044
# 1        0.205000
# 2        0.286277
# 4        0.211896
# 7        0.181732
# ...           ...
# 29934    0.280635
# 29935    0.259185
# 29936    0.275839
# 29938    0.230835
# 29939    0.179433
#
# [22658 rows x 24 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22658 entries, 0 to 29939
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   possStatusD      22658 non-null  object
#  1   price            22658 non-null  int32
#  2   priceD           22658 non-null  object
#  3   vl               12333 non-null  object
#  4   powerStatusD     22658 non-null  object
#  5   carpetArea       22658 non-null  object
#  6   sqFtPrice        22658 non-null  float64
#  7   furnishedD       22658 non-null  object
#  8   bathD            22605 non-null  object
#  9   parkingD         22658 non-null  object
#  10  ctName           22658 non-null  object
#  11  bedroomD         22658 non-null  object
#  12  coveredArea      22658 non-null  float64
#  13  carpAreaUnit     22658 non-null  object
#  14  isVTReqEligible  16115 non-null  object
#  15  balconiesD       4500 non-null   object
#  16  facingD          3338 non-null   object
#  17  floors           22658 non-null  object
#  18  lc               778 non-null    object
#  19  lcLst            778 non-null    object
#  20  iTarget          2 non-null      object
#  21  brfdesc          1 non-null      object
#  22  propVid          1 non-null      object
#  23  areaPercent      22658 non-null  float64
# dtypes: float64(3), int32(1), object(20)
# memory usage: 4.2+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
house_data['balconiesD'] = house_data['balconiesD'].astype(float)
# house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '26", "Jun '25", "Oct '26", 'Ready to Move', "Dec '25",
#        "Dec '24", "Dec '29", "Mar '28", "Dec '28", "Dec '27",
#        'Under Construction', "Oct '27", "Sep '27", "Dec '30", "Mar '26",
#        "Jun '27", 'Immediately', "May '27", "Nov '26", "Oct '24",
#        "Sep '26", "Sep '25"], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '26", "Jun '25", "Oct '26", 'Ready to Move', "Dec '25",
#        "Dec '24", "Dec '29", "Mar '28", "Dec '28", "Dec '27",
#        'Under Construction', "Oct '27", "Sep '27", "Dec '30", "Mar '26",
#        "Jun '27", "May '27", "Nov '26", "Oct '24", "Sep '26", "Sep '25"],
#       dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 1399.961112191328

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#          possStatusD     price    priceD   vl      powerStatusD  carpetArea  \
# 0            Dec '26   9681975  96.8 Lac    Y  No/Rare Powercut       862.0
# 1            Jun '25  14400000   1.44 Cr  NaN  No/Rare Powercut      1113.0
# 2            Oct '26  17675000   1.76 Cr    Y  No/Rare Powercut      1087.0
# 4      Ready to Move   9918888  99.2 Lac    Y  No/Rare Powercut       636.0
# 7      Ready to Move   9500000    95 Lac  NaN  No/Rare Powercut       860.0
# ...              ...       ...       ...  ...               ...         ...
# 29934        Sep '25  22422000   2.24 Cr    Y  No/Rare Powercut       951.0
# 29935        Sep '25  21857000   2.18 Cr    Y  No/Rare Powercut      1472.0
# 29936        Dec '24  20502989   2.05 Cr    Y  No/Rare Powercut      1079.0
# 29938        Dec '26  10097000      1 Cr    Y  No/Rare Powercut       903.0
# 29939        Jun '25  15000000   1.50 Cr  NaN  No/Rare Powercut      1157.0
#
#        sqFtPrice   furnishedD bathD   parkingD  ... isVTReqEligible  \
# 0         8637.0  Unfurnished     2  1 Covered  ...            True
# 1        10286.0  Unfurnished     3          0  ...            True
# 2        11605.0  Unfurnished     3  1 Covered  ...            True
# 4        12291.0  Unfurnished     2  1 Covered  ...            True
# 7         9039.0  Unfurnished     2  1 Covered  ...            True
# ...          ...          ...   ...        ...  ...             ...
# 29934    16961.0  Unfurnished     2          0  ...            True
# 29935    11000.0  Unfurnished     3          0  ...            True
# 29936    13760.0  Unfurnished     3          0  ...            True
# 29938     8601.0  Unfurnished     2  1 Covered  ...            True
# 29939    10638.0  Unfurnished     3          0  ...            True
#
#        balconiesD  facingD floors   lc  lcLst iTarget  brfdesc propVid  \
# 0             NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 1             NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 2             NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 4             NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 7             1.0     East    7.0  NaN    NaN     NaN      NaN     NaN
# ...           ...      ...    ...  ...    ...     ...      ...     ...
# 29934         NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 29935         NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 29936         NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 29938         NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
# 29939         NaN      NaN    0.0  NaN    NaN     NaN      NaN     NaN
#
#       areaPercent
# 0        0.231044
# 1        0.205000
# 2        0.286277
# 4        0.211896
# 7        0.181732
# ...           ...
# 29934    0.280635
# 29935    0.259185
# 29936    0.275839
# 29938    0.230835
# 29939    0.179433
#
# [18697 rows x 24 columns]

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7936\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, price, priceD, vl, powerStatusD, carpetArea, sqFtPrice, furnishedD, bathD, parkingD, ctName, bedroomD, coveredArea, carpAreaUnit, isVTReqEligible, balconiesD, facingD, floors, lc, lcLst, iTarget, brfdesc, propVid, areaPercent]
# Index: []
#
# [0 rows x 24 columns]

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, vl, powerStatusD, carpetArea, sqFtPrice, furnishedD, bathD, parkingD, ctName, bedroomD, coveredArea, carpAreaUnit, isVTReqEligible, balconiesD, facingD, floors, lc, lcLst, iTarget, brfdesc, propVid, areaPercent]
# Index: []
#
# [0 rows x 24 columns]

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  carpetArea  sqFtPrice  bedroomD  coveredArea  \
# price        1.000000    0.225667  -0.475497  0.151421     0.132921
# carpetArea   0.225667    1.000000   0.009023  0.418716     0.385637
# sqFtPrice   -0.475497    0.009023   1.000000 -0.001314    -0.004331
# bedroomD     0.151421    0.418716  -0.001314  1.000000     0.232203
# coveredArea  0.132921    0.385637  -0.004331  0.232203     1.000000
# balconiesD   0.036054    0.150382   0.009175  0.243014     0.180564
# floors      -0.110962   -0.145152   0.008164 -0.252728    -0.104719
# areaPercent  0.004086   -0.000934  -0.836926  0.009456     0.016025
#
#              balconiesD    floors  areaPercent
# price          0.036054 -0.110962     0.004086
# carpetArea     0.150382 -0.145152    -0.000934
# sqFtPrice      0.009175  0.008164    -0.836926
# bedroomD       0.243014 -0.252728     0.009456
# coveredArea    0.180564 -0.104719     0.016025
# balconiesD     1.000000  0.132435    -0.004574
# floors         0.132435  1.000000    -0.029470
# areaPercent   -0.004574 -0.029470     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, vl, powerStatusD, carpetArea, sqFtPrice, furnishedD, bathD, parkingD, ctName, bedroomD, coveredArea, carpAreaUnit, isVTReqEligible, balconiesD, facingD, floors, lc, lcLst, iTarget, brfdesc, propVid, areaPercent]
# Index: []
#
# [0 rows x 24 columns]

# %%
house_data
# Out:
#          possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0            Dec '26   9681975  96.8 Lac  No/Rare Powercut       862.0
# 1            Jun '25  14400000   1.44 Cr  No/Rare Powercut      1113.0
# 2            Oct '26  17675000   1.76 Cr  No/Rare Powercut      1087.0
# 4      Ready to Move   9918888  99.2 Lac  No/Rare Powercut       636.0
# 7      Ready to Move   9500000    95 Lac  No/Rare Powercut       860.0
# ...              ...       ...       ...               ...         ...
# 29934        Sep '25  22422000   2.24 Cr  No/Rare Powercut       951.0
# 29935        Sep '25  21857000   2.18 Cr  No/Rare Powercut      1472.0
# 29936        Dec '24  20502989   2.05 Cr  No/Rare Powercut      1079.0
# 29938        Dec '26  10097000      1 Cr  No/Rare Powercut       903.0
# 29939        Jun '25  15000000   1.50 Cr  No/Rare Powercut      1157.0
#
#        sqFtPrice   furnishedD bathD   parkingD ctName  bedroomD  coveredArea  \
# 0         8637.0  Unfurnished     2  1 Covered   Pune       2.0       1121.0
# 1        10286.0  Unfurnished     3          0   Pune       2.0       1400.0
# 2        11605.0  Unfurnished     3  1 Covered   Pune       3.0       1523.0
# 4        12291.0  Unfurnished     2  1 Covered   Pune       2.0        807.0
# 7         9039.0  Unfurnished     2  1 Covered   Pune       2.0       1051.0
# ...          ...          ...   ...        ...    ...       ...          ...
# 29934    16961.0  Unfurnished     2          0   Pune       2.0       1322.0
# 29935    11000.0  Unfurnished     3          0   Pune       3.0       1987.0
# 29936    13760.0  Unfurnished     3          0   Pune       3.0       1490.0
# 29938     8601.0  Unfurnished     2  1 Covered   Pune       2.0       1174.0
# 29939    10638.0  Unfurnished     3          0   Pune       2.0       1410.0
#
#       carpAreaUnit  balconiesD facingD  floors  areaPercent
# 0            Sq-ft         NaN     NaN     0.0     0.231044
# 1            Sq-ft         NaN     NaN     0.0     0.205000
# 2            Sq-ft         NaN     NaN     0.0     0.286277
# 4            Sq-ft         NaN     NaN     0.0     0.211896
# 7            Sq-ft         1.0    East     7.0     0.181732
# ...            ...         ...     ...     ...          ...
# 29934        Sq-ft         NaN     NaN     0.0     0.280635
# 29935        Sq-ft         NaN     NaN     0.0     0.259185
# 29936        Sq-ft         NaN     NaN     0.0     0.275839
# 29938        Sq-ft         NaN     NaN     0.0     0.230835
# 29939        Sq-ft         NaN     NaN     0.0     0.179433
#
# [22658 rows x 17 columns]

# %%
house_data.drop(["lc", "lcLst", "iTarget", "brfdesc", "propVid"], axis=1, inplace=True)

# %%
house_data.drop(["isVTReqEligible", "vl"], axis=1, inplace=True)

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ("Oct '26",
#  17675000,
#  '1.76 Cr',
#  'No/Rare Powercut',
#  1087.0,
#  11605.0,
#  'Unfurnished',
#  '3',
#  '1 Covered',
#  'Pune',
#  3.0,
#  1523.0,
#  'Sq-ft',
#  nan,
#  nan,
#  0.0,
#  0.2862770847012475)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'carpetArea',
#  'sqFtPrice',
#  'furnishedD',
#  'bathD',
#  'parkingD',
#  'ctName',
#  'bedroomD',
#  'coveredArea',
#  'carpAreaUnit',
#  'balconiesD',
#  'facingD',
#  'floors',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gigar\anaconda3\lib\site-packages (2.9.9)

# %%
city = 'Pune'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 658
