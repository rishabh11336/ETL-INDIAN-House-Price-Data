# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsAhmedabad.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'PKO2GHKdDoZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': '5hBiFRzU4b9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': 'JYADwm7blaxzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': 'Tlb/aE1WrmZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': 'BeP+fbTm14VzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': 'DF0lr4r5dnNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': 'huWisc/DNGJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': 'Cc0aK/hup0pzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': '/7J+E1llUK1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'edP8tiwq5wVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        522  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        523  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        524  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        525  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        526  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        527  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        528  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        529  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        530  \
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        531
# nsrResultList                                                         None
# resultList               [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 530 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'PKO2GHKdDoZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': '5hBiFRzU4b9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'JYADwm7blaxzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': 'Tlb/aE1WrmZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': 'BeP+fbTm14VzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': 'DF0lr4r5dnNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': 'huWisc/DNGJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': 'Cc0aK/hup0pzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': '/7J+E1llUK1zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'edP8tiwq5wVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       522  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       523  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       524  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       525  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       526  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       527  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       528  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       529  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       530  \
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       531
# resultList              [{'encId': 'pU2IBIJ0rXpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 530 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "New Delhi"

# %%
house_data
# Out:
#                           encId         possStatusD pmtSource availableFrom  \
# 0      PKO2GHKdDoZzpSvf+uAgZw==  Under Construction       Web       Apr '25
# 1      zA6I5poF8X1zpSvf+uAgZw==  Under Construction       Web       Apr '26
# 2      dqz+CnAqTZNzpSvf+uAgZw==       Ready to Move       Web       Mar '24
# 3      CvaAVyAXNo9zpSvf+uAgZw==       Ready to Move       Web           NaN
# 4      G19Hr2x/3m5zpSvf+uAgZw==  Under Construction       Web       Dec '24
# ...                         ...                 ...       ...           ...
# 15895  CZrSaW+GsM5zpSvf+uAgZw==  Under Construction       Web       Dec '24
# 15896  JaDGDwc2hFNzpSvf+uAgZw==  Under Construction       Web       Dec '24
# 15897  fVhANieER9pzpSvf+uAgZw==  Under Construction       Web       Apr '25
# 15898  OAkuMHeQH0tzpSvf+uAgZw==  Under Construction       Web       Apr '25
# 15899  vVAYB5GvNfRzpSvf+uAgZw==             Apr '24   Project       Apr '24
#
#       cntvl                                                url floorNo  \
# 0       100  3-BHK-2565-Sq-ft-Multistorey-Apartment-FOR-Sal...       2
# 1       100  3-BHK-2648-Sq-ft-Multistorey-Apartment-FOR-Sal...       7
# 2       NaN  3-BHK-1836-Sq-ft-Multistorey-Apartment-FOR-Sal...       5
# 3       NaN  2-BHK-1280-Sq-ft-Penthouse-FOR-Sale-South-Bopa...      13
# 4        70  3-BHK-2025-Sq-ft-Multistorey-Apartment-FOR-Sal...       6
# ...     ...                                                ...     ...
# 15895   100  3-BHK-2598-Sq-ft-Multistorey-Apartment-FOR-Sal...       8
# 15896   120  3-BHK-2598-Sq-ft-Multistorey-Apartment-FOR-Sal...       6
# 15897   100  3-BHK-2565-Sq-ft-Multistorey-Apartment-FOR-Sal...       6
# 15898   100  3-BHK-250-Sq-yrd-Multistorey-Apartment-FOR-Sal...       5
# 15899   NaN  3-BHK-1948-Sq-ft-Multistorey-Apartment-FOR-Sal...     NaN
#
#        noBfCt   st modstat  ...  brfdesc bachelor   vl devLogo  devOpSn  \
# 0           0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 1           0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 2           3  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 3           0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 4           0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# ...       ...  ...     ...  ...      ...      ...  ...     ...      ...
# 15895       0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 15896       0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 15897       0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 15898       0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
# 15899       0  511   20205  ...      NaN      NaN  NaN     NaN      NaN
#
#        devtp devpc devpuc pfAgCg       city
# 0        NaN   NaN    NaN    NaN  New Delhi
# 1        NaN   NaN    NaN    NaN  New Delhi
# 2        NaN   NaN    NaN    NaN  New Delhi
# 3        NaN   NaN    NaN    NaN  New Delhi
# 4        NaN   NaN    NaN    NaN  New Delhi
# ...      ...   ...    ...    ...        ...
# 15895    NaN   NaN    NaN    NaN  New Delhi
# 15896    NaN   NaN    NaN    NaN  New Delhi
# 15897    NaN   NaN    NaN    NaN  New Delhi
# 15898    NaN   NaN    NaN    NaN  New Delhi
# 15899    NaN   NaN    NaN    NaN  New Delhi
#
# [15900 rows x 271 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# availableFrom
# cntvl
# url
# floorNo
# noBfCt
# st
# modstat
# appVer
# appSub
# deviceType
# sendbirdId
# lastAccessDate
# lastReplyDate
# sipro
# comFlag
# appExc
# cScore
# postDateT
# endDateT
# pl
# luxAmenities
# luxAmenitiesD
# appovedAuthC
# nriPref
# availUnit
# enc_Id
# cowDays
# price
# priceD
# imgCt
# propertyImageNew
# seoDesc
# propCat
# id
# pmtmtrendPercentage
# flooringTyD
# adroomD
# powerStatusD
# maintenanceD
# sv
# agtCrSt
# cg
# pp
# maintenanceCharges
# bookingAmtExact
# dImgSrc
# landmark
# seoLtSc
# lc
# pSc
# lcLst
# pCct
# lCct
# pcTcCt
# ac
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# companyname
# contName
# auto_desc
# sqFtPrD
# carpetArea
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# imageDate
# supV
# lmtDName
# pkgid
# achTdS
# opSn
# opSnD
# sid
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# isVis
# showupfront
# agtCerStatus
# caCompNameD
# postedLabelD
# OwnershipTypeD
# furnishedD
# balconiesD
# bathD
# parkingD
# facingD
# amenFacingD
# transactionTypeD
# floorD
# propTypeD
# ctName
# bedroomD
# userType
# transType
# isPreferred
# floors
# brokerConnect
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# crisilRv1CtBy
# crisilNoOfEmployees
# crisilStarRating
# crisilOpSinceYear
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# smartDiaryApiTag
# waterStatus
# isLuxury
# coveredArea
# covAreaUnit
# carpAreaUnit
# modifiedDate
# imgUrl
# image
# actualOwner
# amenities
# isProjProp
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# pckCon
# ctCurr
# ctLast
# rEcd
# endDt
# ranPropImg
# catAdd1
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# operatingSinceYear
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# investorlisting
# investorguide
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# agentContinuityStr
# isLuxuryServiceAvailable
# luxAmenMap
# nonluxAmenMap
# ctaDetailBean
# lCtDate
# projectSocietyLink
# devName
# landmarkDetails
# prjname
# criLogo
# agComCt
# pmtUsp1
# pmtUspWap
# psmid
# pmtUsp
# devId
# newUrl
# seoPsmDt
# dealDesc
# isRera
# reraId
# acD
# la
# landAreaUnit
# isReraAgent
# agentReraState
# landAreaUnitD
# psmapproved
# ltOther
# taImg
# psmImage
# psmImgCt
# psmUspImgWeb
# psmUspImgMob
# tag
# tagWap
# possBy
# prjHl1
# prjLtHl1
# prjSrc
# siteVisitProp
# prjid
# floorCsntrAllowed
# crisilRv1
# crisilRv2
# crisilRv2CtBy
# crircname1
# crircname2
# dues
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# isExcl
# pmtTCabin
# rdWidth
# nOs
# noOfSVis
# sVisMinDt
# sVisMaxDt
# pmtUsp2
# pmtUsp2Wap
# adCn
# comPantry
# agentDetailUrl
# isprimeListingType
# isCornerPlot
# dimD
# pbrk
# pbrkp
# cpmp
# iTarget
# nr
# appExcRe
# gateComm
# brfdesc
# bachelor
# vl
# devLogo
# devOpSn
# devtp
# devpc
# devpuc
# pfAgCg
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId dqz+CnAqTZNzpSvf+uAgZw== CvaAVyAXNo9zpSvf+uAgZw==
# possStatusD Ready to Move Ready to Move
# pmtSource Web Web
# availableFrom Mar '24 nan
# cntvl nan nan
# url 3-BHK-1836-Sq-ft-Multistorey-Apartment-FOR-Sale-Amraiwadi-Usmanpura-in-Ahmedabad&id=4d423731303335303239 2-BHK-1280-Sq-ft-Penthouse-FOR-Sale-South-Bopal-in-Ahmedabad&id=4d423637353335303537
# floorNo 5 13
# noBfCt 3 0
# st 511 511
# modstat 20205 20205
# appVer 353.0 431.0
# appSub Y Y
# deviceType and and
# sendbirdId 87d7e5bb-8acd-4ffa-8a46-b8441eeafbe0pint1332 ecb02f2c-1cba-416b-9085-ee9cf9ab5adfalpe9286
# lastAccessDate 1710095400000.0 1710181800000.0
# lastReplyDate nan 1597948200000.0
# sipro 71252777 70561647 67625999 71417097 66350187 69159003 60107769 69722921
# comFlag N Y
# appExc N N
# cScore 100 100
# postDateT 2024-03-03T23:43:24.000Z 2024-03-10T23:45:21.000Z
# endDateT 2024-05-02T23:43:24.000Z 2024-05-09T23:45:21.000Z
# pl Y Y
# luxAmenities 12224 12230 12216 12217 12560 12561 12234 12236 12556 12558 12230 12216 12217
# luxAmenitiesD Banquet Hall,Outdoor Tennis Courts,Visitor Parking,Intercom Facility Water Front,Hilltop,Skyline View,Island Kitchen Layout,Fireplace,Sky Villa,Outdoor Tennis Courts,Visitor Parking,Intercom Facility
# appovedAuthC AMC AMC
# nriPref Y Y
# availUnit 20.0 2.0
# enc_Id dqz+CnAqTZNUIO9WU5fekA== CvaAVyAXNo8EHWttSQQywQ==
# cowDays 0 0
# price 11199600.0 6500000.0
# priceD 1.11 Cr 65 Lac
# imgCt 10 15
# propertyImageNew https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_1_am04JPG01_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_2_am08JPG_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_3_am05JPG_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_4_am01JPG_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_5_am07JPG_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_7_oyerccc_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_8_ymcc_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_6_ROCHURESHYAMHEIGHTSpagestojpg0007_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_9_ROCHURESHYAMHEIGHTSpagestojpg0008_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_10_ROCHURESHYAMHEIGHTSpagestojpg0006_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_1_hatsAppImage20230614at6.11.30PM2_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_9_hatsAppImage20230614at6.11.35PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_8_hatsAppImage20230614at6.11.36PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_2_hatsAppImage20230614at6.11.30PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_3_hatsAppImage20230614at6.11.29PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_4_hatsAppImage20230614at6.11.33PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_5_hatsAppImage20230614at6.11.36PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_7_hatsAppImage20230614at6.11.32PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_10_hatsAppImage20230614at6.11.34PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_11_hatsAppImage20230614at6.11.35PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_14_hatsAppImage20230614at6.11.33PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_16_hatsAppImage20230614at6.11.31PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_17_hatsAppImage20230614at6.11.30PM_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_20_hatsAppImage20230614at6.11.29PM1_180_240.jpeg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_6_hatsAppImage20230614at6.11.34PM_180_240.jpeg
# seoDesc A  3 BHK flat is available for sale in Amraiwadi Usmanpura, Ahmedabad. This spacious flat is available for sale at a very reasonable price. Located in Amraiwadi Usmanpura, this ready to move apartment is sold at a fair selling price of INR 1.11 Cr. You should know the possession date of this flat is Mar '24. Available in unfurnished state, this apartment is a great buy. This 3 BHK flat is in close proximity to landmarks like nava wadaj road, bhimjipura road and balol nagar road are few of the i. You can find this 2 BHK flat for sale in South Bopal, Ahmedabad. This flat is situated within Sky Sol. This flat for resale is an attractive property. You can buy this ready to move flat in South Bopal at a reasonable price of INR 65 Lac. You will find it unfurnished. Some nearby landmarks are the residential property is located on safal parisar road south bopal..
# propCat 20292 20292
# id 71035029 67535057
# pmtmtrendPercentage 0 0
# flooringTyD Ceramic Tiles,Granite,Marble,Marbonite,Mosaic,Normal Tiles/Kotah Stone,Vitrified Marbonite,Normal Tiles/Kotah Stone,Vitrified
# adroomD Study,Store Store
# powerStatusD No/Rare Powercut No/Rare Powercut
# maintenanceD Per sq. Unit Monthly Monthly
# sv Y nan
# agtCrSt nan Y
# cg b b
# pp B Z
# maintenanceCharges 2 1500
# bookingAmtExact 551000 200000
# dImgSrc 10511 10511
# landmark Nava Wadaj Road, Bhimjipura Road and Balol Nagar Road are few of the i The Residential Property is located on safal parisar road south bopal.
# seoLtSc 1 2
# lc nan 3
# pSc 0 0
# lcLst nan South Bopal
# pCct 0 0
# lCct 0 48
# pcTcCt 0 0
# ac nan 11652.0
# caSqFt 1836.0 1280.0
# ltcoordGeo 23.05112117,72.57027612 23.0183554050494,72.4737809420189
# iba Y X
# ct 2690 2690
# lt 159182.0 89345.0
# loc 159182.0 89345.0
# bd 11702 11701
# ca 1836 1280
# ty 10002 10021
# dtldesc Strategically situated off 132 Feet Ring Road, Nava Vadaj is an upcoming residential and growing commercial area located in northwestern zone of Ahmedabad. Akhbar Nagar, Vijar Nagar, Mansukh Nagar, Vijar Nagar and Patrakar Colony are a few neighbouring areas of this locale. Offering a mix of builder floors, multistory apartments and houses, Nava Vadaj is an ideal destination for middle class and upper middleclass families. Satyam Skyline II, Gunatit Antilia, Apurva Aasthaa Opal, Vandana Park Society and Mahavir Estate are renowned wellplanned residential projects in Nava Vadaj. Welldevelop 2 bhk penthouse 1280 sq ft 778 sq ft terrace available for resale. prime location. 1 car covered allotted parking. for more details for visit the property contact with us.
# plgdtldesc Strategically situated off 132 Feet Ring Road, Nava Vadaj is an upcoming residential and growing commercial area located in northwestern zone of Ahmedabad. Akhbar Nagar, Vijar Nagar, Mansukh Nagar, Vijar Nagar and Patrakar Colony are a few neighbouring areas of this locale. Offering a mix of builder floors, multistory apartments and houses, Nava Vadaj is an ideal destination for middle class and upper middleclass families. Satyam Skyline II, Gunatit Antilia, Apurva Aasthaa Opal, Vandana Park Society and Mahavir Estate are renowned wellplanned residential projects in Nava Vadaj. Welldevelop 2 bhk penthouse 1280 sq ft 778 sq ft terrace available for resale. prime location. 1 car covered allotted parking. for more details for visit the property contact with us.
# oid 31919979 23028919
# oname Shyam Vijay Infrastructure LLP Alpesh  Panchal
# sdp Y Y
# companyname nan Meldi Properties
# contName nan Alpesh
# auto_desc 3 BHK, Multistorey Apartment is available for Sale in Amraiwadi Usmanpura, Ahmedabad for 1.1 Crore(s) 2 BHK, Penthouse is available for Sale in South Bopal, Ahmedabad for 65.0 Lac(s)
# sqFtPrD 6100.0 5078.0
# carpetArea 1017 775
# pkg 10070 10075
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 0.0 23.0176119
# pmtLong 0.0 72.461435
# moisd 50 50
# imageDate 2024/Jan/23 2023/Jun/15
# supV Y Y
# lmtDName Amraiwadi Usmanpura South Bopal, Bopal
# pkgid 300745 285625
# achTdS 35 821
# opSn nan 111111
# opSnD nan 2016
# sid 13672,13560,13520,13534 13520,13558,13502
# locSeoName Amraiwadi Usmanpura South Bopal
# propImg 71035029_2_am08JPG.jpg 67535057_10_hatsAppImage20230614at6.11.34PM1.jpeg
# coverAreaUnitD Sq-ft Sq-ft
# ppd 20240304 20240311
# ppdL 1709509404000 1710114321000
# achTm 12 402
# achTmS 12 402
# soc Y Y
# tmsrt 231357 051521
# ecd 20240304 20240311
# prm y y
# sqFtPrice 6100.0 5078.0
# isVis W W
# showupfront N N
# agtCerStatus nan nan
# caCompNameD Shyam Vijay Infrastructure LLP Meldi Properties
# postedLabelD Posted: Mar 04, '24 Posted: Mar 11, '24
# OwnershipTypeD Freehold Freehold
# furnishedD Unfurnished Unfurnished
# balconiesD 1 1
# bathD 3 2
# parkingD 1 Covered, 1 Open 1 Covered
# facingD North - East North - East
# amenFacingD Garden/Park, Main Road Main Road
# transactionTypeD New Property Resale
# floorD 5 of 14 Floor 13 of 13 Floor
# propTypeD Apartment Penthouse
# ctName Ahmedabad Ahmedabad
# bedroomD 3 2
# userType Builder Agent
# transType Sale Sale
# isPreferred false false
# floors 14 13
# brokerConnect nan N
# dImgRf PROP304374835 PROP281722543
# localityPhoto 0 0
# defaultAdddressGoogle Ahmedabad, Gujarat Ahmedabad, Gujarat
# propertyTitle 3BHK Multistorey Apartment for New Property in Amraiwadi Usmanpura 2BHK Penthouse for Resale in Sky Sol at South Bopal, Bopal
# crisilRv1CtBy nan Lalit N/A
# crisilNoOfEmployees nan 15
# crisilStarRating nan 3
# crisilOpSinceYear nan nan
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h80_w120/71035029_2_am08JPG_80_120.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h80_w120/67535057_10_hatsAppImage20230614at6.11.34PM1_80_120.jpeg
# wapImgUrl1 https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_2_am08JPG_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_10_hatsAppImage20230614at6.11.34PM1_180_240.jpeg
# seoURL propertyDetails-3-BHK-1836-Sqft-Flat-FOR-Sale-Amraiwadi-Usmanpura-in-Ahmedabad&id=dqz+CnAqTZNzpSvf+uAgZw==&category=Sale propertyDetails-2-BHK-1280-Sqft-Penthouse-FOR-Sale-South-Bopal-in-Ahmedabad&id=CvaAVyAXNo9zpSvf+uAgZw==&category=Sale
# smartDiaryApiTag nan Y
# waterStatus Water Availability 24 Hours Available Water Availability 24 Hours Available
# isLuxury F F
# coveredArea 1836 1280
# covAreaUnit 12800 12800
# carpAreaUnit Sq-ft Sq-ft
# modifiedDate Mar 04, '24 Mar 11, '24
# imgUrl nan nan
# image https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_4_am01JPG_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_2_hatsAppImage20230614at6.11.30PM1_180_240.jpeg
# actualOwner 31919979 23028919
# amenities 12201 12202 12204 12206 12207 12208 12209 12213 12216 12217 12218 12222 12224 12226 12228 12230 12202 12203 12204 12206 12207 12208 12209 12211 12212 12213 12216 12217 12218 12219 12222 12228 12230 12234 12236 12556 12558 12560 12561
# isProjProp N N
# pglmtkey 31919979_1 23028919_1
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 1411738.9 10279277.0
# sortCode1b 5193179.0 10279287.0
# sortCode22 0.0 0.0
# sortCode26 1386528.0 0.5700000000000001
# ubicnt 50 50
# pckCon nan 56.03
# ctCurr nan 15486
# ctLast nan 0
# rEcd 20240304 20240311
# endDt May 03, '24 May 10, '24
# ranPropImg https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/23/Photo_h180_w240/71035029_4_am01JPG_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/15/Photo_h180_w240/67535057_2_hatsAppImage20230614at6.11.30PM1_180_240.jpeg
# catAdd1 501. South Bopal,Ahmedabad
# pmtdesc_hi Amraiwadi Usmanpura, अहमदाबाद में स्थित इस आकर्षक 3 BHK फ्लैट को अभी खरीदा जा सकता है। यह फ्लैट में बड़ा सा 3 बाथरूम है; जो परिवार के सभी लोगोें की सुविधा के लिए डिज़ाइन किए गए हैं। यह बेहतरीन 3 BHK प्रॉपर्टी में आपकी गाड़ी के लिए 1कवर्ड,  1 Open पार्किंग की जगह भी है। अब आपको और फ्लैट देखने की जरुरत नहीं है, क्योंकि सेल के लिए यह फ्लैट शहर में सबसे किफायती कीमत पर उपलब्ध है। Amraiwadi Usmanpura में स्थित यह रेडी टू मूव फ्लैट मात्र रु. 1.11 Cr की किफायती कीमत पर उपलब्ध है। पज़ेशन की तारीख - जब खरीदार को फ्लैट दिया जाता है - इस प्रॉपर्टी के लिए Mar '24 है। इस अनफर्निश्ड घर को अच्छी लाइफस्टाइल के लिए सभी सुविधाएं उपलब्ध कराते हुए डिजाइन किया गया है।  साउथ भोपाल, अहमदाबाद में स्थित यह बेहतरीन 2 BHK फ्लैट बिक्री के लिए पूरी तरह तैयार है। स्काई शोल टाउनशिप में स्थित इस प्रॉपर्टी तक कनेक्टिविटी अच्छी है। इसमें 2 बाथरूम हैं। इस 2 BHK अपार्टमेंट में आपको अपनी कार के लिए निःशुल्क 1कवर्ड पार्किंग की जगह मिलती है। यह फ्लैट रेसले प्रॉपर्टी के रूप में उपलब्ध है। साउथ भोपाल में स्थित यह रेडी टू मूव फ्लैट रु. 65 Lac के उचित मूल्य पर खरीदी जा सकता है। फ्लैट को खासतौर पर अच्छी लाइफस्टाइल के लिए डिज़ाइन किया गया है। यह अनफर्निश्ड है और इसमें सभी तरह की सुविधाएं हैं। स्काई शोल यहां रहने वाले लोगों को वॉटर फ्रंट, हिलटॉप, स्काइलाइन व्यू, इसलैंड किचन लेआउट, फायरप्लेस जैसी अत्याधुनिक सुविधाएं उपलब्ध कराता है।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# operatingSinceYear nan 2016
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc Sq-ft Sq-ft
# investorlisting N N
# investorguide N N
# ampDesc Strategically situated off 132 Feet Ring Road, Nava Vadaj is an upcoming residential and growing com 2 bhk penthouse 1280 sq ft 778 sq ft terrace available for resale. prime location. 1 car covered all
# b2cCardEligibility false false
# maskedMobileNumber +91-99XXXXXXX32 +91-99XXXXXXX00
# agentContinuityStr nan 15000+ Buyers Served
# isLuxuryServiceAvailable False False
# luxAmenMap {'12224': 'Banquet Hall', '12230': 'Outdoor Tennis Courts', '12216': 'Visitor Parking', '12217': 'Intercom Facility'} {'12560': 'Water Front', '12561': 'Hilltop', '12234': 'Skyline View', '12236': 'Island Kitchen Layout'}
# nonluxAmenMap {} {}
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# lCtDate 1710227517000.0 1709714741000.0
# projectSocietyLink nan sky-sol-south-bopal-ahmedabad-pdpid-4d4235303932343634
# devName nan Saanvi Nirman
# landmarkDetails nan ['19201|1.3 Km from Sobo Center', '19210|7.4 Km from Doordarshan Metro Station', '19202|1.2 Km from Shanti Asiatic School']
# prjname nan Sky Sol
# criLogo nan 12023
# agComCt nan 70.0
# pmtUsp1 nan nan
# pmtUspWap nan nan
# psmid nan 5092464
# pmtUsp nan nan
# devId nan 77849
# newUrl nan project-sky-sol-for-sale-in-ahmedabad-pppfs
# seoPsmDt nan {"bhkPriceRange":{"3 BHK":{"minPrice":"60.0 Lac","maxPrice":"65.0 Lac"},"2 BHK":{"minPrice":"45.7 Lac","maxPrice":"61.0 Lac"}}}
# dealDesc Free Registration & Stamp Duty nan
# isRera Y Y
# reraId PR/GJ/AHMEDABAD/AHMEDABAD CITY/AUDA/RAA08184/15032 AA01179/260625R1
# acD nan Less than 5 years
# la nan 1280
# landAreaUnit nan 12850.0
# isReraAgent nan Y
# agentReraState nan AG/GJ/AHMEDABAD/DASKROI/AUDA/AA01179/260625R1
# landAreaUnitD nan Sq-ft
# psmapproved nan nan
# ltOther nan nan
# taImg nan nan
# psmImage nan nan
# psmImgCt nan nan
# psmUspImgWeb nan nan
# psmUspImgMob nan nan
# tag nan nan
# tagWap nan nan
# possBy nan nan
# prjHl1 nan nan
# prjLtHl1 nan nan
# prjSrc nan nan
# siteVisitProp nan nan
# prjid nan nan
# floorCsntrAllowed nan nan
# crisilRv1 nan nan
# crisilRv2 nan nan
# crisilRv2CtBy nan nan
# crircname1 nan nan
# crircname2 nan nan
# dues nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# isExcl nan nan
# pmtTCabin nan nan
# rdWidth nan nan
# nOs nan nan
# noOfSVis nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# adCn nan nan
# comPantry nan nan
# agentDetailUrl nan nan
# isprimeListingType nan nan
# isCornerPlot nan nan
# dimD nan nan
# pbrk nan nan
# pbrkp nan nan
# cpmp nan nan
# iTarget nan nan
# nr nan nan
# appExcRe nan nan
# gateComm nan nan
# brfdesc nan nan
# bachelor nan nan
# vl nan nan
# devLogo nan nan
# devOpSn nan nan
# devtp nan nan
# devpc nan nan
# devpuc nan nan
# pfAgCg nan nan
# city New Delhi New Delhi

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"lc",
"pSc",
"lcLst",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"nr",
"appExcRe",
"pbrk",
"pbrkp",
"brfdesc",
"crircname2",
"iTarget",
"bachelor",
"vl",
"devLogo",
"devOpSn",
"devtp",
"devpc",
"devpuc",
"pfAgCg",
"ctLast",
"crisilRv1",
"crisilRv2",
"crisilRv2CtBy",
"crircname1"], axis=1, inplace=True)

# %%
house_data
# Out:
#               possStatusD                                       luxAmenities  \
# 0      Under Construction                                              12216
# 1      Under Construction  12560 12556 12237 12238 12229 12230 12220 1222...
# 2           Ready to Move                            12224 12230 12216 12217
# 3           Ready to Move  12560 12561 12234 12236 12556 12558 12230 1221...
# 4      Under Construction  12560 12527 12562 12556 12237 12215 12224 1222...
# ...                   ...                                                ...
# 15895  Under Construction                                        12224 12216
# 15896  Under Construction                                                NaN
# 15897  Under Construction                                              12216
# 15898  Under Construction                            12229 12220 12216 12217
# 15899             Apr '24                                                NaN
#
#                                            luxAmenitiesD       price  \
# 0                                        Visitor Parking  12800000.0
# 1      Water Front,Fireplace,Full Glass Wall,House he...  13240000.0
# 2      Banquet Hall,Outdoor Tennis Courts,Visitor Par...  11199600.0
# 3      Water Front,Hilltop,Skyline View,Island Kitche...   6500000.0
# 4      Water Front,Sea facing,Smart Home,Fireplace,Fu...   9675000.0
# ...                                                  ...         ...
# 15895                       Banquet Hall,Visitor Parking  14290000.0
# 15896                                                NaN  15590000.0
# 15897                                    Visitor Parking  12800000.0
# 15898  Jogging and Strolling Track,Laundry Service,Vi...  11250000.0
# 15899                                                NaN   9740000.0
#
#          priceD                                   propertyImageNew  \
# 0       1.28 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 1       1.32 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 2       1.11 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 3        65 Lac  https://img.staticmb.com/mbphoto/property/crop...
# 4      96.8 Lac  https://img.staticmb.com/mbphoto/property/crop...
# ...         ...                                                ...
# 15895   1.42 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 15896   1.55 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 15897   1.28 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 15898   1.12 Cr  https://img.staticmb.com/mbphoto/property/crop...
# 15899  97.4 Lac                                                NaN
#
#            powerStatusD          maintenanceD  sqFtPrD carpetArea  ...  \
# 0      No/Rare Powercut               Monthly   5366.0       1410  ...
# 1      No/Rare Powercut               Monthly   5000.0       1457  ...
# 2      No/Rare Powercut  Per sq. Unit Monthly   6100.0       1017  ...
# 3      No/Rare Powercut               Monthly   5078.0        775  ...
# 4      No/Rare Powercut               Monthly   4777.0       1113  ...
# ...                 ...                   ...      ...        ...  ...
# 15895  No/Rare Powercut               Monthly   5500.0       1507  ...
# 15896  No/Rare Powercut               Monthly   6000.0        NaN  ...
# 15897  No/Rare Powercut               Monthly   5366.0       1410  ...
# 15898  No/Rare Powercut              One-Time  45000.0        143  ...
# 15899  No/Rare Powercut                   NaN   5000.0        NaN  ...
#
#                floorD     ctName bedroomD floors coveredArea covAreaUnit  \
# 0       2 of 14 Floor  Ahmedabad        3     14        2565       12800
# 1       7 of 21 Floor  Ahmedabad        3     21        2648       12800
# 2       5 of 14 Floor  Ahmedabad        3     14        1836       12800
# 3      13 of 13 Floor  Ahmedabad        2     13        1280       12800
# 4       6 of 14 Floor  Ahmedabad        3     14        2025       12800
# ...               ...        ...      ...    ...         ...         ...
# 15895   8 of 21 Floor  Ahmedabad        3     21        2598       12800
# 15896   6 of 22 Floor  Ahmedabad        3     22        2598       12800
# 15897   6 of 14 Floor  Ahmedabad        3     14        2565       12800
# 15898   5 of 14 Floor  Ahmedabad        3     14         250       12803
# 15899             NaN  Ahmedabad        3    NaN        1948       12800
#
#       carpAreaUnit                                              image  \
# 0            Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 1            Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 2            Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 3            Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 4            Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# ...            ...                                                ...
# 15895        Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 15896          NaN  https://img.staticmb.com/mbimages/project/Phot...
# 15897        Sq-ft  https://img.staticmb.com/mbphoto/property/crop...
# 15898       Sq-yrd  https://img.staticmb.com/mbphoto/property/crop...
# 15899          NaN  https://img.staticmb.com/mbimages/project/Phot...
#
#                                                amenities       city
# 0      12202 12207 12208 12209 12211 12213 12216 1221...  New Delhi
# 1      12201 12202 12204 12205 12206 12207 12208 1221...  New Delhi
# 2      12201 12202 12204 12206 12207 12208 12209 1221...  New Delhi
# 3      12202 12203 12204 12206 12207 12208 12209 1221...  New Delhi
# 4      12201 12202 12204 12205 12206 12207 12208 1220...  New Delhi
# ...                                                  ...        ...
# 15895  12202 12204 12205 12206 12207 12208 12216 1221...  New Delhi
# 15896                      12202 12204 12205 12206 12208  New Delhi
# 15897  12202 12207 12208 12209 12211 12213 12216 1221...  New Delhi
# 15898  12201 12202 12204 12206 12207 12208 12209 1221...  New Delhi
# 15899                                                NaN  New Delhi
#
# [15900 rows x 27 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD          107
# luxAmenities        7945
# luxAmenitiesD       7946
# price                121
# priceD                 0
# propertyImageNew    6653
# powerStatusD        4233
# maintenanceD        8423
# sqFtPrD              845
# carpetArea          7021
# sqFtPrice            864
# OwnershipTypeD      7214
# furnishedD           122
# balconiesD          6276
# bathD                 93
# parkingD            5442
# facingD             7417
# floorD              5501
# ctName                 0
# bedroomD               0
# floors              5505
# coveredArea          787
# covAreaUnit          786
# carpAreaUnit        7020
# image               2220
# amenities           7066
# city                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# luxAmenities        7945
# luxAmenitiesD       7946
# price                121
# priceD                 0
# propertyImageNew    6653
# powerStatusD        4233
# maintenanceD        8423
# sqFtPrD              845
# carpetArea          7021
# sqFtPrice            864
# OwnershipTypeD      7214
# furnishedD           122
# balconiesD          6276
# bathD                 93
# parkingD            5442
# facingD             7417
# floorD              5501
# ctName                 0
# bedroomD               0
# floors              5505
# coveredArea          787
# covAreaUnit          786
# carpAreaUnit        7020
# image               2220
# amenities           7066
# city                   0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#               possStatusD       price    priceD      powerStatusD carpetArea  \
# 0      Under Construction  12800000.0   1.28 Cr  No/Rare Powercut       1410
# 1      Under Construction  13240000.0   1.32 Cr  No/Rare Powercut       1457
# 2           Ready to Move  11199600.0   1.11 Cr  No/Rare Powercut       1017
# 3           Ready to Move   6500000.0    65 Lac  No/Rare Powercut        775
# 4      Under Construction   9675000.0  96.8 Lac  No/Rare Powercut       1113
# ...                   ...         ...       ...               ...        ...
# 15895  Under Construction  14290000.0   1.42 Cr  No/Rare Powercut       1507
# 15896  Under Construction  15590000.0   1.55 Cr  No/Rare Powercut        NaN
# 15897  Under Construction  12800000.0   1.28 Cr  No/Rare Powercut       1410
# 15898  Under Construction  11250000.0   1.12 Cr  No/Rare Powercut        143
# 15899             Apr '24   9740000.0  97.4 Lac  No/Rare Powercut        NaN
#
#        sqFtPrice   furnishedD balconiesD bathD           parkingD  \
# 0         4990.0  Unfurnished          1     3          1 Covered
# 1         5000.0  Unfurnished          2     3          2 Covered
# 2         6100.0  Unfurnished          1     3  1 Covered, 1 Open
# 3         5078.0  Unfurnished          1     2          1 Covered
# 4         4778.0  Unfurnished          1     3          2 Covered
# ...          ...          ...        ...   ...                ...
# 15895     5500.0  Unfurnished          1     3          2 Covered
# 15896     6001.0  Unfurnished          1     4          2 Covered
# 15897     4990.0  Unfurnished          1     3          1 Covered
# 15898     5000.0  Unfurnished          1     3          1 Covered
# 15899     5000.0  Unfurnished        NaN     3          1 Covered
#
#             facingD     ctName bedroomD floors coveredArea carpAreaUnit
# 0      North - West  Ahmedabad        3     14        2565        Sq-ft
# 1              East  Ahmedabad        3     21        2648        Sq-ft
# 2      North - East  Ahmedabad        3     14        1836        Sq-ft
# 3      North - East  Ahmedabad        2     13        1280        Sq-ft
# 4              East  Ahmedabad        3     14        2025        Sq-ft
# ...             ...        ...      ...    ...         ...          ...
# 15895          East  Ahmedabad        3     21        2598        Sq-ft
# 15896          East  Ahmedabad        3     22        2598          NaN
# 15897  North - West  Ahmedabad        3     14        2565        Sq-ft
# 15898          East  Ahmedabad        3     14         250       Sq-yrd
# 15899           NaN  Ahmedabad        3    NaN        1948          NaN
#
# [15900 rows x 16 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             11661
# Less Than 2 Hour Powercut        5
# 4 To 6 Hours Powercut            1
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#              possStatusD       price    priceD               powerStatusD  \
# 56    Under Construction  11000000.0   1.10 Cr  Less Than 2 Hour Powercut
# 71    Under Construction   8942300.0  89.4 Lac  Less Than 2 Hour Powercut
# 574   Under Construction   7280000.0  72.8 Lac  Less Than 2 Hour Powercut
# 3236       Ready to Move   6400000.0    64 Lac  Less Than 2 Hour Powercut
# 4186       Ready to Move   4100000.0    41 Lac  Less Than 2 Hour Powercut
#
#      carpetArea  sqFtPrice   furnishedD balconiesD bathD  \
# 56         1210     5000.0  Unfurnished          1     3
# 71          223     4456.0  Unfurnished          1     3
# 574         965     4282.0  Unfurnished          1     3
# 3236        NaN     5689.0    Furnished          1     3
# 4186        650     2733.0  Unfurnished          1     2
#
#                    parkingD       facingD     ctName bedroomD floors  \
# 56                1 Covered          East  Ahmedabad        3     14
# 71                1 Covered          East  Ahmedabad        3     14
# 574               1 Covered          East  Ahmedabad        3     14
# 3236              3 Covered         North  Ahmedabad        3      2
# 4186  202 Covered, 202 Open  North - East  Ahmedabad        2      7
#
#      coveredArea carpAreaUnit
# 56          2200        Sq-ft
# 71           223        Sq-ft
# 574         1700        Sq-ft
# 3236         125          NaN
# 4186        1500        Sq-ft

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price            121
# priceD             0
# powerStatusD    4233
# carpetArea      7021
# sqFtPrice        864
# furnishedD       122
# balconiesD      6276
# bathD             93
# parkingD        5442
# facingD         7417
# ctName             0
# bedroomD           0
# floors          5505
# coveredArea      787
# carpAreaUnit    7020
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 15900

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.4502923976608187' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.36238129724022716

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#               possStatusD       price    priceD      powerStatusD carpetArea  \
# 0      Under Construction  12800000.0   1.28 Cr  No/Rare Powercut       1410
# 1      Under Construction  13240000.0   1.32 Cr  No/Rare Powercut       1457
# 2           Ready to Move  11199600.0   1.11 Cr  No/Rare Powercut       1017
# 3           Ready to Move   6500000.0    65 Lac  No/Rare Powercut        775
# 4      Under Construction   9675000.0  96.8 Lac  No/Rare Powercut       1113
# ...                   ...         ...       ...               ...        ...
# 15895  Under Construction  14290000.0   1.42 Cr  No/Rare Powercut       1507
# 15896  Under Construction  15590000.0   1.55 Cr  No/Rare Powercut     2078.4
# 15897  Under Construction  12800000.0   1.28 Cr  No/Rare Powercut       1410
# 15898  Under Construction  11250000.0   1.12 Cr  No/Rare Powercut        143
# 15899             Apr '24   9740000.0  97.4 Lac  No/Rare Powercut     1558.4
#
#        sqFtPrice   furnishedD balconiesD bathD           parkingD  \
# 0         4990.0  Unfurnished          1     3          1 Covered
# 1         5000.0  Unfurnished          2     3          2 Covered
# 2         6100.0  Unfurnished          1     3  1 Covered, 1 Open
# 3         5078.0  Unfurnished          1     2          1 Covered
# 4         4778.0  Unfurnished          1     3          2 Covered
# ...          ...          ...        ...   ...                ...
# 15895     5500.0  Unfurnished          1     3          2 Covered
# 15896     6001.0  Unfurnished          1     4          2 Covered
# 15897     4990.0  Unfurnished          1     3          1 Covered
# 15898     5000.0  Unfurnished          1     3          1 Covered
# 15899     5000.0  Unfurnished        NaN     3          1 Covered
#
#             facingD     ctName bedroomD floors  coveredArea carpAreaUnit  \
# 0      North - West  Ahmedabad        3     14       2565.0        Sq-ft
# 1              East  Ahmedabad        3     21       2648.0        Sq-ft
# 2      North - East  Ahmedabad        3     14       1836.0        Sq-ft
# 3      North - East  Ahmedabad        2     13       1280.0        Sq-ft
# 4              East  Ahmedabad        3     14       2025.0        Sq-ft
# ...             ...        ...      ...    ...          ...          ...
# 15895          East  Ahmedabad        3     21       2598.0        Sq-ft
# 15896          East  Ahmedabad        3     22       2598.0        Sq-ft
# 15897  North - West  Ahmedabad        3     14       2565.0        Sq-ft
# 15898          East  Ahmedabad        3     14        250.0       Sq-yrd
# 15899           NaN  Ahmedabad        3      0       1948.0        Sq-ft
#
#        areaPercent
# 0         0.450292
# 1         0.449773
# 2         0.446078
# 3         0.394531
# 4         0.450370
# ...            ...
# 15895     0.419938
# 15896     0.000000
# 15897     0.450292
# 15898     0.428000
# 15899     0.000000
#
# [15113 rows x 17 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price             84
# priceD             0
# powerStatusD       0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      5806
# bathD             83
# parkingD           0
# facingD         7113
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# areaPercent        0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#         possStatusD  price          priceD      powerStatusD carpetArea  \
# 4760  Ready to Move    NaN  Call for Price  No/Rare Powercut      547.2
# 4761  Ready to Move    NaN  Call for Price  No/Rare Powercut     1224.0
# 4762  Ready to Move    NaN  Call for Price  No/Rare Powercut     1524.0
# 4763  Ready to Move    NaN  Call for Price  No/Rare Powercut      660.8
# 4765  Ready to Move    NaN  Call for Price  No/Rare Powercut        127
# ...             ...    ...             ...               ...        ...
# 4874  Ready to Move    NaN  Call for Price  No/Rare Powercut       80.0
# 4875  Ready to Move    NaN  Call for Price  No/Rare Powercut      139.2
# 4877  Ready to Move    NaN  Call for Price  No/Rare Powercut      960.0
# 4878  Ready to Move    NaN  Call for Price  No/Rare Powercut     2400.0
# 4879  Ready to Move    NaN  Call for Price  No/Rare Powercut        600
#
#       sqFtPrice   furnishedD balconiesD bathD parkingD facingD     ctName  \
# 4760        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4761        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4762        0.0    Furnished          1     2        0     NaN  Ahmedabad
# 4763        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4765        0.0  Unfurnished          2     2        0     NaN  Ahmedabad
# ...         ...          ...        ...   ...      ...     ...        ...
# 4874        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4875        0.0    Furnished        NaN     2        0     NaN  Ahmedabad
# 4877        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4878        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4879        0.0  Unfurnished          1     2        0     NaN  Ahmedabad
#
#      bedroomD floors  coveredArea carpAreaUnit  areaPercent
# 4760        2      0        684.0        Sq-ft     0.000000
# 4761        3      0       1530.0        Sq-ft     0.000000
# 4762        3      0       1905.0        Sq-ft     0.000000
# 4763        3      0        826.0        Sq-ft     0.000000
# 4765        3      5        141.0        Sq-ft     0.099291
# ...       ...    ...          ...          ...          ...
# 4874        2      0        100.0        Sq-ft     0.000000
# 4875        3     11        174.0        Sq-ft     0.000000
# 4877        2      0       1200.0        Sq-ft     0.000000
# 4878        2      0       3000.0        Sq-ft     0.000000
# 4879        2      4       1000.0        Sq-ft     0.400000
#
# [84 rows x 17 columns]

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price              0
# priceD             0
# powerStatusD       0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      5806
# bathD             83
# parkingD           0
# facingD         7113
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# areaPercent        0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['2.10', 'Cr']

# %%
house_data[house_data['price']==0]
# Out:
#         possStatusD  price          priceD      powerStatusD carpetArea  \
# 4760  Ready to Move      0  Call for Price  No/Rare Powercut      547.2
# 4761  Ready to Move      0  Call for Price  No/Rare Powercut     1224.0
# 4762  Ready to Move      0  Call for Price  No/Rare Powercut     1524.0
# 4763  Ready to Move      0  Call for Price  No/Rare Powercut      660.8
# 4765  Ready to Move      0  Call for Price  No/Rare Powercut        127
# ...             ...    ...             ...               ...        ...
# 4874  Ready to Move      0  Call for Price  No/Rare Powercut       80.0
# 4875  Ready to Move      0  Call for Price  No/Rare Powercut      139.2
# 4877  Ready to Move      0  Call for Price  No/Rare Powercut      960.0
# 4878  Ready to Move      0  Call for Price  No/Rare Powercut     2400.0
# 4879  Ready to Move      0  Call for Price  No/Rare Powercut        600
#
#       sqFtPrice   furnishedD balconiesD bathD parkingD facingD     ctName  \
# 4760        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4761        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4762        0.0    Furnished          1     2        0     NaN  Ahmedabad
# 4763        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4765        0.0  Unfurnished          2     2        0     NaN  Ahmedabad
# ...         ...          ...        ...   ...      ...     ...        ...
# 4874        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4875        0.0    Furnished        NaN     2        0     NaN  Ahmedabad
# 4877        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4878        0.0  Unfurnished        NaN   NaN        0     NaN  Ahmedabad
# 4879        0.0  Unfurnished          1     2        0     NaN  Ahmedabad
#
#      bedroomD floors  coveredArea carpAreaUnit  areaPercent
# 4760        2      0        684.0        Sq-ft     0.000000
# 4761        3      0       1530.0        Sq-ft     0.000000
# 4762        3      0       1905.0        Sq-ft     0.000000
# 4763        3      0        826.0        Sq-ft     0.000000
# 4765        3      5        141.0        Sq-ft     0.099291
# ...       ...    ...          ...          ...          ...
# 4874        2      0        100.0        Sq-ft     0.000000
# 4875        3     11        174.0        Sq-ft     0.000000
# 4877        2      0       1200.0        Sq-ft     0.000000
# 4878        2      0       3000.0        Sq-ft     0.000000
# 4879        2      4       1000.0        Sq-ft     0.400000
#
# [84 rows x 17 columns]

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price              0
# priceD             0
# powerStatusD       0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      5750
# bathD             40
# parkingD           0
# facingD         7030
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# areaPercent        0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array(['North - West', 'East', 'North - East', 'West', nan, 'North',
#        'South - East', 'South -West', 'South'], dtype=object)

# %%
house_data
# Out:
#               possStatusD     price    priceD      powerStatusD carpetArea  \
# 0      Under Construction  12800000   1.28 Cr  No/Rare Powercut       1410
# 1      Under Construction  13240000   1.32 Cr  No/Rare Powercut       1457
# 2           Ready to Move  11199600   1.11 Cr  No/Rare Powercut       1017
# 3           Ready to Move   6500000    65 Lac  No/Rare Powercut        775
# 4      Under Construction   9675000  96.8 Lac  No/Rare Powercut       1113
# ...                   ...       ...       ...               ...        ...
# 15895  Under Construction  14290000   1.42 Cr  No/Rare Powercut       1507
# 15896  Under Construction  15590000   1.55 Cr  No/Rare Powercut     2078.4
# 15897  Under Construction  12800000   1.28 Cr  No/Rare Powercut       1410
# 15898  Under Construction  11250000   1.12 Cr  No/Rare Powercut        143
# 15899             Apr '24   9740000  97.4 Lac  No/Rare Powercut     1558.4
#
#        sqFtPrice   furnishedD balconiesD bathD           parkingD  \
# 0         4990.0  Unfurnished          1     3          1 Covered
# 1         5000.0  Unfurnished          2     3          2 Covered
# 2         6100.0  Unfurnished          1     3  1 Covered, 1 Open
# 3         5078.0  Unfurnished          1     2          1 Covered
# 4         4778.0  Unfurnished          1     3          2 Covered
# ...          ...          ...        ...   ...                ...
# 15895     5500.0  Unfurnished          1     3          2 Covered
# 15896     6001.0  Unfurnished          1     4          2 Covered
# 15897     4990.0  Unfurnished          1     3          1 Covered
# 15898     5000.0  Unfurnished          1     3          1 Covered
# 15899     5000.0  Unfurnished        NaN     3          1 Covered
#
#             facingD     ctName bedroomD floors  coveredArea carpAreaUnit  \
# 0      North - West  Ahmedabad        3     14       2565.0        Sq-ft
# 1              East  Ahmedabad        3     21       2648.0        Sq-ft
# 2      North - East  Ahmedabad        3     14       1836.0        Sq-ft
# 3      North - East  Ahmedabad        2     13       1280.0        Sq-ft
# 4              East  Ahmedabad        3     14       2025.0        Sq-ft
# ...             ...        ...      ...    ...          ...          ...
# 15895          East  Ahmedabad        3     21       2598.0        Sq-ft
# 15896          East  Ahmedabad        3     22       2598.0        Sq-ft
# 15897  North - West  Ahmedabad        3     14       2565.0        Sq-ft
# 15898          East  Ahmedabad        3     14        250.0       Sq-yrd
# 15899           NaN  Ahmedabad        3      0       1948.0        Sq-ft
#
#        areaPercent
# 0         0.450292
# 1         0.449773
# 2         0.446078
# 3         0.394531
# 4         0.450370
# ...            ...
# 15895     0.419938
# 15896     0.000000
# 15897     0.450292
# 15898     0.428000
# 15899     0.000000
#
# [15029 rows x 17 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15029 entries, 0 to 15899
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   15029 non-null  object
#  1   price         15029 non-null  int32
#  2   priceD        15029 non-null  object
#  3   powerStatusD  15029 non-null  object
#  4   carpetArea    15029 non-null  object
#  5   sqFtPrice     15029 non-null  float64
#  6   furnishedD    15029 non-null  object
#  7   balconiesD    9279 non-null   object
#  8   bathD         14989 non-null  object
#  9   parkingD      15029 non-null  object
#  10  facingD       7999 non-null   object
#  11  ctName        15029 non-null  object
#  12  bedroomD      15029 non-null  object
#  13  floors        15029 non-null  object
#  14  coveredArea   15029 non-null  float64
#  15  carpAreaUnit  15029 non-null  object
#  16  areaPercent   15029 non-null  float64
# dtypes: float64(3), int32(1), object(13)
# memory usage: 2.0+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
house_data['balconiesD'] = house_data['balconiesD'].astype(float)
house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Dec '25", "Dec '26",
#        "Sep '25", "Dec '24", "Jul '24", 'Immediately', "Apr '24",
#        "Jun '27", "Aug '25", "Jun '26", "Dec '27"], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Dec '25", "Dec '26",
#        "Sep '25", "Dec '24", "Jul '24", "Apr '24", "Jun '27", "Jun '26",
#        "Dec '27"], dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 2648.0

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#               possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0      Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 1      Under Construction  13240000   1.32 Cr  No/Rare Powercut      1457.0
# 2           Ready to Move  11199600   1.11 Cr  No/Rare Powercut      1017.0
# 3           Ready to Move   6500000    65 Lac  No/Rare Powercut       775.0
# 4      Under Construction   9675000  96.8 Lac  No/Rare Powercut      1113.0
# ...                   ...       ...       ...               ...         ...
# 15895  Under Construction  14290000   1.42 Cr  No/Rare Powercut      1507.0
# 15896  Under Construction  15590000   1.55 Cr  No/Rare Powercut      2078.4
# 15897  Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 15898  Under Construction  11250000   1.12 Cr  No/Rare Powercut       143.0
# 15899             Apr '24   9740000  97.4 Lac  No/Rare Powercut      1558.4
#
#        sqFtPrice   furnishedD  balconiesD  bathD           parkingD  \
# 0         4990.0  Unfurnished         1.0    3.0          1 Covered
# 1         5000.0  Unfurnished         2.0    3.0          2 Covered
# 2         6100.0  Unfurnished         1.0    3.0  1 Covered, 1 Open
# 3         5078.0  Unfurnished         1.0    2.0          1 Covered
# 4         4778.0  Unfurnished         1.0    3.0          2 Covered
# ...          ...          ...         ...    ...                ...
# 15895     5500.0  Unfurnished         1.0    3.0          2 Covered
# 15896     6001.0  Unfurnished         1.0    4.0          2 Covered
# 15897     4990.0  Unfurnished         1.0    3.0          1 Covered
# 15898     5000.0  Unfurnished         1.0    3.0          1 Covered
# 15899     5000.0  Unfurnished         NaN    3.0          1 Covered
#
#             facingD     ctName  bedroomD  floors  coveredArea carpAreaUnit  \
# 0      North - West  Ahmedabad       3.0    14.0       2565.0        Sq-ft
# 1              East  Ahmedabad       3.0    21.0       2648.0        Sq-ft
# 2      North - East  Ahmedabad       3.0    14.0       1836.0        Sq-ft
# 3      North - East  Ahmedabad       2.0    13.0       1280.0        Sq-ft
# 4              East  Ahmedabad       3.0    14.0       2025.0        Sq-ft
# ...             ...        ...       ...     ...          ...          ...
# 15895          East  Ahmedabad       3.0    21.0       2598.0        Sq-ft
# 15896          East  Ahmedabad       3.0    22.0       2598.0        Sq-ft
# 15897  North - West  Ahmedabad       3.0    14.0       2565.0        Sq-ft
# 15898          East  Ahmedabad       3.0    14.0        250.0       Sq-yrd
# 15899           NaN  Ahmedabad       3.0     0.0       1948.0        Sq-ft
#
#        areaPercent
# 0         0.450292
# 1         0.449773
# 2         0.446078
# 3         0.394531
# 4         0.450370
# ...            ...
# 15895     0.419938
# 15896     0.000000
# 15897     0.450292
# 15898     0.428000
# 15899     0.000000
#
# [12227 rows x 17 columns]

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_9476\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, parkingD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, areaPercent]
# Index: []

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, parkingD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, areaPercent]
# Index: []

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  carpetArea  sqFtPrice  balconiesD     bathD  bedroomD  \
# price        1.000000    0.204036   0.280119   -0.088403  0.460122  0.463485
# carpetArea   0.204036    1.000000  -0.064416    0.004877  0.295042  0.281048
# sqFtPrice    0.280119   -0.064416   1.000000    0.070142  0.020956  0.023534
# balconiesD  -0.088403    0.004877   0.070142    1.000000 -0.182471 -0.177770
# bathD        0.460122    0.295042   0.020956   -0.182471  1.000000  0.773708
# bedroomD     0.463485    0.281048   0.023534   -0.177770  0.773708  1.000000
# floors       0.003364    0.064124  -0.082578   -0.178719  0.194684  0.141179
# coveredArea  0.069931    0.478155  -0.044320   -0.008783  0.107125  0.119253
# areaPercent -0.027520   -0.372543  -0.071681   -0.078163  0.014003  0.008575
#
#                floors  coveredArea  areaPercent
# price        0.003364     0.069931    -0.027520
# carpetArea   0.064124     0.478155    -0.372543
# sqFtPrice   -0.082578    -0.044320    -0.071681
# balconiesD  -0.178719    -0.008783    -0.078163
# bathD        0.194684     0.107125     0.014003
# bedroomD     0.141179     0.119253     0.008575
# floors       1.000000     0.054093     0.102053
# coveredArea  0.054093     1.000000     0.020840
# areaPercent  0.102053     0.020840     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, parkingD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, areaPercent]
# Index: []

# %%
house_data
# Out:
#               possStatusD     price    priceD      powerStatusD  carpetArea  \
# 0      Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 1      Under Construction  13240000   1.32 Cr  No/Rare Powercut      1457.0
# 2           Ready to Move  11199600   1.11 Cr  No/Rare Powercut      1017.0
# 3           Ready to Move   6500000    65 Lac  No/Rare Powercut       775.0
# 4      Under Construction   9675000  96.8 Lac  No/Rare Powercut      1113.0
# ...                   ...       ...       ...               ...         ...
# 15895  Under Construction  14290000   1.42 Cr  No/Rare Powercut      1507.0
# 15896  Under Construction  15590000   1.55 Cr  No/Rare Powercut      2078.4
# 15897  Under Construction  12800000   1.28 Cr  No/Rare Powercut      1410.0
# 15898  Under Construction  11250000   1.12 Cr  No/Rare Powercut       143.0
# 15899             Apr '24   9740000  97.4 Lac  No/Rare Powercut      1558.4
#
#        sqFtPrice   furnishedD  balconiesD  bathD           parkingD  \
# 0         4990.0  Unfurnished         1.0    3.0          1 Covered
# 1         5000.0  Unfurnished         2.0    3.0          2 Covered
# 2         6100.0  Unfurnished         1.0    3.0  1 Covered, 1 Open
# 3         5078.0  Unfurnished         1.0    2.0          1 Covered
# 4         4778.0  Unfurnished         1.0    3.0          2 Covered
# ...          ...          ...         ...    ...                ...
# 15895     5500.0  Unfurnished         1.0    3.0          2 Covered
# 15896     6001.0  Unfurnished         1.0    4.0          2 Covered
# 15897     4990.0  Unfurnished         1.0    3.0          1 Covered
# 15898     5000.0  Unfurnished         1.0    3.0          1 Covered
# 15899     5000.0  Unfurnished         NaN    3.0          1 Covered
#
#             facingD     ctName  bedroomD  floors  coveredArea carpAreaUnit  \
# 0      North - West  Ahmedabad       3.0    14.0       2565.0        Sq-ft
# 1              East  Ahmedabad       3.0    21.0       2648.0        Sq-ft
# 2      North - East  Ahmedabad       3.0    14.0       1836.0        Sq-ft
# 3      North - East  Ahmedabad       2.0    13.0       1280.0        Sq-ft
# 4              East  Ahmedabad       3.0    14.0       2025.0        Sq-ft
# ...             ...        ...       ...     ...          ...          ...
# 15895          East  Ahmedabad       3.0    21.0       2598.0        Sq-ft
# 15896          East  Ahmedabad       3.0    22.0       2598.0        Sq-ft
# 15897  North - West  Ahmedabad       3.0    14.0       2565.0        Sq-ft
# 15898          East  Ahmedabad       3.0    14.0        250.0       Sq-yrd
# 15899           NaN  Ahmedabad       3.0     0.0       1948.0        Sq-ft
#
#        areaPercent
# 0         0.450292
# 1         0.449773
# 2         0.446078
# 3         0.394531
# 4         0.450370
# ...            ...
# 15895     0.419938
# 15896     0.000000
# 15897     0.450292
# 15898     0.428000
# 15899     0.000000
#
# [15029 rows x 17 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15029 entries, 0 to 15899
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   15029 non-null  object
#  1   price         15029 non-null  int32
#  2   priceD        15029 non-null  object
#  3   powerStatusD  15029 non-null  object
#  4   carpetArea    15029 non-null  float64
#  5   sqFtPrice     15029 non-null  float64
#  6   furnishedD    15029 non-null  object
#  7   balconiesD    9279 non-null   float64
#  8   bathD         14989 non-null  float64
#  9   parkingD      15029 non-null  object
#  10  facingD       7999 non-null   object
#  11  ctName        15029 non-null  object
#  12  bedroomD      15029 non-null  float64
#  13  floors        15029 non-null  float64
#  14  coveredArea   15029 non-null  float64
#  15  carpAreaUnit  15029 non-null  object
#  16  areaPercent   15029 non-null  float64
# dtypes: float64(8), int32(1), object(8)
# memory usage: 2.5+ MB

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ('Ready to Move',
#  11199600,
#  '1.11 Cr',
#  'No/Rare Powercut',
#  1017.0,
#  6100.0,
#  'Unfurnished',
#  1.0,
#  3.0,
#  '1 Covered, 1 Open',
#  'North - East',
#  'Ahmedabad',
#  3.0,
#  14.0,
#  1836.0,
#  'Sq-ft',
#  0.44607843137254904)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'carpetArea',
#  'sqFtPrice',
#  'furnishedD',
#  'balconiesD',
#  'bathD',
#  'parkingD',
#  'facingD',
#  'ctName',
#  'bedroomD',
#  'floors',
#  'coveredArea',
#  'carpAreaUnit',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2-2.9.9-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 1.1 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.2 MB 1.9 MB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.3 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
city = 'Ahmedabad'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 29
