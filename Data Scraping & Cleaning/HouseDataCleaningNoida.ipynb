# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsNoida.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'zUAHudZPV6tzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': '5JnxdSvxM9NzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': 'JVxo5E9ErztzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': '9kn+3kjPKHJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': 'rcFs9JUGdhNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': 'EeCEWsLY/CBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': '25pRAH0t4XlzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': 'yPSXRqiy5TBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': 'GvxrPHGmPPRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'G++Yp4Pn7AtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        299  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        300  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        301  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        302  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        303  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        304  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        305  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        306  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        307  \
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        308
# nsrResultList                                                         None
# resultList               [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 307 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'zUAHudZPV6tzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': '5JnxdSvxM9NzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'JVxo5E9ErztzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': '9kn+3kjPKHJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': 'rcFs9JUGdhNzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': 'EeCEWsLY/CBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': '25pRAH0t4XlzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': 'yPSXRqiy5TBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': 'GvxrPHGmPPRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'G++Yp4Pn7AtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       299  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       300  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       301  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       302  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       303  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       304  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       305  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       306  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       307  \
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       308
# resultList              [{'encId': 'CWuL1g1OxChzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 307 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "Noida"

# %%
house_data
# Out:
#                          encId         possStatusD pmtSource availableFrom  \
# 0     zUAHudZPV6tzpSvf+uAgZw==  Under Construction       Web       Apr '28
# 1     VZjGG5JqG4VzpSvf+uAgZw==  Under Construction       Web       Jul '28
# 2     QOHF8fL11qRzpSvf+uAgZw==  Under Construction       Web       Sep '24
# 3     Q+Hxfpuv3J9zpSvf+uAgZw==  Under Construction       Web       Oct '27
# 4     lAI9d1yosdBzpSvf+uAgZw==       Ready to Move       Web           NaN
# ...                        ...                 ...       ...           ...
# 9205  F963HXipyH9zpSvf+uAgZw==       Ready to Move   Project       Oct '22
# 9206  1N60+o5RNWlzpSvf+uAgZw==             Apr '28   Project           NaN
# 9207  pCAVX7K1/vhzpSvf+uAgZw==  Under Construction   android       Mar '25
# 9208  MiCk7dCV6W9zpSvf+uAgZw==  Under Construction       Web       Dec '27
# 9209  bAIzb/Tq5TFzpSvf+uAgZw==  Under Construction       Web       Jul '28
#
#      cntvl                                                url floorNo  noBfCt  \
# 0     1250  3-BHK-3270-Sq-ft-Multistorey-Apartment-FOR-Sal...       7       0
# 1      140  3-BHK-2304-Sq-ft-Multistorey-Apartment-FOR-Sal...      12       0
# 2      100  3-BHK-1404-Sq-ft-Multistorey-Apartment-FOR-Sal...      12       0
# 3      140  3-BHK-2555-Sq-ft-Multistorey-Apartment-FOR-Sal...      12       0
# 4      100  3-BHK-1385-Sq-ft-Multistorey-Apartment-FOR-Sal...      11       0
# ...    ...                                                ...     ...     ...
# 9205   850  2-BHK-1050-Sq-ft-Multistorey-Apartment-FOR-Sal...     NaN       0
# 9206   850  3-BHK-1608-Sq-ft-Multistorey-Apartment-FOR-Sal...     NaN       0
# 9207   100  2-BHK-1100-Sq-ft-Multistorey-Apartment-FOR-Sal...      24       0
# 9208   NaN  3-BHK-1800-Sq-ft-Multistorey-Apartment-FOR-Sal...      10       0
# 9209   140  3-BHK-2034-Sq-ft-Multistorey-Apartment-FOR-Sal...       9       0
#
#        st modstat  ...  pmtUsp2Wap crisilRv1 crisilRv2  crisilRv2CtBy  \
# 0     509   20203  ...         NaN       NaN       NaN            NaN
# 1     509   20203  ...         NaN       NaN       NaN            NaN
# 2     509   20205  ...         NaN       NaN       NaN            NaN
# 3     509   20205  ...         NaN       NaN       NaN            NaN
# 4     509   20205  ...         NaN       NaN       NaN            NaN
# ...   ...     ...  ...         ...       ...       ...            ...
# 9205  509   20205  ...         NaN       NaN       NaN            NaN
# 9206  509   20203  ...         NaN       NaN       NaN            NaN
# 9207  509   20205  ...         NaN       NaN       NaN            NaN
# 9208  509   20205  ...         NaN       NaN       NaN            NaN
# 9209  509   20205  ...         NaN       NaN       NaN            NaN
#
#      crircname1 crircname2 gateComm pfAgCg iTarget   city
# 0           NaN        NaN      NaN    NaN     NaN  Noida
# 1           NaN        NaN      NaN    NaN     NaN  Noida
# 2           NaN        NaN      NaN    NaN     NaN  Noida
# 3           NaN        NaN      NaN    NaN     NaN  Noida
# 4           NaN        NaN      NaN    NaN     NaN  Noida
# ...         ...        ...      ...    ...     ...    ...
# 9205        NaN        NaN      NaN    NaN     NaN  Noida
# 9206        NaN        NaN      NaN    NaN     NaN  Noida
# 9207        NaN        NaN      NaN    NaN     NaN  Noida
# 9208        NaN        NaN      NaN    NaN     NaN  Noida
# 9209        NaN        NaN      NaN    NaN     NaN  Noida
#
# [9210 rows x 262 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# availableFrom
# cntvl
# url
# floorNo
# noBfCt
# st
# modstat
# appVer
# appSub
# deviceType
# lastAccessDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# cScore
# devName
# postDateT
# endDateT
# pl
# luxAmenities
# luxAmenitiesD
# availUnit
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# seoDesc
# psmUspImgWeb
# psmUspImgMob
# psmImage
# propCat
# id
# pmtmtrendPercentage
# flooringTyD
# adroomD
# powerStatusD
# maintenanceD
# sv
# cg
# pp
# bookingAmtExact
# dImgSrc
# landmark
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# ac
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# companyname
# contName
# auto_desc
# prjname
# sqFtPrD
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# supV
# lmtDName
# pkgid
# agComCt
# achTdS
# opSn
# opSnD
# sid
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# isVis
# showupfront
# agtCerStatus
# isRera
# reraId
# caCompNameD
# postedLabelD
# OwnershipTypeD
# furnishedD
# balconiesD
# bathD
# parkingD
# facingD
# amenFacingD
# transactionTypeD
# floorD
# propTypeD
# ctName
# bedroomD
# userType
# transType
# agentDetailUrl
# isprimeListingType
# floors
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# psmImgCt
# waterStatus
# isLuxury
# coveredArea
# covAreaUnit
# modifiedDate
# image
# actualOwner
# amenities
# isProjProp
# devId
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# pckCon
# ctCurr
# ctLast
# endDt
# newUrl
# catAdd1
# seoPsmDt
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# operatingSinceYear
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# investorlisting
# investorguide
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# isLuxuryServiceAvailable
# luxAmenMap
# nonluxAmenMap
# ctaDetailBean
# sendbirdId
# appovedAuthC
# nriPref
# dues
# propertyImageNew
# agtCrSt
# maintenanceCharges
# carpetArea
# imageDate
# isPreferred
# carpAreaUnit
# ranPropImg
# agentContinuityStr
# isReraAgent
# agentReraState
# rEcd
# taImg
# crisilRv1CtBy
# crisilNoOfEmployees
# crisilStarRating
# crisilOpSinceYear
# imgUrl
# lCtDate
# lastReplyDate
# acD
# ltOther
# pmtUspWap
# pmtUsp
# brokerConnect
# smartDiaryApiTag
# psmapproved
# pmtUsp1
# possBy
# prjHl1
# prjLtHl1
# prjSrc
# siteVisitProp
# prjid
# tag
# tagWap
# criLogo
# dealDesc
# pmtTCabin
# la
# landAreaUnit
# landAreaUnitD
# pbrk
# pbrkp
# dimD
# floorCsntrAllowed
# rdWidth
# nOs
# isExcl
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# noOfSVis
# adCn
# sVisMinDt
# sVisMaxDt
# isCornerPlot
# comPantry
# psmpreferred
# vl
# appExcRe
# cpmp
# pmtUsp2
# pmtUsp2Wap
# crisilRv1
# crisilRv2
# crisilRv2CtBy
# crircname1
# crircname2
# gateComm
# pfAgCg
# iTarget
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId QOHF8fL11qRzpSvf+uAgZw== Q+Hxfpuv3J9zpSvf+uAgZw==
# possStatusD Under Construction Under Construction
# pmtSource Web Web
# availableFrom Sep '24 Oct '27
# cntvl 100 140
# url 3-BHK-1404-Sq-ft-Multistorey-Apartment-FOR-Sale-Sector-150-in-Noida&id=4d423731373333313233 3-BHK-2555-Sq-ft-Multistorey-Apartment-FOR-Sale-Sector-150-in-Noida-r1&id=4d423633323738383133
# floorNo 12 12
# noBfCt 0 0
# st 509 509
# modstat 20205 20205
# appVer 418.0 337.0
# appSub Y Y
# deviceType and ios
# lastAccessDate 1710095400000.0 1710181800000.0
# projectSocietyLink eldeco-live-by-the-greens-sector-150-noida-pdpid-4d4235313139363239 prateek-canary-sector-150-noida-pdpid-4d4235313236353535
# sipro 71148791 71061653 71222305 71293631 70912971 71305109 71145791 71183201
# comFlag Y Y
# appExc N N
# cScore 80 95
# devName Eldeco Prateek Group
# postDateT 2024-03-11T23:45:42.000Z 2024-03-11T23:45:38.000Z
# endDateT 2024-05-10T23:45:42.000Z 2024-05-10T23:45:38.000Z
# pl Y Y
# luxAmenities 12229 12230 12223 12214 12216 12217 12239 12225 12538 12533 12524 12215 12224 12229 12230 12221 12223 12214 12216 12217 12227
# luxAmenitiesD Jogging and Strolling Track,Outdoor Tennis Courts,RO Water System,Service/Goods Lift,Visitor Parking,Intercom Facility Concierge Services,Bar/Lounge,Fingerprint Access,Health club with Steam / Jaccuzi,Golf Course,Air Conditioned,Banquet Hall,Jogging and Strolling Track,Outdoor Tennis Courts,Internet/Wi-Fi Connectivity,RO Water System,Service/Goods Lift,Visitor Parking,Intercom Facility,Conference Room
# availUnit 3.0 5.0
# enc_Id QOHF8fL11qQVDQWJFhHUuQ== Q+Hxfpuv3J+Tr0Bo6ZOU9w==
# cowDays 0 0
# price 12000000.0 30000000.0
# priceD 1.20 Cr 3 Cr
# imgCt 33 25
# landmarkDetails ['19201|2.9 Km from Stellar Business Park', '19210|3.2 Km from Sector 148 Metro', '19202|3.1 Km from K R Managalam World School Galgotia University'] ['19201|2.9 Km from Stellar Business Park', '19210|3.2 Km from Sector 148 Metro', '19202|3.1 Km from K R Managalam World School Galgotia University']
# seoDesc A  3 BHK flat is available for sale in Sector 150, Noida. This flat is situated within Eldeco Live By The Greens. This flat for resale is a choice property. You can buy this under construction flat in Sector 150 at a reasonable price of INR 1.20 Cr. This flat is available for possession on Sep '24. You will find it unfurnished. Prominent landmarks in and around this locality are sector 148 metro, noida expressway. Sector 150, Noida has a 3 BHK apartment for sale with various amenities. It enjoys a prime location within Prateek Canary. This flat that is available for sale is a good investment. This apartment in one of the significant areas of Sector 150 is under construction, and can be purchased at the best price of INR 3 Cr. Its possession date is Oct '27. You will find it semi-furnished. Some of the landmarks near the flat include golf course metro station 45 meter road adjacent..
# psmUspImgWeb Lawn Tennis Court|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Web-31-Eldeco-Live-By-The-Greens-Noida-5119629_470_689_310_462.jpg,Cricket Academy by Rohit Sharma|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Web-27-Eldeco-Live-By-The-Greens-Noida-5119629_470_689_310_462.jpg nan
# psmUspImgMob Lawn Tennis Court|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Mob-30-Eldeco-Live-By-The-Greens-Noida-5119629_380_324_310_462.jpg,Huge Swimming Pool|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Mob-29-Eldeco-Live-By-The-Greens-Noida-5119629_470_689_310_462.jpg,Huge Swimming Pool|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Mob-28-Eldeco-Live-By-The-Greens-Noida-5119629_380_324_310_462.jpg,Cricket Academy by Rohit Sharma|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/09/18/USP-Mob-26-Eldeco-Live-By-The-Greens-Noida-5119629_380_324_310_462.jpg nan
# psmImage https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/05/22/Project-Photo-22-Eldeco-Live-By-The-Greens-Noida-5119629_345_1366_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2020/12/11/Project-Photo-8-Prateek-Canary-Noida-5126555_345_1366_310_462.jpg
# propCat 20292 20292
# id 71733123 63278813
# pmtmtrendPercentage 0 0
# flooringTyD Vitrified,Wooden Vitrified,Wooden
# adroomD None of these Servant Room
# powerStatusD No/Rare Powercut No/Rare Powercut
# maintenanceD Monthly Monthly
# sv Y nan
# cg b b
# pp Z Z
# bookingAmtExact 200000 200000
# dImgSrc 11120 11120
# landmark Sector 148 metro, Noida Expressway Golf course Metro station 45 meter road adjacent.
# seoLtSc 13 13
# pSc 0 0
# pCct 0 0
# lCct 0 0
# pcTcCt 0 0
# ac 10080.0 10080.0
# caSqFt 1404.0 2555.0
# ltcoordGeo 28.421663,77.488898 28.421663,77.488898
# iba X X
# ct 6403 6403
# lt 88670.0 88670.0
# loc 88670.0 88670.0
# bd 11702 11702
# ca 1404 2555
# ty 10002 10002
# dtldesc Apartment available for sale in Eldeco Live by the greens park facing. Call for more details We all dream of a home which fulfills our wishes of living in a luxurious apartment where all the facilities are served with zero interruption. Well, here we present Canary by Prateek Group in sector 150, Noida. Prateek canary is a panoramic housing project which gives you the ultimate experience of the modern and advanced lifestyle. Prateek Canary provides remarkable amenities for adults and children.What are the key details of the projectPrateek Canary has 3BHK and 4BHK apartments to offer with the carpet units of 1,700  6,100 sq. ft.
# plgdtldesc Apartment available for sale in Eldeco Live by the greens park facing. Call for more details We all dream of a home which fulfills our wishes of living in a luxurious apartment where all the facilities are served with zero interruption. Well, here we present Canary by Prateek Group in sector 150, Noida. Prateek canary is a panoramic housing project which gives you the ultimate experience of the modern and advanced lifestyle. Prateek Canary provides remarkable amenities for adults and children.What are the key details of the projectPrateek Canary has 3BHK and 4BHK apartments to offer with the carpet units of 1,700  6,100 sq. ft.
# oid 29883849 41061877
# oname Devendra Tripathi ADESH BANSAL
# sdp Y Y
# companyname Bluecrumbs New Door Realty
# contName Devendra  Adesh Bansal
# auto_desc 3 BHK, Multistorey Apartment is available for Sale in Sector 150, Noida for 1.2 Crore(s) 3 BHK, Multistorey Apartment is available for Sale in Sector 150, Noida for 3.0 Crore(s)
# prjname Eldeco Live By The Greens Prateek Canary
# sqFtPrD 8547.0 11741.0
# pkg 10075 10198
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 28.421663 28.421663
# pmtLong 77.488898 77.488898
# moisd 50 50
# supV Y Y
# lmtDName Sector 150, Pusta Road Sector 150, Pusta Road
# pkgid 286287 286287
# agComCt 2.0 nan
# achTdS 94 105
# opSn 11099 11086
# opSnD 2004 1991
# sid 13520,13558,13502 13520,13558,13502
# locSeoName Sector 150 Sector 150
# propImg 2023/05/22/Project-Photo-34-Eldeco-Live-By-The-Greens-Noida-5119629_720_1280.jpg 2020/12/11/Project-Photo-10-Prateek-Canary-Noida-5126555_600_800.jpg
# coverAreaUnitD Sq-ft Sq-ft
# ppd 20240312 20240312
# ppdL 1710200742000 1710200738000
# achTm 26 37
# achTmS 26 37
# soc Y Y
# tmsrt 051542 051538
# ecd 20240312 20240312
# prm y y
# sqFtPrice 8547.0 11742.0
# psmid 5119629 5126555
# isVis N N
# showupfront N N
# agtCerStatus Y Y
# isRera Y Y
# reraId UPRERAPRJ15172 UPRERAPRJ591510
# caCompNameD Bluecrumbs New Door Realty
# postedLabelD Posted Yesterday Posted Yesterday
# OwnershipTypeD Leasehold Leasehold
# furnishedD Unfurnished Semi-Furnished
# balconiesD 3 3
# bathD 2 4
# parkingD 1 Covered 2 Covered
# facingD North - East North - East
# amenFacingD Garden/Park Garden/Park, Pool, Main Road
# transactionTypeD Resale New Property
# floorD 12 of 22 Floor 12 of 28 Floor
# propTypeD Apartment Apartment
# ctName Noida Noida
# bedroomD 3 3
# userType Agent Agent
# transType Sale Sale
# agentDetailUrl nan nan
# isprimeListingType nan nan
# floors 22 28
# dImgRf PROJ2175089 PROJ1745339
# localityPhoto 0 0
# defaultAdddressGoogle Noida, Delhi NCR Noida, Delhi NCR
# propertyTitle 3BHK Multistorey Apartment for Resale in Eldeco Live By The Greens at Sector 150, Pusta Road 3BHK Multistorey Apartment for New Property in Prateek Canary at Sector 150, Pusta Road
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbimages/project/Photo_h80_w120/2023/05/22/Project-Photo-34-Eldeco-Live-By-The-Greens-Noida-5119629_720_1280_80_120.jpg https://img.staticmb.com/mbimages/project/Photo_h80_w120/2020/12/11/Project-Photo-10-Prateek-Canary-Noida-5126555_600_800_80_120.jpg
# wapImgUrl1 https://img.staticmb.com/mbimages/project/Photo_h100_w150/2023/05/22/Project-Photo-34-Eldeco-Live-By-The-Greens-Noida-5119629_720_1280_100_150.jpg https://img.staticmb.com/mbimages/project/Photo_h100_w150/2020/12/11/Project-Photo-10-Prateek-Canary-Noida-5126555_600_800_100_150.jpg
# seoURL propertyDetails-3-BHK-1404-Sqft-Flat-FOR-Sale-Sector-150-in-Noida&id=QOHF8fL11qRzpSvf+uAgZw==&category=Sale propertyDetails-3-BHK-2555-Sqft-Flat-FOR-Sale-Sector-150-in-Noida-r1&id=Q+Hxfpuv3J9zpSvf+uAgZw==&category=Sale
# psmImgCt 33 28
# waterStatus Water Availability 24 Hours Available Water Availability 24 Hours Available
# isLuxury F F
# coveredArea 1404 2555
# covAreaUnit 12800 12800
# modifiedDate Yesterday Yesterday
# image https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/05/22/Project-Photo-34-Eldeco-Live-By-The-Greens-Noida-5119629_720_1280_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2020/12/11/Project-Photo-10-Prateek-Canary-Noida-5126555_600_800_310_462.jpg
# actualOwner 29883849 41061877
# amenities 12201 12202 12204 12205 12206 12207 12208 12209 12211 12213 12214 12216 12217 12218 12219 12223 12228 12229 12230 12201 12202 12203 12204 12205 12206 12207 12208 12209 12211 12214 12215 12216 12217 12219 12221 12222 12223 12224 12225 12226 12227 12228 12229 12230 12239 12524 12533 12538
# isProjProp N N
# devId 57716 54958
# pglmtkey 29883849_2 41061877_1
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 1402501.4 1051876.5
# sortCode1b 3952501.2 3856876.5
# sortCode22 0.0 0.0
# sortCode26 1402500.0 876562.5
# ubicnt 50 50
# pckCon 0.3 2.33
# ctCurr 25 126
# ctLast 0 0
# endDt May 11, '24 May 11, '24
# newUrl project-eldeco-live-by-the-greens-for-sale-in-noida-pppfs project-prateek-canary-for-sale-in-noida-pppfs
# catAdd1 Sector 150,Noida Sector 150,Noida
# seoPsmDt {"usp":["Cafe and Swimming Pool","Acres of Greens","Spectacular River View","Crickingdom Cricket Academy by Rohit Sharma"],"bhkPriceRange":{"3 BHK":{"minPrice":"1.0 Cr","maxPrice":"1.60 Cr"},"2 BHK":{"minPrice":"81.0 Lac","maxPrice":"1.22 Cr"}}} {"bhkPriceRange":{"3 BHK":{"minPrice":"1.05 Cr","maxPrice":"1.17 Cr"}}}
# pmtdesc_hi नॉएडा के प्राइम लोकेशन सेक्टर 150 में स्थित बिक्री के लिए उपलब्ध यह बड़ा सा 3 BHK फ्लैट एक बहुत ही अच्छी तरह से बनाये गए प्रोजेक्ट का हिस्सा है। यह फ्लैट एल्डेको लाइव बाय दी ग्रीन्स कॉम्पलेक्स के भीतर एक बेहतरीन जगह पर है। यहां रहने वाले लोगों की सुविधा के लिए, फ्लैट में 2 बाथरूम हैं। गाड़ी को खड़ी करने के लिए इस 3 BHK अपार्टमेंट के साथ 1कवर्ड पार्किंग की जगह उपलब्ध है। रेसले के लिए सही अपार्टमेंट की आपकी तलाश इस अपार्टमेंट को देखते ही खत्म हो जायेगी। यह अंडर कंस्ट्रक्शन फ्लैट रु. 1.20 Cr की किफायती मूल्य पर उपलब्ध है। पज़ेशन की तारीख - जब खरीदार को फ्लैट दिया जाता है - इस प्रॉपर्टी के लिए Sep '24 है। यह घर अनफर्निश्ड है, इसलिए आप इसे खरीदने का सोच सकते हैं। एल्डेको लाइव बाय दी ग्रीन्स में जॉगिंग एंड स्ट्रॉलिंग ट्रैक, आउटडोर टेनिस कोर्ट्स, आरओ वॉटर सिस्टम, सर्विस/गुड्स लिफ्ट, विजिटर पार्किंग सहित कई सुविधाएं उपलब्ध हैं।  नॉएडा के प्रीमियम सेक्टर 150 में स्थित यह रेडी टू मूव-इन 3 BHK फ्लैट बिक्री के लिए उपलब्ध है। प्रतीक कैनरी में बेहतरीन तरीके से डिज़ाइन किए गए अपार्टमेंट में रहते हुए अच्छी लाइफस्टाइल के अपने अनुभव को बढ़ाएं। यहां रहने वाले लोगों की सुविधा के लिए 4 बाथरूम हैं। अपनी गाड़ी को पार्क करने के लिए, इस 3 BHK फ्लैट के साथ 2कवर्ड पार्किंग की जगह उपलब्ध है। यह फ्लैट सेल प्रॉपर्टी के रूप में उपलब्ध है। सेक्टर 150 में स्थित रु. 3 Cr के उचित बिक्री मूल्य के लिए उपलब्ध, यह अंडर कंस्ट्रक्शन अपार्टमेंट एक शानदार मौका है। फ्लैट के पज़ेशन की तारीख Oct '27 है। यह एक सेमि-फर्निश्ड अपार्टमेंट है। प्रतीक कैनरी में अच्छी क्वालिटी के साथ कंसीर्ज सर्विसेज, बार/लाउन्ज, फिंगरप्रिंट एक्सेस, हेल्थ क्लब विथ स्टीम / जकूज़ी, गोल्फ कोर्स जैसी हर तरह की सुविधाएं मिलती है, जिससे आप आराम से रह सके।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# operatingSinceYear 2004 1991
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc Sq-ft Sq-ft
# investorlisting N N
# investorguide N N
# ampDesc Apartment available for sale in Eldeco Live by the greens park facing. Call for more details We all dream of a home which fulfills our wishes of living in a luxurious apartment where all the fa
# b2cCardEligibility false false
# maskedMobileNumber +91-81XXXXXXX86 +91-78XXXXXXX15
# isLuxuryServiceAvailable False False
# luxAmenMap {'12229': 'Jogging and Strolling Track', '12230': 'Outdoor Tennis Courts', '12223': 'RO Water System', '12214': 'Service/Goods Lift'} {'12239': 'Concierge Services', '12225': 'Bar/Lounge', '12538': 'Fingerprint Access', '12533': 'Health club with Steam / Jaccuzi'}
# nonluxAmenMap {} {}
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# sendbirdId deefb6dc-cb65-4013-a263-d07d95f84e92info9952 nan
# appovedAuthC NOIDA NOIDA
# nriPref nan nan
# dues nan nan
# propertyImageNew nan https://img.staticmb.com/mbphoto/property/cropped_images/2022/Oct/04/Photo_h180_w240/63278813_2_CEParkway-5_180_240.jpg
# agtCrSt Y Y
# maintenanceCharges 5000 7500
# carpetArea 827 1618
# imageDate nan nan
# isPreferred false false
# carpAreaUnit Sq-ft Sq-ft
# ranPropImg nan nan
# agentContinuityStr nan 100+ Buyers Served
# isReraAgent Y Y
# agentReraState UPRERAAGT16897 UPRERAAGT23820
# rEcd 20240312 20240312
# taImg nan Profile-1-41061877_133_199.jpeg
# crisilRv1CtBy nan lalit Sharma
# crisilNoOfEmployees nan 10
# crisilStarRating nan 4
# crisilOpSinceYear nan 2014
# imgUrl nan https://img.staticmb.com/mbimages/user/Photo_h75_w75/41061877_WhatsAppImage20220919at74823PM_75_75.jpeg
# lCtDate nan nan
# lastReplyDate nan nan
# acD nan nan
# ltOther nan nan
# pmtUspWap nan nan
# pmtUsp nan nan
# brokerConnect nan nan
# smartDiaryApiTag nan nan
# psmapproved nan nan
# pmtUsp1 nan nan
# possBy nan nan
# prjHl1 nan nan
# prjLtHl1 nan nan
# prjSrc nan nan
# siteVisitProp nan nan
# prjid nan nan
# tag nan nan
# tagWap nan nan
# criLogo nan nan
# dealDesc nan nan
# pmtTCabin nan nan
# la nan nan
# landAreaUnit nan nan
# landAreaUnitD nan nan
# pbrk nan nan
# pbrkp nan nan
# dimD nan nan
# floorCsntrAllowed nan nan
# rdWidth nan nan
# nOs nan nan
# isExcl nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# noOfSVis nan nan
# adCn nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# isCornerPlot nan nan
# comPantry nan nan
# psmpreferred nan nan
# vl nan nan
# appExcRe nan nan
# cpmp nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# crisilRv1 nan nan
# crisilRv2 nan nan
# crisilRv2CtBy nan nan
# crircname1 nan nan
# crircname2 nan nan
# gateComm nan nan
# pfAgCg nan nan
# iTarget nan nan
# city Noida Noida

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"pSc",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"appExcRe",
"pbrk",
"pbrkp",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#              possStatusD                                       luxAmenities  \
# 0     Under Construction  12562 12528 12522 12236 12239 12556 12521 1223...
# 1     Under Construction  12562 12528 12235 12239 12532 12237 12225 1253...
# 2     Under Construction                12229 12230 12223 12214 12216 12217
# 3     Under Construction  12239 12225 12538 12533 12524 12215 12224 1222...
# 4          Ready to Move  12521 12533 12524 12224 12229 12220 12221 1222...
# ...                  ...                                                ...
# 9205       Ready to Move                                                NaN
# 9206             Apr '28                                                NaN
# 9207  Under Construction  12225 12215 12224 12229 12230 12221 12223 1221...
# 9208  Under Construction  12562 12235 12239 12532 12521 12225 12238 1221...
# 9209  Under Construction  12562 12528 12235 12239 12532 12237 12225 1253...
#
#                                           luxAmenitiesD       price   priceD  \
# 0     Smart Home,Skydeck,Private jaccuzi,Island Kitc...  59000000.0  5.90 Cr
# 1     Smart Home,Skydeck,Wrap Around Balcony,Concier...  32256000.0  3.22 Cr
# 2     Jogging and Strolling Track,Outdoor Tennis Cou...  12000000.0  1.20 Cr
# 3     Concierge Services,Bar/Lounge,Fingerprint Acce...  30000000.0     3 Cr
# 4     Private pool ,Health club with Steam / Jaccuzi...  14000000.0  1.40 Cr
# ...                                                 ...         ...      ...
# 9205                                                NaN  11550000.0  1.15 Cr
# 9206                                                NaN  13989600.0  1.39 Cr
# 9207  Bar/Lounge,Air Conditioned,Banquet Hall,Joggin...  12750000.0  1.27 Cr
# 9208  Smart Home,Wrap Around Balcony,Concierge Servi...  25000000.0  2.50 Cr
# 9209  Smart Home,Skydeck,Wrap Around Balcony,Concier...  28476000.0  2.84 Cr
#
#           powerStatusD maintenanceD  sqFtPrD  sqFtPrice OwnershipTypeD  ...  \
# 0     No/Rare Powercut      Monthly  18042.0    18043.0      Leasehold  ...
# 1     No/Rare Powercut      Monthly  15858.0    14000.0      Leasehold  ...
# 2     No/Rare Powercut      Monthly   8547.0     8547.0      Leasehold  ...
# 3     No/Rare Powercut      Monthly  11741.0    11742.0      Leasehold  ...
# 4     No/Rare Powercut      Monthly  10108.0    10108.0      Leasehold  ...
# ...                ...          ...      ...        ...            ...  ...
# 9205  No/Rare Powercut          NaN  11000.0    11000.0            NaN  ...
# 9206  No/Rare Powercut          NaN   8700.0     8700.0            NaN  ...
# 9207               NaN          NaN  11591.0    11591.0      Leasehold  ...
# 9208  No/Rare Powercut      Monthly  13888.0    13889.0       Freehold  ...
# 9209  No/Rare Powercut      Monthly  14000.0    14000.0      Leasehold  ...
#
#      carpAreaUnit psmpreferred   vl crisilRv1 crisilRv2 crisilRv2CtBy  \
# 0             NaN          NaN  NaN       NaN       NaN           NaN
# 1           Sq-ft          NaN  NaN       NaN       NaN           NaN
# 2           Sq-ft          NaN  NaN       NaN       NaN           NaN
# 3           Sq-ft          NaN  NaN       NaN       NaN           NaN
# 4             NaN          NaN  NaN       NaN       NaN           NaN
# ...           ...          ...  ...       ...       ...           ...
# 9205          NaN          NaN  NaN       NaN       NaN           NaN
# 9206          NaN          NaN    Y       NaN       NaN           NaN
# 9207          NaN          NaN  NaN       NaN       NaN           NaN
# 9208        Sq-ft          NaN  NaN       NaN       NaN           NaN
# 9209        Sq-ft          NaN  NaN       NaN       NaN           NaN
#
#      crircname1 crircname2 iTarget   city
# 0           NaN        NaN     NaN  Noida
# 1           NaN        NaN     NaN  Noida
# 2           NaN        NaN     NaN  Noida
# 3           NaN        NaN     NaN  Noida
# 4           NaN        NaN     NaN  Noida
# ...         ...        ...     ...    ...
# 9205        NaN        NaN     NaN  Noida
# 9206        NaN        NaN     NaN  Noida
# 9207        NaN        NaN     NaN  Noida
# 9208        NaN        NaN     NaN  Noida
# 9209        NaN        NaN     NaN  Noida
#
# [9210 rows x 36 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD           61
# luxAmenities        4177
# luxAmenitiesD       4181
# price                 74
# priceD                 0
# powerStatusD        2239
# maintenanceD        6009
# sqFtPrD              125
# sqFtPrice            134
# OwnershipTypeD      4877
# furnishedD            57
# balconiesD          4424
# bathD                 51
# parkingD            3134
# facingD             4943
# floorD              3453
# ctName                 0
# bedroomD               0
# floors              3698
# coveredArea           73
# covAreaUnit           73
# image                500
# amenities           3359
# ctLast              4120
# propertyImageNew    5847
# carpetArea          6526
# carpAreaUnit        6528
# psmpreferred        9204
# vl                  8257
# crisilRv1           9209
# crisilRv2           9209
# crisilRv2CtBy       9209
# crircname1          9209
# crircname2          9209
# iTarget             8496
# city                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD            0
# luxAmenities        4177
# luxAmenitiesD       4181
# price                 74
# priceD                 0
# powerStatusD        2239
# maintenanceD        6009
# sqFtPrD              125
# sqFtPrice            134
# OwnershipTypeD      4877
# furnishedD            57
# balconiesD          4424
# bathD                 51
# parkingD            3134
# facingD             4943
# floorD              3453
# ctName                 0
# bedroomD               0
# floors              3698
# coveredArea           73
# covAreaUnit           73
# image                500
# amenities           3359
# ctLast              4120
# propertyImageNew    5847
# carpetArea          6526
# carpAreaUnit        6528
# psmpreferred        9204
# vl                  8257
# crisilRv1           9209
# crisilRv2           9209
# crisilRv2CtBy       9209
# crircname1          9209
# crircname2          9209
# iTarget             8496
# city                   0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#              possStatusD       price   priceD      powerStatusD  sqFtPrice  \
# 0     Under Construction  59000000.0  5.90 Cr  No/Rare Powercut    18043.0
# 1     Under Construction  32256000.0  3.22 Cr  No/Rare Powercut    14000.0
# 2     Under Construction  12000000.0  1.20 Cr  No/Rare Powercut     8547.0
# 3     Under Construction  30000000.0     3 Cr  No/Rare Powercut    11742.0
# 4          Ready to Move  14000000.0  1.40 Cr  No/Rare Powercut    10108.0
# ...                  ...         ...      ...               ...        ...
# 9205       Ready to Move  11550000.0  1.15 Cr  No/Rare Powercut    11000.0
# 9206             Apr '28  13989600.0  1.39 Cr  No/Rare Powercut     8700.0
# 9207  Under Construction  12750000.0  1.27 Cr               NaN    11591.0
# 9208  Under Construction  25000000.0  2.50 Cr  No/Rare Powercut    13889.0
# 9209  Under Construction  28476000.0  2.84 Cr  No/Rare Powercut    14000.0
#
#           furnishedD balconiesD bathD           parkingD       facingD  ...  \
# 0     Semi-Furnished          4     4          2 Covered  North - East  ...
# 1     Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
# 2        Unfurnished          3     2          1 Covered  North - East  ...
# 3     Semi-Furnished          3     4          2 Covered  North - East  ...
# 4     Semi-Furnished          4     3          1 Covered  South - East  ...
# ...              ...        ...   ...                ...           ...  ...
# 9205     Unfurnished        NaN     2                NaN           NaN  ...
# 9206     Unfurnished        NaN     3          1 Covered           NaN  ...
# 9207     Unfurnished          3     2                NaN          East  ...
# 9208  Semi-Furnished          4     3          1 Covered          East  ...
# 9209  Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
#
#      carpetArea carpAreaUnit psmpreferred   vl crisilRv1 crisilRv2  \
# 0           NaN          NaN          NaN  NaN       NaN       NaN
# 1          1950        Sq-ft          NaN  NaN       NaN       NaN
# 2           827        Sq-ft          NaN  NaN       NaN       NaN
# 3          1618        Sq-ft          NaN  NaN       NaN       NaN
# 4           NaN          NaN          NaN  NaN       NaN       NaN
# ...         ...          ...          ...  ...       ...       ...
# 9205        NaN          NaN          NaN  NaN       NaN       NaN
# 9206        NaN          NaN          NaN    Y       NaN       NaN
# 9207        NaN          NaN          NaN  NaN       NaN       NaN
# 9208       1275        Sq-ft          NaN  NaN       NaN       NaN
# 9209       1710        Sq-ft          NaN  NaN       NaN       NaN
#
#      crisilRv2CtBy crircname1 crircname2 iTarget
# 0              NaN        NaN        NaN     NaN
# 1              NaN        NaN        NaN     NaN
# 2              NaN        NaN        NaN     NaN
# 3              NaN        NaN        NaN     NaN
# 4              NaN        NaN        NaN     NaN
# ...            ...        ...        ...     ...
# 9205           NaN        NaN        NaN     NaN
# 9206           NaN        NaN        NaN     NaN
# 9207           NaN        NaN        NaN     NaN
# 9208           NaN        NaN        NaN     NaN
# 9209           NaN        NaN        NaN     NaN
#
# [9210 rows x 24 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             6949
# Less Than 2 Hour Powercut      17
# 2 To 4 Hours Powercut           3
# Over 6 Hours Powercut           2
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#              possStatusD       price    priceD               powerStatusD  \
# 32         Ready to Move  36000000.0   3.60 Cr  Less Than 2 Hour Powercut
# 73         Ready to Move   8000000.0    80 Lac  Less Than 2 Hour Powercut
# 82    Under Construction  30088000.0      3 Cr  Less Than 2 Hour Powercut
# 102   Under Construction  25900000.0   2.59 Cr  Less Than 2 Hour Powercut
# 155        Ready to Move   9000000.0    90 Lac  Less Than 2 Hour Powercut
# 165        Ready to Move  14090000.0   1.40 Cr  Less Than 2 Hour Powercut
# 187        Ready to Move   9400000.0    94 Lac  Less Than 2 Hour Powercut
# 347        Ready to Move   7000000.0    70 Lac  Less Than 2 Hour Powercut
# 459        Ready to Move   7600000.0    76 Lac  Less Than 2 Hour Powercut
# 553        Ready to Move   4794400.0  47.9 Lac  Less Than 2 Hour Powercut
# 583        Ready to Move  10500000.0   1.05 Cr  Less Than 2 Hour Powercut
# 857        Ready to Move   9000000.0    90 Lac  Less Than 2 Hour Powercut
# 1005       Ready to Move  12000000.0   1.20 Cr  Less Than 2 Hour Powercut
# 1416       Ready to Move   4500000.0    45 Lac  Less Than 2 Hour Powercut
# 1611       Ready to Move  10000000.0      1 Cr  Less Than 2 Hour Powercut
# 1837       Ready to Move   1990000.0  19.9 Lac  Less Than 2 Hour Powercut
# 1954       Ready to Move   3388000.0  33.9 Lac  Less Than 2 Hour Powercut
#
#       sqFtPrice      furnishedD balconiesD bathD           parkingD  \
# 32      16744.0  Semi-Furnished          4     4          2 Covered
# 73       7442.0  Semi-Furnished          2     2          1 Covered
# 82      14166.0  Semi-Furnished          4     4          2 Covered
# 102     14000.0  Semi-Furnished          3     3          2 Covered
# 155      7725.0  Semi-Furnished          4     2          1 Covered
# 165      9090.0  Semi-Furnished          5     2          1 Covered
# 187      6886.0  Semi-Furnished          4     3          1 Covered
# 347      5109.0  Semi-Furnished          4     2          1 Covered
# 459      6667.0  Semi-Furnished          3     2          1 Covered
# 553      3551.0  Semi-Furnished          2     2  1 Covered, 1 Open
# 583      7442.0  Semi-Furnished          3     3          1 Covered
# 857      7463.0  Semi-Furnished          3     2             2 Open
# 1005     7059.0  Semi-Furnished          2     2             1 Open
# 1416     5625.0       Furnished          1     2            20 Open
# 1611     7692.0  Semi-Furnished          1     2             2 Open
# 1837     2970.0  Semi-Furnished        NaN     2          1 Covered
# 1954      311.0  Semi-Furnished        NaN     2                NaN
#
#            facingD  ... carpetArea carpAreaUnit psmpreferred   vl crisilRv1  \
# 32    North - East  ...       1790        Sq-ft          NaN  NaN       NaN
# 73    North - East  ...        875        Sq-ft          NaN  NaN       NaN
# 82            East  ...        NaN          NaN          NaN  NaN       NaN
# 102    South -West  ...       1240        Sq-ft          NaN  NaN       NaN
# 155   North - East  ...        840        Sq-ft          NaN  NaN       NaN
# 165   North - East  ...       1400        Sq-ft          NaN  NaN       NaN
# 187   North - East  ...       1250        Sq-ft          NaN  NaN       NaN
# 347   North - East  ...       1050        Sq-ft          NaN  NaN       NaN
# 459            NaN  ...        NaN          NaN          NaN  NaN       NaN
# 553   North - East  ...       1150        Sq-ft          NaN  NaN       NaN
# 583   North - East  ...       1500        Sq-ft          NaN  NaN       NaN
# 857           East  ...        NaN          NaN          NaN  NaN       NaN
# 1005  North - West  ...       1550        Sq-ft          NaN  NaN       NaN
# 1416          East  ...        650        Sq-ft          NaN  NaN       NaN
# 1611  North - East  ...        NaN          NaN          NaN  NaN       NaN
# 1837          West  ...        NaN          NaN          NaN  NaN       NaN
# 1954  North - East  ...        NaN          NaN          NaN  NaN       NaN
#
#      crisilRv2 crisilRv2CtBy crircname1 crircname2 iTarget
# 32         NaN           NaN        NaN        NaN     NaN
# 73         NaN           NaN        NaN        NaN     NaN
# 82         NaN           NaN        NaN        NaN     NaN
# 102        NaN           NaN        NaN        NaN     NaN
# 155        NaN           NaN        NaN        NaN     NaN
# 165        NaN           NaN        NaN        NaN     NaN
# 187        NaN           NaN        NaN        NaN     NaN
# 347        NaN           NaN        NaN        NaN     NaN
# 459        NaN           NaN        NaN        NaN     NaN
# 553        NaN           NaN        NaN        NaN     NaN
# 583        NaN           NaN        NaN        NaN     NaN
# 857        NaN           NaN        NaN        NaN     NaN
# 1005       NaN           NaN        NaN        NaN     NaN
# 1416       NaN           NaN        NaN        NaN     NaN
# 1611       NaN           NaN        NaN        NaN     NaN
# 1837       NaN           NaN        NaN        NaN     NaN
# 1954       NaN           NaN        NaN        NaN     NaN
#
# [17 rows x 24 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price              74
# priceD              0
# powerStatusD     2239
# sqFtPrice         134
# furnishedD         57
# balconiesD       4424
# bathD              51
# parkingD         3134
# facingD          4943
# ctName              0
# bedroomD            0
# floors           3698
# coveredArea        73
# carpetArea       6526
# carpAreaUnit     6528
# psmpreferred     9204
# vl               8257
# crisilRv1        9209
# crisilRv2        9209
# crisilRv2CtBy    9209
# crircname1       9209
# crircname2       9209
# iTarget          8496
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 9210

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.15364583333333334' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.2832898550782803

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#              possStatusD       price   priceD      powerStatusD  sqFtPrice  \
# 0     Under Construction  59000000.0  5.90 Cr  No/Rare Powercut    18043.0
# 1     Under Construction  32256000.0  3.22 Cr  No/Rare Powercut    14000.0
# 2     Under Construction  12000000.0  1.20 Cr  No/Rare Powercut     8547.0
# 3     Under Construction  30000000.0     3 Cr  No/Rare Powercut    11742.0
# 4          Ready to Move  14000000.0  1.40 Cr  No/Rare Powercut    10108.0
# ...                  ...         ...      ...               ...        ...
# 9205       Ready to Move  11550000.0  1.15 Cr  No/Rare Powercut    11000.0
# 9206             Apr '28  13989600.0  1.39 Cr  No/Rare Powercut     8700.0
# 9207  Under Construction  12750000.0  1.27 Cr  No/Rare Powercut    11591.0
# 9208  Under Construction  25000000.0  2.50 Cr  No/Rare Powercut    13889.0
# 9209  Under Construction  28476000.0  2.84 Cr  No/Rare Powercut    14000.0
#
#           furnishedD balconiesD bathD           parkingD       facingD  ...  \
# 0     Semi-Furnished          4     4          2 Covered  North - East  ...
# 1     Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
# 2        Unfurnished          3     2          1 Covered  North - East  ...
# 3     Semi-Furnished          3     4          2 Covered  North - East  ...
# 4     Semi-Furnished          4     3          1 Covered  South - East  ...
# ...              ...        ...   ...                ...           ...  ...
# 9205     Unfurnished        NaN     2                  0           NaN  ...
# 9206     Unfurnished        NaN     3          1 Covered           NaN  ...
# 9207     Unfurnished          3     2                  0          East  ...
# 9208  Semi-Furnished          4     3          1 Covered          East  ...
# 9209  Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
#
#      carpAreaUnit psmpreferred   vl  crisilRv1 crisilRv2 crisilRv2CtBy  \
# 0           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 1           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 2           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 3           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 4           Sq-ft          NaN  NaN        NaN       NaN           NaN
# ...           ...          ...  ...        ...       ...           ...
# 9205        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9206        Sq-ft          NaN    Y        NaN       NaN           NaN
# 9207        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9208        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9209        Sq-ft          NaN  NaN        NaN       NaN           NaN
#
#      crircname1 crircname2 iTarget areaPercent
# 0           NaN        NaN     NaN    0.000000
# 1           NaN        NaN     NaN    0.153646
# 2           NaN        NaN     NaN    0.410969
# 3           NaN        NaN     NaN    0.366732
# 4           NaN        NaN     NaN    0.000000
# ...         ...        ...     ...         ...
# 9205        NaN        NaN     NaN    0.000000
# 9206        NaN        NaN     NaN    0.000000
# 9207        NaN        NaN     NaN    0.000000
# 9208        NaN        NaN     NaN    0.291667
# 9209        NaN        NaN     NaN    0.159292
#
# [9137 rows x 25 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price              61
# priceD              0
# powerStatusD        0
# sqFtPrice           0
# furnishedD          0
# balconiesD       4409
# bathD              44
# parkingD            0
# facingD          4882
# ctName              0
# bedroomD            0
# floors              0
# coveredArea         0
# carpetArea          0
# carpAreaUnit        0
# psmpreferred     9131
# vl               8184
# crisilRv1        9136
# crisilRv2        9136
# crisilRv2CtBy    9136
# crircname1       9136
# crircname2       9136
# iTarget          8423
# areaPercent         0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#         possStatusD  price          priceD      powerStatusD  sqFtPrice  \
# 1997  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 1999  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2000  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2001  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2004  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# ...             ...    ...             ...               ...        ...
# 2066  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2067  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2068  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2069  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
# 2074  Ready to Move    NaN  Call for Price  No/Rare Powercut        0.0
#
#           furnishedD balconiesD bathD   parkingD facingD  ... carpAreaUnit  \
# 1997     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 1999     Unfurnished          3     3          0     NaN  ...        Sq-ft
# 2000     Unfurnished          4     3          0     NaN  ...        Sq-ft
# 2001     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 2004     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# ...              ...        ...   ...        ...     ...  ...          ...
# 2066  Semi-Furnished          4     2  1 Covered     NaN  ...        Sq-ft
# 2067  Semi-Furnished        NaN     2          0     NaN  ...        Sq-ft
# 2068  Semi-Furnished        NaN     2          0     NaN  ...        Sq-ft
# 2069     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 2074  Semi-Furnished        NaN     2  1 Covered     NaN  ...        Sq-ft
#
#      psmpreferred   vl  crisilRv1 crisilRv2 crisilRv2CtBy crircname1  \
# 1997          NaN  NaN        NaN       NaN           NaN        NaN
# 1999          NaN  NaN        NaN       NaN           NaN        NaN
# 2000          NaN  NaN        NaN       NaN           NaN        NaN
# 2001          NaN  NaN        NaN       NaN           NaN        NaN
# 2004          NaN  NaN        NaN       NaN           NaN        NaN
# ...           ...  ...        ...       ...           ...        ...
# 2066          NaN  NaN        NaN       NaN           NaN        NaN
# 2067          NaN  NaN        NaN       NaN           NaN        NaN
# 2068          NaN  NaN        NaN       NaN           NaN        NaN
# 2069          NaN  NaN        NaN       NaN           NaN        NaN
# 2074          NaN  NaN        NaN       NaN           NaN        NaN
#
#      crircname2 iTarget areaPercent
# 1997        NaN     NaN         0.0
# 1999        NaN     NaN         0.0
# 2000        NaN     NaN         0.0
# 2001        NaN     NaN         0.0
# 2004        NaN     NaN         0.0
# ...         ...     ...         ...
# 2066        NaN     NaN         0.0
# 2067        NaN     NaN         0.0
# 2068        NaN     NaN         0.0
# 2069        NaN     NaN         0.0
# 2074        NaN     NaN         0.0
#
# [61 rows x 25 columns]

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\1780203852.py:2: RuntimeWarning: invalid value encountered in cast
#   house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price               0
# priceD              0
# powerStatusD        0
# sqFtPrice           0
# furnishedD          0
# balconiesD       4409
# bathD              44
# parkingD            0
# facingD          4882
# ctName              0
# bedroomD            0
# floors              0
# coveredArea         0
# carpetArea          0
# carpAreaUnit        0
# psmpreferred     9131
# vl               8184
# crisilRv1        9136
# crisilRv2        9136
# crisilRv2CtBy    9136
# crircname1       9136
# crircname2       9136
# iTarget          8423
# areaPercent         0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['2.33', 'Cr']

# %%
house_data[house_data['price']==0]
# Out:
#         possStatusD  price          priceD      powerStatusD  sqFtPrice  \
# 1997  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 1999  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2000  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2001  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2004  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# ...             ...    ...             ...               ...        ...
# 2066  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2067  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2068  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2069  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
# 2074  Ready to Move      0  Call for Price  No/Rare Powercut        0.0
#
#           furnishedD balconiesD bathD   parkingD facingD  ... carpAreaUnit  \
# 1997     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 1999     Unfurnished          3     3          0     NaN  ...        Sq-ft
# 2000     Unfurnished          4     3          0     NaN  ...        Sq-ft
# 2001     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 2004     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# ...              ...        ...   ...        ...     ...  ...          ...
# 2066  Semi-Furnished          4     2  1 Covered     NaN  ...        Sq-ft
# 2067  Semi-Furnished        NaN     2          0     NaN  ...        Sq-ft
# 2068  Semi-Furnished        NaN     2          0     NaN  ...        Sq-ft
# 2069     Unfurnished        NaN   NaN          0     NaN  ...        Sq-ft
# 2074  Semi-Furnished        NaN     2  1 Covered     NaN  ...        Sq-ft
#
#      psmpreferred   vl  crisilRv1 crisilRv2 crisilRv2CtBy crircname1  \
# 1997          NaN  NaN        NaN       NaN           NaN        NaN
# 1999          NaN  NaN        NaN       NaN           NaN        NaN
# 2000          NaN  NaN        NaN       NaN           NaN        NaN
# 2001          NaN  NaN        NaN       NaN           NaN        NaN
# 2004          NaN  NaN        NaN       NaN           NaN        NaN
# ...           ...  ...        ...       ...           ...        ...
# 2066          NaN  NaN        NaN       NaN           NaN        NaN
# 2067          NaN  NaN        NaN       NaN           NaN        NaN
# 2068          NaN  NaN        NaN       NaN           NaN        NaN
# 2069          NaN  NaN        NaN       NaN           NaN        NaN
# 2074          NaN  NaN        NaN       NaN           NaN        NaN
#
#      crircname2 iTarget areaPercent
# 1997        NaN     NaN         0.0
# 1999        NaN     NaN         0.0
# 2000        NaN     NaN         0.0
# 2001        NaN     NaN         0.0
# 2004        NaN     NaN         0.0
# ...         ...     ...         ...
# 2066        NaN     NaN         0.0
# 2067        NaN     NaN         0.0
# 2068        NaN     NaN         0.0
# 2069        NaN     NaN         0.0
# 2074        NaN     NaN         0.0
#
# [61 rows x 25 columns]

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price               0
# priceD              0
# powerStatusD        0
# sqFtPrice           0
# furnishedD          0
# balconiesD       4368
# bathD              15
# parkingD            0
# facingD          4821
# ctName              0
# bedroomD            0
# floors              0
# coveredArea         0
# carpetArea          0
# carpAreaUnit        0
# psmpreferred     9070
# vl               8123
# crisilRv1        9075
# crisilRv2        9075
# crisilRv2CtBy    9075
# crircname1       9075
# crircname2       9075
# iTarget          8362
# areaPercent         0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array(['North - East', 'South - East', 'East', 'North - West', nan,
#        'South -West', 'North', 'West', 'South'], dtype=object)

# %%
house_data
# Out:
#              possStatusD     price   priceD      powerStatusD  sqFtPrice  \
# 0     Under Construction  59000000  5.90 Cr  No/Rare Powercut    18043.0
# 1     Under Construction  32256000  3.22 Cr  No/Rare Powercut    14000.0
# 2     Under Construction  12000000  1.20 Cr  No/Rare Powercut     8547.0
# 3     Under Construction  30000000     3 Cr  No/Rare Powercut    11742.0
# 4          Ready to Move  14000000  1.40 Cr  No/Rare Powercut    10108.0
# ...                  ...       ...      ...               ...        ...
# 9205       Ready to Move  11550000  1.15 Cr  No/Rare Powercut    11000.0
# 9206             Apr '28  13989600  1.39 Cr  No/Rare Powercut     8700.0
# 9207  Under Construction  12750000  1.27 Cr  No/Rare Powercut    11591.0
# 9208  Under Construction  25000000  2.50 Cr  No/Rare Powercut    13889.0
# 9209  Under Construction  28476000  2.84 Cr  No/Rare Powercut    14000.0
#
#           furnishedD balconiesD bathD           parkingD       facingD  ...  \
# 0     Semi-Furnished          4     4          2 Covered  North - East  ...
# 1     Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
# 2        Unfurnished          3     2          1 Covered  North - East  ...
# 3     Semi-Furnished          3     4          2 Covered  North - East  ...
# 4     Semi-Furnished          4     3          1 Covered  South - East  ...
# ...              ...        ...   ...                ...           ...  ...
# 9205     Unfurnished        NaN     2                  0           NaN  ...
# 9206     Unfurnished        NaN     3          1 Covered           NaN  ...
# 9207     Unfurnished          3     2                  0          East  ...
# 9208  Semi-Furnished          4     3          1 Covered          East  ...
# 9209  Semi-Furnished          4     3  1 Covered, 1 Open  North - East  ...
#
#      carpAreaUnit psmpreferred   vl  crisilRv1 crisilRv2 crisilRv2CtBy  \
# 0           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 1           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 2           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 3           Sq-ft          NaN  NaN        NaN       NaN           NaN
# 4           Sq-ft          NaN  NaN        NaN       NaN           NaN
# ...           ...          ...  ...        ...       ...           ...
# 9205        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9206        Sq-ft          NaN    Y        NaN       NaN           NaN
# 9207        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9208        Sq-ft          NaN  NaN        NaN       NaN           NaN
# 9209        Sq-ft          NaN  NaN        NaN       NaN           NaN
#
#      crircname1 crircname2 iTarget areaPercent
# 0           NaN        NaN     NaN    0.000000
# 1           NaN        NaN     NaN    0.153646
# 2           NaN        NaN     NaN    0.410969
# 3           NaN        NaN     NaN    0.366732
# 4           NaN        NaN     NaN    0.000000
# ...         ...        ...     ...         ...
# 9205        NaN        NaN     NaN    0.000000
# 9206        NaN        NaN     NaN    0.000000
# 9207        NaN        NaN     NaN    0.000000
# 9208        NaN        NaN     NaN    0.291667
# 9209        NaN        NaN     NaN    0.159292
#
# [9076 rows x 25 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9076 entries, 0 to 9209
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   possStatusD    9076 non-null   object
#  1   price          9076 non-null   int32
#  2   priceD         9076 non-null   object
#  3   powerStatusD   9076 non-null   object
#  4   sqFtPrice      9076 non-null   float64
#  5   furnishedD     9076 non-null   object
#  6   balconiesD     4708 non-null   object
#  7   bathD          9061 non-null   object
#  8   parkingD       9076 non-null   object
#  9   facingD        4255 non-null   object
#  10  ctName         9076 non-null   object
#  11  bedroomD       9076 non-null   object
#  12  floors         9076 non-null   object
#  13  coveredArea    9076 non-null   float64
#  14  carpetArea     9076 non-null   object
#  15  carpAreaUnit   9076 non-null   object
#  16  psmpreferred   6 non-null      object
#  17  vl             953 non-null    object
#  18  crisilRv1      1 non-null      object
#  19  crisilRv2      1 non-null      object
#  20  crisilRv2CtBy  1 non-null      object
#  21  crircname1     1 non-null      object
#  22  crircname2     1 non-null      object
#  23  iTarget        714 non-null    object
#  24  areaPercent    9076 non-null   float64
# dtypes: float64(3), int32(1), object(21)
# memory usage: 1.8+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
# house_data['balconiesD'] = house_data['balconiesD'].astype(float)
house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Jul '28", "May '25",
#        "Apr '28", "Sep '29", "Mar '26", "Aug '26", "Nov '27", "Apr '25",
#        "Oct '24"], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Jul '28", "May '25",
#        "Apr '28", "Sep '29", "Mar '26", "Aug '26", "Nov '27", "Apr '25",
#        "Oct '24"], dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 2304.0

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#              possStatusD     price    priceD      powerStatusD  sqFtPrice  \
# 2     Under Construction  12000000   1.20 Cr  No/Rare Powercut     8547.0
# 11         Ready to Move  13500000   1.35 Cr  No/Rare Powercut    10843.0
# 15    Under Construction  13300000   1.33 Cr  No/Rare Powercut     9473.0
# 16    Under Construction  28476000   2.84 Cr  No/Rare Powercut    14000.0
# 20    Under Construction   8274000  82.7 Lac  No/Rare Powercut     7000.0
# ...                  ...       ...       ...               ...        ...
# 9200             May '25  12603500   1.26 Cr  No/Rare Powercut     9100.0
# 9202  Under Construction  15500000   1.55 Cr  No/Rare Powercut    14720.0
# 9205       Ready to Move  11550000   1.15 Cr  No/Rare Powercut    11000.0
# 9206             Apr '28  13989600   1.39 Cr  No/Rare Powercut     8700.0
# 9207  Under Construction  12750000   1.27 Cr  No/Rare Powercut    11591.0
#
#        furnishedD balconiesD  bathD           parkingD       facingD  ...  \
# 2     Unfurnished          3    2.0          1 Covered  North - East  ...
# 11    Unfurnished          2    2.0          1 Covered  North - East  ...
# 15    Unfurnished          3    2.0         11 Covered          East  ...
# 16    Unfurnished          4    3.0  1 Covered, 1 Open  North - East  ...
# 20    Unfurnished          3    2.0          1 Covered  North - East  ...
# ...           ...        ...    ...                ...           ...  ...
# 9200  Unfurnished        NaN    2.0                  0           NaN  ...
# 9202  Unfurnished          3    2.0          1 Covered  North - East  ...
# 9205  Unfurnished        NaN    2.0                  0           NaN  ...
# 9206  Unfurnished        NaN    3.0          1 Covered           NaN  ...
# 9207  Unfurnished          3    2.0                  0          East  ...
#
#      carpAreaUnit  psmpreferred   vl  crisilRv1  crisilRv2 crisilRv2CtBy  \
# 2           Sq-ft           NaN  NaN        NaN        NaN           NaN
# 11          Sq-ft           NaN  NaN        NaN        NaN           NaN
# 15          Sq-ft           NaN  NaN        NaN        NaN           NaN
# 16          Sq-ft           NaN  NaN        NaN        NaN           NaN
# 20          Sq-ft           NaN  NaN        NaN        NaN           NaN
# ...           ...           ...  ...        ...        ...           ...
# 9200        Sq-ft           NaN  NaN        NaN        NaN           NaN
# 9202        Sq-ft           NaN  NaN        NaN        NaN           NaN
# 9205        Sq-ft           NaN  NaN        NaN        NaN           NaN
# 9206        Sq-ft           NaN    Y        NaN        NaN           NaN
# 9207        Sq-ft           NaN  NaN        NaN        NaN           NaN
#
#      crircname1 crircname2 iTarget areaPercent
# 2           NaN        NaN     NaN    0.410969
# 11          NaN        NaN     NaN    0.373494
# 15          NaN        NaN     NaN    0.294872
# 16          NaN        NaN     NaN    0.382989
# 20          NaN        NaN     NaN    0.489848
# ...         ...        ...     ...         ...
# 9200        NaN        NaN       Y    0.000000
# 9202        NaN        NaN     NaN    0.000000
# 9205        NaN        NaN     NaN    0.000000
# 9206        NaN        NaN     NaN    0.000000
# 9207        NaN        NaN     NaN    0.000000
#
# [3306 rows x 25 columns]

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_3152\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, sqFtPrice, furnishedD, balconiesD, bathD, parkingD, facingD, ctName, bedroomD, floors, coveredArea, carpetArea, carpAreaUnit, psmpreferred, vl, crisilRv1, crisilRv2, crisilRv2CtBy, crircname1, crircname2, iTarget, areaPercent]
# Index: []
#
# [0 rows x 25 columns]

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, sqFtPrice, furnishedD, balconiesD, bathD, parkingD, facingD, ctName, bedroomD, floors, coveredArea, carpetArea, carpAreaUnit, psmpreferred, vl, crisilRv1, crisilRv2, crisilRv2CtBy, crircname1, crircname2, iTarget, areaPercent]
# Index: []
#
# [0 rows x 25 columns]

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  sqFtPrice     bathD  bedroomD    floors  coveredArea  \
# price        1.000000  -0.832037  0.262212  0.248341 -0.003297     0.132188
# sqFtPrice   -0.832037   1.000000 -0.024675 -0.018990  0.012526    -0.026441
# bathD        0.262212  -0.024675  1.000000  0.611197 -0.078612     0.543482
# bedroomD     0.248341  -0.018990  0.611197  1.000000  0.010308     0.468307
# floors      -0.003297   0.012526 -0.078612  0.010308  1.000000     0.144722
# coveredArea  0.132188  -0.026441  0.543482  0.468307  0.144722     1.000000
# carpetArea   0.119359  -0.025672  0.510976  0.451673  0.098669     0.942027
# areaPercent  0.004188  -0.003842  0.045185  0.040928  0.223247     0.162034
#
#              carpetArea  areaPercent
# price          0.119359     0.004188
# sqFtPrice     -0.025672    -0.003842
# bathD          0.510976     0.045185
# bedroomD       0.451673     0.040928
# floors         0.098669     0.223247
# coveredArea    0.942027     0.162034
# carpetArea     1.000000    -0.056603
# areaPercent   -0.056603     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]

# %%
house_data
# Out:
#              possStatusD     price   priceD      powerStatusD  sqFtPrice  \
# 0     Under Construction  59000000  5.90 Cr  No/Rare Powercut    18043.0
# 1     Under Construction  32256000  3.22 Cr  No/Rare Powercut    14000.0
# 2     Under Construction  12000000  1.20 Cr  No/Rare Powercut     8547.0
# 3     Under Construction  30000000     3 Cr  No/Rare Powercut    11742.0
# 4          Ready to Move  14000000  1.40 Cr  No/Rare Powercut    10108.0
# ...                  ...       ...      ...               ...        ...
# 9205       Ready to Move  11550000  1.15 Cr  No/Rare Powercut    11000.0
# 9206             Apr '28  13989600  1.39 Cr  No/Rare Powercut     8700.0
# 9207  Under Construction  12750000  1.27 Cr  No/Rare Powercut    11591.0
# 9208  Under Construction  25000000  2.50 Cr  No/Rare Powercut    13889.0
# 9209  Under Construction  28476000  2.84 Cr  No/Rare Powercut    14000.0
#
#           furnishedD balconiesD  bathD           parkingD       facingD  \
# 0     Semi-Furnished          4    4.0          2 Covered  North - East
# 1     Semi-Furnished          4    3.0  1 Covered, 1 Open  North - East
# 2        Unfurnished          3    2.0          1 Covered  North - East
# 3     Semi-Furnished          3    4.0          2 Covered  North - East
# 4     Semi-Furnished          4    3.0          1 Covered  South - East
# ...              ...        ...    ...                ...           ...
# 9205     Unfurnished        NaN    2.0                  0           NaN
# 9206     Unfurnished        NaN    3.0          1 Covered           NaN
# 9207     Unfurnished          3    2.0                  0          East
# 9208  Semi-Furnished          4    3.0          1 Covered          East
# 9209  Semi-Furnished          4    3.0  1 Covered, 1 Open  North - East
#
#      ctName  bedroomD  floors  coveredArea  carpetArea carpAreaUnit  \
# 0     Noida       3.0    35.0       3270.0      2616.0        Sq-ft
# 1     Noida       3.0    28.0       2304.0      1950.0        Sq-ft
# 2     Noida       3.0    22.0       1404.0       827.0        Sq-ft
# 3     Noida       3.0    28.0       2555.0      1618.0        Sq-ft
# 4     Noida       3.0    27.0       1385.0      1108.0        Sq-ft
# ...     ...       ...     ...          ...         ...          ...
# 9205  Noida       2.0     0.0       1050.0       840.0        Sq-ft
# 9206  Noida       3.0     0.0       1608.0      1286.4        Sq-ft
# 9207  Noida       2.0    28.0       1100.0       880.0        Sq-ft
# 9208  Noida       3.0    30.0       1800.0      1275.0        Sq-ft
# 9209  Noida       3.0    28.0       2034.0      1710.0        Sq-ft
#
#       areaPercent
# 0        0.000000
# 1        0.153646
# 2        0.410969
# 3        0.366732
# 4        0.000000
# ...           ...
# 9205     0.000000
# 9206     0.000000
# 9207     0.000000
# 9208     0.291667
# 9209     0.159292
#
# [9076 rows x 17 columns]

# %%
house_data.drop(["psmpreferred", "vl", "crisilRv1", "crisilRv2", "crisilRv2CtBy", "crircname1", "crircname2", "iTarget"], axis=1, inplace=True)

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ('Under Construction',
#  12000000,
#  '1.20 Cr',
#  'No/Rare Powercut',
#  8547.0,
#  'Unfurnished',
#  '3',
#  2.0,
#  '1 Covered',
#  'North - East',
#  'Noida',
#  3.0,
#  22.0,
#  1404.0,
#  827.0,
#  'Sq-ft',
#  0.41096866096866097)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'sqFtPrice',
#  'furnishedD',
#  'balconiesD',
#  'bathD',
#  'parkingD',
#  'facingD',
#  'ctName',
#  'bedroomD',
#  'floors',
#  'coveredArea',
#  'carpetArea',
#  'carpAreaUnit',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gigar\anaconda3\lib\site-packages (2.9.9)

# %%
city = 'Noida'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 76
