# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsKolkata.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'MBxrXGJtusdzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': 'vS+wISiZx4xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': 'nSWLJspMhY9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': 'amvzyh68wxVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': '2Z5ow6mXJgVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': '0K43kNm0vglzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': 'rcSCphQt8D5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': '1/mP3Ok7/txzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': 'sAx7PF/T/ydzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'sioAoj5zs7xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        787  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        788  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        789  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        790  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        791  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        792  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        793  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        794  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        795  \
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        796
# nsrResultList                                                         None
# resultList               [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 795 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'MBxrXGJtusdzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': 'vS+wISiZx4xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'nSWLJspMhY9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': 'amvzyh68wxVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': '2Z5ow6mXJgVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': '0K43kNm0vglzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': 'rcSCphQt8D5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': '1/mP3Ok7/txzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': 'sAx7PF/T/ydzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'sioAoj5zs7xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       787  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       788  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       789  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       790  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       791  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       792  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       793  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       794  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       795  \
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       796
# resultList              [{'encId': 'DwGHIl+5XbpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 795 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "Kolkata"

# %%
house_data
# Out:
#                           encId    possStatusD pmtSource   possBy iTarget  \
# 0      MBxrXGJtusdzpSvf+uAgZw==        Dec '24   Project  Dec '24       Y
# 1      mOx53msbmetzpSvf+uAgZw==        Dec '27   Project  Dec '27     NaN
# 2      3yFXTp+vxM5zpSvf+uAgZw==        Dec '27   Project  Dec '27     NaN
# 3      3Sgz6Z+7HQJzpSvf+uAgZw==  Ready to Move   android      NaN     NaN
# 4      T8J/z8zTMGZzpSvf+uAgZw==  Ready to Move   Project      NaN       Y
# ...                         ...            ...       ...      ...     ...
# 23845  mWtAJhAQHrFzpSvf+uAgZw==        Oct '28   Project  Oct '28     NaN
# 23846  IMDeZyHHpPVzpSvf+uAgZw==        Feb '26   Project  Feb '26     NaN
# 23847  CQZgNira3T1zpSvf+uAgZw==        Dec '27   Project  Dec '27     NaN
# 23848  yNXuQFaeTSdzpSvf+uAgZw==        Dec '28   Project  Dec '28       Y
# 23849  FiBO/LCEB7FzpSvf+uAgZw==        Dec '24   Project  Dec '24       Y
#
#       cntvl                                                url  noBfCt   st  \
# 0       343  2-BHK-966-Sq-ft-Multistorey-Apartment-FOR-Sale...       0  534
# 1       253  3-BHK-1336-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# 2       126  3-BHK-1030-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# 3       140  3-BHK-1654-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# 4       150  3-BHK-1298-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# ...     ...                                                ...     ...  ...
# 23845   171  3-BHK-1439-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# 23846   212  2-BHK-753-Sq-ft-Multistorey-Apartment-FOR-Sale...       0  534
# 23847   613  3-BHK-1077-Sq-ft-Multistorey-Apartment-FOR-Sal...       0  534
# 23848   574  2-BHK-665-Sq-ft-Multistorey-Apartment-FOR-Sale...       0  534
# 23849   343  2-BHK-723-Sq-ft-Multistorey-Apartment-FOR-Sale...       0  534
#
#       modstat  ...  gateComm  appExcRe cpmp propVid crisilRv1  crisilRv2  \
# 0       20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 1       20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 2       20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 3       20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 4       20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# ...       ...  ...       ...       ...  ...     ...       ...        ...
# 23845   20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 23846   20203  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 23847   20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 23848   20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
# 23849   20205  ...       NaN       NaN  NaN     NaN       NaN        NaN
#
#       crisilRv2CtBy crircname1 crircname2     city
# 0               NaN        NaN        NaN  Kolkata
# 1               NaN        NaN        NaN  Kolkata
# 2               NaN        NaN        NaN  Kolkata
# 3               NaN        NaN        NaN  Kolkata
# 4               NaN        NaN        NaN  Kolkata
# ...             ...        ...        ...      ...
# 23845           NaN        NaN        NaN  Kolkata
# 23846           NaN        NaN        NaN  Kolkata
# 23847           NaN        NaN        NaN  Kolkata
# 23848           NaN        NaN        NaN  Kolkata
# 23849           NaN        NaN        NaN  Kolkata
#
# [23850 rows x 268 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# possBy
# iTarget
# cntvl
# url
# noBfCt
# st
# modstat
# lCtDate
# appVer
# appSub
# deviceType
# sendbirdId
# lastAccessDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# cScore
# devName
# prjHl1
# postDateT
# endDateT
# pl
# prjSrc
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# seoDesc
# psmUspImgWeb
# psmUspImgMob
# psmImage
# propCat
# siteVisitProp
# id
# pmtmtrendPercentage
# powerStatusD
# sv
# cg
# pp
# prjid
# dImgSrc
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# companyname
# contName
# auto_desc
# prjname
# sqFtPrD
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# dealDesc
# supV
# lmtDName
# achTdS
# opSn
# opSnD
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# isVis
# showupfront
# isRera
# reraId
# caCompNameD
# postedLabelD
# furnishedD
# bathD
# transactionTypeD
# floorCsntrAllowed
# propTypeD
# ctName
# bedroomD
# userType
# transType
# isPreferred
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# psmImgCt
# waterStatus
# isLuxury
# coveredArea
# covAreaUnit
# modifiedDate
# image
# actualOwner
# isProjProp
# devId
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# rEcd
# endDt
# newUrl
# seoPsmDt
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# operatingSinceYear
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# isLuxuryServiceAvailable
# ctaDetailBean
# availableFrom
# prjLtHl1
# flooringTyD
# bookingAmtExact
# ac
# agtCerStatus
# parkingD
# floorNo
# taImg
# luxAmenities
# luxAmenitiesD
# propertyImageNew
# pfAgCg
# adroomD
# agtCrSt
# landmark
# acD
# imageDate
# pkgid
# pmtUspWap
# sid
# pmtUsp
# OwnershipTypeD
# balconiesD
# facingD
# amenFacingD
# floorD
# floors
# brokerConnect
# smartDiaryApiTag
# imgUrl
# amenities
# psmapproved
# pckCon
# ctCurr
# ctLast
# ranPropImg
# catAdd1
# investorlisting
# investorguide
# agentContinuityStr
# luxAmenMap
# nonluxAmenMap
# carpetArea
# carpAreaUnit
# appovedAuthC
# nriPref
# availUnit
# maintenanceD
# maintenanceCharges
# lc
# lcLst
# criLogo
# pmtUsp1
# tag
# tagWap
# crisilRv1CtBy
# crisilStarRating
# lastReplyDate
# vl
# ltOther
# agComCt
# crisilNoOfEmployees
# crisilOpSinceYear
# isReraAgent
# agentReraState
# la
# landAreaUnit
# dimD
# rdWidth
# nOs
# landAreaUnitD
# isCornerPlot
# dues
# brfdesc
# devLogo
# devOpSn
# devtp
# devpc
# devpuc
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# isExcl
# sVisMinDt
# sVisMaxDt
# pmtTCabin
# pmtUsp2
# pmtUsp2Wap
# adCn
# comPantry
# agentDetailUrl
# isprimeListingType
# noOfSVis
# gateComm
# appExcRe
# cpmp
# propVid
# crisilRv1
# crisilRv2
# crisilRv2CtBy
# crircname1
# crircname2
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId 3yFXTp+vxM5zpSvf+uAgZw== 3Sgz6Z+7HQJzpSvf+uAgZw==
# possStatusD Dec '27 Ready to Move
# pmtSource Project android
# possBy Dec '27 nan
# iTarget nan nan
# cntvl 126 140
# url 3-BHK-1030-Sq-ft-Multistorey-Apartment-FOR-Sale-Rajarhat-in-Kolkata&id=4d423635353539313433 3-BHK-1654-Sq-ft-Multistorey-Apartment-FOR-Sale-Prince-Anwar-Shah-Road-in-Kolkata&id=4d423730383238383631
# noBfCt 0 0
# st 534 534
# modstat 20205 20205
# lCtDate 1709833172000.0 1709430140000.0
# appVer nan 479.0
# appSub N Y
# deviceType nan and
# sendbirdId nan 3069924e-a62b-4c42-be65-99bbf5d6efdfsbgr7111
# lastAccessDate 1710009000000.0 1710181800000.0
# projectSocietyLink dtc-capital-city-rajarhat-kolkata-pdpid-4d4235333532303037 south-city-prince-anwar-shah-road-kolkata-pdpid-4d4235303232343637
# sipro 56321491 70987067 64011307 70404341 70168669 71460449 70230415 70999801
# comFlag Y N
# appExc N N
# cScore 46 74
# devName DTC Projects Pvt. Ltd. South City Projects Kol Ltd.
# prjHl1 Residential project with all modern amenities nan
# postDateT 2024-03-12T17:35:36.000Z 2024-03-10T23:45:38.000Z
# endDateT 2024-05-11T17:35:36.000Z 2024-05-09T23:45:38.000Z
# pl Y Y
# prjSrc 20521 nan
# enc_Id 3yFXTp+vxM7hw1WqrwxvGA== 3Sgz6Z+7HQJWVYXLB2DhZw==
# cowDays 0 0
# price 5300000.0 19200000.0
# priceD 53 Lac 1.92 Cr
# imgCt 26 4
# landmarkDetails ['19201|1.2 Km from PS QUBE', '19210|1.3 Km from Upcoming Chinar Park Metro Station', '19202|0.4 Km from Pramila Memorial Institute'] ['19201|1.7 Km from Priya Cinema Hall', '19210|0.9 Km from Mahanayak Uttam Kumar metro station', '19202|0.2 Km from Tollygunge Girls High School']
# seoDesc 3 BHK flat available for sale in Kolkata in the prime location of Rajarhat. Located in Dtc Capital City, this flat is equipped with premium facilities. This flat is available as a  sale property. The dec '27 flat in Rajarhat is all ready for sale at a low-priced budget of INR 53 Lac. The apartment's possession date is Dec '27. This unfurnished apartment for sale is strategically designed. A  3 BHK flat is available for sale in Prince Anwar Shah Road, Kolkata. It is located in South City. This flat is available as a  resale property. This ready to move flat is offered at an economical price of INR 1.92 Cr. This premium semi-furnished flat spells quality and comfort at a competitive price. Some neighbouring landmarks are south city mall..
# psmUspImgWeb Indoor Cricket Pitch|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/01/11/null-34-DTC-Capital-City-Kolkata-5352007_470_689_310_462.jpg,Amazing Mini Theatre|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/01/11/null-32-DTC-Capital-City-Kolkata-5352007_470_689_310_462.jpg nan
# psmUspImgMob Indoor Cricket Pitch|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/01/11/null-33-DTC-Capital-City-Kolkata-5352007_380_324_310_462.jpg,Amazing Mini Theatre|https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/01/11/null-31-DTC-Capital-City-Kolkata-5352007_380_324_310_462.jpg nan
# psmImage https://img.staticmb.com/mbimages/project/Photo_h310_w462/2022/10/26/Project-Photo-26-DTC-Capital-City-Kolkata-5352007_345_1366_310_462.jpg nan
# propCat 20292 20292
# siteVisitProp 0.0 nan
# id 65559143 70828861
# pmtmtrendPercentage 0 0
# powerStatusD No/Rare Powercut nan
# sv Y nan
# cg b b
# pp B Z
# prjid 157513 nan
# dImgSrc 11120 10504
# seoLtSc 1 40
# pSc 0 0
# pCct 0 0
# lCct 0 0
# pcTcCt 0 0
# caSqFt 1030.0 1654.0
# ltcoordGeo 22.6322091416971,88.4501774973632 22.5019933303721,88.3577659820217
# iba Y X
# ct 6903 6903
# lt 79304.0 84835.0
# loc 79304.0 84835.0
# bd 11702 11702
# ca 1030 1654
# ty 10002 10002
# dtldesc DTC Capital city Rajarhat is largest residential project with 10 towers of G+14. DTC capital city has 2Bhk, 3Bhk apartments with starting size of 910 sqft Super built.DTC capital city has modern club house with all facilities and amenities at podium level. DTC Capital City has launched 3 towers tower 1,2,4 as on date. It has total 1142 apartments in phase 1. DTC Capital city has 70000 sqft club house with G+2 level which host all the amenities such as swimming pool, badminton court, gym etc. It is Beautiful Flat and very airy Flat.
# plgdtldesc DTC Capital city Rajarhat is largest residential project with 10 towers of G+14. DTC capital city has 2Bhk, 3Bhk apartments with starting size of 910 sqft Super built.DTC capital city has modern club house with all facilities and amenities at podium level. DTC Capital City has launched 3 towers tower 1,2,4 as on date. It has total 1142 apartments in phase 1. DTC Capital city has 70000 sqft club house with G+2 level which host all the amenities such as swimming pool, badminton court, gym etc. It is Beautiful Flat and very airy Flat.
# oid 38338699 5571802
# oname Aakash Sinha Shayandeep Banerjee
# sdp Y Y
# companyname DTC Projects Private Limited SB Ground Realty Pvt. Ltd.
# contName Aakash Sinha Shayandeep Banerjee
# auto_desc 3 BHK, Multistorey Apartment is available for Sale in Rajarhat, Kolkata for 53.0 Lac(s) 3 BHK, Multistorey Apartment is available for Sale in Prince Anwar Shah Road, Kolkata for 1.9 Crore(s)
# prjname DTC Capital City South City
# sqFtPrD 5146.0 11608.0
# pkg 10070 10075
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 22.6322091416971 22.5011331
# pmtLong 88.4501774973632 88.3513137
# moisd 50 50
# dealDesc nan nan
# supV Y Y
# lmtDName Rajarhat Prince Anwar Shah Road
# achTdS 87 213
# opSn 11075 11105
# opSnD 1980 2010
# locSeoName Rajarhat Prince Anwar Shah Road
# propImg 2022/12/14/Project-Photo-10-DTC-Capital-City-Kolkata-5352007_1200_1600.jpg 70828861_1_PropertyImage289-6411805115707.jpg
# coverAreaUnitD Sq-ft Sq-ft
# ppd 20240312 20240311
# ppdL 1710264936000 1710114338000
# achTm 103 75
# achTmS 103 75
# soc N Y
# tmsrt 165904 051538
# ecd 20240220 20240311
# prm y y
# sqFtPrice 5146.0 11608.0
# psmid 5352007 5022467
# isVis Z N
# showupfront N N
# isRera Y nan
# reraId WBRERA/P/NOR/2023/000136 nan
# caCompNameD DTC Projects Private Limited SB Ground Realty Pvt. Ltd.
# postedLabelD Posted Yesterday Posted: Mar 11, '24
# furnishedD Unfurnished Semi-Furnished
# bathD 2 2
# transactionTypeD New Property Resale
# floorCsntrAllowed 14 nan
# propTypeD Apartment Apartment
# ctName Kolkata Kolkata
# bedroomD 3 3
# userType Builder Agent
# transType Sale Sale
# isPreferred false false
# dImgRf PROJ2073803 PROP302917427
# localityPhoto 0 0
# defaultAdddressGoogle Kolkata, West Bengal Kolkata, West Bengal
# propertyTitle 3BHK Multistorey Apartment for New Property in DTC Capital City at Rajarhat 3BHK Multistorey Apartment for Resale in South City at Prince Anwar Shah Road
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbimages/project/Photo_h80_w120/2022/12/14/Project-Photo-10-DTC-Capital-City-Kolkata-5352007_1200_1600_80_120.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h80_w120/70828861_1_PropertyImage289-6411805115707_80_120.jpg
# wapImgUrl1 https://img.staticmb.com/mbimages/project/Photo_h100_w150/2022/12/14/Project-Photo-10-DTC-Capital-City-Kolkata-5352007_1200_1600_100_150.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_1_PropertyImage289-6411805115707_180_240.jpg
# seoURL propertyDetails-3-BHK-1030-Sqft-Flat-FOR-Sale-Rajarhat-in-Kolkata&id=3yFXTp+vxM5zpSvf+uAgZw==&category=Sale propertyDetails-3-BHK-1654-Sqft-Flat-FOR-Sale-Prince-Anwar-Shah-Road-in-Kolkata&id=3Sgz6Z+7HQJzpSvf+uAgZw==&category=Sale
# psmImgCt 26 nan
# waterStatus Water Availability 24 Hours Available nan
# isLuxury F F
# coveredArea 1030 1654
# covAreaUnit 12800 12800
# modifiedDate Yesterday Mar 11, '24
# image https://img.staticmb.com/mbimages/project/Photo_h310_w462/2022/12/14/Project-Photo-10-DTC-Capital-City-Kolkata-5352007_1200_1600_310_462.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_8_PropertyImage701-7510418213055_180_240.jpg
# actualOwner 38338699 5571802
# isProjProp Y N
# devId 71437 55337
# pglmtkey 38338699_2 5571802_1
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 57041044.0 29548808.0
# sortCode1b 37076692.0 29548804.0
# sortCode22 0.0 0.0
# sortCode26 40219360.0 0.0
# ubicnt 50 50
# rEcd 20240312 20240311
# endDt May 11, '24 May 10, '24
# newUrl project-dtc-capital-city-for-sale-in-kolkata-pppfs project-south-city-for-sale-in-kolkata-pppfs
# seoPsmDt {"bhkPriceRange":{"4 BHK":{"minPrice":"95.0 Lac","maxPrice":"95.0 Lac"},"3 BHK":{"minPrice":"53.0 Lac","maxPrice":"82.0 Lac"},"2 BHK":{"minPrice":"45.0 Lac","maxPrice":"45.0 Lac"}}} {"bhkPriceRange":{"4 BHK":{"minPrice":"2.05 Cr","maxPrice":"4.0 Cr"},"3 BHK":{"minPrice":"1.30 Cr","maxPrice":"3.10 Cr"},"2 BHK":{"minPrice":"1.40 Cr","maxPrice":"1.55 Cr"}}}
# pmtdesc_hi राजारहाट, कोलकाता में स्थित यह शानदार 3 BHK फ्लैट बिक्री के लिए उपलब्ध है। प्राइम लोकेशन पर स्थित यह प्रॉपर्टी Dtc Capital City सोसायटी में बनी है। 3 BHK फ्लैट में 2 बाथरूम हैं। यह फ्लैट सेल प्रॉपर्टी के रूप में उपलब्ध है। राजारहाट में स्थित यह dec '27 फ्लैट रु. 53 Lac के उचित मूल्य पर खरीदने के लिए उपलब्ध है। Dec '27 इस अपार्टमेंट के पज़ेशन की तारीख है। यह फ्लैट अनफर्निश्ड है और फैमिली को रहने के लिए सही है।  प्रिंस अनवर शाह रोड, कोलकाता में स्थित इस आकर्षक 3 BHK अपार्टमेंट को अभी खरीदा जा सकता है। यह साउथ सिटी में अच्छी जगह पर है। कुल 2 बाथरूम हैं ताकि यहां रहने वाले लोगों किसी तरह की परेशानी न हो। यह फ्लैट रेसले के लिए एक आकर्षक प्रॉपर्टी है। यह रेडी टू मूव फ्लैट रु. 1.92 Cr की किफायती मूल्य पर उपलब्ध है। यह अपार्टमेंट सेमि-फर्निश्ड है। साउथ सिटी में बार/लाउन्ज, एयर कंडिशन्ड, बैंक्वेट हॉल, जॉगिंग एंड स्ट्रॉलिंग ट्रैक, आउटडोर टेनिस कोर्ट्स सहित कई सुविधाएं उपलब्ध हैं।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# operatingSinceYear 1980 2010
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc Sq-ft Sq-ft
# ampDesc DTC Capital city Rajarhat is largest residential project with 10 towers of G+14. DTC capital city ha It is Beautiful Flat and very airy Flat.
# b2cCardEligibility false false
# maskedMobileNumber +91-98XXXXXXX56 +91-98XXXXXXX11
# isLuxuryServiceAvailable False False
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# availableFrom Dec '27 nan
# prjLtHl1 9 Mins From Rajarhat Apes Hospital nan
# flooringTyD Vitrified nan
# bookingAmtExact 100001 500000
# ac 10080.0 11654.0
# agtCerStatus N nan
# parkingD nan nan
# floorNo nan 26
# taImg nan Profile-1-5571802_1024_719.jpeg
# luxAmenities nan 12225 12215 12224 12229 12230 12220 12221 12223 12214 12217 12227
# luxAmenitiesD nan Bar/Lounge,Air Conditioned,Banquet Hall,Jogging and Strolling Track,Outdoor Tennis Courts,Laundry Service,Internet/Wi-Fi Connectivity,RO Water System,Service/Goods Lift,Intercom Facility,Conference Room
# propertyImageNew nan https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_1_PropertyImage289-6411805115707_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_8_PropertyImage701-7510418213055_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_9_PropertyImage990-7284694722358_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_10_PropertyImage365-1134614175611_180_240.jpg
# pfAgCg nan r , s
# adroomD nan Servant Room
# agtCrSt nan Y
# landmark nan South city mall.
# acD nan 10 to 15 years
# imageDate nan 2024/Jan/08
# pkgid nan 286373
# pmtUspWap nan East Facing Property
# sid nan 13520,13558,13502
# pmtUsp nan East Facing Property
# OwnershipTypeD nan Freehold
# balconiesD nan 1
# facingD nan East
# amenFacingD nan Pool, Garden/Park, Main Road
# floorD nan 26 of 35 Floor
# floors nan 35
# brokerConnect nan Y
# smartDiaryApiTag nan Y
# imgUrl nan https://img.staticmb.com/mbimages/user/Photo_h75_w75/5571802_ProfileImage_75_75.jpeg
# amenities nan 12201 12202 12203 12204 12205 12206 12207 12208 12209 12213 12214 12215 12217 12218 12219 12220 12221 12222 12223 12224 12225 12226 12227 12228 12229 12230
# psmapproved nan Y
# pckCon nan 2.43
# ctCurr nan 434
# ctLast nan 0
# ranPropImg nan https://img.staticmb.com/mbphoto/property/cropped_images/2024/Jan/08/Photo_h180_w240/70828861_8_PropertyImage701-7510418213055_180_240.jpg
# catAdd1 nan South city residency.
# investorlisting nan N
# investorguide nan N
# agentContinuityStr nan 100+ Buyers Served
# luxAmenMap nan {'12225': 'Bar/Lounge', '12215': 'Air Conditioned', '12224': 'Banquet Hall', '12229': 'Jogging and Strolling Track'}
# nonluxAmenMap nan {}
# carpetArea nan nan
# carpAreaUnit nan nan
# appovedAuthC nan nan
# nriPref nan nan
# availUnit nan nan
# maintenanceD nan nan
# maintenanceCharges nan nan
# lc nan nan
# lcLst nan nan
# criLogo nan nan
# pmtUsp1 nan nan
# tag nan nan
# tagWap nan nan
# crisilRv1CtBy nan nan
# crisilStarRating nan nan
# lastReplyDate nan nan
# vl nan nan
# ltOther nan nan
# agComCt nan nan
# crisilNoOfEmployees nan nan
# crisilOpSinceYear nan nan
# isReraAgent nan nan
# agentReraState nan nan
# la nan nan
# landAreaUnit nan nan
# dimD nan nan
# rdWidth nan nan
# nOs nan nan
# landAreaUnitD nan nan
# isCornerPlot nan nan
# dues nan nan
# brfdesc nan nan
# devLogo nan nan
# devOpSn nan nan
# devtp nan nan
# devpc nan nan
# devpuc nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# isExcl nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# pmtTCabin nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# adCn nan nan
# comPantry nan nan
# agentDetailUrl nan nan
# isprimeListingType nan nan
# noOfSVis nan nan
# gateComm nan nan
# appExcRe nan nan
# cpmp nan nan
# propVid nan nan
# crisilRv1 nan nan
# crisilRv2 nan nan
# crisilRv2CtBy nan nan
# crircname1 nan nan
# crircname2 nan nan
# city Kolkata Kolkata

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"lc",
"pSc",
"lcLst",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"appExcRe",
"brfdesc",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD iTarget       price    priceD      powerStatusD  sqFtPrD  \
# 0            Dec '24       Y   4170000.0  41.7 Lac  No/Rare Powercut   4317.0
# 1            Dec '27     NaN   8720103.0  87.2 Lac  No/Rare Powercut   6527.0
# 2            Dec '27     NaN   5300000.0    53 Lac  No/Rare Powercut   5146.0
# 3      Ready to Move     NaN  19200000.0   1.92 Cr               NaN  11608.0
# 4      Ready to Move       Y   5062200.0  50.6 Lac  No/Rare Powercut   3900.0
# ...              ...     ...         ...       ...               ...      ...
# 23845        Oct '28     NaN   6043800.0  60.4 Lac  No/Rare Powercut   4200.0
# 23846        Feb '26     NaN   4115000.0  41.2 Lac  No/Rare Powercut   5465.0
# 23847        Dec '27     NaN   8600000.0    86 Lac  No/Rare Powercut   7985.0
# 23848        Dec '28       Y   5230350.0  52.3 Lac  No/Rare Powercut   7865.0
# 23849        Dec '24       Y   3280000.0  32.8 Lac  No/Rare Powercut   4537.0
#
#        sqFtPrice      furnishedD bathD   ctName  ... devtp devpc devpuc  \
# 0         4317.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 1         6527.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 2         5146.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 3        11608.0  Semi-Furnished     2  Kolkata  ...   NaN   NaN    NaN
# 4         3900.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# ...          ...             ...   ...      ...  ...   ...   ...    ...
# 23845     4200.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 23846     5465.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 23847     7985.0     Unfurnished     3  Kolkata  ...   NaN   NaN    NaN
# 23848     7865.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
# 23849     4537.0     Unfurnished     2  Kolkata  ...   NaN   NaN    NaN
#
#       propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1 crircname2     city
# 0         NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 1         NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 2         NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 3         NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 4         NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# ...       ...       ...       ...           ...        ...        ...      ...
# 23845     NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 23846     NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 23847     NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 23848     NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
# 23849     NaN       NaN       NaN           NaN        NaN        NaN  Kolkata
#
# [23850 rows x 41 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD           224
# iTarget             21807
# price                 230
# priceD                  0
# powerStatusD        11179
# sqFtPrD               876
# sqFtPrice             906
# furnishedD            252
# bathD                 195
# ctName                  0
# bedroomD                0
# coveredArea           742
# covAreaUnit           737
# image                3614
# parkingD            20105
# luxAmenities        20626
# luxAmenitiesD       20630
# propertyImageNew    15848
# OwnershipTypeD      17914
# balconiesD          14296
# facingD             18182
# floorD              11667
# floors              11681
# amenities           18504
# ctLast              18932
# carpetArea          15103
# carpAreaUnit        15107
# maintenanceD        20473
# vl                  18130
# devLogo             23440
# devOpSn             23440
# devtp               23440
# devpc               23440
# devpuc              23440
# propVid             23848
# crisilRv1           23442
# crisilRv2           23442
# crisilRv2CtBy       23442
# crircname1          23442
# crircname2          23442
# city                    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD             0
# iTarget             21807
# price                 230
# priceD                  0
# powerStatusD        11179
# sqFtPrD               876
# sqFtPrice             906
# furnishedD            252
# bathD                 195
# ctName                  0
# bedroomD                0
# coveredArea           742
# covAreaUnit           737
# image                3614
# parkingD            20105
# luxAmenities        20626
# luxAmenitiesD       20630
# propertyImageNew    15848
# OwnershipTypeD      17914
# balconiesD          14296
# facingD             18182
# floorD              11667
# floors              11681
# amenities           18504
# ctLast              18932
# carpetArea          15103
# carpAreaUnit        15107
# maintenanceD        20473
# vl                  18130
# devLogo             23440
# devOpSn             23440
# devtp               23440
# devpc               23440
# devpuc              23440
# propVid             23848
# crisilRv1           23442
# crisilRv2           23442
# crisilRv2CtBy       23442
# crircname1          23442
# crircname2          23442
# city                    0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD iTarget       price    priceD      powerStatusD  \
# 0            Dec '24       Y   4170000.0  41.7 Lac  No/Rare Powercut
# 1            Dec '27     NaN   8720103.0  87.2 Lac  No/Rare Powercut
# 2            Dec '27     NaN   5300000.0    53 Lac  No/Rare Powercut
# 3      Ready to Move     NaN  19200000.0   1.92 Cr               NaN
# 4      Ready to Move       Y   5062200.0  50.6 Lac  No/Rare Powercut
# ...              ...     ...         ...       ...               ...
# 23845        Oct '28     NaN   6043800.0  60.4 Lac  No/Rare Powercut
# 23846        Feb '26     NaN   4115000.0  41.2 Lac  No/Rare Powercut
# 23847        Dec '27     NaN   8600000.0    86 Lac  No/Rare Powercut
# 23848        Dec '28       Y   5230350.0  52.3 Lac  No/Rare Powercut
# 23849        Dec '24       Y   3280000.0  32.8 Lac  No/Rare Powercut
#
#        sqFtPrice      furnishedD bathD   ctName bedroomD  ... devOpSn devtp  \
# 0         4317.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 1         6527.0     Unfurnished     2  Kolkata        3  ...     NaN   NaN
# 2         5146.0     Unfurnished     2  Kolkata        3  ...     NaN   NaN
# 3        11608.0  Semi-Furnished     2  Kolkata        3  ...     NaN   NaN
# 4         3900.0     Unfurnished     2  Kolkata        3  ...     NaN   NaN
# ...          ...             ...   ...      ...      ...  ...     ...   ...
# 23845     4200.0     Unfurnished     2  Kolkata        3  ...     NaN   NaN
# 23846     5465.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 23847     7985.0     Unfurnished     3  Kolkata        3  ...     NaN   NaN
# 23848     7865.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 23849     4537.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
#
#       devpc devpuc propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1  \
# 0       NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 1       NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 2       NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 3       NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 4       NaN    NaN     NaN       NaN       NaN           NaN        NaN
# ...     ...    ...     ...       ...       ...           ...        ...
# 23845   NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 23846   NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 23847   NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 23848   NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 23849   NaN    NaN     NaN       NaN       NaN           NaN        NaN
#
#        crircname2
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 23845         NaN
# 23846         NaN
# 23847         NaN
# 23848         NaN
# 23849         NaN
#
# [23850 rows x 29 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             12653
# Less Than 2 Hour Powercut       15
# 2 To 4 Hours Powercut            2
# Over 6 Hours Powercut            1
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#          possStatusD iTarget      price    priceD               powerStatusD  \
# 106    Ready to Move     NaN  4200000.0    42 Lac  Less Than 2 Hour Powercut
# 783    Ready to Move     NaN  3000000.0    30 Lac  Less Than 2 Hour Powercut
# 903    Ready to Move     NaN  2500000.0    25 Lac  Less Than 2 Hour Powercut
# 1636   Ready to Move     NaN  1600000.0    16 Lac  Less Than 2 Hour Powercut
# 1835   Ready to Move     NaN  4046250.0  40.5 Lac  Less Than 2 Hour Powercut
# 2232   Ready to Move     NaN  4000000.0    40 Lac  Less Than 2 Hour Powercut
# 4950   Ready to Move     NaN  3900000.0    39 Lac  Less Than 2 Hour Powercut
# 5742   Ready to Move     NaN  7000000.0    70 Lac  Less Than 2 Hour Powercut
# 6419   Ready to Move     NaN  7200000.0    72 Lac  Less Than 2 Hour Powercut
# 7111   Ready to Move     NaN  4500000.0    45 Lac  Less Than 2 Hour Powercut
# 7715   Ready to Move     NaN  5300000.0    53 Lac  Less Than 2 Hour Powercut
# 8298   Ready to Move     NaN  2450000.0  24.5 Lac  Less Than 2 Hour Powercut
# 9265   Ready to Move     NaN  3700000.0    37 Lac  Less Than 2 Hour Powercut
# 9320   Ready to Move     NaN  4050000.0  40.5 Lac  Less Than 2 Hour Powercut
# 10818  Ready to Move     NaN  4300000.0    43 Lac  Less Than 2 Hour Powercut
#
#        sqFtPrice      furnishedD bathD   ctName bedroomD  ... devOpSn devtp  \
# 106       4615.0  Semi-Furnished     2  Kolkata        2  ...     NaN   NaN
# 783       3947.0  Semi-Furnished     2  Kolkata        2  ...     NaN   NaN
# 903       3577.0     Unfurnished     1  Kolkata        2  ...     NaN   NaN
# 1636      2302.0     Unfurnished     1  Kolkata        2  ...     NaN   NaN
# 1835      4150.0  Semi-Furnished     2  Kolkata        2  ...     NaN   NaN
# 2232      3643.0             NaN     2  Kolkata        2  ...     NaN   NaN
# 4950      5039.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 5742         NaN       Furnished     2  Kolkata        3  ...     NaN   NaN
# 6419      5854.0       Furnished     2  Kolkata        3  ...     NaN   NaN
# 7111      4737.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 7715      4431.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 8298      3798.0     Unfurnished     1  Kolkata        2  ...     NaN   NaN
# 9265      3627.0     Unfurnished     2  Kolkata        2  ...     NaN   NaN
# 9320      3240.0       Furnished     2  Kolkata        3  ...     NaN   NaN
# 10818     5733.0     Unfurnished     1  Kolkata        2  ...     NaN   NaN
#
#       devpc devpuc propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1  \
# 106     NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 783     NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 903     NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 1636    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 1835    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 2232    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 4950    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 5742    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 6419    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 7111    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 7715    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 8298    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 9265    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 9320    NaN    NaN     NaN       NaN       NaN           NaN        NaN
# 10818   NaN    NaN     NaN       NaN       NaN           NaN        NaN
#
#        crircname2
# 106           NaN
# 783           NaN
# 903           NaN
# 1636          NaN
# 1835          NaN
# 2232          NaN
# 4950          NaN
# 5742          NaN
# 6419          NaN
# 7111          NaN
# 7715          NaN
# 8298          NaN
# 9265          NaN
# 9320          NaN
# 10818         NaN
#
# [15 rows x 29 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD          0
# iTarget          21807
# price              230
# priceD               0
# powerStatusD     11179
# sqFtPrice          906
# furnishedD         252
# bathD              195
# ctName               0
# bedroomD             0
# coveredArea        742
# parkingD         20105
# balconiesD       14296
# facingD          18182
# floors           11681
# carpetArea       15103
# carpAreaUnit     15107
# vl               18130
# devLogo          23440
# devOpSn          23440
# devtp            23440
# devpc            23440
# devpuc           23440
# propVid          23848
# crisilRv1        23442
# crisilRv2        23442
# crisilRv2CtBy    23442
# crircname1       23442
# crircname2       23442
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 23850

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.35285053929121724' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# -0.1375057563775565

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#          possStatusD iTarget       price    priceD      powerStatusD  \
# 0            Dec '24       Y   4170000.0  41.7 Lac  No/Rare Powercut
# 1            Dec '27     NaN   8720103.0  87.2 Lac  No/Rare Powercut
# 2            Dec '27     NaN   5300000.0    53 Lac  No/Rare Powercut
# 3      Ready to Move     NaN  19200000.0   1.92 Cr  No/Rare Powercut
# 4      Ready to Move       Y   5062200.0  50.6 Lac  No/Rare Powercut
# ...              ...     ...         ...       ...               ...
# 23845        Oct '28     NaN   6043800.0  60.4 Lac  No/Rare Powercut
# 23846        Feb '26     NaN   4115000.0  41.2 Lac  No/Rare Powercut
# 23847        Dec '27     NaN   8600000.0    86 Lac  No/Rare Powercut
# 23848        Dec '28       Y   5230350.0  52.3 Lac  No/Rare Powercut
# 23849        Dec '24       Y   3280000.0  32.8 Lac  No/Rare Powercut
#
#        sqFtPrice      furnishedD bathD   ctName bedroomD  ...  devtp devpc  \
# 0         4317.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
# 1         6527.0     Unfurnished     2  Kolkata        3  ...    NaN   NaN
# 2         5146.0     Unfurnished     2  Kolkata        3  ...    NaN   NaN
# 3        11608.0  Semi-Furnished     2  Kolkata        3  ...    NaN   NaN
# 4         3900.0     Unfurnished     2  Kolkata        3  ...    NaN   NaN
# ...          ...             ...   ...      ...      ...  ...    ...   ...
# 23845     4200.0     Unfurnished     2  Kolkata        3  ...    NaN   NaN
# 23846     5465.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
# 23847     7985.0     Unfurnished     3  Kolkata        3  ...    NaN   NaN
# 23848     7865.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
# 23849     4537.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
#
#       devpuc propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1 crircname2  \
# 0        NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 1        NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 2        NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 3        NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 4        NaN     NaN       NaN       NaN           NaN        NaN        NaN
# ...      ...     ...       ...       ...           ...        ...        ...
# 23845    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 23846    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 23847    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 23848    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 23849    NaN     NaN       NaN       NaN           NaN        NaN        NaN
#
#        areaPercent
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.352851
# ...            ...
# 23845     0.000000
# 23846     0.000000
# 23847     0.000000
# 23848     0.111278
# 23849     0.000000
#
# [23108 rows x 30 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD          0
# iTarget          21065
# price              168
# priceD               0
# powerStatusD         0
# sqFtPrice            0
# furnishedD           0
# bathD              176
# ctName               0
# bedroomD             0
# coveredArea          0
# parkingD             0
# balconiesD       14062
# facingD          17653
# floors               0
# carpetArea           0
# carpAreaUnit         0
# vl               17388
# devLogo          22698
# devOpSn          22698
# devtp            22698
# devpc            22698
# devpuc           22698
# propVid          23106
# crisilRv1        22700
# crisilRv2        22700
# crisilRv2CtBy    22700
# crircname1       22700
# crircname2       22700
# areaPercent          0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#          possStatusD iTarget  price          priceD      powerStatusD  \
# 11370  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11371  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11373  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11374  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11376  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# ...              ...     ...    ...             ...               ...
# 11594  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11595  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11596  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11598  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
# 11599  Ready to Move     NaN    NaN  Call for Price  No/Rare Powercut
#
#        sqFtPrice      furnishedD bathD   ctName bedroomD  ...  devtp devpc  \
# 11370        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11371        0.0     Unfurnished   NaN  Kolkata        3  ...    NaN   NaN
# 11373        0.0       Furnished     2  Kolkata        2  ...    NaN   NaN
# 11374        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11376        0.0     Unfurnished   NaN  Kolkata        3  ...    NaN   NaN
# ...          ...             ...   ...      ...      ...  ...    ...   ...
# 11594        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11595        0.0  Semi-Furnished     2  Kolkata        2  ...    NaN   NaN
# 11596        0.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
# 11598        0.0  Semi-Furnished     2  Kolkata        2  ...    NaN   NaN
# 11599        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
#
#       devpuc propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1 crircname2  \
# 11370    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11371    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11373    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11374    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11376    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# ...      ...     ...       ...       ...           ...        ...        ...
# 11594    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11595    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11596    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11598    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11599    NaN     NaN       NaN       NaN           NaN        NaN        NaN
#
#        areaPercent
# 11370     0.000000
# 11371     0.000000
# 11373    -0.312500
# 11374     0.000000
# 11376     0.000000
# ...            ...
# 11594     0.000000
# 11595     0.235294
# 11596     0.250681
# 11598     0.000000
# 11599     0.000000
#
# [168 rows x 30 columns]

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD          0
# iTarget          21065
# price                0
# priceD               0
# powerStatusD         0
# sqFtPrice            0
# furnishedD           0
# bathD              176
# ctName               0
# bedroomD             0
# coveredArea          0
# parkingD             0
# balconiesD       14062
# facingD          17653
# floors               0
# carpetArea           0
# carpAreaUnit         0
# vl               17388
# devLogo          22698
# devOpSn          22698
# devtp            22698
# devpc            22698
# devpuc           22698
# propVid          23106
# crisilRv1        22700
# crisilRv2        22700
# crisilRv2CtBy    22700
# crircname1       22700
# crircname2       22700
# areaPercent          0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 house_data.iloc[23,2].split(" ")
#
# AttributeError: 'numpy.int32' object has no attribute 'split'

# %%
house_data[house_data['price']==0]
# Out:
#          possStatusD iTarget  price          priceD      powerStatusD  \
# 11370  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11371  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11373  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11374  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11376  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# ...              ...     ...    ...             ...               ...
# 11594  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11595  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11596  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11598  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
# 11599  Ready to Move     NaN      0  Call for Price  No/Rare Powercut
#
#        sqFtPrice      furnishedD bathD   ctName bedroomD  ...  devtp devpc  \
# 11370        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11371        0.0     Unfurnished   NaN  Kolkata        3  ...    NaN   NaN
# 11373        0.0       Furnished     2  Kolkata        2  ...    NaN   NaN
# 11374        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11376        0.0     Unfurnished   NaN  Kolkata        3  ...    NaN   NaN
# ...          ...             ...   ...      ...      ...  ...    ...   ...
# 11594        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
# 11595        0.0  Semi-Furnished     2  Kolkata        2  ...    NaN   NaN
# 11596        0.0     Unfurnished     2  Kolkata        2  ...    NaN   NaN
# 11598        0.0  Semi-Furnished     2  Kolkata        2  ...    NaN   NaN
# 11599        0.0     Unfurnished   NaN  Kolkata        2  ...    NaN   NaN
#
#       devpuc propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1 crircname2  \
# 11370    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11371    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11373    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11374    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11376    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# ...      ...     ...       ...       ...           ...        ...        ...
# 11594    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11595    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11596    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11598    NaN     NaN       NaN       NaN           NaN        NaN        NaN
# 11599    NaN     NaN       NaN       NaN           NaN        NaN        NaN
#
#        areaPercent
# 11370     0.000000
# 11371     0.000000
# 11373    -0.312500
# 11374     0.000000
# 11376     0.000000
# ...            ...
# 11594     0.000000
# 11595     0.235294
# 11596     0.250681
# 11598     0.000000
# 11599     0.000000
#
# [168 rows x 30 columns]

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD          0
# iTarget          20897
# price                0
# priceD               0
# powerStatusD         0
# sqFtPrice            0
# furnishedD           0
# bathD              104
# ctName               0
# bedroomD             0
# coveredArea          0
# parkingD             0
# balconiesD       13955
# facingD          17496
# floors               0
# carpetArea           0
# carpAreaUnit         0
# vl               17220
# devLogo          22530
# devOpSn          22530
# devtp            22530
# devpc            22530
# devpuc           22530
# propVid          22938
# crisilRv1        22532
# crisilRv2        22532
# crisilRv2CtBy    22532
# crircname1       22532
# crircname2       22532
# areaPercent          0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array([nan, 'East', 'North - East', 'North - West', 'South -West',
#        'South', 'South - East', 'West', 'North'], dtype=object)

# %%
house_data
# Out:
#          possStatusD iTarget     price    priceD      powerStatusD  sqFtPrice  \
# 0            Dec '24       Y   4170000  41.7 Lac  No/Rare Powercut     4317.0
# 1            Dec '27     NaN   8720103  87.2 Lac  No/Rare Powercut     6527.0
# 2            Dec '27     NaN   5300000    53 Lac  No/Rare Powercut     5146.0
# 3      Ready to Move     NaN  19200000   1.92 Cr  No/Rare Powercut    11608.0
# 4      Ready to Move       Y   5062200  50.6 Lac  No/Rare Powercut     3900.0
# ...              ...     ...       ...       ...               ...        ...
# 23845        Oct '28     NaN   6043800  60.4 Lac  No/Rare Powercut     4200.0
# 23846        Feb '26     NaN   4115000  41.2 Lac  No/Rare Powercut     5465.0
# 23847        Dec '27     NaN   8600000    86 Lac  No/Rare Powercut     7985.0
# 23848        Dec '28       Y   5230350  52.3 Lac  No/Rare Powercut     7865.0
# 23849        Dec '24       Y   3280000  32.8 Lac  No/Rare Powercut     4537.0
#
#            furnishedD bathD   ctName bedroomD  ...  devtp devpc devpuc  \
# 0         Unfurnished     2  Kolkata        2  ...    NaN   NaN    NaN
# 1         Unfurnished     2  Kolkata        3  ...    NaN   NaN    NaN
# 2         Unfurnished     2  Kolkata        3  ...    NaN   NaN    NaN
# 3      Semi-Furnished     2  Kolkata        3  ...    NaN   NaN    NaN
# 4         Unfurnished     2  Kolkata        3  ...    NaN   NaN    NaN
# ...               ...   ...      ...      ...  ...    ...   ...    ...
# 23845     Unfurnished     2  Kolkata        3  ...    NaN   NaN    NaN
# 23846     Unfurnished     2  Kolkata        2  ...    NaN   NaN    NaN
# 23847     Unfurnished     3  Kolkata        3  ...    NaN   NaN    NaN
# 23848     Unfurnished     2  Kolkata        2  ...    NaN   NaN    NaN
# 23849     Unfurnished     2  Kolkata        2  ...    NaN   NaN    NaN
#
#       propVid crisilRv1 crisilRv2 crisilRv2CtBy crircname1 crircname2  \
# 0         NaN       NaN       NaN           NaN        NaN        NaN
# 1         NaN       NaN       NaN           NaN        NaN        NaN
# 2         NaN       NaN       NaN           NaN        NaN        NaN
# 3         NaN       NaN       NaN           NaN        NaN        NaN
# 4         NaN       NaN       NaN           NaN        NaN        NaN
# ...       ...       ...       ...           ...        ...        ...
# 23845     NaN       NaN       NaN           NaN        NaN        NaN
# 23846     NaN       NaN       NaN           NaN        NaN        NaN
# 23847     NaN       NaN       NaN           NaN        NaN        NaN
# 23848     NaN       NaN       NaN           NaN        NaN        NaN
# 23849     NaN       NaN       NaN           NaN        NaN        NaN
#
#        areaPercent
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.352851
# ...            ...
# 23845     0.000000
# 23846     0.000000
# 23847     0.000000
# 23848     0.111278
# 23849     0.000000
#
# [22940 rows x 30 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22940 entries, 0 to 23849
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   possStatusD    22940 non-null  object
#  1   iTarget        2043 non-null   object
#  2   price          22940 non-null  int32
#  3   priceD         22940 non-null  object
#  4   powerStatusD   22940 non-null  object
#  5   sqFtPrice      22940 non-null  float64
#  6   furnishedD     22940 non-null  object
#  7   bathD          22836 non-null  object
#  8   ctName         22940 non-null  object
#  9   bedroomD       22940 non-null  object
#  10  coveredArea    22940 non-null  float64
#  11  parkingD       22940 non-null  object
#  12  balconiesD     8985 non-null   object
#  13  facingD        5444 non-null   object
#  14  floors         22940 non-null  object
#  15  carpetArea     22940 non-null  object
#  16  carpAreaUnit   22940 non-null  object
#  17  vl             5720 non-null   object
#  18  devLogo        410 non-null    object
#  19  devOpSn        410 non-null    float64
#  20  devtp          410 non-null    float64
#  21  devpc          410 non-null    float64
#  22  devpuc         410 non-null    float64
#  23  propVid        2 non-null      object
#  24  crisilRv1      408 non-null    object
#  25  crisilRv2      408 non-null    object
#  26  crisilRv2CtBy  408 non-null    object
#  27  crircname1     408 non-null    object
#  28  crircname2     408 non-null    object
#  29  areaPercent    22940 non-null  float64
# dtypes: float64(7), int32(1), object(22)
# memory usage: 5.3+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
house_data['balconiesD'] = house_data['balconiesD'].astype(float)
# house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '24", "Dec '27", 'Ready to Move', "Sep '24", "Dec '28",
#        'Under Construction', "Jun '25", "Dec '26", "Oct '25", "Apr '25",
#        'Ongoing', "Apr '24", "Sep '28", "Dec '25", "Oct '24", "Feb '27",
#        'Immediately', "Jun '24", 'Ready To Move', "Jun '27", "Mar '28",
#        "Sep '25", "Mar '27", "Mar '25", "Oct '26", "Oct '28", "Feb '26"],
#       dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '24", "Dec '27", 'Ready to Move', "Sep '24", "Dec '28",
#        'Under Construction', "Jun '25", "Dec '26", "Oct '25", "Apr '25",
#        'Ongoing', "Apr '24", "Sep '28", "Dec '25", "Oct '24", "Feb '27",
#        "Jun '24", 'Ready To Move', "Jun '27", "Mar '28", "Sep '25",
#        "Mar '27", "Mar '25", "Oct '26", "Oct '28", "Feb '26"],
#       dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 1336.0047495020683

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#          possStatusD iTarget    price    priceD      powerStatusD  sqFtPrice  \
# 0            Dec '24       Y  4170000  41.7 Lac  No/Rare Powercut     4317.0
# 1            Dec '27     NaN  8720103  87.2 Lac  No/Rare Powercut     6527.0
# 2            Dec '27     NaN  5300000    53 Lac  No/Rare Powercut     5146.0
# 4      Ready to Move       Y  5062200  50.6 Lac  No/Rare Powercut     3900.0
# 5      Ready to Move     NaN  3872400  38.7 Lac  No/Rare Powercut     4200.0
# ...              ...     ...      ...       ...               ...        ...
# 23845        Oct '28     NaN  6043800  60.4 Lac  No/Rare Powercut     4200.0
# 23846        Feb '26     NaN  4115000  41.2 Lac  No/Rare Powercut     5465.0
# 23847        Dec '27     NaN  8600000    86 Lac  No/Rare Powercut     7985.0
# 23848        Dec '28       Y  5230350  52.3 Lac  No/Rare Powercut     7865.0
# 23849        Dec '24       Y  3280000  32.8 Lac  No/Rare Powercut     4537.0
#
#         furnishedD bathD   ctName  bedroomD  ...  devtp devpc  devpuc propVid  \
# 0      Unfurnished     2  Kolkata       2.0  ...    NaN   NaN     NaN     NaN
# 1      Unfurnished     2  Kolkata       3.0  ...    NaN   NaN     NaN     NaN
# 2      Unfurnished     2  Kolkata       3.0  ...    NaN   NaN     NaN     NaN
# 4      Unfurnished     2  Kolkata       3.0  ...    NaN   NaN     NaN     NaN
# 5      Unfurnished     2  Kolkata       2.0  ...    NaN   NaN     NaN     NaN
# ...            ...   ...      ...       ...  ...    ...   ...     ...     ...
# 23845  Unfurnished     2  Kolkata       3.0  ...    NaN   NaN     NaN     NaN
# 23846  Unfurnished     2  Kolkata       2.0  ...    NaN   NaN     NaN     NaN
# 23847  Unfurnished     3  Kolkata       3.0  ...    NaN   NaN     NaN     NaN
# 23848  Unfurnished     2  Kolkata       2.0  ...    NaN   NaN     NaN     NaN
# 23849  Unfurnished     2  Kolkata       2.0  ...    NaN   NaN     NaN     NaN
#
#        crisilRv1  crisilRv2 crisilRv2CtBy crircname1 crircname2  areaPercent
# 0            NaN        NaN           NaN        NaN        NaN     0.000000
# 1            NaN        NaN           NaN        NaN        NaN     0.000000
# 2            NaN        NaN           NaN        NaN        NaN     0.000000
# 4            NaN        NaN           NaN        NaN        NaN     0.352851
# 5            NaN        NaN           NaN        NaN        NaN     0.000000
# ...          ...        ...           ...        ...        ...          ...
# 23845        NaN        NaN           NaN        NaN        NaN     0.000000
# 23846        NaN        NaN           NaN        NaN        NaN     0.000000
# 23847        NaN        NaN           NaN        NaN        NaN     0.000000
# 23848        NaN        NaN           NaN        NaN        NaN     0.111278
# 23849        NaN        NaN           NaN        NaN        NaN     0.000000
#
# [16943 rows x 30 columns]

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_7984\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, iTarget, price, priceD, powerStatusD, sqFtPrice, furnishedD, bathD, ctName, bedroomD, coveredArea, parkingD, balconiesD, facingD, floors, carpetArea, carpAreaUnit, vl, devLogo, devOpSn, devtp, devpc, devpuc, propVid, crisilRv1, crisilRv2, crisilRv2CtBy, crircname1, crircname2, areaPercent]
# Index: []
#
# [0 rows x 30 columns]

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, iTarget, price, priceD, powerStatusD, sqFtPrice, furnishedD, bathD, ctName, bedroomD, coveredArea, parkingD, balconiesD, facingD, floors, carpetArea, carpAreaUnit, vl, devLogo, devOpSn, devtp, devpc, devpuc, propVid, crisilRv1, crisilRv2, crisilRv2CtBy, crircname1, crircname2, areaPercent]
# Index: []
#
# [0 rows x 30 columns]

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  sqFtPrice  bedroomD  coveredArea  balconiesD    floors  \
# price        1.000000   0.734824  0.447171     0.595811    0.216017  0.156420
# sqFtPrice    0.734824   1.000000  0.176148     0.109245    0.021223  0.053202
# bedroomD     0.447171   0.176148  1.000000     0.554207    0.294862  0.065414
# coveredArea  0.595811   0.109245  0.554207     1.000000    0.356371  0.105447
# balconiesD   0.216017   0.021223  0.294862     0.356371    1.000000  0.188639
# floors       0.156420   0.053202  0.065414     0.105447    0.188639  1.000000
# carpetArea   0.187278   0.035706  0.178089     0.316103    0.132286  0.035813
# devOpSn      0.454711   0.147602  0.707971     0.842698         NaN -0.707971
# devtp       -0.528854  -0.771473 -0.240302     0.895708         NaN  0.240302
# devpc       -0.307084  -0.594008  0.002445     0.976837         NaN -0.002445
# devpuc      -0.950929  -0.803004 -1.000000    -0.216374         NaN  1.000000
# areaPercent -0.003293   0.001753 -0.008238     0.026959   -0.011945  0.003545
#
#              carpetArea   devOpSn     devtp     devpc    devpuc  areaPercent
# price          0.187278  0.454711 -0.528854 -0.307084 -0.950929    -0.003293
# sqFtPrice      0.035706  0.147602 -0.771473 -0.594008 -0.803004     0.001753
# bedroomD       0.178089  0.707971 -0.240302  0.002445 -1.000000    -0.008238
# coveredArea    0.316103  0.842698  0.895708  0.976837 -0.216374     0.026959
# balconiesD     0.132286       NaN       NaN       NaN       NaN    -0.011945
# floors         0.035813 -0.707971  0.240302 -0.002445  1.000000     0.003545
# carpetArea     1.000000  0.994950  0.598827  0.775279 -0.633512    -0.076830
# devOpSn        0.994950  1.000000  0.515421  0.707971 -0.707971     0.000000
# devtp          0.598827  0.515421  1.000000  0.970108  0.240302    -0.856937
# devpc          0.775279  0.707971  0.970108  1.000000 -0.002445    -0.706242
# devpuc        -0.633512 -0.707971  0.240302 -0.002445  1.000000    -0.706242
# areaPercent   -0.076830  0.000000 -0.856937 -0.706242 -0.706242     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]

# %%
house_data
# Out:
#          possStatusD     price    priceD      powerStatusD  sqFtPrice  \
# 0            Dec '24   4170000  41.7 Lac  No/Rare Powercut     4317.0
# 1            Dec '27   8720103  87.2 Lac  No/Rare Powercut     6527.0
# 2            Dec '27   5300000    53 Lac  No/Rare Powercut     5146.0
# 3      Ready to Move  19200000   1.92 Cr  No/Rare Powercut    11608.0
# 4      Ready to Move   5062200  50.6 Lac  No/Rare Powercut     3900.0
# ...              ...       ...       ...               ...        ...
# 23845        Oct '28   6043800  60.4 Lac  No/Rare Powercut     4200.0
# 23846        Feb '26   4115000  41.2 Lac  No/Rare Powercut     5465.0
# 23847        Dec '27   8600000    86 Lac  No/Rare Powercut     7985.0
# 23848        Dec '28   5230350  52.3 Lac  No/Rare Powercut     7865.0
# 23849        Dec '24   3280000  32.8 Lac  No/Rare Powercut     4537.0
#
#            furnishedD bathD  bedroomD  coveredArea           parkingD  \
# 0         Unfurnished     2       2.0        966.0                  0
# 1         Unfurnished     2       3.0       1336.0          1 Covered
# 2         Unfurnished     2       3.0       1030.0                  0
# 3      Semi-Furnished     2       3.0       1654.0                  0
# 4         Unfurnished     2       3.0       1298.0          1 Covered
# ...               ...   ...       ...          ...                ...
# 23845     Unfurnished     2       3.0       1439.0          1 Covered
# 23846     Unfurnished     2       2.0        753.0  1 Covered, 1 Open
# 23847     Unfurnished     3       3.0       1077.0          1 Covered
# 23848     Unfurnished     2       2.0        665.0          1 Covered
# 23849     Unfurnished     2       2.0        723.0                  0
#
#        balconiesD facingD  floors  carpetArea carpAreaUnit  areaPercent
# 0             NaN     NaN     0.0       772.8        Sq-ft     0.000000
# 1             NaN     NaN     0.0      1068.8        Sq-ft     0.000000
# 2             NaN     NaN     0.0       824.0        Sq-ft     0.000000
# 3             1.0    East    35.0      1323.2        Sq-ft     0.000000
# 4             NaN     NaN     0.0       840.0        Sq-ft     0.352851
# ...           ...     ...     ...         ...          ...          ...
# 23845         NaN     NaN     0.0      1151.2        Sq-ft     0.000000
# 23846         NaN     NaN     0.0       602.4        Sq-ft     0.000000
# 23847         NaN     NaN     0.0       861.6        Sq-ft     0.000000
# 23848         NaN     NaN     0.0       591.0        Sq-ft     0.111278
# 23849         NaN     NaN     0.0       578.4        Sq-ft     0.000000
#
# [22940 rows x 16 columns]

# %%
house_data.drop(["iTarget", "ctName", "vl", "devtp",	"devpc", "devpuc", "devLogo", "devOpSn"], axis=1, inplace=True)

# %%
house_data.drop(["propVid", "crisilRv1", "crisilRv2", "crisilRv2CtBy", "crircname1", "crircname2"], axis=1, inplace=True)

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ("Dec '27",
#  5300000,
#  '53 Lac',
#  'No/Rare Powercut',
#  5146.0,
#  'Unfurnished',
#  '2',
#  3.0,
#  1030.0,
#  0,
#  nan,
#  nan,
#  0.0,
#  824.0,
#  'Sq-ft',
#  0.0)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'sqFtPrice',
#  'furnishedD',
#  'bathD',
#  'bedroomD',
#  'coveredArea',
#  'parkingD',
#  'balconiesD',
#  'facingD',
#  'floors',
#  'carpetArea',
#  'carpAreaUnit',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gigar\anaconda3\lib\site-packages (2.9.9)

# %%
city = 'Kolkata'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 940
