# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsMumbai.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'Hjujt6RPLcVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': 'DcxONr285wZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': 'bxrVtRrUI4xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': 'UUPlG01NTaZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': 'T2oYmME2ABRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': '2/FBLbHrWEJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': '61zq+jdknHtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': 'xKJ1vqNbGbtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': 'EJdRSYYfykZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'vuFyyRpmusBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        990  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        991  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        992  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        993  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        994  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        995  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        996  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        997  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        998  \
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        999
# nsrResultList                                                         None
# resultList               [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 998 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'Hjujt6RPLcVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': 'DcxONr285wZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'bxrVtRrUI4xzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': 'UUPlG01NTaZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': 'T2oYmME2ABRzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': '2/FBLbHrWEJzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': '61zq+jdknHtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': 'xKJ1vqNbGbtzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': 'EJdRSYYfykZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'vuFyyRpmusBzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       990  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       991  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       992  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       993  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       994  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       995  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       996  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       997  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       998  \
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       999
# resultList              [{'encId': '5ryIf6tpY3ZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 998 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "New Delhi"

# %%
house_data
# Out:
#                           encId    possStatusD pmtSource   possBy  \
# 0      Hjujt6RPLcVzpSvf+uAgZw==        Dec '28   Project  Dec '28
# 1      lcDQOj0T1NdzpSvf+uAgZw==        Jun '27   Project  Jun '27
# 2      NQxj/gcnFI1zpSvf+uAgZw==        Dec '26   Project  Dec '26
# 3      WCYJH8zacihzpSvf+uAgZw==        Apr '25   Project  Apr '25
# 4      HKoHrHTWn8xzpSvf+uAgZw==        Nov '28   Project  Nov '28
# ...                         ...            ...       ...      ...
# 29935  Iw2gu7MSteRzpSvf+uAgZw==        Dec '26   Project  Dec '26
# 29936  Ndu+NgAK659zpSvf+uAgZw==        Sep '26   Project  Sep '26
# 29937  R5i6AM3+G7JzpSvf+uAgZw==  Ready to Move   Project      NaN
# 29938  FQC/KCN6w7NzpSvf+uAgZw==        Dec '27   Project  Dec '27
# 29939  8ZCgXVBGyIFzpSvf+uAgZw==        Dec '28   Project  Dec '28
#
#       availableFrom cntvl                                                url  \
# 0           Dec '28  1250  3-BHK-1600-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 1           Jun '27   840  3-BHK-1122-Sq-ft-Multistorey-Apartment-FOR-Sal...
# 2           Dec '26   805  2-BHK-824-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 3           Apr '25   608  2-BHK-613-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 4           Nov '28   916  2-BHK-1210-Sq-ft-Multistorey-Apartment-FOR-Sal...
# ...             ...   ...                                                ...
# 29935       Dec '26  1027  2-BHK-710-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 29936       Sep '26   245  2-BHK-607-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 29937           NaN  1470  2-BHK-687-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 29938       Dec '27   413  2-BHK-573-Sq-ft-Multistorey-Apartment-FOR-Sale...
# 29939       Dec '28  1250  3-BHK-1350-Sq-ft-Multistorey-Apartment-FOR-Sal...
#
#        noBfCt   st modstat  ...  noOfSVis isCornerPlot comPantry bachelor  \
# 0           0  520   20205  ...       NaN          NaN       NaN      NaN
# 1           0  520   20205  ...       NaN          NaN       NaN      NaN
# 2           0  520   20205  ...       NaN          NaN       NaN      NaN
# 3           0  520   20205  ...       NaN          NaN       NaN      NaN
# 4           0  520   20205  ...       NaN          NaN       NaN      NaN
# ...       ...  ...     ...  ...       ...          ...       ...      ...
# 29935       0  520   20205  ...       NaN          NaN       NaN      NaN
# 29936       0  520   20205  ...       NaN          NaN       NaN      NaN
# 29937       0  520   20205  ...       NaN          NaN       NaN      NaN
# 29938       0  520   20205  ...       NaN          NaN       NaN      NaN
# 29939       0  520   20205  ...       NaN          NaN       NaN      NaN
#
#         nr  dimD cpmp brfdesc appExcRe       city
# 0      NaN   NaN  NaN     NaN      NaN  New Delhi
# 1      NaN   NaN  NaN     NaN      NaN  New Delhi
# 2      NaN   NaN  NaN     NaN      NaN  New Delhi
# 3      NaN   NaN  NaN     NaN      NaN  New Delhi
# 4      NaN   NaN  NaN     NaN      NaN  New Delhi
# ...    ...   ...  ...     ...      ...        ...
# 29935  NaN   NaN  NaN     NaN      NaN  New Delhi
# 29936  NaN   NaN  NaN     NaN      NaN  New Delhi
# 29937  NaN   NaN  NaN     NaN      NaN  New Delhi
# 29938  NaN   NaN  NaN     NaN      NaN  New Delhi
# 29939  NaN   NaN  NaN     NaN      NaN  New Delhi
#
# [29940 rows x 262 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# possBy
# availableFrom
# cntvl
# url
# noBfCt
# st
# modstat
# appVer
# appSub
# deviceType
# sendbirdId
# lastAccessDate
# lastReplyDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# taImg
# cScore
# devName
# prjHl1
# prjLtHl1
# postDateT
# endDateT
# pl
# prjSrc
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# seoDesc
# psmImage
# propCat
# siteVisitProp
# pfAgCg
# id
# pmtmtrendPercentage
# flooringTyD
# powerStatusD
# sv
# cg
# pp
# prjid
# bookingAmtExact
# dImgSrc
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# ac
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# companyname
# contName
# auto_desc
# prjname
# sqFtPrD
# carpetArea
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# supV
# lmtDName
# criLogo
# achTdS
# opSn
# opSnD
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# isVis
# showupfront
# isRera
# isReraAgent
# agentReraState
# reraId
# caCompNameD
# postedLabelD
# furnishedD
# bathD
# parkingD
# transactionTypeD
# floorCsntrAllowed
# propTypeD
# ctName
# bedroomD
# userType
# transType
# isPreferred
# brokerConnect
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# crisilRv1CtBy
# crisilNoOfEmployees
# crisilStarRating
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# psmImgCt
# smartDiaryApiTag
# waterStatus
# isLuxury
# coveredArea
# covAreaUnit
# carpAreaUnit
# modifiedDate
# imgUrl
# image
# actualOwner
# isProjProp
# devId
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# pckCon
# ctCurr
# ctLast
# rEcd
# endDt
# newUrl
# seoPsmDt
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# operatingSinceYear
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# agentContinuityStr
# isLuxuryServiceAvailable
# ctaDetailBean
# iTarget
# lCtDate
# luxAmenities
# luxAmenitiesD
# agtCerStatus
# amenities
# luxAmenMap
# nonluxAmenMap
# psmapproved
# floorNo
# vl
# floorD
# floors
# psmUspImgWeb
# psmUspImgMob
# dealDesc
# crisilOpSinceYear
# appovedAuthC
# nriPref
# availUnit
# propertyImageNew
# adroomD
# maintenanceD
# agtCrSt
# maintenanceCharges
# landmark
# acD
# imageDate
# pkgid
# pmtUspWap
# tag
# tagWap
# sid
# pmtUsp
# OwnershipTypeD
# facingD
# amenFacingD
# ranPropImg
# catAdd1
# investorlisting
# investorguide
# agComCt
# balconiesD
# pmtUsp1
# dues
# ltOther
# attrImg
# lc
# lcLst
# adCn
# gateComm
# pmtUsp2
# pmtUsp2Wap
# pbrk
# pbrkp
# agentDetailUrl
# isprimeListingType
# pmtTCabin
# la
# landAreaUnit
# landAreaUnitD
# rdWidth
# nOs
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# isExcl
# sVisMinDt
# sVisMaxDt
# noOfSVis
# isCornerPlot
# comPantry
# bachelor
# nr
# dimD
# cpmp
# brfdesc
# appExcRe
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId NQxj/gcnFI1zpSvf+uAgZw== WCYJH8zacihzpSvf+uAgZw==
# possStatusD Dec '26 Apr '25
# pmtSource Project Project
# possBy Dec '26 Apr '25
# availableFrom Dec '26 Apr '25
# cntvl 805 608
# url 2-BHK-824-Sq-ft-Multistorey-Apartment-FOR-Sale-Andheri-East-in-Mumbai&id=4d423731373038393833 2-BHK-613-Sq-ft-Multistorey-Apartment-FOR-Sale-Ghatkopar-East-in-Mumbai&id=4d423731363936313831
# noBfCt 0 0
# st 520 520
# modstat 20205 20205
# appVer nan 475.0
# appSub N Y
# deviceType nan and
# sendbirdId 70d5d033-55de-46f8-8dac-4fc1c6e6f494shar2000 5911b483-5dd2-4564-b9dd-00522397754eshre3377
# lastAccessDate 1522434600000.0 1710181800000.0
# lastReplyDate nan 1588530600000.0
# projectSocietyLink park-royale-andheri-east-mumbai-pdpid-4d4235303737313636 drushti-sapphire-ghatkopar-east-mumbai-pdpid-4d4235333235383035
# sipro 70364039 68565493 68984965 69500855 71065253 71010123 68545977 70960317
# comFlag Y Y
# appExc N N
# taImg nan nan
# cScore 35 50
# devName Pride Group Drushti Group
# prjHl1 Spacious Apartments with Efficient Layouts  Multipurpose Lawn for fun and leisure activity
# prjLtHl1 Marol Metro Station : 10 mins  Eastern express highway 0.9 km
# postDateT 2024-03-12T17:35:37.000Z 2024-03-11T17:35:38.000Z
# endDateT 2024-05-11T17:35:37.000Z 2024-05-10T17:35:38.000Z
# pl Y Y
# prjSrc 20521 20527
# enc_Id NQxj/gcnFI0OA6TRJmrOuw== WCYJH8zacigrlqz1C2Etvg==
# cowDays 0 0
# price 22500000.0 17000000.0
# priceD 2.25 Cr 1.70 Cr
# imgCt 20 34
# landmarkDetails ['19201|0.0 Km from 99acres.com', '19210|0.6 Km from Airport Road metro station, Mumbai', '19202|0.2 Km from Pd Hinduja College Of Nursing'] ['19201|1.8 Km from Goldcrest Business Park', '19210|0.9 Km from Ghatkopar metro station, Mumbai', '19202|0.2 Km from Ramniranjan Jhunjhunwala College']
# seoDesc Have a look at this 2 BHK flat for sale in Andheri East, Mumbai. The flat has a prime location within Park Royale. This apartment for sale is among the best bargains available. This dec '26 flat is offered at an economical price of INR 2.25 Cr. The possession date of the property is Dec '26. The apartment is sold in unfurnished state. Have a look at this 2 BHK flat for sale in Ghatkopar East, Mumbai. Being located in Drushti Sapphire, the property is easily accessible. This is one of the best properties available for sale. This apr '25 flat in Ghatkopar East can be availed at a reasonable price of INR 1.70 Cr. This flat is available for possession on Apr '25. This unfurnished apartment for sale is strategically designed.
# psmImage https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/03/10/Project-Photo-20-Park-Royale-Mumbai-5077166_345_1366_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/03/06/Project-Photo-36-Drushti-Sapphire-Mumbai-5325805_345_1366_310_462.jpg
# propCat 20292 20292
# siteVisitProp 0.0 0.0
# pfAgCg nan nan
# id 71708983 71696181
# pmtmtrendPercentage 0 0
# flooringTyD nan Vitrified
# powerStatusD No/Rare Powercut No/Rare Powercut
# sv Y Y
# cg b b
# pp B Z
# prjid 644619 644585
# bookingAmtExact nan nan
# dImgSrc 11120 11120
# seoLtSc 1 1
# pSc 0 0
# pCct 0 0
# lCct 0 0
# pcTcCt 0 0
# ac 10080.0 10080.0
# caSqFt nan nan
# ltcoordGeo 19.1154908,72.8726952 19.07907,72.907976
# iba Y X
# ct 4320 4320
# lt 60017.0 78859.0
# loc 60017.0 78859.0
# bd 11701 11701
# ca nan nan
# ty 10002 10002
# dtldesc Park Royale comes loaded with attributes and amenities that add charm to your way of life and makes living an experience you will relish day after day, minute after minute. The adjoining 7 acres landscaped gar tranquil and refreshing lifestyle and give you the elixir of life. a exclusive swimming pool and clubhouse makes it a place straight out of your dreams while the luxury of a Jacuzzi and Steam Bath would be the perfect way of rejuvenating and relaxing after hard days of work. Drushti Sapphire is Located in Ghatkopar East, Nearing Possession by August 2024, Well Planned Project, Podium Level 20+ Lifestyle Amenities, 3 Level Basement Car Parking, 2BHK Apartments with Lifetime open and amenities Views, Project is Well Connected to the Markets, School, Hospitals and Ghatkopar Railway and Metro Station, Quote Price is All Inclusive which is Negotiable kindly Contact me for Best Deal.
# plgdtldesc Park Royale comes loaded with attributes and amenities that add charm to your way of life and makes living an experience you will relish day after day, minute after minute. The adjoining 7 acres landscaped gar tranquil and refreshing lifestyle and give you the elixir of life. a exclusive swimming pool and clubhouse makes it a place straight out of your dreams while the luxury of a Jacuzzi and Steam Bath would be the perfect way of rejuvenating and relaxing after hard days of work. Drushti Sapphire is Located in Ghatkopar East, Nearing Possession by August 2024, Well Planned Project, Podium Level 20+ Lifestyle Amenities, 3 Level Basement Car Parking, 2BHK Apartments with Lifetime open and amenities Views, Project is Well Connected to the Markets, School, Hospitals and Ghatkopar Railway and Metro Station, Quote Price is All Inclusive which is Negotiable kindly Contact me for Best Deal.
# oid 14121927 5871792
# oname Sharan Pramod  Bhole
# sdp Y Y
# companyname nan nan
# contName nan nan
# auto_desc 2 BHK, Multistorey Apartment is available for Sale in Andheri East, Mumbai for 2.2 Crore(s) 2 BHK, Multistorey Apartment is available for Sale in Ghatkopar East, Mumbai for 1.7 Crore(s)
# prjname Park Royale Drushti Sapphire
# sqFtPrD nan nan
# carpetArea 824 613
# pkg 10070 10070
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 19.1154908 19.07907
# pmtLong 72.8726952 72.907976
# moisd 50 50
# supV Y Y
# lmtDName Andheri East Ghatkopar East
# criLogo nan nan
# achTdS 46 0
# opSn nan nan
# opSnD nan nan
# locSeoName Andheri East Ghatkopar East
# propImg 2024/03/10/Project-Photo-5-Park-Royale-Mumbai-5077166_2000_1335.jpg 2024/03/04/Project-Photo-16-Drushti-Sapphire-Mumbai-5325805_1340_1600.jpg
# coverAreaUnitD nan nan
# ppd 20240312 20240311
# ppdL 1710264937000 1710178538000
# achTm 13 0
# achTmS 13 0
# soc N N
# tmsrt 124237 134016
# ecd 20240312 20240312
# prm y y
# sqFtPrice nan nan
# psmid 5077166 5325805
# isVis Z Z
# showupfront N N
# isRera Y Y
# isReraAgent nan Y
# agentReraState nan A51800005304
# reraId P51800053602 P51800032434
# caCompNameD Sharan Pramod  Bhole
# postedLabelD Posted Yesterday Posted: Mar 11, '24
# furnishedD Unfurnished Unfurnished
# bathD 2 2
# parkingD 1 Covered 1 Covered
# transactionTypeD New Property New Property
# floorCsntrAllowed nan nan
# propTypeD Apartment Apartment
# ctName Mumbai Mumbai
# bedroomD 2 2
# userType Builder Agent
# transType Sale Sale
# isPreferred false false
# brokerConnect nan nan
# dImgRf PROJ2337303 PROJ2332477
# localityPhoto 0 0
# defaultAdddressGoogle Mumbai, Maharashtra Mumbai, Maharashtra
# propertyTitle 2BHK Multistorey Apartment for New Property in Park Royale at Andheri East 2BHK Multistorey Apartment for New Property in Drushti Sapphire at Ghatkopar East
# crisilRv1CtBy nan nan
# crisilNoOfEmployees nan nan
# crisilStarRating nan nan
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbimages/project/Photo_h80_w120/2024/03/10/Project-Photo-5-Park-Royale-Mumbai-5077166_2000_1335_80_120.jpg https://img.staticmb.com/mbimages/project/Photo_h80_w120/2024/03/04/Project-Photo-16-Drushti-Sapphire-Mumbai-5325805_1340_1600_80_120.jpg
# wapImgUrl1 https://img.staticmb.com/mbimages/project/Photo_h100_w150/2024/03/10/Project-Photo-5-Park-Royale-Mumbai-5077166_2000_1335_100_150.jpg https://img.staticmb.com/mbimages/project/Photo_h100_w150/2024/03/04/Project-Photo-16-Drushti-Sapphire-Mumbai-5325805_1340_1600_100_150.jpg
# seoURL propertyDetails-2-BHK-824-Sqft-Flat-FOR-Sale-Andheri-East-in-Mumbai&id=NQxjslshgcnFI1zpSvf+uAgZw==&category=Sale propertyDetails-2-BHK-613-Sqft-Flat-FOR-Sale-Ghatkopar-East-in-Mumbai&id=WCYJH8zacihzpSvf+uAgZw==&category=Sale
# psmImgCt 20 34
# smartDiaryApiTag nan nan
# waterStatus Water Availability 24 Hours Available Water Availability 24 Hours Available
# isLuxury F F
# coveredArea nan nan
# covAreaUnit nan nan
# carpAreaUnit Sq-ft Sq-ft
# modifiedDate Yesterday Mar 11, '24
# imgUrl nan nan
# image https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/03/10/Project-Photo-5-Park-Royale-Mumbai-5077166_2000_1335_310_462.jpg https://img.staticmb.com/mbimages/project/Photo_h310_w462/2024/03/04/Project-Photo-16-Drushti-Sapphire-Mumbai-5325805_1340_1600_310_462.jpg
# actualOwner 14121927 5871792
# isProjProp Y Y
# devId 55591 65848
# pglmtkey 14121927_1 5871792_1
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 64942724.0 63814468.0
# sortCode1b 64942728.0 63814468.0
# sortCode22 0.0 0.0
# sortCode26 45790800.0 45045684.0
# ubicnt 50 50
# pckCon nan 0.3
# ctCurr nan 1
# ctLast nan 0
# rEcd 20240312 20240311
# endDt May 11, '24 May 10, '24
# newUrl nan project-drushti-sapphire-for-sale-in-mumbai-pppfs
# seoPsmDt {"bhkPriceRange":{"3 BHK":{"minPrice":"2.76 Cr","maxPrice":"2.96 Cr"},"2 BHK":{"minPrice":"2.15 Cr","maxPrice":"2.25 Cr"}}} {"bhkPriceRange":{"2 BHK":{"minPrice":"1.69 Cr","maxPrice":"1.83 Cr"}}}
# pmtdesc_hi अँधेरी ईस्ट, मुंबई में स्थित यह खूबसूरत 2 BHK फ्लैट बिक्री के लिए उपलब्ध है। यह पार्क रॉयल कॉम्पलेक्स में है, जो यहाँ का एक प्राइम लोकेशन है। यहां रहने वाले लोगों की सुविधा के लिए 2 बाथरूम हैं। इस 2 BHK अपार्टमेंट में आपको अपनी कार के लिए निःशुल्क 1कवर्ड पार्किंग की जगह मिलती है। सेल के लिए उपलब्ध यह फ्लैट एक अच्छी जगह पर है। अँधेरी ईस्ट में स्थित रु. 2.25 Cr के उचित बिक्री मूल्य के लिए उपलब्ध, यह dec '26 अपार्टमेंट एक शानदार मौका है। यह फ्लैट Dec '26 को पज़ेशन के लिए उपलब्ध है। फ्लैट अनफर्निश्ड कंडीशन में बेचा जाता है।  घाटकोपर ईस्ट, मुंबई में स्थित यह शानदार 2 BHK फ्लैट बिक्री के लिए उपलब्ध है। यह फ्लैट दृष्टी सफायर की प्रसिद्ध टाउनशिप में स्थित है। इस फ्लैट में अच्छी क्वालिटी के सामान वाले कुल 2 बाथरूम हैं। बिक्री के लिए उपलब्ध इस 2 BHK फ्लैट के साथ परिवार के सभी सदस्यों के लिए अलग-अलग 1कवर्ड पार्किंग है। यह सेल के लिए एक पसंदीदा अपार्टमेंट है। घाटकोपर ईस्ट में स्थित रु. 1.70 Cr के उचित बिक्री मूल्य के लिए उपलब्ध, यह apr '25 अपार्टमेंट एक शानदार मौका है। यह फ्लैट Apr '25 को पज़ेशन के लिए उपलब्ध है। यह प्रीमियम अनफर्निश्ड फ्लैट बहुत ही किफायती कीमत पर उपलब्ध है और इसमें सभी तरह की सुविधाएं है।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# operatingSinceYear nan nan
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc nan nan
# ampDesc Park Royale comes loaded with attributes and amenities that add charm to your way of life and makes  Drushti Sapphire is Located in Ghatkopar East, Nearing Possession by August 2024, Well Planned Proje
# b2cCardEligibility false false
# maskedMobileNumber +91-80XXXXXXX00 +91-98XXXXXXX77
# agentContinuityStr nan nan
# isLuxuryServiceAvailable False False
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# iTarget nan nan
# lCtDate 1709870633000.0 nan
# luxAmenities nan nan
# luxAmenitiesD nan nan
# agtCerStatus N nan
# amenities nan nan
# luxAmenMap nan nan
# nonluxAmenMap nan nan
# psmapproved Y nan
# floorNo nan 14
# vl nan Y
# floorD nan 14 of 17 Floor
# floors nan 17
# psmUspImgWeb nan nan
# psmUspImgMob nan nan
# dealDesc nan nan
# crisilOpSinceYear nan nan
# appovedAuthC nan nan
# nriPref nan nan
# availUnit nan nan
# propertyImageNew nan nan
# adroomD nan nan
# maintenanceD nan nan
# agtCrSt nan nan
# maintenanceCharges nan nan
# landmark nan nan
# acD nan nan
# imageDate nan nan
# pkgid nan nan
# pmtUspWap nan nan
# tag nan nan
# tagWap nan nan
# sid nan nan
# pmtUsp nan nan
# OwnershipTypeD nan nan
# facingD nan nan
# amenFacingD nan nan
# ranPropImg nan nan
# catAdd1 nan nan
# investorlisting nan nan
# investorguide nan nan
# agComCt nan nan
# balconiesD nan nan
# pmtUsp1 nan nan
# dues nan nan
# ltOther nan nan
# attrImg nan nan
# lc nan nan
# lcLst nan nan
# adCn nan nan
# gateComm nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# pbrk nan nan
# pbrkp nan nan
# agentDetailUrl nan nan
# isprimeListingType nan nan
# pmtTCabin nan nan
# la nan nan
# landAreaUnit nan nan
# landAreaUnitD nan nan
# rdWidth nan nan
# nOs nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# isExcl nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# noOfSVis nan nan
# isCornerPlot nan nan
# comPantry nan nan
# bachelor nan nan
# nr nan nan
# dimD nan nan
# cpmp nan nan
# brfdesc nan nan
# appExcRe nan nan
# city New Delhi New Delhi

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"lc",
"pSc",
"lcLst",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"nr",
"appExcRe",
"pbrk",
"pbrkp",
"brfdesc",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD       price   priceD      powerStatusD  sqFtPrD  \
# 0            Dec '28  54500000.0  5.45 Cr  No/Rare Powercut  34062.0
# 1            Jun '27  35000000.0  3.50 Cr  No/Rare Powercut      NaN
# 2            Dec '26  22500000.0  2.25 Cr  No/Rare Powercut      NaN
# 3            Apr '25  17000000.0  1.70 Cr  No/Rare Powercut      NaN
# 4            Nov '28  23380000.0  2.33 Cr  No/Rare Powercut  19322.0
# ...              ...         ...      ...               ...      ...
# 29935        Dec '26  19100000.0  1.91 Cr  No/Rare Powercut      NaN
# 29936        Sep '26  14847000.0  1.48 Cr  No/Rare Powercut      NaN
# 29937  Ready to Move  27400000.0  2.74 Cr  No/Rare Powercut      NaN
# 29938        Dec '27  15800000.0  1.58 Cr  No/Rare Powercut      NaN
# 29939        Dec '28  47500000.0  4.75 Cr  No/Rare Powercut  35185.0
#
#       carpetArea  sqFtPrice      furnishedD bathD   parkingD  ...  \
# 0           1340    34062.0     Unfurnished     3  1 Covered  ...
# 1           1122        NaN     Unfurnished     3  1 Covered  ...
# 2            824        NaN     Unfurnished     2  1 Covered  ...
# 3            613        NaN     Unfurnished     2  1 Covered  ...
# 4            835    19322.0  Semi-Furnished     2        NaN  ...
# ...          ...        ...             ...   ...        ...  ...
# 29935        710        NaN     Unfurnished     2        NaN  ...
# 29936        607        NaN     Unfurnished     3        NaN  ...
# 29937        687        NaN     Unfurnished     2  1 Covered  ...
# 29938        573        NaN     Unfurnished     2  1 Covered  ...
# 29939       1100    35185.0     Unfurnished     3  1 Covered  ...
#
#                floorD floors propertyImageNew          maintenanceD  \
# 0                 NaN    NaN              NaN                   NaN
# 1                 NaN    NaN              NaN                   NaN
# 2                 NaN    NaN              NaN                   NaN
# 3      14 of 17 Floor     17              NaN                   NaN
# 4                 NaN    NaN              NaN                   NaN
# ...               ...    ...              ...                   ...
# 29935             NaN    NaN              NaN  Per sq. Unit Monthly
# 29936             NaN    NaN              NaN                   NaN
# 29937             NaN    NaN              NaN                   NaN
# 29938             NaN    NaN              NaN                   NaN
# 29939             NaN    NaN              NaN                   NaN
#
#       OwnershipTypeD facingD balconiesD attrImg bachelor       city
# 0                NaN     NaN        NaN     NaN      NaN  New Delhi
# 1                NaN     NaN        NaN     NaN      NaN  New Delhi
# 2                NaN     NaN        NaN     NaN      NaN  New Delhi
# 3                NaN     NaN        NaN     NaN      NaN  New Delhi
# 4                NaN     NaN        NaN     NaN      NaN  New Delhi
# ...              ...     ...        ...     ...      ...        ...
# 29935            NaN     NaN        NaN     NaN      NaN  New Delhi
# 29936            NaN     NaN        NaN     NaN      NaN  New Delhi
# 29937            NaN     NaN        NaN     NaN      NaN  New Delhi
# 29938            NaN     NaN        NaN     NaN      NaN  New Delhi
# 29939            NaN     NaN        NaN     NaN      NaN  New Delhi
#
# [29940 rows x 32 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD            88
# price                  92
# priceD                  0
# powerStatusD         4825
# sqFtPrD             14955
# carpetArea           3982
# sqFtPrice           15044
# furnishedD            488
# bathD                  96
# parkingD            16934
# ctName                  0
# bedroomD                0
# coveredArea         14982
# covAreaUnit         14979
# carpAreaUnit         3997
# image                1604
# ctLast              18554
# iTarget             28344
# luxAmenities        23859
# luxAmenitiesD       23859
# amenities           23362
# vl                  14029
# floorD              20990
# floors              20999
# propertyImageNew    26106
# maintenanceD        26277
# OwnershipTypeD      25811
# facingD             26005
# balconiesD          26175
# attrImg             28708
# bachelor            29939
# city                    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD             0
# price                  92
# priceD                  0
# powerStatusD         4825
# sqFtPrD             14955
# carpetArea           3982
# sqFtPrice           15044
# furnishedD            488
# bathD                  96
# parkingD            16934
# ctName                  0
# bedroomD                0
# coveredArea         14982
# covAreaUnit         14979
# carpAreaUnit         3997
# image                1604
# ctLast              18554
# iTarget             28344
# luxAmenities        23859
# luxAmenitiesD       23859
# amenities           23362
# vl                  14029
# floorD              20990
# floors              20999
# propertyImageNew    26106
# maintenanceD        26277
# OwnershipTypeD      25811
# facingD             26005
# balconiesD          26175
# attrImg             28708
# bachelor            29939
# city                    0
# dtype: int64

# %%
house_data.drop(["luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#          possStatusD       price   priceD      powerStatusD carpetArea  \
# 0            Dec '28  54500000.0  5.45 Cr  No/Rare Powercut       1340
# 1            Jun '27  35000000.0  3.50 Cr  No/Rare Powercut       1122
# 2            Dec '26  22500000.0  2.25 Cr  No/Rare Powercut        824
# 3            Apr '25  17000000.0  1.70 Cr  No/Rare Powercut        613
# 4            Nov '28  23380000.0  2.33 Cr  No/Rare Powercut        835
# ...              ...         ...      ...               ...        ...
# 29935        Dec '26  19100000.0  1.91 Cr  No/Rare Powercut        710
# 29936        Sep '26  14847000.0  1.48 Cr  No/Rare Powercut        607
# 29937  Ready to Move  27400000.0  2.74 Cr  No/Rare Powercut        687
# 29938        Dec '27  15800000.0  1.58 Cr  No/Rare Powercut        573
# 29939        Dec '28  47500000.0  4.75 Cr  No/Rare Powercut       1100
#
#        sqFtPrice      furnishedD bathD   parkingD  ctName bedroomD  \
# 0        34062.0     Unfurnished     3  1 Covered  Mumbai        3
# 1            NaN     Unfurnished     3  1 Covered  Mumbai        3
# 2            NaN     Unfurnished     2  1 Covered  Mumbai        2
# 3            NaN     Unfurnished     2  1 Covered  Mumbai        2
# 4        19322.0  Semi-Furnished     2        NaN  Mumbai        2
# ...          ...             ...   ...        ...     ...      ...
# 29935        NaN     Unfurnished     2        NaN  Mumbai        2
# 29936        NaN     Unfurnished     3        NaN  Mumbai        2
# 29937        NaN     Unfurnished     2  1 Covered  Mumbai        2
# 29938        NaN     Unfurnished     2  1 Covered  Mumbai        2
# 29939    35185.0     Unfurnished     3  1 Covered  Mumbai        3
#
#       coveredArea carpAreaUnit iTarget   vl floors facingD balconiesD attrImg  \
# 0            1600        Sq-ft     NaN  NaN    NaN     NaN        NaN     NaN
# 1             NaN        Sq-ft       Y  NaN    NaN     NaN        NaN     NaN
# 2             NaN        Sq-ft     NaN  NaN    NaN     NaN        NaN     NaN
# 3             NaN        Sq-ft     NaN    Y     17     NaN        NaN     NaN
# 4            1210        Sq-ft     NaN    Y    NaN     NaN        NaN     NaN
# ...           ...          ...     ...  ...    ...     ...        ...     ...
# 29935         NaN        Sq-ft     NaN    Y    NaN     NaN        NaN     NaN
# 29936         NaN        Sq-ft     NaN    Y    NaN     NaN        NaN     NaN
# 29937         NaN        Sq-ft     NaN    Y    NaN     NaN        NaN     NaN
# 29938         NaN        Sq-ft       Y  NaN    NaN     NaN        NaN     NaN
# 29939        1350        Sq-ft     NaN  NaN    NaN     NaN        NaN     NaN
#
#       bachelor
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 29935      NaN
# 29936      NaN
# 29937      NaN
# 29938      NaN
# 29939      NaN
#
# [29940 rows x 20 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             25104
# Less Than 2 Hour Powercut        8
# Over 6 Hours Powercut            2
# 2 To 4 Hours Powercut            1
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#              possStatusD       price    priceD               powerStatusD  \
# 363   Under Construction  24900000.0   2.49 Cr  Less Than 2 Hour Powercut
# 2158       Ready to Move   2150000.0  21.5 Lac  Less Than 2 Hour Powercut
# 2175       Ready to Move  31000000.0   3.10 Cr  Less Than 2 Hour Powercut
# 3268       Ready to Move   8000000.0    80 Lac  Less Than 2 Hour Powercut
# 4483       Ready to Move   3900000.0    39 Lac  Less Than 2 Hour Powercut
# 5575       Ready to Move  14000000.0   1.40 Cr  Less Than 2 Hour Powercut
# 5792       Ready to Move   6300000.0    63 Lac  Less Than 2 Hour Powercut
# 5953       Ready to Move   4000000.0    40 Lac  Less Than 2 Hour Powercut
#
#      carpetArea  sqFtPrice      furnishedD bathD   parkingD  ctName bedroomD  \
# 363         958    25992.0     Unfurnished     3  1 Covered  Mumbai        3
# 2158        550     2774.0     Unfurnished     2   101 Open  Mumbai        2
# 2175        850    32632.0       Furnished     3  2 Covered  Mumbai        2
# 3268       1238     4785.0       Furnished     2        NaN  Mumbai        2
# 4483        526     4722.0  Semi-Furnished     2        NaN  Mumbai        2
# 5575       1240        NaN  Semi-Furnished     3  1 Covered  Mumbai        3
# 5792        449     9692.0     Unfurnished     2        NaN  Mumbai        2
# 5953        865     4624.0     Unfurnished     2    10 Open  Mumbai        2
#
#      coveredArea carpAreaUnit iTarget   vl floors       facingD balconiesD  \
# 363          958        Sq-ft     NaN  NaN     17          East        NaN
# 2158         775        Sq-ft     NaN  NaN      3           NaN          3
# 2175         950        Sq-ft     NaN  NaN     21  North - East          2
# 3268        1672        Sq-ft     NaN  NaN      3          West          1
# 4483         826        Sq-ft     NaN  NaN      7           NaN        NaN
# 5575         NaN        Sq-ft     NaN  NaN      7          West        NaN
# 5792         650        Sq-ft     NaN  NaN     21   South -West          2
# 5953         865        Sq-ft     NaN  NaN      7          West          3
#
#                                                 attrImg bachelor
# 363                                                 NaN      NaN
# 2158                                                NaN      NaN
# 2175  https://img.staticmb.com/mbphoto/property/crop...      NaN
# 3268  https://img.staticmb.com/mbphoto/property/crop...      NaN
# 4483                                                NaN      NaN
# 5575                                                NaN      NaN
# 5792                                                NaN      NaN
# 5953                                                NaN      NaN

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price              92
# priceD              0
# powerStatusD     4825
# carpetArea       3982
# sqFtPrice       15044
# furnishedD        488
# bathD              96
# parkingD        16934
# ctName              0
# bedroomD            0
# coveredArea     14982
# carpAreaUnit     3997
# iTarget         28344
# vl              14029
# floors          20999
# facingD         26005
# balconiesD      26175
# attrImg         28708
# bachelor        29939
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 29940

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.1625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.09674387020597192

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#               possStatusD       price   priceD      powerStatusD carpetArea  \
# 0                 Dec '28  54500000.0  5.45 Cr  No/Rare Powercut       1340
# 4                 Nov '28  23380000.0  2.33 Cr  No/Rare Powercut        835
# 7                 Dec '26  18400000.0  1.84 Cr  No/Rare Powercut        763
# 8      Under Construction  30000000.0     3 Cr  No/Rare Powercut        772
# 9                 Jun '26  14300000.0  1.43 Cr  No/Rare Powercut        623
# ...                   ...         ...      ...               ...        ...
# 29929             Jun '29  53400000.0  5.34 Cr  No/Rare Powercut        866
# 29931       Ready to Move  30900000.0  3.09 Cr  No/Rare Powercut       1037
# 29932             Dec '26  15200000.0  1.52 Cr  No/Rare Powercut        605
# 29933       Ready to Move  29000000.0  2.90 Cr  No/Rare Powercut        850
# 29939             Dec '28  47500000.0  4.75 Cr  No/Rare Powercut       1100
#
#        sqFtPrice      furnishedD bathD   parkingD  ctName  ... coveredArea  \
# 0        34062.0     Unfurnished     3  1 Covered  Mumbai  ...      1600.0
# 4        19322.0  Semi-Furnished     2          0  Mumbai  ...      1210.0
# 7        20109.0     Unfurnished     2  1 Covered  Mumbai  ...       915.0
# 8        33822.0  Semi-Furnished     2  1 Covered  Mumbai  ...       887.0
# 9        19972.0     Unfurnished     2  1 Covered  Mumbai  ...       716.0
# ...          ...             ...   ...        ...     ...  ...         ...
# 29929    53668.0  Semi-Furnished     2  1 Covered  Mumbai  ...       995.0
# 29931    24720.0     Unfurnished     3  1 Covered  Mumbai  ...      1250.0
# 29932    21408.0     Unfurnished     2          0  Mumbai  ...       710.0
# 29933    23200.0  Semi-Furnished     2  1 Covered  Mumbai  ...      1250.0
# 29939    35185.0     Unfurnished     3  1 Covered  Mumbai  ...      1350.0
#
#        carpAreaUnit iTarget   vl floors facingD balconiesD attrImg bachelor  \
# 0             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 4             Sq-ft     NaN    Y      0     NaN        NaN     NaN      NaN
# 7             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 8             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 9             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# ...             ...     ...  ...    ...     ...        ...     ...      ...
# 29929         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 29931         Sq-ft     NaN  NaN     43     NaN        NaN     NaN      NaN
# 29932         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 29933         Sq-ft     NaN  NaN     38    East          3     NaN      NaN
# 29939         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
#
#       areaPercent
# 0        0.162500
# 4        0.309917
# 7        0.166120
# 8        0.129651
# 9        0.129888
# ...           ...
# 29929    0.129648
# 29931    0.170400
# 29932    0.147887
# 29933    0.320000
# 29939    0.185185
#
# [14958 rows x 21 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price              63
# priceD              0
# powerStatusD        0
# carpetArea          0
# sqFtPrice           0
# furnishedD          0
# bathD              87
# parkingD            0
# ctName              0
# bedroomD            0
# coveredArea         0
# carpAreaUnit        0
# iTarget         14957
# vl              10186
# floors              0
# facingD         11316
# balconiesD      12242
# attrImg         13886
# bachelor        14957
# areaPercent         0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#         possStatusD  price          priceD      powerStatusD carpetArea  \
# 5998  Ready to Move    NaN  Call for Price  No/Rare Powercut      840.0
# 6000  Ready to Move    NaN  Call for Price  No/Rare Powercut      624.0
# 6001  Ready to Move    NaN  Call for Price  No/Rare Powercut      252.0
# 6003  Ready to Move    NaN  Call for Price  No/Rare Powercut      560.0
# 6004  Ready to Move    NaN  Call for Price  No/Rare Powercut        800
# ...             ...    ...             ...               ...        ...
# 6080  Ready to Move    NaN  Call for Price  No/Rare Powercut      560.0
# 6081  Ready to Move    NaN  Call for Price  No/Rare Powercut      800.0
# 6082  Ready to Move    NaN  Call for Price  No/Rare Powercut      728.8
# 6083  Ready to Move    NaN  Call for Price  No/Rare Powercut      480.0
# 6085  Ready to Move    NaN  Call for Price  No/Rare Powercut       50.4
#
#       sqFtPrice      furnishedD bathD parkingD  ctName  ... coveredArea  \
# 5998        0.0     Unfurnished   NaN        0  Mumbai  ...      1050.0
# 6000        0.0     Unfurnished   NaN        0  Mumbai  ...       780.0
# 6001        0.0     Unfurnished   NaN        0  Mumbai  ...       315.0
# 6003        0.0     Unfurnished     1        0  Mumbai  ...       700.0
# 6004        0.0     Unfurnished     2        0  Mumbai  ...      1100.0
# ...         ...             ...   ...      ...     ...  ...         ...
# 6080        0.0     Unfurnished     2        0  Mumbai  ...       700.0
# 6081        0.0  Semi-Furnished     2        0  Mumbai  ...      1000.0
# 6082        0.0     Unfurnished   NaN        0  Mumbai  ...       911.0
# 6083        0.0     Unfurnished     2        0  Mumbai  ...       600.0
# 6085        0.0     Unfurnished   NaN        0  Mumbai  ...        63.0
#
#       carpAreaUnit iTarget   vl floors facingD balconiesD attrImg bachelor  \
# 5998         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6000         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6001         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6003         Sq-ft     NaN  NaN      4     NaN        NaN     NaN      NaN
# 6004         Sq-ft     NaN  NaN     12     NaN          1     NaN      NaN
# ...            ...     ...  ...    ...     ...        ...     ...      ...
# 6080         Sq-ft     NaN  NaN      6     NaN        NaN     NaN      NaN
# 6081         Sq-ft     NaN  NaN      7     NaN        NaN     NaN      NaN
# 6082         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6083         Sq-ft     NaN  NaN      7     NaN        NaN     NaN      NaN
# 6085         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
#
#      areaPercent
# 5998    0.000000
# 6000    0.000000
# 6001    0.000000
# 6003    0.000000
# 6004    0.272727
# ...          ...
# 6080    0.000000
# 6081    0.000000
# 6082    0.000000
# 6083    0.000000
# 6085    0.000000
#
# [63 rows x 21 columns]

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\1780203852.py:2: RuntimeWarning: invalid value encountered in cast
#   house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price               0
# priceD              0
# powerStatusD        0
# carpetArea          0
# sqFtPrice           0
# furnishedD          0
# bathD              87
# parkingD            0
# ctName              0
# bedroomD            0
# coveredArea         0
# carpAreaUnit        0
# iTarget         14957
# vl              10186
# floors              0
# facingD         11316
# balconiesD      12242
# attrImg         13886
# bachelor        14957
# areaPercent         0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['1.85', 'Cr']

# %%
house_data[house_data['price']==0]
# Out:
#         possStatusD  price          priceD      powerStatusD carpetArea  \
# 5998  Ready to Move      0  Call for Price  No/Rare Powercut      840.0
# 6000  Ready to Move      0  Call for Price  No/Rare Powercut      624.0
# 6001  Ready to Move      0  Call for Price  No/Rare Powercut      252.0
# 6003  Ready to Move      0  Call for Price  No/Rare Powercut      560.0
# 6004  Ready to Move      0  Call for Price  No/Rare Powercut        800
# ...             ...    ...             ...               ...        ...
# 6080  Ready to Move      0  Call for Price  No/Rare Powercut      560.0
# 6081  Ready to Move      0  Call for Price  No/Rare Powercut      800.0
# 6082  Ready to Move      0  Call for Price  No/Rare Powercut      728.8
# 6083  Ready to Move      0  Call for Price  No/Rare Powercut      480.0
# 6085  Ready to Move      0  Call for Price  No/Rare Powercut       50.4
#
#       sqFtPrice      furnishedD bathD parkingD  ctName  ... coveredArea  \
# 5998        0.0     Unfurnished   NaN        0  Mumbai  ...      1050.0
# 6000        0.0     Unfurnished   NaN        0  Mumbai  ...       780.0
# 6001        0.0     Unfurnished   NaN        0  Mumbai  ...       315.0
# 6003        0.0     Unfurnished     1        0  Mumbai  ...       700.0
# 6004        0.0     Unfurnished     2        0  Mumbai  ...      1100.0
# ...         ...             ...   ...      ...     ...  ...         ...
# 6080        0.0     Unfurnished     2        0  Mumbai  ...       700.0
# 6081        0.0  Semi-Furnished     2        0  Mumbai  ...      1000.0
# 6082        0.0     Unfurnished   NaN        0  Mumbai  ...       911.0
# 6083        0.0     Unfurnished     2        0  Mumbai  ...       600.0
# 6085        0.0     Unfurnished   NaN        0  Mumbai  ...        63.0
#
#       carpAreaUnit iTarget   vl floors facingD balconiesD attrImg bachelor  \
# 5998         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6000         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6001         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6003         Sq-ft     NaN  NaN      4     NaN        NaN     NaN      NaN
# 6004         Sq-ft     NaN  NaN     12     NaN          1     NaN      NaN
# ...            ...     ...  ...    ...     ...        ...     ...      ...
# 6080         Sq-ft     NaN  NaN      6     NaN        NaN     NaN      NaN
# 6081         Sq-ft     NaN  NaN      7     NaN        NaN     NaN      NaN
# 6082         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 6083         Sq-ft     NaN  NaN      7     NaN        NaN     NaN      NaN
# 6085         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
#
#      areaPercent
# 5998    0.000000
# 6000    0.000000
# 6001    0.000000
# 6003    0.000000
# 6004    0.272727
# ...          ...
# 6080    0.000000
# 6081    0.000000
# 6082    0.000000
# 6083    0.000000
# 6085    0.000000
#
# [63 rows x 21 columns]

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_18480\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD         0
# price               0
# priceD              0
# powerStatusD        0
# carpetArea          0
# sqFtPrice           0
# furnishedD          0
# bathD              47
# parkingD            0
# ctName              0
# bedroomD            0
# coveredArea         0
# carpAreaUnit        0
# iTarget         14894
# vl              10123
# floors              0
# facingD         11254
# balconiesD      12186
# attrImg         13829
# bachelor        14894
# areaPercent         0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array([nan, 'East', 'West', 'North', 'North - East', 'South -West',
#        'North - West', 'South', 'South - East'], dtype=object)

# %%
house_data
# Out:
#               possStatusD     price   priceD      powerStatusD carpetArea  \
# 0                 Dec '28  54500000  5.45 Cr  No/Rare Powercut       1340
# 4                 Nov '28  23380000  2.33 Cr  No/Rare Powercut        835
# 7                 Dec '26  18400000  1.84 Cr  No/Rare Powercut        763
# 8      Under Construction  30000000     3 Cr  No/Rare Powercut        772
# 9                 Jun '26  14300000  1.43 Cr  No/Rare Powercut        623
# ...                   ...       ...      ...               ...        ...
# 29929             Jun '29  53400000  5.34 Cr  No/Rare Powercut        866
# 29931       Ready to Move  30900000  3.09 Cr  No/Rare Powercut       1037
# 29932             Dec '26  15200000  1.52 Cr  No/Rare Powercut        605
# 29933       Ready to Move  29000000  2.90 Cr  No/Rare Powercut        850
# 29939             Dec '28  47500000  4.75 Cr  No/Rare Powercut       1100
#
#        sqFtPrice      furnishedD bathD   parkingD  ctName  ... coveredArea  \
# 0        34062.0     Unfurnished     3  1 Covered  Mumbai  ...      1600.0
# 4        19322.0  Semi-Furnished     2          0  Mumbai  ...      1210.0
# 7        20109.0     Unfurnished     2  1 Covered  Mumbai  ...       915.0
# 8        33822.0  Semi-Furnished     2  1 Covered  Mumbai  ...       887.0
# 9        19972.0     Unfurnished     2  1 Covered  Mumbai  ...       716.0
# ...          ...             ...   ...        ...     ...  ...         ...
# 29929    53668.0  Semi-Furnished     2  1 Covered  Mumbai  ...       995.0
# 29931    24720.0     Unfurnished     3  1 Covered  Mumbai  ...      1250.0
# 29932    21408.0     Unfurnished     2          0  Mumbai  ...       710.0
# 29933    23200.0  Semi-Furnished     2  1 Covered  Mumbai  ...      1250.0
# 29939    35185.0     Unfurnished     3  1 Covered  Mumbai  ...      1350.0
#
#        carpAreaUnit iTarget   vl floors facingD balconiesD attrImg bachelor  \
# 0             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 4             Sq-ft     NaN    Y      0     NaN        NaN     NaN      NaN
# 7             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 8             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 9             Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# ...             ...     ...  ...    ...     ...        ...     ...      ...
# 29929         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 29931         Sq-ft     NaN  NaN     43     NaN        NaN     NaN      NaN
# 29932         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
# 29933         Sq-ft     NaN  NaN     38    East          3     NaN      NaN
# 29939         Sq-ft     NaN  NaN      0     NaN        NaN     NaN      NaN
#
#       areaPercent
# 0        0.162500
# 4        0.309917
# 7        0.166120
# 8        0.129651
# 9        0.129888
# ...           ...
# 29929    0.129648
# 29931    0.170400
# 29932    0.147887
# 29933    0.320000
# 29939    0.185185
#
# [14895 rows x 21 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14895 entries, 0 to 29939
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   14895 non-null  object
#  1   price         14895 non-null  int32
#  2   priceD        14895 non-null  object
#  3   powerStatusD  14895 non-null  object
#  4   carpetArea    14895 non-null  object
#  5   sqFtPrice     14895 non-null  float64
#  6   furnishedD    14895 non-null  object
#  7   bathD         14848 non-null  object
#  8   parkingD      14895 non-null  object
#  9   ctName        14895 non-null  object
#  10  bedroomD      14895 non-null  object
#  11  coveredArea   14895 non-null  float64
#  12  carpAreaUnit  14895 non-null  object
#  13  iTarget       1 non-null      object
#  14  vl            4772 non-null   object
#  15  floors        14895 non-null  object
#  16  facingD       3641 non-null   object
#  17  balconiesD    2709 non-null   object
#  18  attrImg       1066 non-null   object
#  19  bachelor      1 non-null      object
#  20  areaPercent   14895 non-null  float64
# dtypes: float64(3), int32(1), object(17)
# memory usage: 2.4+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
# house_data['balconiesD'] = house_data['balconiesD'].astype(float)
house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '28", "Nov '28", "Dec '26", 'Under Construction', "Jun '26",
#        'Ready to Move', "Dec '25", "Dec '27", "May '25", "Jun '27",
#        "Mar '25", "Oct '29", 'Immediately', "Oct '24", "Jun '30",
#        "Jun '29"], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(["Dec '28", "Nov '28", "Dec '26", 'Under Construction', "Jun '26",
#        'Ready to Move', "Dec '25", "Dec '27", "May '25", "Jun '27",
#        "Mar '25", "Oct '29", "Oct '24", "Jun '30", "Jun '29"],
#       dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 house_data['price'][1]/house_data['sqFtPrice'][1]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 1

# %%
house_data[house_data['furnishedD']=='Unfurnished']

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, powerStatusD, carpetArea, sqFtPrice, furnishedD, bathD, parkingD, ctName, bedroomD, coveredArea, carpAreaUnit, iTarget, vl, floors, facingD, balconiesD, attrImg, bachelor, areaPercent]
# Index: []
#
# [0 rows x 21 columns]

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  carpetArea  sqFtPrice     bathD  bedroomD  coveredArea  \
# price        1.000000    0.369228  -0.588494  0.281329  0.245363     0.284774
# carpetArea   0.369228    1.000000   0.005636  0.725369  0.732931     0.795825
# sqFtPrice   -0.588494    0.005636   1.000000 -0.004549 -0.008406    -0.014455
# bathD        0.281329    0.725369  -0.004549  1.000000  0.875706     0.584782
# bedroomD     0.245363    0.732931  -0.008406  0.875706  1.000000     0.585762
# coveredArea  0.284774    0.795825  -0.014455  0.584782  0.585762     1.000000
# floors      -0.030070    0.174712  -0.014064  0.029725 -0.001939     0.194731
# areaPercent  0.006247    0.015169  -0.473115  0.014215  0.011585     0.047834
#
#                floors  areaPercent
# price       -0.030070     0.006247
# carpetArea   0.174712     0.015169
# sqFtPrice   -0.014064    -0.473115
# bathD        0.029725     0.014215
# bedroomD    -0.001939     0.011585
# coveredArea  0.194731     0.047834
# floors       1.000000     0.016099
# areaPercent  0.016099     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]

# %%
house_data
# Out:
#               possStatusD     price   priceD      powerStatusD  carpetArea  \
# 0                 Dec '28  54500000  5.45 Cr  No/Rare Powercut      1340.0
# 4                 Nov '28  23380000  2.33 Cr  No/Rare Powercut       835.0
# 7                 Dec '26  18400000  1.84 Cr  No/Rare Powercut       763.0
# 8      Under Construction  30000000     3 Cr  No/Rare Powercut       772.0
# 9                 Jun '26  14300000  1.43 Cr  No/Rare Powercut       623.0
# ...                   ...       ...      ...               ...         ...
# 29929             Jun '29  53400000  5.34 Cr  No/Rare Powercut       866.0
# 29931       Ready to Move  30900000  3.09 Cr  No/Rare Powercut      1037.0
# 29932             Dec '26  15200000  1.52 Cr  No/Rare Powercut       605.0
# 29933       Ready to Move  29000000  2.90 Cr  No/Rare Powercut       850.0
# 29939             Dec '28  47500000  4.75 Cr  No/Rare Powercut      1100.0
#
#        sqFtPrice      furnishedD  bathD   parkingD  ctName  bedroomD  \
# 0        34062.0     Unfurnished    3.0  1 Covered  Mumbai       3.0
# 4        19322.0  Semi-Furnished    2.0          0  Mumbai       2.0
# 7        20109.0     Unfurnished    2.0  1 Covered  Mumbai       2.0
# 8        33822.0  Semi-Furnished    2.0  1 Covered  Mumbai       2.0
# 9        19972.0     Unfurnished    2.0  1 Covered  Mumbai       2.0
# ...          ...             ...    ...        ...     ...       ...
# 29929    53668.0  Semi-Furnished    2.0  1 Covered  Mumbai       2.0
# 29931    24720.0     Unfurnished    3.0  1 Covered  Mumbai       3.0
# 29932    21408.0     Unfurnished    2.0          0  Mumbai       2.0
# 29933    23200.0  Semi-Furnished    2.0  1 Covered  Mumbai       2.0
# 29939    35185.0     Unfurnished    3.0  1 Covered  Mumbai       3.0
#
#        coveredArea carpAreaUnit  floors facingD balconiesD  areaPercent
# 0           1600.0        Sq-ft     0.0     NaN        NaN     0.162500
# 4           1210.0        Sq-ft     0.0     NaN        NaN     0.309917
# 7            915.0        Sq-ft     0.0     NaN        NaN     0.166120
# 8            887.0        Sq-ft     0.0     NaN        NaN     0.129651
# 9            716.0        Sq-ft     0.0     NaN        NaN     0.129888
# ...            ...          ...     ...     ...        ...          ...
# 29929        995.0        Sq-ft     0.0     NaN        NaN     0.129648
# 29931       1250.0        Sq-ft    43.0     NaN        NaN     0.170400
# 29932        710.0        Sq-ft     0.0     NaN        NaN     0.147887
# 29933       1250.0        Sq-ft    38.0    East          3     0.320000
# 29939       1350.0        Sq-ft     0.0     NaN        NaN     0.185185
#
# [14895 rows x 17 columns]

# %%
house_data.drop(["iTarget",	"vl", "attrImg", "bachelor"], axis=1, inplace=True)

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ("Dec '26",
#  18400000,
#  '1.84 Cr',
#  'No/Rare Powercut',
#  763.0,
#  20109.0,
#  'Unfurnished',
#  2.0,
#  '1 Covered',
#  'Mumbai',
#  2.0,
#  915.0,
#  'Sq-ft',
#  0.0,
#  nan,
#  nan,
#  0.16612021857923498)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'powerStatusD',
#  'carpetArea',
#  'sqFtPrice',
#  'furnishedD',
#  'bathD',
#  'parkingD',
#  'ctName',
#  'bedroomD',
#  'coveredArea',
#  'carpAreaUnit',
#  'floors',
#  'facingD',
#  'balconiesD',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gigar\anaconda3\lib\site-packages (2.9.9)

# %%
city = 'Mumbai'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 895
