# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json('resultsGurugram.json')
data
# Out:
#                                                                        2    \
# nsrResultList                                                         None
# resultList               [{'encId': 'CDYat+AnHk9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        3    \
# nsrResultList                                                         None
# resultList               [{'encId': 'MNcOJClel9NzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        4    \
# nsrResultList                                                         None
# resultList               [{'encId': 'Z0n/Fnhxn8pzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        5    \
# nsrResultList                                                         None
# resultList               [{'encId': '8Umc1XrpdNFzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        6    \
# nsrResultList                                                         None
# resultList               [{'encId': 'QnXVOEiC5m5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        7    \
# nsrResultList                                                         None
# resultList               [{'encId': 'EdGdF1yTb4FzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        8    \
# nsrResultList                                                         None
# resultList               [{'encId': 'aZDMyC4VBnhzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        9    \
# nsrResultList                                                         None
# resultList               [{'encId': 'fCg5s0JkurhzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        10   \
# nsrResultList                                                         None
# resultList               [{'encId': 'FbvXqlRYqRVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        11   \
# nsrResultList                                                         None
# resultList               [{'encId': 'YremAh0RDgpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                          ...  \
# nsrResultList            ...
# resultList               ...
# editAdditionalDataBean   ...
# societyExpertResultList  ...
#
#                                                                        549  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        550  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        551  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        552  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        553  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        554  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        555  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        556  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        557  \
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
#                                                                        558
# nsrResultList                                                         None
# resultList               [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean   {'nriUser': 'N', 'nriCityName': None, 'zonePri...
# societyExpertResultList                                               None
#
# [4 rows x 557 columns]

# %%
data.drop(['societyExpertResultList','nsrResultList'], axis=0, inplace=True)

# %%
data
# Out:
#                                                                       2    \
# resultList              [{'encId': 'CDYat+AnHk9zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       3    \
# resultList              [{'encId': 'MNcOJClel9NzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       4    \
# resultList              [{'encId': 'Z0n/Fnhxn8pzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       5    \
# resultList              [{'encId': '8Umc1XrpdNFzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       6    \
# resultList              [{'encId': 'QnXVOEiC5m5zpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       7    \
# resultList              [{'encId': 'EdGdF1yTb4FzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       8    \
# resultList              [{'encId': 'aZDMyC4VBnhzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       9    \
# resultList              [{'encId': 'fCg5s0JkurhzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       10   \
# resultList              [{'encId': 'FbvXqlRYqRVzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       11   \
# resultList              [{'encId': 'YremAh0RDgpzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                         ...  \
# resultList              ...
# editAdditionalDataBean  ...
#
#                                                                       549  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       550  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       551  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       552  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       553  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       554  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       555  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       556  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       557  \
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
#                                                                       558
# resultList              [{'encId': '37ajqfqSicZzpSvf+uAgZw==', 'possSt...
# editAdditionalDataBean  {'nriUser': 'N', 'nriCityName': None, 'zonePri...
#
# [2 rows x 557 columns]

# %%
df = data.iloc[0,:]

# %%
pages = len(df)
house_per_page = 30
house_dataset = []

# %%
for i in range(pages):
    for j in range(house_per_page):
        house = df.iloc[i][j]
        # add house to dataset
        house_dataset.append(house)

# %%
house_data = pd.DataFrame(house_dataset)

# %%
house_data["city"] = "New Delhi"

# %%
house_data
# Out:
#                           encId         possStatusD pmtSource availableFrom  \
# 0      CDYat+AnHk9zpSvf+uAgZw==  Under Construction       Web       Jun '24
# 1      DXqBDee/23pzpSvf+uAgZw==  Under Construction       Web       May '24
# 2      fooPF8yaBllzpSvf+uAgZw==       Ready to Move       Web           NaN
# 3      y6VQuBrbYmVzpSvf+uAgZw==       Ready to Move       Web           NaN
# 4      6VaZSMrLv49zpSvf+uAgZw==       Ready to Move       Web           NaN
# ...                         ...                 ...       ...           ...
# 16705  jXlvcJko4dhzpSvf+uAgZw==       Ready to Move       Web           NaN
# 16706  T0VpZ4+PildzpSvf+uAgZw==             Dec '26   Project       Dec '26
# 16707  43o8kAHq4oNzpSvf+uAgZw==             Feb '31   Project       Feb '31
# 16708  dnahsETWMOpzpSvf+uAgZw==             Aug '29   Project       Aug '27
# 16709  OLEsLGi1qptzpSvf+uAgZw==       Ready to Move       Web       Mar '24
#
#       cntvl                                                url floorNo  \
# 0      1250  3-BHK-1967-Sq-ft-Multistorey-Apartment-FOR-Sal...       6
# 1      1250  3-BHK-1850-Sq-ft-Multistorey-Apartment-FOR-Sal...      30
# 2      1077  3-BHK-303-Sq-yrd-Multistorey-Apartment-FOR-Sal...       1
# 3      1077  2-BHK-1381-Sq-ft-Multistorey-Apartment-FOR-Sal...      12
# 4      1077  3-BHK-1650-Sq-ft-Multistorey-Apartment-FOR-Sal...       7
# ...     ...                                                ...     ...
# 16705   140  3-BHK-2149-Sq-ft-Multistorey-Apartment-FOR-Sal...       8
# 16706  1000  3-BHK-1190-Sq-ft-Builder-Floor-Apartment-FOR-S...     NaN
# 16707  1250  3-BHK-3035-Sq-ft-Multistorey-Apartment-FOR-Sal...     NaN
# 16708  1000  3-BHK-1450-Sq-ft-Multistorey-Apartment-FOR-Sal...     NaN
# 16709  1250  3-BHK-2781-Sq-ft-Multistorey-Apartment-FOR-Sal...       8
#
#        noBfCt   st modstat  ...  isExcl noOfSVis cpmp appExcRe  isCornerPlot  \
# 0           0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 1           0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 2           0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 3           0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 4           0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# ...       ...  ...     ...  ...     ...      ...  ...      ...           ...
# 16705       0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 16706       0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 16707       0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 16708       0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
# 16709       0  509   20205  ...     NaN      NaN  NaN      NaN           NaN
#
#        gateComm bachelor   nr   vl       city
# 0           NaN      NaN  NaN  NaN  New Delhi
# 1           NaN      NaN  NaN  NaN  New Delhi
# 2           NaN      NaN  NaN  NaN  New Delhi
# 3           NaN      NaN  NaN  NaN  New Delhi
# 4           NaN      NaN  NaN  NaN  New Delhi
# ...         ...      ...  ...  ...        ...
# 16705       NaN      NaN  NaN  NaN  New Delhi
# 16706       NaN      NaN  NaN  NaN  New Delhi
# 16707       NaN      NaN  NaN  NaN  New Delhi
# 16708       NaN      NaN  NaN  NaN  New Delhi
# 16709       NaN      NaN  NaN  NaN  New Delhi
#
# [16710 rows x 260 columns]

# %%
print(*house_data.columns, sep="\n")
# Out:
# encId
# possStatusD
# pmtSource
# availableFrom
# cntvl
# url
# floorNo
# noBfCt
# st
# modstat
# appVer
# appSub
# deviceType
# sendbirdId
# lastAccessDate
# lastReplyDate
# projectSocietyLink
# sipro
# comFlag
# appExc
# taImg
# cScore
# devName
# postDateT
# endDateT
# pl
# luxAmenities
# luxAmenitiesD
# appovedAuthC
# availUnit
# enc_Id
# cowDays
# price
# priceD
# imgCt
# landmarkDetails
# seoDesc
# psmUspImgWeb
# psmUspImgMob
# psmImage
# propCat
# pfAgCg
# id
# pmtmtrendPercentage
# flooringTyD
# adroomD
# maintenanceD
# sv
# agtCrSt
# cg
# pp
# maintenanceCharges
# bookingAmtExact
# dImgSrc
# landmark
# seoLtSc
# pSc
# pCct
# lCct
# pcTcCt
# ac
# acD
# caSqFt
# ltcoordGeo
# iba
# ct
# lt
# loc
# bd
# ca
# ty
# dtldesc
# plgdtldesc
# oid
# oname
# sdp
# companyname
# contName
# auto_desc
# prjname
# sqFtPrD
# carpetArea
# pkg
# isPaidUser
# ctVerifd
# pmtLat
# pmtLong
# moisd
# supV
# lmtDName
# criLogo
# pkgid
# achTdS
# opSn
# opSnD
# pmtUsp1
# pmtUspWap
# sid
# locSeoName
# propImg
# coverAreaUnitD
# ppd
# ppdL
# achTm
# achTmS
# soc
# tmsrt
# ecd
# prm
# sqFtPrice
# psmid
# isVis
# showupfront
# agtCerStatus
# pmtUsp
# caCompNameD
# postedLabelD
# OwnershipTypeD
# furnishedD
# balconiesD
# bathD
# facingD
# amenFacingD
# transactionTypeD
# floorD
# propTypeD
# ctName
# bedroomD
# userType
# transType
# isPreferred
# floors
# brokerConnect
# dImgRf
# localityPhoto
# defaultAdddressGoogle
# propertyTitle
# crisilRv1CtBy
# crisilStarRating
# postedEditedLabel
# wapImgUrl
# wapImgUrl1
# seoURL
# psmImgCt
# smartDiaryApiTag
# isLuxury
# coveredArea
# covAreaUnit
# carpAreaUnit
# modifiedDate
# imgUrl
# image
# actualOwner
# amenities
# isProjProp
# devId
# pglmtkey
# grpBky1
# grpBky2
# grpBky3
# grpBky4
# grpBky5
# grpBky6
# grpBky7
# sortCode1
# sortCode1b
# sortCode22
# sortCode26
# ubicnt
# pckCon
# ctCurr
# ctLast
# rEcd
# endDt
# newUrl
# catAdd1
# seoPsmDt
# pmtdesc_hi
# legalDocStatusList
# infraStatusList
# isPrimeLocProp
# operatingSinceYear
# tenantsPreference
# isThisListingAPremiumOnly
# isAdvertiserOfThisListingAOwnerAndUnPaid
# covAreaUnitDesc
# investorlisting
# investorguide
# ampDesc
# b2cCardEligibility
# maskedMobileNumber
# agentContinuityStr
# isLuxuryServiceAvailable
# luxAmenMap
# nonluxAmenMap
# ctaDetailBean
# lCtDate
# powerStatusD
# isRera
# reraId
# parkingD
# waterStatus
# propertyImageNew
# imageDate
# crisilNoOfEmployees
# crisilOpSinceYear
# ranPropImg
# nriPref
# agComCt
# la
# pmtUsp2
# pmtUsp2Wap
# tag
# tagWap
# landAreaUnit
# landAreaUnitD
# possBy
# prjHl1
# prjLtHl1
# prjSrc
# siteVisitProp
# prjid
# iTarget
# psmapproved
# agentDetailUrl
# isprimeListingType
# lc
# lcLst
# dues
# ltOther
# isReraAgent
# agentReraState
# pmtTCabin
# dealDesc
# pbrk
# pbrkp
# adCn
# comPantry
# floorCsntrAllowed
# nOs
# dsla
# ctaRuleId
# personType
# minPrice
# maxPrice
# exc
# sVisMinDt
# sVisMaxDt
# dimD
# rdWidth
# isExcl
# noOfSVis
# cpmp
# appExcRe
# isCornerPlot
# gateComm
# bachelor
# nr
# vl
# city

# %%
for x in range(len(house_data.columns)):
    print(house_data.columns[x], house_data.iloc[2,x], house_data.iloc[3,x])
# Out:
# encId fooPF8yaBllzpSvf+uAgZw== y6VQuBrbYmVzpSvf+uAgZw==
# possStatusD Ready to Move Ready to Move
# pmtSource Web Web
# availableFrom nan nan
# cntvl 1077 1077
# url 3-BHK-303-Sq-yrd-Multistorey-Apartment-FOR-Sale-Sector-102-in-Gurgaon&id=4d423634373333363137 2-BHK-1381-Sq-ft-Multistorey-Apartment-FOR-Sale-Sector-108-in-Gurgaon&id=4d423633363130303633
# floorNo 1 12
# noBfCt 0 0
# st 509 509
# modstat 20205 20205
# appVer 479.0 478.0
# appSub Y Y
# deviceType and and
# sendbirdId fba0e063-89d3-4584-927f-a2f3c56e56e9vika2228 d0b4303e-8393-4d8d-bb20-557e4c5b697fvina4457
# lastAccessDate 1710181800000.0 1710181800000.0
# lastReplyDate 1588703400000.0 nan
# projectSocietyLink bptp-amstoria-floors-sector-102-gurgaon-pdpid-4d4235323836313539 sobha-city-sector-108-gurgaon-pdpid-4d4235303836323234
# sipro 67010175 70158059 71391425 65418739 70824813 68445141 68124743 70703817
# comFlag N Y
# appExc N N
# taImg Profile-1-825326_196_200.jpeg Profile-1-37903937_1024_768.jpeg
# cScore 100 100
# devName Dev Constructions SOBHA Ltd.
# postDateT 2024-03-10T23:45:37.000Z 2024-03-10T23:45:22.000Z
# endDateT 2024-05-09T23:45:37.000Z 2024-05-09T23:45:22.000Z
# pl Y Y
# luxAmenities 12229 12230 12221 12216 12215 12224 12229 12230 12214 12216 12217
# luxAmenitiesD Jogging and Strolling Track,Outdoor Tennis Courts,Internet/Wi-Fi Connectivity,Visitor Parking Air Conditioned,Banquet Hall,Jogging and Strolling Track,Outdoor Tennis Courts,Service/Goods Lift,Visitor Parking,Intercom Facility
# appovedAuthC HUDA HSIIDC
# availUnit 1.0 0.0
# enc_Id fooPF8yaBlniH/fPrjIy5A== y6VQuBrbYmWBvMHl1V77Vw==
# cowDays 0 0
# price 23000000.0 23000000.0
# priceD 2.30 Cr 2.30 Cr
# imgCt 27 30
# landmarkDetails ['19201|4.4 Km from Daulatabad Flyover', '19210|9.9 Km from IFFCO Chowk Metro Station', '19202|1.1 Km from Imperial Heritage School'] ['19201|4.3 Km from Daulatabad Flyover', '19210|9.9 Km from IFFCO Chowk Metro Station', '19202|2.4 Km from Shanti Niketan Public School']
# seoDesc The  3 BHK flat is available for sale in Sector 102, Gurgaon.  This flat is situated within the renowned township of Bptp Amstoria Floors. This apartment for resale is among the best bargains available. This ready to move apartment in the Sector 102 is available for an attractive price of INR 2.30 Cr. It is a unfurnished apartment. project near to all major location like hospital, market,  school. are some of the well-known landmarks in this locality. Have a look at this 2 BHK flat for sale in Sector 108, Gurgaon. This well designed apartment is located within Sobha City. This apartment is available for immediate resale. This ready to move flat in Sector 108 is available for a reasonable price of INR 2.30 Cr. The flat is semi-furnished and comes with all basic facilities. Some nearby landmarks are bang on 75m project near to delhi border.
# psmUspImgWeb nan nan
# psmUspImgMob nan nan
# psmImage nan nan
# propCat 20292 20292
# pfAgCg s s
# id 64733617 63610063
# pmtmtrendPercentage 0 0
# flooringTyD Wooden Vitrified,Wooden
# adroomD Study None of these
# maintenanceD Per sq. Unit Monthly Per sq. Unit Monthly
# sv nan nan
# agtCrSt Y Y
# cg b b
# pp Z Z
# maintenanceCharges 2 3
# bookingAmtExact 100000 100000
# dImgSrc 10511 10511
# landmark Project near to all major location like hospital, market,  school. bang on 75m project near to delhi border
# seoLtSc 1 1
# pSc 0 0
# pCct 0 0
# lCct 0 0
# pcTcCt 0 0
# ac 11652.0 11651.0
# acD Less than 5 years New Construction
# caSqFt 2727.0 1381.0
# ltcoordGeo 28.4763113,76.9716096 28.5132589756612,76.9826987890288
# iba X X
# ct 2951 2951
# lt 87106.0 89626.0
# loc 87106.0 89626.0
# bd 11702 11701
# ca 303 1381
# ty 10002 10002
# dtldesc Project is well maintained, Spacious room, luxury amenities, well maintained staff An east facing 2 bhk apartment in sector108 gurgaon, gurgaon is available for sale. This property is a part of .It has a super builtUp area of 1381 sq.Ft. The apartment is spaciously designed with 2 bedrooms, 2 bathrooms and more than 1 balconies. It overlooks a parkgarden and club. The width of facing road is 75.00 sq.Yards. It is situated inside gated premises. The apartment is on the 12th floor of 18 floors and offers 01covered parking. The ownership of the apartment is freehold.
# plgdtldesc Project is well maintained, Spacious room, luxury amenities, well maintained staff An east facing 2 bhk apartment in sector108 gurgaon, gurgaon is available for sale. This property is a part of .It has a super builtUp area of 1381 sq.Ft. The apartment is spaciously designed with 2 bedrooms, 2 bathrooms and more than 1 balconies. It overlooks a parkgarden and club. The width of facing road is 75.00 sq.Yards. It is situated inside gated premises. The apartment is on the 12th floor of 18 floors and offers 01covered parking. The ownership of the apartment is freehold.
# oid 825326 37903937
# oname Vikas Lamba Lamba Vinay Sehrawat
# sdp Y Y
# companyname Suresh Properties  Smart Home Realty
# contName Vikas Lamba Vinay Sehrawat
# auto_desc 3 BHK, Multistorey Apartment is available for Sale in Sector 102, Gurgaon for 2.3 Crore(s) 2 BHK, Multistorey Apartment is available for Sale in Sector 108, Gurgaon for 2.3 Crore(s)
# prjname BPTP Amstoria Floors Sobha City
# sqFtPrD 75907.0 16654.0
# carpetArea 160 1099
# pkg 10198 10198
# isPaidUser Y Y
# ctVerifd N N
# pmtLat 28.4763113 28.5132589756612
# pmtLong 76.9716096 76.9826987890288
# moisd 50 50
# supV Y Y
# lmtDName Sector 102 Sector 108
# criLogo 12022 nan
# pkgid 287423 285605
# achTdS 682 873
# opSn 11095 11095
# opSnD 2000 2000
# pmtUsp1 nan nan
# pmtUspWap nan nan
# sid 13520,13558,13502 13520,13558,13502
# locSeoName Sector 102 Sector 108
# propImg 64733617_14_PropertyImage322-46330049986614.jpg 63610063_3_PropertyImage343-51725236275377.jpg
# coverAreaUnitD Sq-yrd Sq-ft
# ppd 20240311 20240311
# ppdL 1710114337000 1710114322000
# achTm 242 413
# achTmS 242 413
# soc Y Y
# tmsrt 051537 051522
# ecd 20240311 20240311
# prm y y
# sqFtPrice 8434.0 16655.0
# psmid 5286159 5086224
# isVis X X
# showupfront N N
# agtCerStatus nan nan
# pmtUsp nan nan
# caCompNameD Suresh Properties  Smart Home Realty
# postedLabelD Posted: Mar 11, '24 Posted: Mar 11, '24
# OwnershipTypeD Freehold Freehold
# furnishedD Unfurnished Semi-Furnished
# balconiesD 3 4
# bathD 3 2
# facingD North - East North - East
# amenFacingD Garden/Park Garden/Park, Main Road
# transactionTypeD Resale Resale
# floorD 1 of 2 Floor 12 of 18 Floor
# propTypeD Apartment Apartment
# ctName Gurgaon Gurgaon
# bedroomD 3 2
# userType Agent Agent
# transType Sale Sale
# isPreferred false false
# floors 2 18
# brokerConnect N nan
# dImgRf PROP263485139 PROP294467433
# localityPhoto 0 0
# defaultAdddressGoogle Gurgaon, Delhi NCR Gurgaon, Delhi NCR
# propertyTitle 3BHK Multistorey Apartment for Resale in BPTP Amstoria Floors at Sector 102 2BHK Multistorey Apartment for Resale in Sobha City at Sector 108
# crisilRv1CtBy Lalit N/A Lalit N/A
# crisilStarRating 4 4
# postedEditedLabel Posted:  Posted:
# wapImgUrl https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h80_w120/64733617_14_PropertyImage322-46330049986614_80_120.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Oct/11/Photo_h80_w120/63610063_3_PropertyImage343-51725236275377_80_120.jpg
# wapImgUrl1 https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_14_PropertyImage322-46330049986614_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Oct/11/Photo_h180_w240/63610063_3_PropertyImage343-51725236275377_180_240.jpg
# seoURL propertyDetails-3-BHK-303-Sqyrd-Flat-FOR-Sale-Sector-102-in-Gurgaon&id=fooPF8yaBllzpSvf+uAgZw==&category=Sale propertyDetails-2-BHK-1381-Sqft-Flat-FOR-Sale-Sector-108-in-Gurgaon&id=y6VQuBrbYmVzpSvf+uAgZw==&category=Sale
# psmImgCt nan nan
# smartDiaryApiTag Y nan
# isLuxury F F
# coveredArea 303 1381
# covAreaUnit 12803 12800
# carpAreaUnit Sq-yrd Sq-ft
# modifiedDate Mar 11, '24 Mar 11, '24
# imgUrl https://img.staticmb.com/mbimages/user/Photo_h75_w75/825326_WhatsAppImage20240117at161841_75_75.jpeg https://img.staticmb.com/mbimages/user/Photo_h75_w75/37903937_WhatsAppImage20231201at1720271_75_75.jpeg
# image https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_10_PropertyImage868-4789555828962_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2022/Nov/19/Photo_h180_w240/63610063_8_PropertyImage483-4917623446703_180_240.jpg
# actualOwner 825326 37903937
# amenities 12201 12202 12203 12204 12205 12208 12211 12216 12218 12219 12221 12229 12230 12201 12202 12203 12204 12205 12206 12207 12208 12209 12211 12213 12214 12215 12216 12217 12218 12222 12224 12226 12229 12230
# isProjProp N N
# devId 50033 69392
# pglmtkey 825326_1 37903937_1
# grpBky1 0 0
# grpBky2 0 0
# grpBky3 0 0
# grpBky4 0 0
# grpBky5 0 0
# grpBky6 0 0
# grpBky7 0 0
# sortCode1 15295504.0 15295504.0
# sortCode1b 15295503.0 15295503.0
# sortCode22 0.0 0.0
# sortCode26 0.08 0.08
# ubicnt 50 50
# pckCon 14.77 22.7
# ctCurr 3317 7940
# ctLast 0 0
# rEcd 20240311 20240311
# endDt May 10, '24 May 10, '24
# newUrl project-bptp-amstoria-floors-for-sale-in-gurgaon-pppfs project-sobha-city-for-sale-in-gurgaon-pppfs
# catAdd1 Sector 102, Gurgaon, Haryana 1081.
# seoPsmDt nan {"bhkPriceRange":{"4 BHK":{"minPrice":"3.88 Cr","maxPrice":"6.10 Cr"},"3 BHK":{"minPrice":"2.80 Cr","maxPrice":"3.70 Cr"},"2 BHK":{"minPrice":"2.40 Cr","maxPrice":"2.40 Cr"}}}
# pmtdesc_hi गुडगाँव के पुराने सेक्टर 102 में स्थित बिक्री के लिए उपलब्ध इस 3 BHK फ्लैट को देखें। यह अच्छी तरह से बनाये गए बीपीटीपी अम्स्टोरिया फ्लोर्स टाउनशिप में एक खास लोकेशन पर स्थित है। अपार्टमेंट में 3 बाथरूम हैं जिससे इसकी खूबसूरती बढ़ती हैं। इस 3 BHK अपार्टमेंट में आपको अपनी कार के लिए निःशुल्क 1 Open पार्किंग की जगह मिलती है। सभी आवश्यक सुविधाओं वाला यह फ्लैट रेसले के लिए उपलब्ध है। सेक्टर 102 में स्थित यह रेडी टू मूव फ्लैट रु. 2.30 Cr के उचित मूल्य पर खरीदने के लिए उपलब्ध है। यह एक अनफर्निश्ड अपार्टमेंट है।  गुडगाँव के प्रीमियम सेक्टर 108 में स्थित यह रेडी टू मूव-इन 2 BHK फ्लैट बिक्री के लिए उपलब्ध है। सोभा सिटी टाउनशिप में यह एक प्राइम लोकेशन पर स्थित है। कुल 2 बाथरूम हैं, जिनमें मॉड्यूलर बाथरूम एक्सेसरीज लगी हैं। 2 BHK फ्लैट के साथ वाहन (वाहनों) की 1कवर्ड पार्किंग के लिए कार पार्किंग की प्राइवेट जगह मिलती है। यह अपार्टमेंट रेसले के लिए काफी पसंदीदा प्रॉपर्टी है। सेक्टर 108 में स्थित यह रेडी टू मूव फ्लैट मात्र रु. 2.30 Cr की किफायती कीमत पर उपलब्ध है। यह मार्डन अपार्टमेंट सेमि-फर्निश्ड है। सोभा सिटी यहां रहने वाले सभी लोगों को एयर कंडिशन्ड, बैंक्वेट हॉल, जॉगिंग एंड स्ट्रॉलिंग ट्रैक, आउटडोर टेनिस कोर्ट्स, सर्विस/गुड्स लिफ्ट जैसी आधुनिक सुविधाएँ उपलब्ध कराता है।
# legalDocStatusList None None
# infraStatusList None None
# isPrimeLocProp Y Y
# operatingSinceYear 2000 2000
# tenantsPreference Bachelors/Family Bachelors/Family
# isThisListingAPremiumOnly True True
# isAdvertiserOfThisListingAOwnerAndUnPaid True True
# covAreaUnitDesc Sq-yrd Sq-ft
# investorlisting N N
# investorguide N N
# ampDesc Project is well maintained, Spacious room, luxury amenities, well maintained staff An east facing 2 bhk apartment in sector108 gurgaon, gurgaon is available for sale. This property is
# b2cCardEligibility false false
# maskedMobileNumber +91-97XXXXXXX31 +91-99XXXXXXX57
# agentContinuityStr 3000+ Buyers Served 7500+ Buyers Served
# isLuxuryServiceAvailable False False
# luxAmenMap {'12229': 'Jogging and Strolling Track', '12230': 'Outdoor Tennis Courts', '12221': 'Internet/Wi-Fi Connectivity', '12216': 'Visitor Parking'} {'12215': 'Air Conditioned', '12224': 'Banquet Hall', '12229': 'Jogging and Strolling Track', '12230': 'Outdoor Tennis Courts'}
# nonluxAmenMap {} {}
# ctaDetailBean {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None} {'ctapid': 0, 'ctaid': 101, 'platform': 0, 'cnd_page': None, 'cndcontactstatus': None, 'header_icon': None, 'cta1': None, 'cta2': None, 'formheader': None, 'formsubheader': None, 'contactbutton': None, 'header_iconcta1': None, 'formheadercta1': None, 'formsubheadercta1': None, 'contactbuttoncta1': None}
# lCtDate nan 1701928245000.0
# powerStatusD No/Rare Powercut No/Rare Powercut
# isRera nan nan
# reraId nan nan
# parkingD 1 Open 1 Covered
# waterStatus Water Availability 24 Hours Available Water Availability 24 Hours Available
# propertyImageNew https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_13_PropertyImage879-6211554342566_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_12_PropertyImage923-743365033675_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_12_PropertyImage923-743365033675_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_11_PropertyImage706-6625218721135_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_6_PropertyImage438-94685574309176_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_6_PropertyImage438-94685574309176_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_5_PropertyImage405-58525588140094_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_6_PropertyImage865-5728964958979_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_4_PropertyImage394-6988874332876_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_3_PropertyImage2-772651820375782_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_2_PropertyImage806-8749752168798_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_4_PropertyImage962-3343187181765_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_8_PropertyImage937-992957563255_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_10_PropertyImage868-4789555828962_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_10_PropertyImage519-8127960265278_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_2_PropertyImage375-9393899675026_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_14_PropertyImage322-46330049986614_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_11_PropertyImage429-1490963941743_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_5_PropertyImage651-2479890481089_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_13_PropertyImage713-5207472122585_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_3_PropertyImage815-5251139566489_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_9_PropertyImage394-93669584384514_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_9_PropertyImage639-9703627320265_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_7_PropertyImage269-3572610953573_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_1_PropertyImage309-09720726034794_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Dec/24/Photo_h180_w240/64733617_12_PropertyImage458-32016461182155_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_7_PropertyImage864-9950347348739_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Oct/11/Photo_h180_w240/63610063_7_PropertyImage60-07071655637664_180_240.jpg,https://img.staticmb.com/mbphoto/property/cropped_images/2022/Nov/19/Photo_h1 ...
# imageDate 2022/Dec/24 2023/Oct/11
# crisilNoOfEmployees 15 10
# crisilOpSinceYear 2018 2018
# ranPropImg https://img.staticmb.com/mbphoto/property/cropped_images/2023/Jun/02/Photo_h180_w240/64733617_10_PropertyImage868-4789555828962_180_240.jpg https://img.staticmb.com/mbphoto/property/cropped_images/2022/Nov/19/Photo_h180_w240/63610063_8_PropertyImage483-4917623446703_180_240.jpg
# nriPref nan Y
# agComCt nan nan
# la nan nan
# pmtUsp2 nan nan
# pmtUsp2Wap nan nan
# tag nan nan
# tagWap nan nan
# landAreaUnit nan nan
# landAreaUnitD nan nan
# possBy nan nan
# prjHl1 nan nan
# prjLtHl1 nan nan
# prjSrc nan nan
# siteVisitProp nan nan
# prjid nan nan
# iTarget nan nan
# psmapproved nan nan
# agentDetailUrl nan nan
# isprimeListingType nan nan
# lc nan nan
# lcLst nan nan
# dues nan nan
# ltOther nan nan
# isReraAgent nan nan
# agentReraState nan nan
# pmtTCabin nan nan
# dealDesc nan nan
# pbrk nan nan
# pbrkp nan nan
# adCn nan nan
# comPantry nan nan
# floorCsntrAllowed nan nan
# nOs nan nan
# dsla nan nan
# ctaRuleId nan nan
# personType nan nan
# minPrice nan nan
# maxPrice nan nan
# exc nan nan
# sVisMinDt nan nan
# sVisMaxDt nan nan
# dimD nan nan
# rdWidth nan nan
# isExcl nan nan
# noOfSVis nan nan
# cpmp nan nan
# appExcRe nan nan
# isCornerPlot nan nan
# gateComm nan nan
# bachelor nan nan
# nr nan nan
# vl nan nan
# city New Delhi New Delhi

# %%
house_data.drop(["encId", "pmtSource", "availableFrom", "cntvl", "url", "floorNo", "noBfCt",
"st",
"modstat",
"lCtDate",
"appVer",
"appSub",
"deviceType",
"lastAccessDate",
"projectSocietyLink",
"sipro",
"comFlag",
"appExc",
"cScore",
"devName",
"postDateT",
"endDateT",
"pl",
"appovedAuthC",
"availUnit",
"enc_Id",
"cowDays",
"imgCt",
"landmarkDetails",
"seoDesc",
"psmImage",
"propCat",
"id",
"pmtmtrendPercentage",
"flooringTyD",
"adroomD",
"agtCrSt",
"cg",
"pp",
"maintenanceCharges",
"bookingAmtExact",
"dImgSrc",
"landmark",
"seoLtSc",
"lc",
"pSc",
"lcLst",
"pCct",
"lCct",
"pcTcCt",
"ac",
"caSqFt",
"ltcoordGeo",
"iba",
"ct",
"lt",
"loc",
"bd",
"ca",
"ty",
"dtldesc",
"plgdtldesc",
"oid",
"oname",
"sdp",
"companyname",
"contName",
"auto_desc",
"prjname",
"pkg",
"isPaidUser",
"ctVerifd",
"pmtLat",
"pmtLong",
"moisd",
"supV",
"lmtDName",
"pkgid",
"achTdS",
"opSn",
"opSnD",
"sid",
"locSeoName",
"propImg",
"coverAreaUnitD",
"ppd",
"ppdL",
"achTm",
"achTmS",
"soc",
"tmsrt",
"ecd",
"prm",
"psmid",
"isVis",
"showupfront",
"agtCerStatus",
"caCompNameD",
"postedLabelD",
"amenFacingD",
"transactionTypeD",
"propTypeD",
"userType",
"transType",
"isPreferred",
"dImgRf",
"localityPhoto",
"defaultAdddressGoogle",
"propertyTitle",
"postedEditedLabel",
"wapImgUrl",
"wapImgUrl1",
"seoURL",
"psmImgCt",
"waterStatus",
"isLuxury",
"modifiedDate",
"actualOwner",
"isProjProp",
"devId",
"pglmtkey",
"grpBky1",
"grpBky2",
"grpBky3",
"grpBky4",
"grpBky5",
"grpBky6",
"grpBky7",
"sortCode1",
"sortCode1b",
"sortCode22",
"sortCode26",
"ubicnt",
"pckCon",
"ctCurr",
"rEcd",
"endDt",
"newUrl",
"catAdd1",
"seoPsmDt",
"pmtdesc_hi",
"legalDocStatusList",
"infraStatusList",
"isPrimeLocProp",
"operatingSinceYear",
"tenantsPreference",
"isThisListingAPremiumOnly",
"isAdvertiserOfThisListingAOwnerAndUnPaid",
"covAreaUnitDesc",
"investorlisting",
"investorguide",
"ampDesc",
"b2cCardEligibility",
"maskedMobileNumber",
"agentContinuityStr",
"isLuxuryServiceAvailable",
"luxAmenMap",
"nonluxAmenMap",
"ctaDetailBean",
"criLogo",
"crisilRv1CtBy",
"crisilNoOfEmployees",
"crisilStarRating",
"crisilOpSinceYear",
"sendbirdId",
"lastReplyDate",
"ltOther",
"agComCt",
"agentDetailUrl",
"isprimeListingType",
"brokerConnect",
"smartDiaryApiTag",
"ranPropImg",
"acD",
"imageDate",
"adCn",
"pmtUspWap",
"pmtUsp",
"comPantry",
"psmapproved",
"nriPref",
"la",
"tag",
"tagWap",
"landAreaUnit",
"landAreaUnitD",
"taImg",
"dues",
"imgUrl",
"sv",
"pmtUsp1",
"isRera",
"reraId",
"dsla",
"ctaRuleId",
"sVisMinDt",
"sVisMaxDt",
"personType",
"minPrice",
"maxPrice",
"exc",
"dealDesc",
"isReraAgent",
"agentReraState",
"pmtUsp2",
"pmtUsp2Wap",
"possBy",
"prjHl1",
"prjLtHl1",
"prjSrc",
"siteVisitProp",
"prjid",
"isExcl",
"nOs",
"noOfSVis",
"pmtTCabin",
"isCornerPlot",
"dimD",
"floorCsntrAllowed",
"rdWidth",
"gateComm",
"psmUspImgWeb",
"psmUspImgMob",
"cpmp",
"nr",
"appExcRe",
"pbrk",
"pbrkp",
"pfAgCg"], axis=1, inplace=True)

# %%
house_data
# Out:
#               possStatusD                                       luxAmenities  \
# 0      Under Construction  12560 12527 12562 12522 12236 12235 12239 1253...
# 1      Under Construction  12527 12522 12236 12521 12225 12524 12224 1222...
# 2           Ready to Move                            12229 12230 12221 12216
# 3           Ready to Move          12215 12224 12229 12230 12214 12216 12217
# 4           Ready to Move                                                NaN
# ...                   ...                                                ...
# 16705       Ready to Move  12239 12556 12225 12215 12224 12229 12230 1222...
# 16706             Dec '26                                                NaN
# 16707             Feb '31                                                NaN
# 16708             Aug '29                                                NaN
# 16709       Ready to Move  12560 12234 12527 12562 12522 12236 12235 1223...
#
#                                            luxAmenitiesD       price  \
# 0      Water Front,Sea facing,Smart Home,Private jacc...  33500000.0
# 1      Sea facing,Private jaccuzi,Island Kitchen Layo...  31450000.0
# 2      Jogging and Strolling Track,Outdoor Tennis Cou...  23000000.0
# 3      Air Conditioned,Banquet Hall,Jogging and Strol...  23000000.0
# 4                                                    NaN  18000000.0
# ...                                                  ...         ...
# 16705  Concierge Services,Fireplace,Bar/Lounge,Air Co...  26300000.0
# 16706                                                NaN   9424800.0
# 16707                                                NaN  56200000.0
# 16708                                                NaN  13900000.0
# 16709  Water Front,Skyline View,Sea facing,Smart Home...  51420000.0
#
#          priceD          maintenanceD  sqFtPrD carpetArea  sqFtPrice  \
# 0       3.35 Cr               Monthly  17031.0       1769    17031.0
# 1       3.14 Cr               Monthly  17000.0       1458    17000.0
# 2       2.30 Cr  Per sq. Unit Monthly  75907.0        160     8434.0
# 3       2.30 Cr  Per sq. Unit Monthly  16654.0       1099    16655.0
# 4       1.80 Cr               Monthly  10909.0        NaN    10909.0
# ...         ...                   ...      ...        ...        ...
# 16705   2.63 Cr               Monthly  12238.0        NaN    12238.0
# 16706  94.2 Lac                   NaN   7920.0        NaN     7920.0
# 16707   5.62 Cr                   NaN  18517.0        NaN    18517.0
# 16708   1.39 Cr                   NaN   9586.0        NaN     9586.0
# 16709   5.14 Cr             Quarterly  18489.0       2500    18490.0
#
#       OwnershipTypeD  ...                                              image  \
# 0           Freehold  ...  https://img.staticmb.com/mbimages/project/Phot...
# 1           Freehold  ...  https://img.staticmb.com/mbimages/project/Phot...
# 2           Freehold  ...  https://img.staticmb.com/mbphoto/property/crop...
# 3           Freehold  ...  https://img.staticmb.com/mbphoto/property/crop...
# 4           Freehold  ...  https://img.staticmb.com/mbphoto/property/crop...
# ...              ...  ...                                                ...
# 16705       Freehold  ...  https://img.staticmb.com/mbimages/project/Phot...
# 16706            NaN  ...  https://img.staticmb.com/mbimages/project/Phot...
# 16707            NaN  ...  https://img.staticmb.com/mbimages/project/Phot...
# 16708            NaN  ...  https://img.staticmb.com/mbimages/project/Phot...
# 16709       Freehold  ...  https://img.staticmb.com/mbimages/project/Phot...
#
#                                                amenities ctLast  \
# 0      12201 12202 12203 12204 12205 12206 12207 1220...      0
# 1      12201 12202 12204 12205 12206 12207 12208 1220...    NaN
# 2      12201 12202 12203 12204 12205 12208 12211 1221...      0
# 3      12201 12202 12203 12204 12205 12206 12207 1220...      0
# 4                                            12202 12208    847
# ...                                                  ...    ...
# 16705  12201 12202 12203 12204 12205 12206 12208 1220...      0
# 16706                                                NaN      0
# 16707                                                NaN      0
# 16708                                                NaN      0
# 16709  12201 12202 12203 12204 12205 12206 12207 1220...      0
#
#            powerStatusD           parkingD  \
# 0                   NaN                NaN
# 1      No/Rare Powercut          2 Covered
# 2      No/Rare Powercut             1 Open
# 3      No/Rare Powercut          1 Covered
# 4      No/Rare Powercut          1 Covered
# ...                 ...                ...
# 16705  No/Rare Powercut  1 Covered, 1 Open
# 16706  No/Rare Powercut          1 Covered
# 16707  No/Rare Powercut          1 Covered
# 16708  No/Rare Powercut          1 Covered
# 16709  No/Rare Powercut          2 Covered
#
#                                         propertyImageNew iTarget bachelor  \
# 0                                                    NaN     NaN      NaN
# 1                                                    NaN     NaN      NaN
# 2      https://img.staticmb.com/mbphoto/property/crop...     NaN      NaN
# 3      https://img.staticmb.com/mbphoto/property/crop...     NaN      NaN
# 4      https://img.staticmb.com/mbphoto/property/crop...     NaN      NaN
# ...                                                  ...     ...      ...
# 16705                                                NaN     NaN      NaN
# 16706                                                NaN     NaN      NaN
# 16707                                                NaN     NaN      NaN
# 16708                                                NaN     NaN      NaN
# 16709                                                NaN     NaN      NaN
#
#         vl       city
# 0      NaN  New Delhi
# 1      NaN  New Delhi
# 2      NaN  New Delhi
# 3      NaN  New Delhi
# 4      NaN  New Delhi
# ...    ...        ...
# 16705  NaN  New Delhi
# 16706  NaN  New Delhi
# 16707  NaN  New Delhi
# 16708  NaN  New Delhi
# 16709  NaN  New Delhi
#
# [16710 rows x 31 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD            67
# luxAmenities         7389
# luxAmenitiesD        7390
# price                  65
# priceD                  1
# maintenanceD         9285
# sqFtPrD               162
# carpetArea           9853
# sqFtPrice             174
# OwnershipTypeD       9183
# furnishedD             77
# balconiesD           7801
# bathD                  59
# facingD              9766
# floorD               7187
# ctName                  0
# bedroomD                1
# floors               7189
# coveredArea           137
# covAreaUnit           136
# carpAreaUnit         9857
# image                 551
# amenities            6786
# ctLast               6390
# powerStatusD         3689
# parkingD             5982
# propertyImageNew    10586
# iTarget             14363
# bachelor            16709
# vl                  14365
# city                    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
possesion = SimpleImputer(strategy='constant', fill_value='Ready to Move')
possD = possesion.fit_transform(pd.DataFrame(house_data['possStatusD']))
house_data['possStatusD'] = pd.DataFrame(possD, columns=['possStatusD'])

# %%
house_data.isna().sum()
# Out:
# possStatusD             0
# luxAmenities         7389
# luxAmenitiesD        7390
# price                  65
# priceD                  1
# maintenanceD         9285
# sqFtPrD               162
# carpetArea           9853
# sqFtPrice             174
# OwnershipTypeD       9183
# furnishedD             77
# balconiesD           7801
# bathD                  59
# facingD              9766
# floorD               7187
# ctName                  0
# bedroomD                1
# floors               7189
# coveredArea           137
# covAreaUnit           136
# carpAreaUnit         9857
# image                 551
# amenities            6786
# ctLast               6390
# powerStatusD         3689
# parkingD             5982
# propertyImageNew    10586
# iTarget             14363
# bachelor            16709
# vl                  14365
# city                    0
# dtype: int64

# %%
house_data.drop(["iTarget", "bachelor", "vl", "luxAmenities", "floorD", "luxAmenitiesD", "OwnershipTypeD", "ctLast", "propertyImageNew", "luxAmenitiesD", "city", "image", "sqFtPrD", "covAreaUnit", "amenities", "maintenanceD"], axis=1, inplace=True)

# %%
house_data
# Out:
#               possStatusD       price    priceD carpetArea  sqFtPrice  \
# 0      Under Construction  33500000.0   3.35 Cr       1769    17031.0
# 1      Under Construction  31450000.0   3.14 Cr       1458    17000.0
# 2           Ready to Move  23000000.0   2.30 Cr        160     8434.0
# 3           Ready to Move  23000000.0   2.30 Cr       1099    16655.0
# 4           Ready to Move  18000000.0   1.80 Cr        NaN    10909.0
# ...                   ...         ...       ...        ...        ...
# 16705       Ready to Move  26300000.0   2.63 Cr        NaN    12238.0
# 16706             Dec '26   9424800.0  94.2 Lac        NaN     7920.0
# 16707             Feb '31  56200000.0   5.62 Cr        NaN    18517.0
# 16708             Aug '29  13900000.0   1.39 Cr        NaN     9586.0
# 16709       Ready to Move  51420000.0   5.14 Cr       2500    18490.0
#
#            furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 0         Unfurnished          3     3          East  Gurgaon        3     18
# 1      Semi-Furnished          3     3  North - East  Gurgaon        3     34
# 2         Unfurnished          3     3  North - East  Gurgaon        3      2
# 3      Semi-Furnished          4     2  North - East  Gurgaon        2     18
# 4      Semi-Furnished          2     3          East  Gurgaon        3     14
# ...               ...        ...   ...           ...      ...      ...    ...
# 16705  Semi-Furnished          4     4  North - East  Gurgaon        3     25
# 16706  Semi-Furnished        NaN     3           NaN  Gurgaon        3    NaN
# 16707  Semi-Furnished        NaN     3           NaN  Gurgaon        3    NaN
# 16708  Semi-Furnished        NaN     3           NaN  Gurgaon        3    NaN
# 16709  Semi-Furnished          2     3         North  Gurgaon        3     20
#
#       coveredArea carpAreaUnit      powerStatusD           parkingD
# 0            1967        Sq-ft               NaN                NaN
# 1            1850        Sq-ft  No/Rare Powercut          2 Covered
# 2             303       Sq-yrd  No/Rare Powercut             1 Open
# 3            1381        Sq-ft  No/Rare Powercut          1 Covered
# 4            1650          NaN  No/Rare Powercut          1 Covered
# ...           ...          ...               ...                ...
# 16705        2149          NaN  No/Rare Powercut  1 Covered, 1 Open
# 16706        1190          NaN  No/Rare Powercut          1 Covered
# 16707        3035          NaN  No/Rare Powercut          1 Covered
# 16708        1450          NaN  No/Rare Powercut          1 Covered
# 16709        2781        Sq-ft  No/Rare Powercut          2 Covered
#
# [16710 rows x 16 columns]

# %%
house_data['powerStatusD'].value_counts()
# Out:
# powerStatusD
# No/Rare Powercut             13004
# Less Than 2 Hour Powercut       14
# Over 6 Hours Powercut            2
# 4 To 6 Hours Powercut            1
# Name: count, dtype: int64

# %%
house_data[house_data['powerStatusD']=='Less Than 2 Hour Powercut']
# Out:
#              possStatusD       price    priceD carpetArea  sqFtPrice  \
# 112        Ready to Move  24500000.0   2.45 Cr       1650    10351.0
# 179   Under Construction  38500000.0   3.85 Cr       1351    16645.0
# 561        Ready to Move  19000000.0   1.90 Cr       1250    12041.0
# 609        Ready to Move  61200000.0   6.12 Cr       1500    34000.0
# 648        Ready to Move  16000000.0   1.60 Cr        240    12800.0
# 1547       Ready to Move   9390000.0  93.9 Lac        NaN     6000.0
# 1944       Ready to Move  18000000.0   1.80 Cr        240    14718.0
# 1980       Ready to Move   8700000.0    87 Lac        913     5513.0
# 1989       Ready to Move   5400000.0    54 Lac        700        NaN
# 2040       Ready to Move   8800000.0    88 Lac       1578     5577.0
# 2061       Ready to Move   4500000.0    45 Lac        585     6569.0
# 2128  Under Construction   8550000.0  85.5 Lac        NaN     4634.0
# 2318       Ready to Move   8500000.0    85 Lac        NaN     7863.0
# 2341       Ready to Move   3800000.0    38 Lac        650        NaN
#
#           furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 112   Semi-Furnished          2     3          East  Gurgaon        3      4
# 179   Semi-Furnished          3     3          East  Gurgaon        3      4
# 561   Semi-Furnished          2     3          East  Gurgaon        3     15
# 609      Unfurnished          2     3         North  Gurgaon        3      1
# 648   Semi-Furnished          2     3         North  Gurgaon        3      3
# 1547  Semi-Furnished          3     3  South - East  Gurgaon        3     13
# 1944     Unfurnished          4     2          East  Gurgaon        2      2
# 1980  Semi-Furnished          4     3  North - East  Gurgaon        2     23
# 1989       Furnished          2     2           NaN  Gurgaon        2     10
# 2040     Unfurnished        NaN     2  North - East  Gurgaon        2     22
# 2061  Semi-Furnished          1     2          East  Gurgaon        2     19
# 2128     Unfurnished          3     3           NaN  Gurgaon        3     23
# 2318     Unfurnished          2     2           NaN  Gurgaon        3      5
# 2341  Semi-Furnished          1     2           NaN  Gurgaon        2      4
#
#      coveredArea carpAreaUnit               powerStatusD           parkingD
# 112         2367        Sq-ft  Less Than 2 Hour Powercut          2 Covered
# 179          NaN        Sq-ft  Less Than 2 Hour Powercut          2 Covered
# 561         1578        Sq-ft  Less Than 2 Hour Powercut          1 Covered
# 609         1800        Sq-ft  Less Than 2 Hour Powercut  2 Covered, 2 Open
# 648         1250       Sq-yrd  Less Than 2 Hour Powercut             2 Open
# 1547        1565          NaN  Less Than 2 Hour Powercut          1 Covered
# 1944        1223       Sq-yrd  Less Than 2 Hour Powercut             3 Open
# 1980        1578        Sq-ft  Less Than 2 Hour Powercut  2 Covered, 1 Open
# 1989         NaN        Sq-ft  Less Than 2 Hour Powercut           160 Open
# 2040        1578        Sq-ft  Less Than 2 Hour Powercut          1 Covered
# 2061         685        Sq-ft  Less Than 2 Hour Powercut                NaN
# 2128        1845          NaN  Less Than 2 Hour Powercut          2 Covered
# 2318        1081          NaN  Less Than 2 Hour Powercut          1 Covered
# 2341         NaN        Sq-ft  Less Than 2 Hour Powercut                NaN

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price             65
# priceD             1
# carpetArea      9853
# sqFtPrice        174
# furnishedD        77
# balconiesD      7801
# bathD             59
# facingD         9766
# ctName             0
# bedroomD           1
# floors          7189
# coveredArea      137
# carpAreaUnit    9857
# powerStatusD    3689
# parkingD        5982
# dtype: int64

# %%
powercut = SimpleImputer(strategy='constant', fill_value='No/Rare Powercut')
power = powercut.fit_transform(pd.DataFrame(house_data['powerStatusD']))
house_data['powerStatusD'] = pd.DataFrame(power, columns=['powerStatusD'])

# %%
floor = SimpleImputer(strategy='constant', fill_value=0)
floor = floor.fit_transform(pd.DataFrame(house_data['floors']))
house_data['floors'] = pd.DataFrame(floor, columns=['floors'])

# %%
carpArea = SimpleImputer(strategy='constant', fill_value="Sq-ft")
carpArea = carpArea.fit_transform(pd.DataFrame(house_data['carpAreaUnit']))
house_data['carpAreaUnit'] = pd.DataFrame(carpArea, columns=['carpAreaUnit'])

# %%
parkingD = SimpleImputer(strategy='constant', fill_value=0)
parkingD = parkingD.fit_transform(pd.DataFrame(house_data['parkingD']))
house_data['parkingD'] = pd.DataFrame(parkingD, columns=['parkingD'])

# %%
furnished = SimpleImputer(strategy='constant', fill_value='Unfurnished')
furnished = furnished.fit_transform(pd.DataFrame(house_data['furnishedD']))
house_data['furnishedD'] = pd.DataFrame(furnished, columns=['furnishedD'])

# %%
house_data['coveredArea'] = pd.to_numeric(house_data['coveredArea'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Filling nan values for rekki

# %%
carpetArea = SimpleImputer(strategy='constant', fill_value=0)
carpetArea = carpetArea.fit_transform(pd.DataFrame(house_data['carpetArea']))
house_data['carpetArea'] = pd.DataFrame(carpetArea, columns=['carpetArea'])

# %%
coveredArea = SimpleImputer(strategy='constant', fill_value=0)
coveredArea = coveredArea.fit_transform(pd.DataFrame(house_data['coveredArea']))
house_data['coveredArea'] = pd.DataFrame(coveredArea, columns=['coveredArea'])

# %%
sqFtPrice = SimpleImputer(strategy='constant', fill_value=0)
sqFtPrice = sqFtPrice.fit_transform(pd.DataFrame(house_data['sqFtPrice']))
house_data['sqFtPrice'] = pd.DataFrame(sqFtPrice, columns=['sqFtPrice'])

# %% [markdown]
# ## Average percentage for carpet and covered area

# %%
len(house_data)
# Out:
# 16710

# %%
house_data['areaPercent'] = 0

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]!=0:
        house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\1360539506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\1360539506.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.10066090493136756' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   house_data['areaPercent'][i] = (int(house_data['coveredArea'][i])-int(house_data['carpetArea'][i]))/int(house_data['coveredArea'][i])

# %%
house_data[house_data['areaPercent']!=0]['areaPercent'].mean()
# Out:
# 0.1850572152730042

# %% [markdown]
# ## fill na carpet area with 80% of covered area

# %%
for i in range(len(house_data)):
    if house_data['coveredArea'][i]!=0 and house_data['carpetArea'][i]==0:
        house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4277676976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_data['carpetArea'][i] = int(house_data['coveredArea'][i])*0.8
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\4172689600.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['carpetArea']!=0][house_data['coveredArea']!=0]

# %%
house_data
# Out:
#               possStatusD       price    priceD carpetArea  sqFtPrice  \
# 0      Under Construction  33500000.0   3.35 Cr       1769    17031.0
# 1      Under Construction  31450000.0   3.14 Cr       1458    17000.0
# 2           Ready to Move  23000000.0   2.30 Cr        160     8434.0
# 3           Ready to Move  23000000.0   2.30 Cr       1099    16655.0
# 4           Ready to Move  18000000.0   1.80 Cr     1320.0    10909.0
# ...                   ...         ...       ...        ...        ...
# 16705       Ready to Move  26300000.0   2.63 Cr     1719.2    12238.0
# 16706             Dec '26   9424800.0  94.2 Lac      952.0     7920.0
# 16707             Feb '31  56200000.0   5.62 Cr     2428.0    18517.0
# 16708             Aug '29  13900000.0   1.39 Cr     1160.0     9586.0
# 16709       Ready to Move  51420000.0   5.14 Cr       2500    18490.0
#
#            furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 0         Unfurnished          3     3          East  Gurgaon        3     18
# 1      Semi-Furnished          3     3  North - East  Gurgaon        3     34
# 2         Unfurnished          3     3  North - East  Gurgaon        3      2
# 3      Semi-Furnished          4     2  North - East  Gurgaon        2     18
# 4      Semi-Furnished          2     3          East  Gurgaon        3     14
# ...               ...        ...   ...           ...      ...      ...    ...
# 16705  Semi-Furnished          4     4  North - East  Gurgaon        3     25
# 16706  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16707  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16708  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16709  Semi-Furnished          2     3         North  Gurgaon        3     20
#
#        coveredArea carpAreaUnit      powerStatusD           parkingD  \
# 0           1967.0        Sq-ft  No/Rare Powercut                  0
# 1           1850.0        Sq-ft  No/Rare Powercut          2 Covered
# 2            303.0       Sq-yrd  No/Rare Powercut             1 Open
# 3           1381.0        Sq-ft  No/Rare Powercut          1 Covered
# 4           1650.0        Sq-ft  No/Rare Powercut          1 Covered
# ...            ...          ...               ...                ...
# 16705       2149.0        Sq-ft  No/Rare Powercut  1 Covered, 1 Open
# 16706       1190.0        Sq-ft  No/Rare Powercut          1 Covered
# 16707       3035.0        Sq-ft  No/Rare Powercut          1 Covered
# 16708       1450.0        Sq-ft  No/Rare Powercut          1 Covered
# 16709       2781.0        Sq-ft  No/Rare Powercut          2 Covered
#
#        areaPercent
# 0         0.100661
# 1         0.211892
# 2         0.471947
# 3         0.204200
# 4         0.000000
# ...            ...
# 16705     0.000000
# 16706     0.000000
# 16707     0.000000
# 16708     0.000000
# 16709     0.101043
#
# [16573 rows x 17 columns]

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price             44
# priceD             0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      7767
# bathD             48
# facingD         9668
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# powerStatusD       0
# parkingD           0
# areaPercent        0
# dtype: int64

# %%
house_data[house_data['priceD']=='Call for Price']
# Out:
#              possStatusD  price          priceD carpetArea  sqFtPrice  \
# 2568       Ready to Move    NaN  Call for Price      596.0        0.0
# 2569  Under Construction    NaN  Call for Price       1067        0.0
# 2570       Ready to Move    NaN  Call for Price     1499.2        0.0
# 2572       Ready to Move    NaN  Call for Price      436.8        0.0
# 2573       Ready to Move    NaN  Call for Price      960.0        0.0
# 2574       Ready to Move    NaN  Call for Price     1760.0        0.0
# 2575       Ready to Move    NaN  Call for Price     1154.4        0.0
# 2578       Ready to Move    NaN  Call for Price      926.4        0.0
# 2579       Ready to Move    NaN  Call for Price      516.0        0.0
# 2581       Ready to Move    NaN  Call for Price      720.0        0.0
# 2582       Ready to Move    NaN  Call for Price      153.6        0.0
# 2583       Ready to Move    NaN  Call for Price     1601.6        0.0
# 2584       Ready to Move    NaN  Call for Price     1760.0        0.0
# 2585       Ready to Move    NaN  Call for Price     1252.0        0.0
# 2587       Ready to Move    NaN  Call for Price      182.4        0.0
# 2589       Ready to Move    NaN  Call for Price     1040.0        0.0
# 2590       Ready to Move    NaN  Call for Price      440.0        0.0
# 2591       Ready to Move    NaN  Call for Price      480.0        0.0
# 2592       Ready to Move    NaN  Call for Price      140.0        0.0
# 2593       Ready to Move    NaN  Call for Price     1040.0        0.0
# 2594       Ready to Move    NaN  Call for Price      960.0        0.0
# 2597       Ready to Move    NaN  Call for Price     1208.8        0.0
# 2599       Ready to Move    NaN  Call for Price      880.0        0.0
# 2600       Ready to Move    NaN  Call for Price     1160.0        0.0
# 2604       Ready to Move    NaN  Call for Price      210.4        0.0
# 2605       Ready to Move    NaN  Call for Price     1016.0        0.0
# 2606       Ready to Move    NaN  Call for Price      520.0        0.0
# 2607       Ready to Move    NaN  Call for Price      896.0        0.0
# 2608       Ready to Move    NaN  Call for Price     1960.0        0.0
# 2610         Immediately    NaN  Call for Price      960.0        0.0
# 2614  Under Construction    NaN  Call for Price     1120.0        0.0
# 2615       Ready to Move    NaN  Call for Price        1.6        0.0
# 2616       Ready to Move    NaN  Call for Price     1636.0        0.0
# 2617       Ready to Move    NaN  Call for Price     1236.0        0.0
# 2618       Ready to Move    NaN  Call for Price      432.0        0.0
# 2619       Ready to Move    NaN  Call for Price     1092.0        0.0
# 2621       Ready to Move    NaN  Call for Price      882.4        0.0
# 2622       Ready to Move    NaN  Call for Price     1080.8        0.0
# 2624       Ready to Move    NaN  Call for Price       17.6        0.0
# 2625       Ready to Move    NaN  Call for Price       40.0        0.0
# 2626       Ready to Move    NaN  Call for Price      720.0        0.0
# 2628       Ready to Move    NaN  Call for Price     1192.0        0.0
# 2629       Ready to Move    NaN  Call for Price     1440.0        0.0
# 2630       Ready to Move    NaN  Call for Price     1008.0        0.0
#
#           furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 2568     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2569     Unfurnished          3     3           NaN  Gurgaon        3     20
# 2570       Furnished          3     3           NaN  Gurgaon        3     10
# 2572     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2573     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2574     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2575     Unfurnished          2     3           NaN  Gurgaon        3     50
# 2578     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2579     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2581  Semi-Furnished        NaN     2           NaN  Gurgaon        2      2
# 2582     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2583     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2584     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2585     Unfurnished        NaN     3           NaN  Gurgaon        3     13
# 2587     Unfurnished        NaN     3           NaN  Gurgaon        3      0
# 2589     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2590     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2591     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2592     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2593  Semi-Furnished        NaN     2           NaN  Gurgaon        3      4
# 2594     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2597  Semi-Furnished        NaN     3           NaN  Gurgaon        3     19
# 2599  Semi-Furnished          2     2           NaN  Gurgaon        2     15
# 2600     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2604     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2605  Semi-Furnished          2     2           NaN  Gurgaon        2     19
# 2606     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2607  Semi-Furnished        NaN     2           NaN  Gurgaon        3      4
# 2608     Unfurnished        NaN     3  North - East  Gurgaon        3     17
# 2610     Unfurnished          2     2           NaN  Gurgaon        2      4
# 2614     Unfurnished          1     3           NaN  Gurgaon        3      5
# 2615     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2616     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2617  Semi-Furnished        NaN     2           NaN  Gurgaon        3     14
# 2618     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2619     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2621     Unfurnished          2     2           NaN  Gurgaon        2      4
# 2622     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2624     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2625     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2626     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2628     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2629     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2630     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
#
#       coveredArea carpAreaUnit      powerStatusD parkingD  areaPercent
# 2568        745.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2569       1894.0        Sq-ft  No/Rare Powercut        0     0.436642
# 2570       1874.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2572        546.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2573       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2574       2200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2575       1443.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2578       1158.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2579        645.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2581        900.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2582        192.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2583       2002.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2584       2200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2585       1565.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2587        228.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2589       1300.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2590        550.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2591        600.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2592        175.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2593       1300.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2594       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2597       1511.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2599       1100.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2600       1450.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2604        263.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2605       1270.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2606        650.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2607       1120.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2608       2450.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2610       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2614       1400.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2615          2.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2616       2045.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2617       1545.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2618        540.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2619       1365.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2621       1103.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2622       1351.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2624         22.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2625         50.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2626        900.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2628       1490.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2629       1800.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2630       1260.0        Sq-ft  No/Rare Powercut        0     0.000000

# %%
Price = SimpleImputer(strategy='constant', fill_value=0)
house_data['price'] = Price.fit_transform(pd.DataFrame(house_data['price'])).astype(int)

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price              0
# priceD             0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      7767
# bathD             48
# facingD         9668
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# powerStatusD       0
# parkingD           0
# areaPercent        0
# dtype: int64

# %%
house_data.iloc[23,2].split(" ")
# Out:
# ['2.20', 'Cr']

# %%
house_data[house_data['price']==0]
# Out:
#              possStatusD  price          priceD carpetArea  sqFtPrice  \
# 2568       Ready to Move      0  Call for Price      596.0        0.0
# 2569  Under Construction      0  Call for Price       1067        0.0
# 2570       Ready to Move      0  Call for Price     1499.2        0.0
# 2572       Ready to Move      0  Call for Price      436.8        0.0
# 2573       Ready to Move      0  Call for Price      960.0        0.0
# 2574       Ready to Move      0  Call for Price     1760.0        0.0
# 2575       Ready to Move      0  Call for Price     1154.4        0.0
# 2578       Ready to Move      0  Call for Price      926.4        0.0
# 2579       Ready to Move      0  Call for Price      516.0        0.0
# 2581       Ready to Move      0  Call for Price      720.0        0.0
# 2582       Ready to Move      0  Call for Price      153.6        0.0
# 2583       Ready to Move      0  Call for Price     1601.6        0.0
# 2584       Ready to Move      0  Call for Price     1760.0        0.0
# 2585       Ready to Move      0  Call for Price     1252.0        0.0
# 2587       Ready to Move      0  Call for Price      182.4        0.0
# 2589       Ready to Move      0  Call for Price     1040.0        0.0
# 2590       Ready to Move      0  Call for Price      440.0        0.0
# 2591       Ready to Move      0  Call for Price      480.0        0.0
# 2592       Ready to Move      0  Call for Price      140.0        0.0
# 2593       Ready to Move      0  Call for Price     1040.0        0.0
# 2594       Ready to Move      0  Call for Price      960.0        0.0
# 2597       Ready to Move      0  Call for Price     1208.8        0.0
# 2599       Ready to Move      0  Call for Price      880.0        0.0
# 2600       Ready to Move      0  Call for Price     1160.0        0.0
# 2604       Ready to Move      0  Call for Price      210.4        0.0
# 2605       Ready to Move      0  Call for Price     1016.0        0.0
# 2606       Ready to Move      0  Call for Price      520.0        0.0
# 2607       Ready to Move      0  Call for Price      896.0        0.0
# 2608       Ready to Move      0  Call for Price     1960.0        0.0
# 2610         Immediately      0  Call for Price      960.0        0.0
# 2614  Under Construction      0  Call for Price     1120.0        0.0
# 2615       Ready to Move      0  Call for Price        1.6        0.0
# 2616       Ready to Move      0  Call for Price     1636.0        0.0
# 2617       Ready to Move      0  Call for Price     1236.0        0.0
# 2618       Ready to Move      0  Call for Price      432.0        0.0
# 2619       Ready to Move      0  Call for Price     1092.0        0.0
# 2621       Ready to Move      0  Call for Price      882.4        0.0
# 2622       Ready to Move      0  Call for Price     1080.8        0.0
# 2624       Ready to Move      0  Call for Price       17.6        0.0
# 2625       Ready to Move      0  Call for Price       40.0        0.0
# 2626       Ready to Move      0  Call for Price      720.0        0.0
# 2628       Ready to Move      0  Call for Price     1192.0        0.0
# 2629       Ready to Move      0  Call for Price     1440.0        0.0
# 2630       Ready to Move      0  Call for Price     1008.0        0.0
#
#           furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 2568     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2569     Unfurnished          3     3           NaN  Gurgaon        3     20
# 2570       Furnished          3     3           NaN  Gurgaon        3     10
# 2572     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2573     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2574     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2575     Unfurnished          2     3           NaN  Gurgaon        3     50
# 2578     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2579     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2581  Semi-Furnished        NaN     2           NaN  Gurgaon        2      2
# 2582     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2583     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2584     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2585     Unfurnished        NaN     3           NaN  Gurgaon        3     13
# 2587     Unfurnished        NaN     3           NaN  Gurgaon        3      0
# 2589     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2590     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2591     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2592     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2593  Semi-Furnished        NaN     2           NaN  Gurgaon        3      4
# 2594     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2597  Semi-Furnished        NaN     3           NaN  Gurgaon        3     19
# 2599  Semi-Furnished          2     2           NaN  Gurgaon        2     15
# 2600     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2604     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2605  Semi-Furnished          2     2           NaN  Gurgaon        2     19
# 2606     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2607  Semi-Furnished        NaN     2           NaN  Gurgaon        3      4
# 2608     Unfurnished        NaN     3  North - East  Gurgaon        3     17
# 2610     Unfurnished          2     2           NaN  Gurgaon        2      4
# 2614     Unfurnished          1     3           NaN  Gurgaon        3      5
# 2615     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2616     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2617  Semi-Furnished        NaN     2           NaN  Gurgaon        3     14
# 2618     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2619     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2621     Unfurnished          2     2           NaN  Gurgaon        2      4
# 2622     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2624     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2625     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2626     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
# 2628     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2629     Unfurnished        NaN   NaN           NaN  Gurgaon        3      0
# 2630     Unfurnished        NaN   NaN           NaN  Gurgaon        2      0
#
#       coveredArea carpAreaUnit      powerStatusD parkingD  areaPercent
# 2568        745.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2569       1894.0        Sq-ft  No/Rare Powercut        0     0.436642
# 2570       1874.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2572        546.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2573       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2574       2200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2575       1443.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2578       1158.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2579        645.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2581        900.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2582        192.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2583       2002.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2584       2200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2585       1565.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2587        228.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2589       1300.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2590        550.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2591        600.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2592        175.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2593       1300.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2594       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2597       1511.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2599       1100.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2600       1450.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2604        263.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2605       1270.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2606        650.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2607       1120.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2608       2450.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2610       1200.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2614       1400.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2615          2.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2616       2045.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2617       1545.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2618        540.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2619       1365.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2621       1103.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2622       1351.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2624         22.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2625         50.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2626        900.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2628       1490.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2629       1800.0        Sq-ft  No/Rare Powercut        0     0.000000
# 2630       1260.0        Sq-ft  No/Rare Powercut        0     0.000000

# %%
house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\1394455010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data = house_data[house_data['price']!=0][house_data['priceD']!='Call for Price']

# %%
house_data.isna().sum()
# Out:
# possStatusD        0
# price              0
# priceD             0
# carpetArea         0
# sqFtPrice          0
# furnishedD         0
# balconiesD      7731
# bathD             20
# facingD         9625
# ctName             0
# bedroomD           0
# floors             0
# coveredArea        0
# carpAreaUnit       0
# powerStatusD       0
# parkingD           0
# areaPercent        0
# dtype: int64

# %%
house_data['facingD'].unique()
# Out:
# array(['East', 'North - East', 'West', nan, 'North', 'South -West',
#        'North - West', 'South - East', 'South'], dtype=object)

# %%
house_data
# Out:
#               possStatusD     price    priceD carpetArea  sqFtPrice  \
# 0      Under Construction  33500000   3.35 Cr       1769    17031.0
# 1      Under Construction  31450000   3.14 Cr       1458    17000.0
# 2           Ready to Move  23000000   2.30 Cr        160     8434.0
# 3           Ready to Move  23000000   2.30 Cr       1099    16655.0
# 4           Ready to Move  18000000   1.80 Cr     1320.0    10909.0
# ...                   ...       ...       ...        ...        ...
# 16705       Ready to Move  26300000   2.63 Cr     1719.2    12238.0
# 16706             Dec '26   9424800  94.2 Lac      952.0     7920.0
# 16707             Feb '31  56200000   5.62 Cr     2428.0    18517.0
# 16708             Aug '29  13900000   1.39 Cr     1160.0     9586.0
# 16709       Ready to Move  51420000   5.14 Cr       2500    18490.0
#
#            furnishedD balconiesD bathD       facingD   ctName bedroomD floors  \
# 0         Unfurnished          3     3          East  Gurgaon        3     18
# 1      Semi-Furnished          3     3  North - East  Gurgaon        3     34
# 2         Unfurnished          3     3  North - East  Gurgaon        3      2
# 3      Semi-Furnished          4     2  North - East  Gurgaon        2     18
# 4      Semi-Furnished          2     3          East  Gurgaon        3     14
# ...               ...        ...   ...           ...      ...      ...    ...
# 16705  Semi-Furnished          4     4  North - East  Gurgaon        3     25
# 16706  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16707  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16708  Semi-Furnished        NaN     3           NaN  Gurgaon        3      0
# 16709  Semi-Furnished          2     3         North  Gurgaon        3     20
#
#        coveredArea carpAreaUnit      powerStatusD           parkingD  \
# 0           1967.0        Sq-ft  No/Rare Powercut                  0
# 1           1850.0        Sq-ft  No/Rare Powercut          2 Covered
# 2            303.0       Sq-yrd  No/Rare Powercut             1 Open
# 3           1381.0        Sq-ft  No/Rare Powercut          1 Covered
# 4           1650.0        Sq-ft  No/Rare Powercut          1 Covered
# ...            ...          ...               ...                ...
# 16705       2149.0        Sq-ft  No/Rare Powercut  1 Covered, 1 Open
# 16706       1190.0        Sq-ft  No/Rare Powercut          1 Covered
# 16707       3035.0        Sq-ft  No/Rare Powercut          1 Covered
# 16708       1450.0        Sq-ft  No/Rare Powercut          1 Covered
# 16709       2781.0        Sq-ft  No/Rare Powercut          2 Covered
#
#        areaPercent
# 0         0.100661
# 1         0.211892
# 2         0.471947
# 3         0.204200
# 4         0.000000
# ...            ...
# 16705     0.000000
# 16706     0.000000
# 16707     0.000000
# 16708     0.000000
# 16709     0.101043
#
# [16529 rows x 17 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16529 entries, 0 to 16709
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   possStatusD   16529 non-null  object
#  1   price         16529 non-null  int32
#  2   priceD        16529 non-null  object
#  3   carpetArea    16529 non-null  object
#  4   sqFtPrice     16529 non-null  float64
#  5   furnishedD    16529 non-null  object
#  6   balconiesD    8798 non-null   object
#  7   bathD         16509 non-null  object
#  8   facingD       6904 non-null   object
#  9   ctName        16529 non-null  object
#  10  bedroomD      16529 non-null  object
#  11  floors        16529 non-null  object
#  12  coveredArea   16529 non-null  float64
#  13  carpAreaUnit  16529 non-null  object
#  14  powerStatusD  16529 non-null  object
#  15  parkingD      16529 non-null  object
#  16  areaPercent   16529 non-null  float64
# dtypes: float64(3), int32(1), object(13)
# memory usage: 2.2+ MB

# %%
house_data['carpetArea'] = house_data['carpetArea'].astype(float)
house_data['balconiesD'] = house_data['balconiesD'].astype(float)
house_data['bathD'] = house_data['bathD'].astype(float)
house_data['bedroomD'] = house_data['bedroomD'].astype(float)
house_data['floors'] = house_data['floors'].astype(float)

# %% [markdown]
# ## Changing date to ready to move or under construction

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Dec '26", "Feb '25",
#        "Aug '29", "Sep '25", "Jun '24", "Feb '31", "May '24", "Jun '26",
#        'Ready To Move', "Nov '27", "Sep '28", "Mar '31", "Apr '24",
#        "Dec '25"], dtype=object)

# %%
house_data['possStatusD'] = house_data['possStatusD'].replace({'Immediately': "Ready to Move", "Under Construction": "Under Construction", "Ready to Move": "Ready to Move", "Aug '25": "Ready to Move", "May '24": "Ready to Move"})

# %%
house_data['possStatusD'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', "Dec '26", "Feb '25",
#        "Aug '29", "Sep '25", "Jun '24", "Feb '31", "Jun '26",
#        'Ready To Move', "Nov '27", "Sep '28", "Mar '31", "Apr '24",
#        "Dec '25"], dtype=object)

# %%
house_data['price'][1]/house_data['sqFtPrice'][1]
# Out:
# 1850.0

# %%
house_data[house_data['furnishedD']=='Unfurnished']
# Out:
#               possStatusD     price   priceD  carpetArea  sqFtPrice  \
# 0      Under Construction  33500000  3.35 Cr      1769.0    17031.0
# 2           Ready to Move  23000000  2.30 Cr       160.0     8434.0
# 7                 Dec '26  21500000  2.15 Cr      1048.0    16412.0
# 8                 Feb '25  12000000  1.20 Cr      1380.0     6957.0
# 13          Ready to Move  27850000  2.78 Cr      1650.0    10509.0
# ...                   ...       ...      ...         ...        ...
# 16685       Ready to Move  17000000  1.70 Cr      1320.0    10303.0
# 16689       Ready to Move  22000000  2.20 Cr      1640.0    10732.0
# 16693             Jun '26  20300000  2.03 Cr      1227.2    13233.0
# 16699             Dec '25  35900000  3.59 Cr      2120.0    13547.0
# 16701             Jun '26  24100000  2.41 Cr      1245.6    15478.0
#
#         furnishedD  balconiesD  bathD       facingD   ctName  bedroomD  \
# 0      Unfurnished         3.0    3.0          East  Gurgaon       3.0
# 2      Unfurnished         3.0    3.0  North - East  Gurgaon       3.0
# 7      Unfurnished         NaN    2.0           NaN  Gurgaon       2.0
# 8      Unfurnished         NaN    3.0           NaN  Gurgaon       3.0
# 13     Unfurnished         5.0    3.0  North - East  Gurgaon       3.0
# ...            ...         ...    ...           ...      ...       ...
# 16685  Unfurnished         2.0    3.0  South - East  Gurgaon       3.0
# 16689  Unfurnished         NaN    2.0           NaN  Gurgaon       2.0
# 16693  Unfurnished         NaN    3.0           NaN  Gurgaon       3.0
# 16699  Unfurnished         NaN    3.0           NaN  Gurgaon       3.0
# 16701  Unfurnished         NaN    3.0           NaN  Gurgaon       3.0
#
#        floors  coveredArea carpAreaUnit      powerStatusD   parkingD  \
# 0        18.0       1967.0        Sq-ft  No/Rare Powercut          0
# 2         2.0        303.0       Sq-yrd  No/Rare Powercut     1 Open
# 7         0.0       1310.0        Sq-ft  No/Rare Powercut  1 Covered
# 8         0.0       1725.0        Sq-ft  No/Rare Powercut          0
# 13       24.0       2650.0        Sq-ft  No/Rare Powercut  2 Covered
# ...       ...          ...          ...               ...        ...
# 16685    13.0       1650.0        Sq-ft  No/Rare Powercut          0
# 16689     0.0       2050.0        Sq-ft  No/Rare Powercut  1 Covered
# 16693     0.0       1534.0        Sq-ft  No/Rare Powercut          0
# 16699     0.0       2650.0        Sq-ft  No/Rare Powercut          0
# 16701     0.0       1557.0        Sq-ft  No/Rare Powercut  1 Covered
#
#        areaPercent
# 0         0.100661
# 2         0.471947
# 7         0.000000
# 8         0.000000
# 13        0.377358
# ...            ...
# 16685     0.000000
# 16689     0.000000
# 16693     0.000000
# 16699     0.000000
# 16701     0.000000
#
# [4147 rows x 17 columns]

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\3164788537.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0].dropna(inplace=True)

# %%
house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Out:
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# C:\Users\Gigar\AppData\Local\Temp\ipykernel_17828\2037736966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   house_data[house_data['sqFtPrice']==0][house_data['coveredArea']==0][house_data['carpetArea']==0]
# Empty DataFrame
# Columns: [possStatusD, price, priceD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, powerStatusD, parkingD, areaPercent]
# Index: []

# %%
house_data[house_data['coveredArea']==0]
# Out:
# Empty DataFrame
# Columns: [possStatusD, price, priceD, carpetArea, sqFtPrice, furnishedD, balconiesD, bathD, facingD, ctName, bedroomD, floors, coveredArea, carpAreaUnit, powerStatusD, parkingD, areaPercent]
# Index: []

# %%
house_data.select_dtypes(exclude=["object"]).corr()
# Out:
#                 price  carpetArea  sqFtPrice  balconiesD     bathD  bedroomD  \
# price        1.000000    0.398756   0.647979    0.184752  0.413217  0.346595
# carpetArea   0.398756    1.000000   0.096780    0.130835  0.221306  0.222908
# sqFtPrice    0.647979    0.096780   1.000000    0.014918  0.143217  0.095132
# balconiesD   0.184752    0.130835   0.014918    1.000000  0.485237  0.224389
# bathD        0.413217    0.221306   0.143217    0.485237  1.000000  0.788324
# bedroomD     0.346595    0.222908   0.095132    0.224389  0.788324  1.000000
# floors       0.329760    0.123944   0.172416    0.254355  0.294041  0.253083
# coveredArea  0.721516    0.597036   0.226127    0.320800  0.393866  0.361502
# areaPercent  0.052316   -0.719369   0.052634   -0.044935  0.051214  0.051260
#
#                floors  coveredArea  areaPercent
# price        0.329760     0.721516     0.052316
# carpetArea   0.123944     0.597036    -0.719369
# sqFtPrice    0.172416     0.226127     0.052634
# balconiesD   0.254355     0.320800    -0.044935
# bathD        0.294041     0.393866     0.051214
# bedroomD     0.253083     0.361502     0.051260
# floors       1.000000     0.236500     0.074629
# coveredArea  0.236500     1.000000     0.038705
# areaPercent  0.074629     0.038705     1.000000

# %%
house_data[house_data['maintenanceD']=='Yearly']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'maintenanceD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 house_data[house_data['maintenanceD']=='Yearly']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'maintenanceD'

# %% [markdown]
# ## Checking rows with all Nan values

# %%
house_data[house_data.isnull().all(axis=1)]

# %%
house_data
# Out:
#               possStatusD     price    priceD  carpetArea  sqFtPrice  \
# 0      Under Construction  33500000   3.35 Cr      1769.0    17031.0
# 1      Under Construction  31450000   3.14 Cr      1458.0    17000.0
# 2           Ready to Move  23000000   2.30 Cr       160.0     8434.0
# 3           Ready to Move  23000000   2.30 Cr      1099.0    16655.0
# 4           Ready to Move  18000000   1.80 Cr      1320.0    10909.0
# ...                   ...       ...       ...         ...        ...
# 16705       Ready to Move  26300000   2.63 Cr      1719.2    12238.0
# 16706             Dec '26   9424800  94.2 Lac       952.0     7920.0
# 16707             Feb '31  56200000   5.62 Cr      2428.0    18517.0
# 16708             Aug '29  13900000   1.39 Cr      1160.0     9586.0
# 16709       Ready to Move  51420000   5.14 Cr      2500.0    18490.0
#
#            furnishedD  balconiesD  bathD       facingD   ctName  bedroomD  \
# 0         Unfurnished         3.0    3.0          East  Gurgaon       3.0
# 1      Semi-Furnished         3.0    3.0  North - East  Gurgaon       3.0
# 2         Unfurnished         3.0    3.0  North - East  Gurgaon       3.0
# 3      Semi-Furnished         4.0    2.0  North - East  Gurgaon       2.0
# 4      Semi-Furnished         2.0    3.0          East  Gurgaon       3.0
# ...               ...         ...    ...           ...      ...       ...
# 16705  Semi-Furnished         4.0    4.0  North - East  Gurgaon       3.0
# 16706  Semi-Furnished         NaN    3.0           NaN  Gurgaon       3.0
# 16707  Semi-Furnished         NaN    3.0           NaN  Gurgaon       3.0
# 16708  Semi-Furnished         NaN    3.0           NaN  Gurgaon       3.0
# 16709  Semi-Furnished         2.0    3.0         North  Gurgaon       3.0
#
#        floors  coveredArea carpAreaUnit      powerStatusD           parkingD  \
# 0        18.0       1967.0        Sq-ft  No/Rare Powercut                  0
# 1        34.0       1850.0        Sq-ft  No/Rare Powercut          2 Covered
# 2         2.0        303.0       Sq-yrd  No/Rare Powercut             1 Open
# 3        18.0       1381.0        Sq-ft  No/Rare Powercut          1 Covered
# 4        14.0       1650.0        Sq-ft  No/Rare Powercut          1 Covered
# ...       ...          ...          ...               ...                ...
# 16705    25.0       2149.0        Sq-ft  No/Rare Powercut  1 Covered, 1 Open
# 16706     0.0       1190.0        Sq-ft  No/Rare Powercut          1 Covered
# 16707     0.0       3035.0        Sq-ft  No/Rare Powercut          1 Covered
# 16708     0.0       1450.0        Sq-ft  No/Rare Powercut          1 Covered
# 16709    20.0       2781.0        Sq-ft  No/Rare Powercut          2 Covered
#
#        areaPercent
# 0         0.100661
# 1         0.211892
# 2         0.471947
# 3         0.204200
# 4         0.000000
# ...            ...
# 16705     0.000000
# 16706     0.000000
# 16707     0.000000
# 16708     0.000000
# 16709     0.101043
#
# [16529 rows x 17 columns]

# %%
import numpy as np
tuple(np.array(house_data.iloc[2,:]))
# Out:
# ('Ready to Move',
#  23000000,
#  '2.30 Cr',
#  160.0,
#  8434.0,
#  'Unfurnished',
#  3.0,
#  3.0,
#  'North - East',
#  'Gurgaon',
#  3.0,
#  2.0,
#  303.0,
#  'Sq-yrd',
#  'No/Rare Powercut',
#  '1 Open',
#  0.47194719471947194)

# %%
list(house_data.columns)
# Out:
# ['possStatusD',
#  'price',
#  'priceD',
#  'carpetArea',
#  'sqFtPrice',
#  'furnishedD',
#  'balconiesD',
#  'bathD',
#  'facingD',
#  'ctName',
#  'bedroomD',
#  'floors',
#  'coveredArea',
#  'carpAreaUnit',
#  'powerStatusD',
#  'parkingD',
#  'areaPercent']

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gigar\anaconda3\lib\site-packages (2.9.9)

# %%
city = 'Gurugram'
# save data in postgreSQL database name "house_data" and table name "Ghaziabad"
from sqlalchemy import create_engine
import json
from psycopg2.extras import Json
from psycopg2 import sql
engine = create_engine('postgresql://postgres:root@localhost:5432/House_Data')

# df.to_sql('table_name', engine, if_exists='replace', index=False)
# Table name
table_name = city

# Write DataFrame to SQL database
house_data.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 529
